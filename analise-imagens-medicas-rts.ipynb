# %% [markdown]
# # MBA FIAP Inteligência Artificial & Machine Learning
#
# ## Visão Computacional: Análise de Imagens Médicas
#
# ## 1. Introdução
#
# As tecnologias de imagens médicas estão cada vez mais integradas aos sitemas de visão computacional, incluindo as imagens de raio-x.
#
# Modelos de equipamentos modernos geram imagens digitais deste tipo de exame, proporcionando análises mais completas e menos _ad-hoc_, com isso algumas pré-análises podem ser realizadas por aplicações baseadas em inteligência artificial para confirmar ou sugerir diagnósticos ao profissional responsável pelo exame.
#
# No campo dos diagósticos por raios-x, a pnenumonia é uma das enfermidades onde seu uso é um dos mais aplicados para determinar o curso de tratamento.
#
# <p align="center">
#     <img src="imagens/NORMAL2-IM-1422-0001.jpeg">
# </p>
#
# ## 2. Instruções
#
# Este projeto final tem como objetivo explorar os conhecimentos adquiridos nas aulas práticas.
#
# Por meio de uma trilha guiada, iremos constuir um modelo que seja capaz de classificar imagens de raio-x para determinar se a determinada pessoa está com alguma condição que necessita maiores cuidados.
#
# De acordo com as imagens disponíveis para o treinamento e validação, será de critério do grupo selecionar as quantidades ideais ou até mesmo pré-processar as imagens para obter o melhor resultado, nos principais indicadores de performance, como precisão, sensibilidade e pontuação F1.
#
# Este projeto poderá ser feita por grupos de até 4 pessoas.
# Caso este projeto seja substitutivo, deverá ser realizado por apenas uma pessoa.
#
# | Nome dos Integrantes              | RM             |  Turma  |
# | :-------------------------------- | :------------- | :-----: |
# | DAVID WILLIAM ZERNERI CUNHA CLARO | RM 339661      |  `17IA` |
# | ROBERTO TENGAN DE SANTANA         | RM 339708      |  `17IA` |
# | SERGIO DUARTE STANISCI            | RM 340192      |  `17IA` |
#
# Por ser um projeto guiado, fique atento quando houver as marcações **Implementação** indica que é necessário realizar alguma implementação em Python no bloco a seguir onde há a inscrição ```##IMPLEMENTAR``` e **Resposta** indica que é esperado uma resposta objetiva relacionado a algum questionamento.
#
# **Cada grupo pode utilizar nas respostas objetivas quaisquer itens necessários que enriqueçam seu ponto vista, como gráficos, fotos e, até mesmo, trechos de código-fonte.**
#
# Pode-se utilizar quantos blocos forem necessários para realizar determinadas implementações ou utilizá-las para justificar as respostas. Não é obrigatório utilizar somente o bloco indicado.
#
# Ao final não se esqueça de subir os arquivos do projeto nas contas do GitHub de cada membro, ou subir na do representante do grupo e os membros realizarem o fork do projeto.
#
# A avaliação terá mais ênfase nos seguintes tópicos de desenvolvimento do projeto:
#
# 1. __Pré-Processamento__
# 2. __Classificação__
# 3. __Performance__
# 4. __Conclusões Finais__

# %% [markdown]
# ## 3.1 Detalhe do problema: a pneunomia
#
# Fonte: [artigo](https://drauziovarella.uol.com.br/doencas-e-sintomas/pneumonia) do Dr. Drauzio Varella.
#
# Pneumonias são infecções que se instalam nos pulmões, órgãos duplos localizados um de cada lado da caixa torácica. Podem acometer a região dos alvéolos pulmonares onde desembocam as ramificações terminais dos brônquios e, às vezes, os interstícios (espaço entre um alvéolo e outro).
#
# Basicamente, pneumonia é provocada pela penetração de um agente infeccioso ou irritante (bactérias, vírus, fungos e por reações alérgicas) no espaço alveolar, onde ocorre a troca gasosa. Esse local deve estar sempre muito limpo, livre de substâncias que possam impedir o contato do ar com o sangue.
#
# Exame clínico, auscultação dos pulmões e radiografias de tórax são recursos essenciais para o diagnóstico de pneumonia.
#
# <p align="center">
#     <img src="imagens/pneumonia.jpeg">
# </p>

# %% [markdown]
# ## 3.2 Diagnóstico por raio-x

# %% [markdown]
# O exame de raio-x traz diferenças em cada tipo de diagnóstico, sendo considerado os seguintes grupos de análise: **normal** (ou controle) onde não há nenhuma condição de infeção, **bacterial pneumonia** (pneumonia bacteriana) que representa a condição de infecção bacteriana e **viral pneumonia** que indica a condição de infecção vira.

# %% [markdown]
# <p align="center">
# <img src="imagens/raiox.png" height="60%" width="60%">
# </p>

# %% [markdown]
# As imagens de controle não são mais brancas ao centro que é onde fica o coração. Já nas imagens com pneumonia é possível notar regiões brancas ao redor dos pulmões, que é como o exame identifica as secreções responsáveis pela infeçcão.
#
# Quando mais regiões brancas ao redor do pulmão mais severa é a inflamação e menos se observa dos detalhes dos pulmões, ficando um pouco esmaecido diante desta condição.

# %% [markdown]
# ## 4.1 Problema
#
# Construir um classificador utilizando _transfer learning_ para identificar as seguintes classes: **controle**, **pneumonia bacteriana** e **pneumonia viral**.
#
# Para construir este classificador, utilize o dataset do [Kaggle Chest Ray Pneumonia](https://www.kaggle.com/paultimothymooney/chest-xray-pneumonia) e organize os dados de forma a separar em cada uma das classes que já estão definidas no diretório ```raiox```, sendo ```controle``` para as imagens normais (sem inflamação), ```bacteria``` para as imagens de pneumonia bacteriana e ```viral``` para as imagens de pneumonia viral.
#
# Determine a quantidade de imagens a serem treinadas e validadas. Utiliza pelo menos, 100 imagens para cada classe.
#
# Compare os resultados com pelo menos 3 classificadores, obtendo os valores de **precisão (precision)**, **sensibilidade (recall)** e **pontuação F1 (F1 Score)**. No guia abaixo, foi indicado os seguintes modelos: ResNet50, VGG16 e VGG19.
#
# >Importante: a escolha do número de imagens devem ser o suficiente para alcançar o valor de **precisão** mínima de 70%.
#
# A construção do modelo será utilizada o framework Keras.

# %% [markdown]
# **Pergunta**: Qual o número de imagens que foram selecionadas para cada classe?

# %% [markdown]
# **Resposta**:
#
# ```Treino```
#
# | Classe         | Quantidade  |
# | :------------- | :---------- |
# | Bacteria       | 1330        |
# | Normal         | 1349        |
# | Virus          | 1345        |
#
# ```Teste```
#
# | Classe         | Quantidade  |
# | :------------- | :---------- |
# | Bacteria       | 242         |
# | Normal         | 234         |
# | Virus          | 148         |

# %% [markdown]
# ## 4.2 Componentes obrigatórios
#
# Este projeto requer a instalação dos seguintes componentes, via ```conda install```:
#
# * Keras
# * Tensorflow
# * Pillow
# * Matplotlib

# %%
import os

import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %matplotlib inline

import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.applications import ResNet50
from keras.applications import VGG16, VGG19
from keras.applications import InceptionResNetV2
from keras.applications.xception import preprocess_input
from keras.applications.resnet50 import preprocess_input as res_pre_input
from keras.applications.vgg16 import preprocess_input
from keras import Model, layers
from keras.models import load_model, model_from_json

import keras.backend as K

# %% [markdown]
# ## 4.3 Carregando imagens de treinamento e validação
#
# Selecione a melhor divisão entre dados de treinamento e validação. O número deverá ser representado em número fracionário, 5% equivale a 0.05, por exemplo.

# %%
## IMPLEMENTE
divisao_treino_validacao = 0.30
seed_param = 10

# %%
train_datagen = ImageDataGenerator(preprocessing_function=res_pre_input)

train_generator = train_datagen.flow_from_directory(
    "raiox/train/",
    batch_size=32,
    class_mode="categorical",
    color_mode="rgb",
    target_size=(224,224))
# Out:
# Found 4024 images belonging to 3 classes.

# %%
test_datagen = ImageDataGenerator(preprocessing_function=res_pre_input)

val_generator = test_datagen.flow_from_directory(
    "raiox/test/",
    batch_size=32,
    class_mode="categorical",
    color_mode="rgb",
    target_size=(224,224))
# Out:
# Found 624 images belonging to 3 classes.

# %%
train_generator.class_indices, val_generator.class_indices
# Out:
# ({'bacteria': 0, 'normal': 1, 'virus': 2},
#  {'bacteria': 0, 'normal': 1, 'virus': 2})

# %% [markdown]
# ## 4.4 Modelos de transfer learning
#
# O Keras já possui classes especializadas para os seguintes modelos de deep-learning treinados com o conjunto de dados [ImageNet](http://www.image-net.org/):
#
# * Xception
# * VGG16
# * VGG19
# * ResNet50
# * InceptionV3
# * InceptionResNetV2
# * MobileNet
# * DenseNet
# * NASNet
# * MobileNetV2
#
# Mais detalhes, veja na [documentação do Keras](https://keras.io/applications/).

# %% [markdown]
# Para este estudo, vamos utilizar para avaliação as seguintes arquiteturas: RestNet50, VGG15 e VGG19.

# %% [markdown]
# ## 4.5 Indicadores de desempenho
#
# O Keras não possui os indicadores de desempenho como precisão, sensibilidade e pontuação f1 por padrão, portanto precisamos implementar externamente.

# %%
def recall_score(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision_score(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1_score(y_true, y_pred):
    precision = precision_score(y_true, y_pred)
    recall = recall_score(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %% [markdown]
# ### 4.5.1 Arquitetura ResNet50

# %% [markdown]
# **Pergunta**: Explique como é constituída a arquitetura do ResNet50? *Utilize, se necessário, gráficos, projetos que utilizam essa arquitetura. Detalhe também sua topologia em camadas e mostre quais as situações essa arquitetura pode ter mais êxito e quais cenários não tem.*

# %% [markdown]
# **Resposta**:
#
# A ResNet é uma Residual Network composta por 152 camadas, a chave de treinar uma rede tão profunda é a utilização de conexões skip ou shortcuts connections. o sinal fornecido por uma camada é enviado para uma camada mais acima da pilha de camadas.
#
# Objetivo de treinar uma Rede Neural é fazer com que a rede chegue a função h(x), se adicionarmos a entrada x à saída da rede, usando a conexão skip, isso forçaria a rede modelar a seguinte função:
# f(x) = h(x) - x ao invés de h(x), isso é chamada de Rede Residual.
#
# Numa rede normal os valores dasa camadas tendem a 0, adicionando as conexões skip modelam a função identidade, acelerando consideravelmente o treinamento.
#
# Com as conexões skip, a rede começa a fazer progresso mesmo sem as camadas iniciarem o treinamento. Graças a essas conexões o sinal consegue trafegar facilmente por toda rede. Essa Rede residual profunda pode ser visto como uma pilha de unidades residuais, praticamente uma pequena rede nerural com a consexão skip.
#
# <p align="center">
# <img src="imagens/Simple_Residual_Block.png" height="60%" width="60%">
# </p>
#
# **Arquitetura ResNet**
#
# Semelhante a GoogleLeNet (LINK), sem a camada de dropout. entre elas há uma pilha muito profunda de unidades residuais simples, cada unidade residual simples é composta por 2 camadas convolucionais com normalização ReLU, usando kernel 3x3 preservando as dimensões espaciais da imagem (stride: 1, padding: SAME).
#
# A ResNet50 utiliza 50 camadas residuais.
#
# **Arquitetura ResNet50**
#
# <p align="center">
# <img src="imagens/ResNet50_architecture-1.png" height="60%" width="60%">
# </p>
#
# A Rede ResNet foi apresentada pela primeira vez em 2015, na competição da ImageNet e conseguiu primeiro lugar em várias categorias, a arquitetura é utilizada para reconhecimento de imagens e também em outros campos de engenharia e ciência. Após as apresentações surgiram diversos modelos com diversas Unidades Residuais **ResNet34**, **ResNet101**, **ResNet152**.
#
# Artigo Original:
#
# [ResNet](https://arxiv.org/abs/1512.03385)

# %% [markdown]
# A técnica de transfer learning consiste de utilizar o mesmo modelo e treiná-lo para outas imagens. Por tal motivo, excluímos a última camada para modelar com as classes que definimos, ou seja, **controle**, **bacteriana** e **viral**.

# %% [markdown]
# Informe a quantidade de classes a serem classificadas.

# %%
## IMPLEMENTE

qtde_classes = 3

# %%
conv_base = ResNet50(include_top=False)

for layer in conv_base.layers:
    layer.trainable = False
# Out:
# D:\FIAP\Anaconda3\envs\tensorflow\lib\site-packages\keras_applications\resnet50.py:265: UserWarning: The output shape of `ResNet50(include_top=False)` has been changed since Keras 2.2.0.
#   warnings.warn('The output shape of `ResNet50(include_top=False)` '

# %%
x = conv_base.output
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(1024, activation='relu')(x) 
x = layers.Dropout(0.5)(x) 

predictions = layers.Dense(qtde_classes, activation='softmax')(x)
model = Model(conv_base.input, predictions)

model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, None, None, 3 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, None, None, 3 0           input_2[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, None, None, 6 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, None, None, 6 256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, None, None, 6 0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, None, None, 6 0           activation_50[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, None, None, 6 0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (None, None, None, 6 4160        max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (BatchNormalizati (None, None, None, 6 256         res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, None, None, 6 0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (None, None, None, 6 36928       activation_51[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (BatchNormalizati (None, None, None, 6 256         res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, None, None, 6 0           bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (None, None, None, 2 16640       activation_52[0][0]
# __________________________________________________________________________________________________
# res2a_branch1 (Conv2D)          (None, None, None, 2 16640       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (BatchNormalizati (None, None, None, 2 1024        res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (BatchNormalizatio (None, None, None, 2 1024        res2a_branch1[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, None, None, 2 0           bn2a_branch2c[0][0]
#                                                                  bn2a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, None, None, 2 0           add_17[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a (Conv2D)         (None, None, None, 6 16448       activation_53[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a (BatchNormalizati (None, None, None, 6 256         res2b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, None, None, 6 0           bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b (Conv2D)         (None, None, None, 6 36928       activation_54[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b (BatchNormalizati (None, None, None, 6 256         res2b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, None, None, 6 0           bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c (Conv2D)         (None, None, None, 2 16640       activation_55[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c (BatchNormalizati (None, None, None, 2 1024        res2b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, None, None, 2 0           bn2b_branch2c[0][0]
#                                                                  activation_53[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, None, None, 2 0           add_18[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a (Conv2D)         (None, None, None, 6 16448       activation_56[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2a (BatchNormalizati (None, None, None, 6 256         res2c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, None, None, 6 0           bn2c_branch2a[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b (Conv2D)         (None, None, None, 6 36928       activation_57[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2b (BatchNormalizati (None, None, None, 6 256         res2c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, None, None, 6 0           bn2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2c (Conv2D)         (None, None, None, 2 16640       activation_58[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2c (BatchNormalizati (None, None, None, 2 1024        res2c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, None, None, 2 0           bn2c_branch2c[0][0]
#                                                                  activation_56[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, None, None, 2 0           add_19[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (None, None, None, 1 32896       activation_59[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (BatchNormalizati (None, None, None, 1 512         res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, None, None, 1 0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b (Conv2D)         (None, None, None, 1 147584      activation_60[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b (BatchNormalizati (None, None, None, 1 512         res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, None, None, 1 0           bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c (Conv2D)         (None, None, None, 5 66048       activation_61[0][0]
# __________________________________________________________________________________________________
# res3a_branch1 (Conv2D)          (None, None, None, 5 131584      activation_59[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (BatchNormalizati (None, None, None, 5 2048        res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1 (BatchNormalizatio (None, None, None, 5 2048        res3a_branch1[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, None, None, 5 0           bn3a_branch2c[0][0]
#                                                                  bn3a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, None, None, 5 0           add_20[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a (Conv2D)         (None, None, None, 1 65664       activation_62[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a (BatchNormalizati (None, None, None, 1 512         res3b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, None, None, 1 0           bn3b_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b (Conv2D)         (None, None, None, 1 147584      activation_63[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b (BatchNormalizati (None, None, None, 1 512         res3b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, None, None, 1 0           bn3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2c (Conv2D)         (None, None, None, 5 66048       activation_64[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c (BatchNormalizati (None, None, None, 5 2048        res3b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, None, None, 5 0           bn3b_branch2c[0][0]
#                                                                  activation_62[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, None, None, 5 0           add_21[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a (Conv2D)         (None, None, None, 1 65664       activation_65[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2a (BatchNormalizati (None, None, None, 1 512         res3c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, None, None, 1 0           bn3c_branch2a[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b (Conv2D)         (None, None, None, 1 147584      activation_66[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2b (BatchNormalizati (None, None, None, 1 512         res3c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, None, None, 1 0           bn3c_branch2b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2c (Conv2D)         (None, None, None, 5 66048       activation_67[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2c (BatchNormalizati (None, None, None, 5 2048        res3c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_22 (Add)                    (None, None, None, 5 0           bn3c_branch2c[0][0]
#                                                                  activation_65[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, None, None, 5 0           add_22[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a (Conv2D)         (None, None, None, 1 65664       activation_68[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2a (BatchNormalizati (None, None, None, 1 512         res3d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, None, None, 1 0           bn3d_branch2a[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b (Conv2D)         (None, None, None, 1 147584      activation_69[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2b (BatchNormalizati (None, None, None, 1 512         res3d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, None, None, 1 0           bn3d_branch2b[0][0]
# __________________________________________________________________________________________________
# res3d_branch2c (Conv2D)         (None, None, None, 5 66048       activation_70[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2c (BatchNormalizati (None, None, None, 5 2048        res3d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_23 (Add)                    (None, None, None, 5 0           bn3d_branch2c[0][0]
#                                                                  activation_68[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, None, None, 5 0           add_23[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a (Conv2D)         (None, None, None, 2 131328      activation_71[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a (BatchNormalizati (None, None, None, 2 1024        res4a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_72 (Activation)      (None, None, None, 2 0           bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b (Conv2D)         (None, None, None, 2 590080      activation_72[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b (BatchNormalizati (None, None, None, 2 1024        res4a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_73 (Activation)      (None, None, None, 2 0           bn4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch2c (Conv2D)         (None, None, None, 1 263168      activation_73[0][0]
# __________________________________________________________________________________________________
# res4a_branch1 (Conv2D)          (None, None, None, 1 525312      activation_71[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c (BatchNormalizati (None, None, None, 1 4096        res4a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn4a_branch1 (BatchNormalizatio (None, None, None, 1 4096        res4a_branch1[0][0]
# __________________________________________________________________________________________________
# add_24 (Add)                    (None, None, None, 1 0           bn4a_branch2c[0][0]
#                                                                  bn4a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, None, None, 1 0           add_24[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a (Conv2D)         (None, None, None, 2 262400      activation_74[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2a (BatchNormalizati (None, None, None, 2 1024        res4b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_75 (Activation)      (None, None, None, 2 0           bn4b_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b (Conv2D)         (None, None, None, 2 590080      activation_75[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2b (BatchNormalizati (None, None, None, 2 1024        res4b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_76 (Activation)      (None, None, None, 2 0           bn4b_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b_branch2c (Conv2D)         (None, None, None, 1 263168      activation_76[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2c (BatchNormalizati (None, None, None, 1 4096        res4b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_25 (Add)                    (None, None, None, 1 0           bn4b_branch2c[0][0]
#                                                                  activation_74[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, None, None, 1 0           add_25[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a (Conv2D)         (None, None, None, 2 262400      activation_77[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2a (BatchNormalizati (None, None, None, 2 1024        res4c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_78 (Activation)      (None, None, None, 2 0           bn4c_branch2a[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b (Conv2D)         (None, None, None, 2 590080      activation_78[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2b (BatchNormalizati (None, None, None, 2 1024        res4c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, None, None, 2 0           bn4c_branch2b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2c (Conv2D)         (None, None, None, 1 263168      activation_79[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2c (BatchNormalizati (None, None, None, 1 4096        res4c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_26 (Add)                    (None, None, None, 1 0           bn4c_branch2c[0][0]
#                                                                  activation_77[0][0]
# __________________________________________________________________________________________________
# activation_80 (Activation)      (None, None, None, 1 0           add_26[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a (Conv2D)         (None, None, None, 2 262400      activation_80[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2a (BatchNormalizati (None, None, None, 2 1024        res4d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_81 (Activation)      (None, None, None, 2 0           bn4d_branch2a[0][0]
# __________________________________________________________________________________________________
# res4d_branch2b (Conv2D)         (None, None, None, 2 590080      activation_81[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2b (BatchNormalizati (None, None, None, 2 1024        res4d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_82 (Activation)      (None, None, None, 2 0           bn4d_branch2b[0][0]
# __________________________________________________________________________________________________
# res4d_branch2c (Conv2D)         (None, None, None, 1 263168      activation_82[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2c (BatchNormalizati (None, None, None, 1 4096        res4d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_27 (Add)                    (None, None, None, 1 0           bn4d_branch2c[0][0]
#                                                                  activation_80[0][0]
# __________________________________________________________________________________________________
# activation_83 (Activation)      (None, None, None, 1 0           add_27[0][0]
# __________________________________________________________________________________________________
# res4e_branch2a (Conv2D)         (None, None, None, 2 262400      activation_83[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2a (BatchNormalizati (None, None, None, 2 1024        res4e_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_84 (Activation)      (None, None, None, 2 0           bn4e_branch2a[0][0]
# __________________________________________________________________________________________________
# res4e_branch2b (Conv2D)         (None, None, None, 2 590080      activation_84[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2b (BatchNormalizati (None, None, None, 2 1024        res4e_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_85 (Activation)      (None, None, None, 2 0           bn4e_branch2b[0][0]
# __________________________________________________________________________________________________
# res4e_branch2c (Conv2D)         (None, None, None, 1 263168      activation_85[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2c (BatchNormalizati (None, None, None, 1 4096        res4e_branch2c[0][0]
# __________________________________________________________________________________________________
# add_28 (Add)                    (None, None, None, 1 0           bn4e_branch2c[0][0]
#                                                                  activation_83[0][0]
# __________________________________________________________________________________________________
# activation_86 (Activation)      (None, None, None, 1 0           add_28[0][0]
# __________________________________________________________________________________________________
# res4f_branch2a (Conv2D)         (None, None, None, 2 262400      activation_86[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2a (BatchNormalizati (None, None, None, 2 1024        res4f_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_87 (Activation)      (None, None, None, 2 0           bn4f_branch2a[0][0]
# __________________________________________________________________________________________________
# res4f_branch2b (Conv2D)         (None, None, None, 2 590080      activation_87[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2b (BatchNormalizati (None, None, None, 2 1024        res4f_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_88 (Activation)      (None, None, None, 2 0           bn4f_branch2b[0][0]
# __________________________________________________________________________________________________
# res4f_branch2c (Conv2D)         (None, None, None, 1 263168      activation_88[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2c (BatchNormalizati (None, None, None, 1 4096        res4f_branch2c[0][0]
# __________________________________________________________________________________________________
# add_29 (Add)                    (None, None, None, 1 0           bn4f_branch2c[0][0]
#                                                                  activation_86[0][0]
# __________________________________________________________________________________________________
# activation_89 (Activation)      (None, None, None, 1 0           add_29[0][0]
# __________________________________________________________________________________________________
# res5a_branch2a (Conv2D)         (None, None, None, 5 524800      activation_89[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2a (BatchNormalizati (None, None, None, 5 2048        res5a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_90 (Activation)      (None, None, None, 5 0           bn5a_branch2a[0][0]
# __________________________________________________________________________________________________
# res5a_branch2b (Conv2D)         (None, None, None, 5 2359808     activation_90[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2b (BatchNormalizati (None, None, None, 5 2048        res5a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_91 (Activation)      (None, None, None, 5 0           bn5a_branch2b[0][0]
# __________________________________________________________________________________________________
# res5a_branch2c (Conv2D)         (None, None, None, 2 1050624     activation_91[0][0]
# __________________________________________________________________________________________________
# res5a_branch1 (Conv2D)          (None, None, None, 2 2099200     activation_89[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2c (BatchNormalizati (None, None, None, 2 8192        res5a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn5a_branch1 (BatchNormalizatio (None, None, None, 2 8192        res5a_branch1[0][0]
# __________________________________________________________________________________________________
# add_30 (Add)                    (None, None, None, 2 0           bn5a_branch2c[0][0]
#                                                                  bn5a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_92 (Activation)      (None, None, None, 2 0           add_30[0][0]
# __________________________________________________________________________________________________
# res5b_branch2a (Conv2D)         (None, None, None, 5 1049088     activation_92[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2a (BatchNormalizati (None, None, None, 5 2048        res5b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_93 (Activation)      (None, None, None, 5 0           bn5b_branch2a[0][0]
# __________________________________________________________________________________________________
# res5b_branch2b (Conv2D)         (None, None, None, 5 2359808     activation_93[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2b (BatchNormalizati (None, None, None, 5 2048        res5b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_94 (Activation)      (None, None, None, 5 0           bn5b_branch2b[0][0]
# __________________________________________________________________________________________________
# res5b_branch2c (Conv2D)         (None, None, None, 2 1050624     activation_94[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2c (BatchNormalizati (None, None, None, 2 8192        res5b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_31 (Add)                    (None, None, None, 2 0           bn5b_branch2c[0][0]
#                                                                  activation_92[0][0]
# __________________________________________________________________________________________________
# activation_95 (Activation)      (None, None, None, 2 0           add_31[0][0]
# __________________________________________________________________________________________________
# res5c_branch2a (Conv2D)         (None, None, None, 5 1049088     activation_95[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2a (BatchNormalizati (None, None, None, 5 2048        res5c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_96 (Activation)      (None, None, None, 5 0           bn5c_branch2a[0][0]
# __________________________________________________________________________________________________
# res5c_branch2b (Conv2D)         (None, None, None, 5 2359808     activation_96[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2b (BatchNormalizati (None, None, None, 5 2048        res5c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_97 (Activation)      (None, None, None, 5 0           bn5c_branch2b[0][0]
# __________________________________________________________________________________________________
# res5c_branch2c (Conv2D)         (None, None, None, 2 1050624     activation_97[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2c (BatchNormalizati (None, None, None, 2 8192        res5c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_32 (Add)                    (None, None, None, 2 0           bn5c_branch2c[0][0]
#                                                                  activation_95[0][0]
# __________________________________________________________________________________________________
# activation_98 (Activation)      (None, None, None, 2 0           add_32[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_2 (Glo (None, 2048)         0           activation_98[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1024)         2098176     global_average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 1024)         0           dense_3[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 3)            3075        dropout_2[0][0]
# ==================================================================================================
# Total params: 25,688,963
# Trainable params: 2,101,251
# Non-trainable params: 23,587,712
# __________________________________________________________________________________________________

# %%
optimizer = keras.optimizers.Adam()
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=[precision_score, recall_score, f1_score])

# %% [markdown]
# O número de épocas define quantas vezes o modelo irá treinar e validar o erro, assim ajustando os pesos para melhor convergência.
# Escolha o número adequado de épocas para alcançarmos pelo menos **70% de precisão de validação**.

# %%
## IMPLEMENTE

qtde_epocas = 10

# %%
history = model.fit(train_generator, 
                              epochs=qtde_epocas, 
                              validation_steps=5, 
                              steps_per_epoch=5, 
                              validation_data=val_generator)
# Out:
# Epoch 1/10
# 5/5 [==============================] - 15s 3s/step - loss: 1.0896 - precision_score: 0.5811 - recall_score: 0.5125 - f1_score: 0.5380 - val_loss: 1.2940 - val_precision_score: 0.7742 - val_recall_score: 0.7500 - val_f1_score: 0.7619
# Epoch 2/10
# 5/5 [==============================] - 11s 2s/step - loss: 1.6635 - precision_score: 0.5762 - recall_score: 0.5688 - f1_score: 0.5724 - val_loss: 1.8444 - val_precision_score: 0.3413 - val_recall_score: 0.3375 - val_f1_score: 0.3393
# Epoch 3/10
# 5/5 [==============================] - 12s 2s/step - loss: 0.9981 - precision_score: 0.7105 - recall_score: 0.6750 - f1_score: 0.6921 - val_loss: 2.9992 - val_precision_score: 0.2250 - val_recall_score: 0.2250 - val_f1_score: 0.2250
# Epoch 4/10
# 5/5 [==============================] - 11s 2s/step - loss: 0.6744 - precision_score: 0.7751 - recall_score: 0.7563 - f1_score: 0.7653 - val_loss: 3.6038 - val_precision_score: 0.2438 - val_recall_score: 0.2438 - val_f1_score: 0.2437
# Epoch 5/10
# 5/5 [==============================] - 12s 2s/step - loss: 0.7795 - precision_score: 0.7339 - recall_score: 0.7125 - f1_score: 0.7229 - val_loss: 2.9310 - val_precision_score: 0.2875 - val_recall_score: 0.2875 - val_f1_score: 0.2875
# Epoch 6/10
# 5/5 [==============================] - 12s 2s/step - loss: 0.6813 - precision_score: 0.7257 - recall_score: 0.7000 - f1_score: 0.7125 - val_loss: 2.2753 - val_precision_score: 0.2662 - val_recall_score: 0.2625 - val_f1_score: 0.2643
# Epoch 7/10
# 5/5 [==============================] - 12s 2s/step - loss: 0.7303 - precision_score: 0.7645 - recall_score: 0.7312 - f1_score: 0.7473 - val_loss: 3.6521 - val_precision_score: 0.1756 - val_recall_score: 0.1750 - val_f1_score: 0.1753
# Epoch 8/10
# 5/5 [==============================] - 12s 2s/step - loss: 0.6141 - precision_score: 0.7402 - recall_score: 0.7250 - f1_score: 0.7324 - val_loss: 4.5982 - val_precision_score: 0.2875 - val_recall_score: 0.2875 - val_f1_score: 0.2875
# Epoch 9/10
# 5/5 [==============================] - 12s 2s/step - loss: 0.9213 - precision_score: 0.6691 - recall_score: 0.6187 - f1_score: 0.6428 - val_loss: 3.5363 - val_precision_score: 0.2514 - val_recall_score: 0.2500 - val_f1_score: 0.2507
# Epoch 10/10
# 5/5 [==============================] - 12s 2s/step - loss: 0.6189 - precision_score: 0.7660 - recall_score: 0.7375 - f1_score: 0.7515 - val_loss: 4.3926 - val_precision_score: 0.2188 - val_recall_score: 0.2188 - val_f1_score: 0.2187

# %% [markdown]
# Um modelo que converge bem possui o gráfico de perda (*loss*) descendente e os gráfico de precisão (*precision*), sensibilidade (*recall*) e pontuação f1 (*f1 score*) em acendente.

# %%
# Exibindo dados de Precisão
plt.plot(history.history['precision_score'])
plt.plot(history.history['val_precision_score'])
plt.title('model precision')
plt.ylabel('precision')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de Sensibilidade
plt.plot(history.history['recall_score'])
plt.plot(history.history['val_recall_score'])
plt.title('model recall')
plt.ylabel('recall')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de F1 Score
plt.plot(history.history['f1_score'])
plt.plot(history.history['val_f1_score'])
plt.title('model f1_score')
plt.ylabel('f1_score')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de Perda
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# **Pergunta**: Avalie os gráficos de perda (*loss*), precisão (*precision*), sensibilidade (*recall*) e pontuação f1 (*f1 score*)  e explique o comportamento de ambos no que tange a convergência do modelo.

# %% [markdown]
# **Resposta**:
#
# Conseguimos verificar que os gráficos de precision, recall e f1 score, são semelhantes, eles atingem o máximo em poucas épocas, repetindo as mesmas quedas durante as épocas, ao final o score de ambos se mantém estável.

# %% [markdown]
# **Pergunta**: Quais são os valores de **precisão (precision)**, **sensibilidade (recall)** de validação?
#
# *Estes valores são exibidos durante o treinamento, utilize a última saída, exemplo:*
#
# ```
# Epoch 10/10 [==============================] - 45s 9s/step - loss: 0.1234 - precision_score: 0.9742 - recall_score: 0.9683 - f1_score: 0.9712 - val_loss: 0.8819 - val_precision_score: 0.6912 - val_recall_score: 0.5649 - val_f1_score: 0.6216```
#
# No caso acima, o valor de precisão, sensibilidade e pontuação de validação são, respectivamente, 69,12%, 56,49% e 62,16%.

# %% [markdown]
# **Resposta**: ```
# Epoch 50/50
# 5/5 [==============================] - 12s 2s/step - loss: 0.3836 - precision_score: 0.8422 - recall_score: 0.8125 - f1_score: 0.8268 - val_loss: 1.6901 - val_precision_score: 0.4734 - val_recall_score: 0.4563 - val_f1_score: 0.4645```
#
# precisão: 47,34%
#
# sensibilidade: 45,63%
#
# validação: 46,45%

# %% [markdown]
# ### 4.5.2 Arquitetura VGG16

# %% [markdown]
# **Pergunta**: Explique como é constituída a arquitetura do VGG16? *Utilize, se necessário, gráficos, projetos que utilizam essa arquitetura. Detalhe também sua topologia em camadas e mostre quais as situações essa arquitetura pode ter mais êxito e quais cenários não tem.*

# %% [markdown]
# **Resposta**:

# %%
conv_base = VGG16(include_top=False)

for layer in conv_base.layers:
    layer.trainable = False

# %%
x = conv_base.output
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(128, activation='relu')(x) 

predictions = layers.Dense(qtde_classes, activation='softmax')(x)
model = Model(conv_base.input, predictions)

model.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, None, None, 3)     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, None, None, 64)    1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, None, None, 64)    36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, None, None, 64)    0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, None, None, 128)   73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, None, None, 128)   147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, None, None, 128)   0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, None, None, 256)   295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, None, None, 256)   590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, None, None, 256)   590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, None, None, 256)   0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, None, None, 512)   1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, None, None, 512)   0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, None, None, 512)   0
# _________________________________________________________________
# global_average_pooling2d_2 ( (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               65664
# _________________________________________________________________
# dense_4 (Dense)              (None, 3)                 387
# =================================================================
# Total params: 14,780,739
# Trainable params: 66,051
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
optimizer = keras.optimizers.Adam()
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=[precision_score, recall_score, f1_score])

# %%
history = model.fit_generator(generator=train_generator, 
                              epochs=qtde_epocas, 
                              validation_steps=5, 
                              steps_per_epoch=5, 
                              validation_data=val_generator)
# Out:
# Epoch 1/50
# 5/5 [==============================] - 25s 5s/step - loss: 2.7586 - precision_score: 0.3700 - recall_score: 0.3500 - f1_score: 0.3595 - val_loss: 1.4497 - val_precision_score: 0.5101 - val_recall_score: 0.4625 - val_f1_score: 0.4849
# Epoch 2/50
# 5/5 [==============================] - 15s 3s/step - loss: 1.1280 - precision_score: 0.6295 - recall_score: 0.6062 - f1_score: 0.6176 - val_loss: 2.1561 - val_precision_score: 0.5317 - val_recall_score: 0.5188 - val_f1_score: 0.5251
# Epoch 3/50
# 5/5 [==============================] - 14s 3s/step - loss: 1.0189 - precision_score: 0.6674 - recall_score: 0.6500 - f1_score: 0.6585 - val_loss: 0.3733 - val_precision_score: 0.6914 - val_recall_score: 0.6687 - val_f1_score: 0.6798
# Epoch 4/50
# 5/5 [==============================] - 14s 3s/step - loss: 1.0451 - precision_score: 0.6770 - recall_score: 0.6687 - f1_score: 0.6728 - val_loss: 1.1889 - val_precision_score: 0.6415 - val_recall_score: 0.6313 - val_f1_score: 0.6363
# Epoch 5/50
# 5/5 [==============================] - 13s 3s/step - loss: 0.9203 - precision_score: 0.7133 - recall_score: 0.7000 - f1_score: 0.7065 - val_loss: 0.6268 - val_precision_score: 0.7446 - val_recall_score: 0.7312 - val_f1_score: 0.7378
# Epoch 6/50
# 5/5 [==============================] - 13s 3s/step - loss: 1.1394 - precision_score: 0.5250 - recall_score: 0.5250 - f1_score: 0.5250 - val_loss: 1.2173 - val_precision_score: 0.6099 - val_recall_score: 0.6062 - val_f1_score: 0.6080
# Epoch 7/50
# 5/5 [==============================] - 13s 3s/step - loss: 0.8256 - precision_score: 0.7139 - recall_score: 0.7063 - f1_score: 0.7100 - val_loss: 1.0580 - val_precision_score: 0.7065 - val_recall_score: 0.6938 - val_f1_score: 0.7000
# Epoch 8/50
# 5/5 [==============================] - 21s 4s/step - loss: 0.8184 - precision_score: 0.7566 - recall_score: 0.7312 - f1_score: 0.7435 - val_loss: 0.7114 - val_precision_score: 0.7541 - val_recall_score: 0.7330 - val_f1_score: 0.7433
# Epoch 9/50
# 5/5 [==============================] - 12s 2s/step - loss: 0.6599 - precision_score: 0.7753 - recall_score: 0.7500 - f1_score: 0.7621 - val_loss: 1.1011 - val_precision_score: 0.6942 - val_recall_score: 0.6812 - val_f1_score: 0.6876
# Epoch 10/50
# 5/5 [==============================] - 16s 3s/step - loss: 0.6676 - precision_score: 0.7393 - recall_score: 0.7250 - f1_score: 0.7320 - val_loss: 0.6426 - val_precision_score: 0.7645 - val_recall_score: 0.7500 - val_f1_score: 0.7571
# Epoch 11/50
# 5/5 [==============================] - 14s 3s/step - loss: 0.6321 - precision_score: 0.7875 - recall_score: 0.7875 - f1_score: 0.7875 - val_loss: 0.8379 - val_precision_score: 0.7280 - val_recall_score: 0.7188 - val_f1_score: 0.7233
# Epoch 12/50
# 5/5 [==============================] - 14s 3s/step - loss: 0.6486 - precision_score: 0.7966 - recall_score: 0.7875 - f1_score: 0.7920 - val_loss: 0.8771 - val_precision_score: 0.7710 - val_recall_score: 0.7625 - val_f1_score: 0.7667
# Epoch 13/50
# 5/5 [==============================] - 14s 3s/step - loss: 0.7236 - precision_score: 0.7557 - recall_score: 0.7250 - f1_score: 0.7399 - val_loss: 0.6454 - val_precision_score: 0.7715 - val_recall_score: 0.7563 - val_f1_score: 0.7637
# Epoch 14/50
# 5/5 [==============================] - 14s 3s/step - loss: 0.5887 - precision_score: 0.7871 - recall_score: 0.7625 - f1_score: 0.7746 - val_loss: 0.4314 - val_precision_score: 0.7947 - val_recall_score: 0.7750 - val_f1_score: 0.7846
# Epoch 15/50
# 5/5 [==============================] - 14s 3s/step - loss: 0.7300 - precision_score: 0.7485 - recall_score: 0.7250 - f1_score: 0.7361 - val_loss: 0.5788 - val_precision_score: 0.7849 - val_recall_score: 0.7563 - val_f1_score: 0.7700
# Epoch 16/50
# 5/5 [==============================] - 15s 3s/step - loss: 0.4021 - precision_score: 0.8381 - recall_score: 0.8062 - f1_score: 0.8218 - val_loss: 0.8752 - val_precision_score: 0.7178 - val_recall_score: 0.7023 - val_f1_score: 0.7099
# Epoch 17/50
# 5/5 [==============================] - 15s 3s/step - loss: 0.6059 - precision_score: 0.7826 - recall_score: 0.7625 - f1_score: 0.7723 - val_loss: 0.5433 - val_precision_score: 0.7610 - val_recall_score: 0.7375 - val_f1_score: 0.7490
# Epoch 18/50
# 5/5 [==============================] - 15s 3s/step - loss: 0.4390 - precision_score: 0.8463 - recall_score: 0.8188 - f1_score: 0.8321 - val_loss: 0.6438 - val_precision_score: 0.7581 - val_recall_score: 0.7437 - val_f1_score: 0.7508
# Epoch 19/50
# 5/5 [==============================] - 17s 3s/step - loss: 0.5295 - precision_score: 0.8099 - recall_score: 0.7937 - f1_score: 0.8014 - val_loss: 1.0501 - val_precision_score: 0.7569 - val_recall_score: 0.7312 - val_f1_score: 0.7436
# Epoch 20/50
# 5/5 [==============================] - 14s 3s/step - loss: 0.4331 - precision_score: 0.8284 - recall_score: 0.8125 - f1_score: 0.8203 - val_loss: 0.5567 - val_precision_score: 0.7334 - val_recall_score: 0.7188 - val_f1_score: 0.7259
# Epoch 21/50
# 5/5 [==============================] - 17s 3s/step - loss: 0.5130 - precision_score: 0.8109 - recall_score: 0.8062 - f1_score: 0.8085 - val_loss: 0.7095 - val_precision_score: 0.8099 - val_recall_score: 0.8000 - val_f1_score: 0.8049
# Epoch 22/50
# 5/5 [==============================] - 14s 3s/step - loss: 0.5384 - precision_score: 0.7813 - recall_score: 0.7563 - f1_score: 0.7684 - val_loss: 0.8635 - val_precision_score: 0.7663 - val_recall_score: 0.7563 - val_f1_score: 0.7611
# Epoch 23/50
# 5/5 [==============================] - 16s 3s/step - loss: 0.3425 - precision_score: 0.8656 - recall_score: 0.8500 - f1_score: 0.8576 - val_loss: 0.7705 - val_precision_score: 0.7527 - val_recall_score: 0.7335 - val_f1_score: 0.7428
# Epoch 24/50
# 5/5 [==============================] - 14s 3s/step - loss: 0.4073 - precision_score: 0.8525 - recall_score: 0.8250 - f1_score: 0.8384 - val_loss: 0.2869 - val_precision_score: 0.8476 - val_recall_score: 0.8375 - val_f1_score: 0.8425
# Epoch 25/50
# 5/5 [==============================] - 14s 3s/step - loss: 0.4863 - precision_score: 0.8282 - recall_score: 0.8125 - f1_score: 0.8202 - val_loss: 0.8584 - val_precision_score: 0.7200 - val_recall_score: 0.7063 - val_f1_score: 0.7130
# Epoch 26/50
# 5/5 [==============================] - 16s 3s/step - loss: 0.3663 - precision_score: 0.8562 - recall_score: 0.8562 - f1_score: 0.8562 - val_loss: 0.5308 - val_precision_score: 0.8123 - val_recall_score: 0.7812 - val_f1_score: 0.7964
# Epoch 27/50
# 5/5 [==============================] - 12s 2s/step - loss: 0.5865 - precision_score: 0.8000 - recall_score: 0.8000 - f1_score: 0.8000 - val_loss: 0.8465 - val_precision_score: 0.7939 - val_recall_score: 0.7688 - val_f1_score: 0.7810
# Epoch 28/50
# 5/5 [==============================] - 17s 3s/step - loss: 0.4862 - precision_score: 0.8024 - recall_score: 0.7812 - f1_score: 0.7915 - val_loss: 0.6761 - val_precision_score: 0.6526 - val_recall_score: 0.6375 - val_f1_score: 0.6449
# Epoch 29/50
# 5/5 [==============================] - 15s 3s/step - loss: 0.5157 - precision_score: 0.8049 - recall_score: 0.7750 - f1_score: 0.7897 - val_loss: 0.6703 - val_precision_score: 0.6984 - val_recall_score: 0.6938 - val_f1_score: 0.6960
# Epoch 30/50
# 5/5 [==============================] - 13s 3s/step - loss: 0.3936 - precision_score: 0.8386 - recall_score: 0.8188 - f1_score: 0.8284 - val_loss: 0.4880 - val_precision_score: 0.7578 - val_recall_score: 0.7437 - val_f1_score: 0.7506
# Epoch 31/50
# 5/5 [==============================] - 15s 3s/step - loss: 0.3830 - precision_score: 0.8576 - recall_score: 0.8250 - f1_score: 0.8408 - val_loss: 0.4474 - val_precision_score: 0.7656 - val_recall_score: 0.7506 - val_f1_score: 0.7579
# Epoch 32/50
# 5/5 [==============================] - 17s 3s/step - loss: 0.6693 - precision_score: 0.7780 - recall_score: 0.7625 - f1_score: 0.7701 - val_loss: 0.7294 - val_precision_score: 0.7484 - val_recall_score: 0.7437 - val_f1_score: 0.7460
# Epoch 33/50
# 5/5 [==============================] - 12s 2s/step - loss: 0.3486 - precision_score: 0.8800 - recall_score: 0.8750 - f1_score: 0.8775 - val_loss: 0.6818 - val_precision_score: 0.7589 - val_recall_score: 0.7500 - val_f1_score: 0.7544
# Epoch 34/50
# 5/5 [==============================] - 14s 3s/step - loss: 0.3878 - precision_score: 0.8488 - recall_score: 0.8375 - f1_score: 0.8431 - val_loss: 0.4927 - val_precision_score: 0.7984 - val_recall_score: 0.7688 - val_f1_score: 0.7830
# Epoch 35/50
# 5/5 [==============================] - 15s 3s/step - loss: 0.4636 - precision_score: 0.7790 - recall_score: 0.7563 - f1_score: 0.7673 - val_loss: 0.3011 - val_precision_score: 0.7890 - val_recall_score: 0.7750 - val_f1_score: 0.7818
# Epoch 36/50
# 5/5 [==============================] - 15s 3s/step - loss: 0.3845 - precision_score: 0.8483 - recall_score: 0.8375 - f1_score: 0.8427 - val_loss: 0.7754 - val_precision_score: 0.7851 - val_recall_score: 0.7750 - val_f1_score: 0.7800
# Epoch 37/50
# 5/5 [==============================] - 16s 3s/step - loss: 0.2902 - precision_score: 0.8969 - recall_score: 0.8750 - f1_score: 0.8857 - val_loss: 0.9754 - val_precision_score: 0.7372 - val_recall_score: 0.7188 - val_f1_score: 0.7277
# Epoch 38/50
# 5/5 [==============================] - 14s 3s/step - loss: 0.3403 - precision_score: 0.8667 - recall_score: 0.8500 - f1_score: 0.8582 - val_loss: 0.6955 - val_precision_score: 0.7467 - val_recall_score: 0.7386 - val_f1_score: 0.7426
# Epoch 39/50
# 5/5 [==============================] - 16s 3s/step - loss: 0.3843 - precision_score: 0.8790 - recall_score: 0.8625 - f1_score: 0.8705 - val_loss: 0.4744 - val_precision_score: 0.7813 - val_recall_score: 0.7625 - val_f1_score: 0.7717
# Epoch 40/50
# 5/5 [==============================] - 15s 3s/step - loss: 0.4158 - precision_score: 0.8655 - recall_score: 0.8438 - f1_score: 0.8543 - val_loss: 0.4487 - val_precision_score: 0.7966 - val_recall_score: 0.7812 - val_f1_score: 0.7888
# Epoch 41/50
# 5/5 [==============================] - 16s 3s/step - loss: 0.3448 - precision_score: 0.8728 - recall_score: 0.8562 - f1_score: 0.8644 - val_loss: 0.6692 - val_precision_score: 0.7438 - val_recall_score: 0.7250 - val_f1_score: 0.7342
# Epoch 42/50
# 5/5 [==============================] - 13s 3s/step - loss: 0.4093 - precision_score: 0.8713 - recall_score: 0.8438 - f1_score: 0.8572 - val_loss: 0.7446 - val_precision_score: 0.7611 - val_recall_score: 0.7563 - val_f1_score: 0.7586
# Epoch 43/50
# 5/5 [==============================] - 15s 3s/step - loss: 0.4134 - precision_score: 0.8841 - recall_score: 0.8562 - f1_score: 0.8698 - val_loss: 0.6832 - val_precision_score: 0.7811 - val_recall_score: 0.7625 - val_f1_score: 0.7716
# Epoch 44/50
# 5/5 [==============================] - 12s 2s/step - loss: 0.4695 - precision_score: 0.8028 - recall_score: 0.7937 - f1_score: 0.7982 - val_loss: 0.6726 - val_precision_score: 0.7834 - val_recall_score: 0.7688 - val_f1_score: 0.7759
# Epoch 45/50
# 5/5 [==============================] - 14s 3s/step - loss: 0.3746 - precision_score: 0.8853 - recall_score: 0.8625 - f1_score: 0.8737 - val_loss: 0.6779 - val_precision_score: 0.7784 - val_recall_score: 0.7688 - val_f1_score: 0.7735
# Epoch 46/50
# 5/5 [==============================] - 15s 3s/step - loss: 0.4351 - precision_score: 0.8413 - recall_score: 0.8313 - f1_score: 0.8362 - val_loss: 0.7493 - val_precision_score: 0.7279 - val_recall_score: 0.7176 - val_f1_score: 0.7227
# Epoch 47/50
# 5/5 [==============================] - 16s 3s/step - loss: 0.5743 - precision_score: 0.7815 - recall_score: 0.7625 - f1_score: 0.7718 - val_loss: 0.6558 - val_precision_score: 0.7530 - val_recall_score: 0.7437 - val_f1_score: 0.7483
# Epoch 48/50
# 5/5 [==============================] - 13s 3s/step - loss: 0.3856 - precision_score: 0.8908 - recall_score: 0.8750 - f1_score: 0.8827 - val_loss: 0.5166 - val_precision_score: 0.8215 - val_recall_score: 0.8062 - val_f1_score: 0.8137
# Epoch 49/50
# 5/5 [==============================] - 14s 3s/step - loss: 0.4753 - precision_score: 0.8345 - recall_score: 0.8188 - f1_score: 0.8265 - val_loss: 0.7891 - val_precision_score: 0.7236 - val_recall_score: 0.7188 - val_f1_score: 0.7211
# Epoch 50/50
# 5/5 [==============================] - 15s 3s/step - loss: 0.4544 - precision_score: 0.8136 - recall_score: 0.7875 - f1_score: 0.8002 - val_loss: 0.6794 - val_precision_score: 0.7940 - val_recall_score: 0.7750 - val_f1_score: 0.7843

# %% [markdown]
# Um modelo que converge bem possui o gráfico de perda (*loss*) descendente e os gráfico de precisão (*precision*), sensibilidade (*recall*) e pontuação f1 (*f1 score*) em acendente.

# %%
# Exibindo dados de Precisão
plt.plot(history.history['precision_score'])
plt.plot(history.history['val_precision_score'])
plt.title('model precision')
plt.ylabel('precision')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de Sensibilidade
plt.plot(history.history['recall_score'])
plt.plot(history.history['val_recall_score'])
plt.title('model recall')
plt.ylabel('recall')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de F1 Score
plt.plot(history.history['f1_score'])
plt.plot(history.history['val_f1_score'])
plt.title('model f1_score')
plt.ylabel('f1_score')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de Perda
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# **Pergunta**: Avalie os gráficos de perda (*loss*), precisão (*precision*), sensibilidade (*recall*) e pontuação f1 (*f1 score*)  e explique o comportamento de ambos no que tange a convergência do modelo.

# %% [markdown]
# **Resposta**:

# %% [markdown]
# **Pergunta**: Quais são os valores de **precisão (precision)**, **sensibilidade (recall)** de validação?
#
# *Estes valores são exibidos durante o treinamento, utilize a última saída, exemplo:*
#
# ```
# Epoch 10/10 [==============================] - 45s 9s/step - loss: 0.1234 - precision_score: 0.9742 - recall_score: 0.9683 - f1_score: 0.9712 - val_loss: 0.8819 - val_precision_score: 0.6912 - val_recall_score: 0.5649 - val_f1_score: 0.6216```
#
# No caso acima, o valor de precisão, sensibilidade e pontuação de validação são, respectivamente, 69,12%, 56,49% e 62,16%.

# %% [markdown]
# **Resposta**:```
# Epoch 50/50
# 5/5 [==============================] - 15s 3s/step - loss: 0.4544 - precision_score: 0.8136 - recall_score: 0.7875 - f1_score: 0.8002 - val_loss: 0.6794 - val_precision_score: 0.7940 - val_recall_score: 0.7750 - val_f1_score: 0.7843```
#
# precisão: 79,40%
#
# sensibilidade: 77,50%
#
# validação: 78,43%

# %% [markdown]
# ### 4.5.3 Arquitetura VGG19

# %% [markdown]
# **Pergunta**: Explique como é constituída a arquitetura do VGG19? *Utilize, se necessário, gráficos, projetos que utilizam essa arquitetura. Detalhe também sua topologia em camadas e mostre quais as situações essa arquitetura pode ter mais êxito e quais cenários não tem.*

# %% [markdown]
# **Resposta**:

# %%
conv_base = VGG19(include_top=False)

for layer in conv_base.layers:
    layer.trainable = False

# %%
x = conv_base.output
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(128, activation='relu')(x) 

predictions = layers.Dense(qtde_classes, activation='softmax')(x)
model = Model(conv_base.input, predictions)

model.summary()
# Out:
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         (None, None, None, 3)     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, None, None, 64)    1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, None, None, 64)    36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, None, None, 64)    0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, None, None, 128)   73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, None, None, 128)   147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, None, None, 128)   0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, None, None, 256)   295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, None, None, 256)   590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, None, None, 256)   590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, None, None, 256)   590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, None, None, 256)   0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, None, None, 512)   1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, None, None, 512)   0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, None, None, 512)   0
# _________________________________________________________________
# global_average_pooling2d_3 ( (None, 512)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 128)               65664
# _________________________________________________________________
# dense_6 (Dense)              (None, 3)                 387
# =================================================================
# Total params: 20,090,435
# Trainable params: 66,051
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
optimizer = keras.optimizers.Adam()
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=[precision_score, recall_score, f1_score])

# %%
history = model.fit_generator(generator=train_generator, 
                              epochs=qtde_epocas, 
                              validation_steps=5, 
                              steps_per_epoch=5, 
                              validation_data=val_generator)
# Out:
# Epoch 1/50
# 5/5 [==============================] - 17s 3s/step - loss: 3.2512 - precision_score: 0.3834 - recall_score: 0.3750 - f1_score: 0.3791 - val_loss: 2.4602 - val_precision_score: 0.4084 - val_recall_score: 0.4000 - val_f1_score: 0.4041
# Epoch 2/50
# 5/5 [==============================] - 18s 4s/step - loss: 2.1310 - precision_score: 0.4665 - recall_score: 0.4500 - f1_score: 0.4580 - val_loss: 1.7128 - val_precision_score: 0.5809 - val_recall_score: 0.5625 - val_f1_score: 0.5714
# Epoch 3/50
# 5/5 [==============================] - 16s 3s/step - loss: 1.1411 - precision_score: 0.6251 - recall_score: 0.6000 - f1_score: 0.6120 - val_loss: 0.9653 - val_precision_score: 0.6113 - val_recall_score: 0.5938 - val_f1_score: 0.6023
# Epoch 4/50
# 5/5 [==============================] - 15s 3s/step - loss: 1.1012 - precision_score: 0.6642 - recall_score: 0.6500 - f1_score: 0.6569 - val_loss: 0.5938 - val_precision_score: 0.7375 - val_recall_score: 0.7375 - val_f1_score: 0.7375
# Epoch 5/50
# 5/5 [==============================] - 17s 3s/step - loss: 0.9172 - precision_score: 0.7428 - recall_score: 0.7063 - f1_score: 0.7239 - val_loss: 1.8995 - val_precision_score: 0.6365 - val_recall_score: 0.6250 - val_f1_score: 0.6307
# Epoch 6/50
# 5/5 [==============================] - 19s 4s/step - loss: 0.9022 - precision_score: 0.7507 - recall_score: 0.7312 - f1_score: 0.7408 - val_loss: 1.0086 - val_precision_score: 0.6981 - val_recall_score: 0.6812 - val_f1_score: 0.6895
# Epoch 7/50
# 5/5 [==============================] - 17s 3s/step - loss: 1.0906 - precision_score: 0.6583 - recall_score: 0.6500 - f1_score: 0.6541 - val_loss: 1.6141 - val_precision_score: 0.6490 - val_recall_score: 0.6375 - val_f1_score: 0.6431
# Epoch 8/50
# 5/5 [==============================] - 16s 3s/step - loss: 0.8794 - precision_score: 0.7651 - recall_score: 0.7500 - f1_score: 0.7574 - val_loss: 1.0897 - val_precision_score: 0.6843 - val_recall_score: 0.6551 - val_f1_score: 0.6691
# Epoch 9/50
# 5/5 [==============================] - 18s 4s/step - loss: 0.6670 - precision_score: 0.7552 - recall_score: 0.7500 - f1_score: 0.7526 - val_loss: 1.8314 - val_precision_score: 0.6893 - val_recall_score: 0.6750 - val_f1_score: 0.6820
# Epoch 10/50
# 5/5 [==============================] - 15s 3s/step - loss: 0.6177 - precision_score: 0.8044 - recall_score: 0.7937 - f1_score: 0.7990 - val_loss: 0.9900 - val_precision_score: 0.7374 - val_recall_score: 0.7188 - val_f1_score: 0.7278
# Epoch 11/50
# 5/5 [==============================] - 19s 4s/step - loss: 0.6429 - precision_score: 0.7784 - recall_score: 0.7688 - f1_score: 0.7735 - val_loss: 1.3822 - val_precision_score: 0.7486 - val_recall_score: 0.7250 - val_f1_score: 0.7363
# Epoch 12/50
# 5/5 [==============================] - 18s 4s/step - loss: 0.6905 - precision_score: 0.7389 - recall_score: 0.7250 - f1_score: 0.7318 - val_loss: 0.6983 - val_precision_score: 0.7400 - val_recall_score: 0.7312 - val_f1_score: 0.7355
# Epoch 13/50
# 5/5 [==============================] - 19s 4s/step - loss: 0.4283 - precision_score: 0.7780 - recall_score: 0.7688 - f1_score: 0.7733 - val_loss: 0.7393 - val_precision_score: 0.7423 - val_recall_score: 0.7375 - val_f1_score: 0.7399
# Epoch 14/50
# 5/5 [==============================] - 16s 3s/step - loss: 0.5630 - precision_score: 0.7933 - recall_score: 0.7688 - f1_score: 0.7806 - val_loss: 1.0369 - val_precision_score: 0.6980 - val_recall_score: 0.6938 - val_f1_score: 0.6958
# Epoch 15/50
# 5/5 [==============================] - 18s 4s/step - loss: 0.5616 - precision_score: 0.8140 - recall_score: 0.7937 - f1_score: 0.8036 - val_loss: 0.9963 - val_precision_score: 0.7272 - val_recall_score: 0.7188 - val_f1_score: 0.7229
# Epoch 16/50
# 5/5 [==============================] - 13s 3s/step - loss: 0.5079 - precision_score: 0.8075 - recall_score: 0.7812 - f1_score: 0.7939 - val_loss: 0.3817 - val_precision_score: 0.7265 - val_recall_score: 0.7210 - val_f1_score: 0.7237
# Epoch 17/50
# 5/5 [==============================] - 19s 4s/step - loss: 0.6948 - precision_score: 0.7749 - recall_score: 0.7563 - f1_score: 0.7652 - val_loss: 1.6960 - val_precision_score: 0.6988 - val_recall_score: 0.6875 - val_f1_score: 0.6931
# Epoch 18/50
# 5/5 [==============================] - 19s 4s/step - loss: 0.6290 - precision_score: 0.7990 - recall_score: 0.7937 - f1_score: 0.7963 - val_loss: 0.6653 - val_precision_score: 0.6957 - val_recall_score: 0.6625 - val_f1_score: 0.6783
# Epoch 19/50
# 5/5 [==============================] - 18s 4s/step - loss: 0.5643 - precision_score: 0.7812 - recall_score: 0.7812 - f1_score: 0.7812 - val_loss: 0.7704 - val_precision_score: 0.8044 - val_recall_score: 0.7937 - val_f1_score: 0.7990
# Epoch 20/50
# 5/5 [==============================] - 17s 3s/step - loss: 0.4810 - precision_score: 0.8363 - recall_score: 0.8000 - f1_score: 0.8172 - val_loss: 0.4203 - val_precision_score: 0.7489 - val_recall_score: 0.7312 - val_f1_score: 0.7399
# Epoch 21/50
# 5/5 [==============================] - 19s 4s/step - loss: 0.7237 - precision_score: 0.7325 - recall_score: 0.7188 - f1_score: 0.7255 - val_loss: 0.8303 - val_precision_score: 0.6938 - val_recall_score: 0.6812 - val_f1_score: 0.6874
# Epoch 22/50
# 5/5 [==============================] - 15s 3s/step - loss: 0.5822 - precision_score: 0.8018 - recall_score: 0.7875 - f1_score: 0.7945 - val_loss: 0.4535 - val_precision_score: 0.7644 - val_recall_score: 0.7500 - val_f1_score: 0.7570
# Epoch 23/50
# 5/5 [==============================] - 17s 3s/step - loss: 0.5529 - precision_score: 0.7861 - recall_score: 0.7812 - f1_score: 0.7836 - val_loss: 1.3008 - val_precision_score: 0.7310 - val_recall_score: 0.7261 - val_f1_score: 0.7285
# Epoch 24/50
# 5/5 [==============================] - 18s 4s/step - loss: 0.5914 - precision_score: 0.7906 - recall_score: 0.7750 - f1_score: 0.7826 - val_loss: 0.8504 - val_precision_score: 0.7091 - val_recall_score: 0.7000 - val_f1_score: 0.7045
# Epoch 25/50
# 5/5 [==============================] - 19s 4s/step - loss: 0.4368 - precision_score: 0.8438 - recall_score: 0.8438 - f1_score: 0.8437 - val_loss: 1.5474 - val_precision_score: 0.7158 - val_recall_score: 0.7063 - val_f1_score: 0.7109
# Epoch 26/50
# 5/5 [==============================] - 18s 4s/step - loss: 0.6145 - precision_score: 0.8205 - recall_score: 0.8000 - f1_score: 0.8096 - val_loss: 1.1475 - val_precision_score: 0.7292 - val_recall_score: 0.7250 - val_f1_score: 0.7271
# Epoch 27/50
# 5/5 [==============================] - 19s 4s/step - loss: 0.5169 - precision_score: 0.8361 - recall_score: 0.8313 - f1_score: 0.8336 - val_loss: 1.1291 - val_precision_score: 0.6562 - val_recall_score: 0.6562 - val_f1_score: 0.6562
# Epoch 28/50
# 5/5 [==============================] - 17s 3s/step - loss: 0.4334 - precision_score: 0.8036 - recall_score: 0.7875 - f1_score: 0.7954 - val_loss: 0.9179 - val_precision_score: 0.7474 - val_recall_score: 0.7375 - val_f1_score: 0.7424
# Epoch 29/50
# 5/5 [==============================] - 15s 3s/step - loss: 0.4615 - precision_score: 0.8290 - recall_score: 0.8188 - f1_score: 0.8238 - val_loss: 0.6707 - val_precision_score: 0.7786 - val_recall_score: 0.7688 - val_f1_score: 0.7736
# Epoch 30/50
# 5/5 [==============================] - 17s 3s/step - loss: 0.5795 - precision_score: 0.7978 - recall_score: 0.7812 - f1_score: 0.7894 - val_loss: 0.9534 - val_precision_score: 0.7124 - val_recall_score: 0.7000 - val_f1_score: 0.7060
# Epoch 31/50
# 5/5 [==============================] - 19s 4s/step - loss: 0.5386 - precision_score: 0.8103 - recall_score: 0.8000 - f1_score: 0.8051 - val_loss: 1.2942 - val_precision_score: 0.7174 - val_recall_score: 0.7028 - val_f1_score: 0.7100
# Epoch 32/50
# 5/5 [==============================] - 18s 4s/step - loss: 0.5927 - precision_score: 0.7842 - recall_score: 0.7750 - f1_score: 0.7794 - val_loss: 0.9155 - val_precision_score: 0.7734 - val_recall_score: 0.7688 - val_f1_score: 0.7710
# Epoch 33/50
# 5/5 [==============================] - 21s 4s/step - loss: 0.5796 - precision_score: 0.8085 - recall_score: 0.7937 - f1_score: 0.8010 - val_loss: 0.9488 - val_precision_score: 0.7088 - val_recall_score: 0.6875 - val_f1_score: 0.6978
# Epoch 34/50
# 5/5 [==============================] - 17s 3s/step - loss: 0.4466 - precision_score: 0.8292 - recall_score: 0.8062 - f1_score: 0.8173 - val_loss: 0.2808 - val_precision_score: 0.7585 - val_recall_score: 0.7500 - val_f1_score: 0.7542
# Epoch 35/50
# 5/5 [==============================] - 18s 4s/step - loss: 0.4097 - precision_score: 0.8542 - recall_score: 0.8438 - f1_score: 0.8489 - val_loss: 0.8557 - val_precision_score: 0.7280 - val_recall_score: 0.7188 - val_f1_score: 0.7233
# Epoch 36/50
# 5/5 [==============================] - 21s 4s/step - loss: 0.5324 - precision_score: 0.7921 - recall_score: 0.7812 - f1_score: 0.7865 - val_loss: 0.8282 - val_precision_score: 0.7798 - val_recall_score: 0.7750 - val_f1_score: 0.7774
# Epoch 37/50
# 5/5 [==============================] - 17s 3s/step - loss: 0.3296 - precision_score: 0.8544 - recall_score: 0.8375 - f1_score: 0.8457 - val_loss: 1.3940 - val_precision_score: 0.6866 - val_recall_score: 0.6687 - val_f1_score: 0.6775
# Epoch 38/50
# 5/5 [==============================] - 18s 4s/step - loss: 0.3359 - precision_score: 0.8857 - recall_score: 0.8687 - f1_score: 0.8771 - val_loss: 0.8107 - val_precision_score: 0.7697 - val_recall_score: 0.7551 - val_f1_score: 0.7622
# Epoch 39/50
# 5/5 [==============================] - 19s 4s/step - loss: 0.2874 - precision_score: 0.8869 - recall_score: 0.8813 - f1_score: 0.8840 - val_loss: 1.1936 - val_precision_score: 0.7232 - val_recall_score: 0.7000 - val_f1_score: 0.7111
# Epoch 40/50
# 5/5 [==============================] - 20s 4s/step - loss: 0.4393 - precision_score: 0.8244 - recall_score: 0.8188 - f1_score: 0.8215 - val_loss: 0.7315 - val_precision_score: 0.7510 - val_recall_score: 0.7375 - val_f1_score: 0.7441
# Epoch 41/50
# 5/5 [==============================] - 18s 4s/step - loss: 0.3545 - precision_score: 0.8782 - recall_score: 0.8562 - f1_score: 0.8670 - val_loss: 0.5338 - val_precision_score: 0.7764 - val_recall_score: 0.7625 - val_f1_score: 0.7693
# Epoch 42/50
# 5/5 [==============================] - 19s 4s/step - loss: 0.4392 - precision_score: 0.8084 - recall_score: 0.7875 - f1_score: 0.7977 - val_loss: 0.7613 - val_precision_score: 0.7358 - val_recall_score: 0.7188 - val_f1_score: 0.7270
# Epoch 43/50
# 5/5 [==============================] - 20s 4s/step - loss: 0.4573 - precision_score: 0.8417 - recall_score: 0.8313 - f1_score: 0.8363 - val_loss: 0.7835 - val_precision_score: 0.6986 - val_recall_score: 0.6938 - val_f1_score: 0.6961
# Epoch 44/50
# 5/5 [==============================] - 20s 4s/step - loss: 0.3474 - precision_score: 0.8615 - recall_score: 0.8562 - f1_score: 0.8588 - val_loss: 0.7172 - val_precision_score: 0.7478 - val_recall_score: 0.7375 - val_f1_score: 0.7426
# Epoch 45/50
# 5/5 [==============================] - 16s 3s/step - loss: 0.4264 - precision_score: 0.7911 - recall_score: 0.7750 - f1_score: 0.7829 - val_loss: 0.6814 - val_precision_score: 0.8092 - val_recall_score: 0.7937 - val_f1_score: 0.8013
# Epoch 46/50
# 5/5 [==============================] - 17s 3s/step - loss: 0.6428 - precision_score: 0.7282 - recall_score: 0.7000 - f1_score: 0.7134 - val_loss: 1.4254 - val_precision_score: 0.6955 - val_recall_score: 0.6801 - val_f1_score: 0.6876
# Epoch 47/50
# 5/5 [==============================] - 18s 4s/step - loss: 0.4495 - precision_score: 0.8159 - recall_score: 0.8062 - f1_score: 0.8110 - val_loss: 1.2110 - val_precision_score: 0.6513 - val_recall_score: 0.6438 - val_f1_score: 0.6474
# Epoch 48/50
# 5/5 [==============================] - 18s 4s/step - loss: 0.5455 - precision_score: 0.7704 - recall_score: 0.7375 - f1_score: 0.7534 - val_loss: 0.5814 - val_precision_score: 0.7470 - val_recall_score: 0.7375 - val_f1_score: 0.7422
# Epoch 49/50
# 5/5 [==============================] - 18s 4s/step - loss: 0.3756 - precision_score: 0.8540 - recall_score: 0.8375 - f1_score: 0.8455 - val_loss: 0.9722 - val_precision_score: 0.8105 - val_recall_score: 0.7812 - val_f1_score: 0.7953
# Epoch 50/50
# 5/5 [==============================] - 20s 4s/step - loss: 0.4776 - precision_score: 0.8253 - recall_score: 0.8000 - f1_score: 0.8124 - val_loss: 1.2850 - val_precision_score: 0.7583 - val_recall_score: 0.7437 - val_f1_score: 0.7509

# %% [markdown]
# Um modelo que converge bem possui o gráfico de perda (*loss*) descendente e os gráfico de precisão (*precision*), sensibilidade (*recall*) e pontuação f1 (*f1 score*) em acendente.

# %%
# Exibindo dados de Precisão
plt.plot(history.history['precision_score'])
plt.plot(history.history['val_precision_score'])
plt.title('model precision')
plt.ylabel('precision')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de Sensibilidade
plt.plot(history.history['recall_score'])
plt.plot(history.history['val_recall_score'])
plt.title('model recall')
plt.ylabel('recall')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de F1 Score
plt.plot(history.history['f1_score'])
plt.plot(history.history['val_f1_score'])
plt.title('model f1_score')
plt.ylabel('f1_score')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de Perda
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# **Pergunta**: Avalie os gráficos de perda (*loss*), precisão (*precision*), sensibilidade (*recall*) e pontuação f1 (*f1 score*)  e explique o comportamento de ambos no que tange a convergência do modelo.

# %% [markdown]
# **Resposta**:

# %% [markdown]
# **Pergunta**: Quais são os valores de **precisão (precision)**, **sensibilidade (recall)** de validação?
#
# *Estes valores são exibidos durante o treinamento, utilize a última saída, exemplo:*
#
# ```
# Epoch 10/10 [==============================] - 45s 9s/step - loss: 0.1234 - precision_score: 0.9742 - recall_score: 0.9683 - f1_score: 0.9712 - val_loss: 0.8819 - val_precision_score: 0.6912 - val_recall_score: 0.5649 - val_f1_score: 0.6216```
#
# No caso acima, o valor de precisão, sensibilidade e pontuação de validação são, respectivamente, 69,12%, 56,49% e 62,16%.

# %% [markdown]
# **Resposta**:```
# Epoch 50/50
# 5/5 [==============================] - 20s 4s/step - loss: 0.4776 - precision_score: 0.8253 - recall_score: 0.8000 - f1_score: 0.8124 - val_loss: 1.2850 - val_precision_score: 0.7583 - val_recall_score: 0.7437 - val_f1_score: 0.7509```
#
# precisão: 75,83%
# sensibilidade: 74,37%
# validação: 75,090%

# %% [markdown]
# ## 4.6 Compartivo de arquiteturas
#
# Preencha a tabela abaixo com os valores dos indicadores de performance apresentados.
#
# _O cálculo do F1-Score é dado por 2 * (Precisão * Sensibilidade) / (Precisão + Sensibilidade)._

# %% [markdown]
# | Modelo   | Precisão (*Precision*) | Sensibilidade (*Recall*) | F1-Score |
# |----------|----------|---------------|----------|
# | ResNet50 | 47,34 %  | 45,63 %       | 45,45 %  |
# | VGG16    | 79,40 %  | 77,50 %       | 78,43    |
# | VGG19    | 75,83 %  | 74,37 %       | 75,09 %  |

# %% [markdown]
# ## 4.7 Conclusões
#
# Analise os resultados da tabela de indicadores do comparativo de arquiteturas e explique os principais motivos pelos quais cada modelo obteve cada resultado.

# %% [markdown]
# **Respota**:

# %% [markdown]
# ## 4.8 Abordagem Extra
#
# Considerando os outros classificadores, escolha outro que ainda não foi utilizado, implemente abaixo. Ao final compare os resultados e explique os resultados.
#
# _Não se esquece de utilizar as importações adequadas para cada modelo.
# A forma de implementação deve respeitar as mesmas condições como valor de split e quantidade de imagens para poder comparar os modelos._

# %%
#IMPLEMENTE

# %%
conv_base = conv_base = InceptionResNetV2(include_top=False)

for layer in conv_base.layers:
    layer.trainable = False

# %%
x = conv_base.output
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(128, activation='relu')(x) 

predictions = layers.Dense(qtde_classes, activation='softmax')(x)
model = Model(conv_base.input, predictions)

model.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            (None, None, None, 3 0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, None, None, 3 864         input_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, None, None, 3 96          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, None, None, 3 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, None, None, 3 9216        activation_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, None, None, 3 96          conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, None, None, 3 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, None, None, 6 18432       activation_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, None, None, 6 192         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, None, None, 6 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, None, None, 6 0           activation_52[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, None, None, 8 5120        max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, None, None, 8 240         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, None, None, 8 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, None, None, 1 138240      activation_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, None, None, 1 576         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, None, None, 1 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, None, None, 1 0           activation_54[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, None, None, 6 12288       max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, None, None, 6 192         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, None, None, 6 0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, None, None, 4 9216        max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, None, None, 9 55296       activation_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, None, None, 4 144         conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, None, None, 9 288         conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, None, None, 4 0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, None, None, 9 0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, None, None, 1 0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, None, None, 9 18432       max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, None, None, 6 76800       activation_56[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, None, None, 9 82944       activation_59[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, None, None, 6 12288       average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, None, None, 9 288         conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, None, None, 6 192         conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, None, None, 9 288         conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, None, None, 6 192         conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, None, None, 9 0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, None, None, 6 0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, None, None, 9 0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, None, None, 6 0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# mixed_5b (Concatenate)          (None, None, None, 3 0           activation_55[0][0]
#                                                                  activation_57[0][0]
#                                                                  activation_60[0][0]
#                                                                  activation_61[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, None, None, 3 10240       mixed_5b[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, None, None, 3 96          conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, None, None, 3 0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, None, None, 3 10240       mixed_5b[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, None, None, 4 13824       activation_65[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, None, None, 3 96          conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, None, None, 4 144         conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, None, None, 3 0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, None, None, 4 0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, None, None, 3 10240       mixed_5b[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, None, None, 3 9216        activation_63[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, None, None, 6 27648       activation_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, None, None, 3 96          conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, None, None, 3 96          conv2d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, None, None, 6 192         conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, None, None, 3 0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, None, None, 3 0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, None, None, 6 0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# block35_1_mixed (Concatenate)   (None, None, None, 1 0           activation_62[0][0]
#                                                                  activation_64[0][0]
#                                                                  activation_67[0][0]
# __________________________________________________________________________________________________
# block35_1_conv (Conv2D)         (None, None, None, 3 41280       block35_1_mixed[0][0]
# __________________________________________________________________________________________________
# block35_1 (Lambda)              (None, None, None, 3 0           mixed_5b[0][0]
#                                                                  block35_1_conv[0][0]
# __________________________________________________________________________________________________
# block35_1_ac (Activation)       (None, None, None, 3 0           block35_1[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, None, None, 3 10240       block35_1_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, None, None, 3 96          conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, None, None, 3 0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, None, None, 3 10240       block35_1_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, None, None, 4 13824       activation_71[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, None, None, 3 96          conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, None, None, 4 144         conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, None, None, 3 0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# activation_72 (Activation)      (None, None, None, 4 0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, None, None, 3 10240       block35_1_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, None, None, 3 9216        activation_69[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, None, None, 6 27648       activation_72[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, None, None, 3 96          conv2d_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, None, None, 3 96          conv2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, None, None, 6 192         conv2d_24[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, None, None, 3 0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, None, None, 3 0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# activation_73 (Activation)      (None, None, None, 6 0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# block35_2_mixed (Concatenate)   (None, None, None, 1 0           activation_68[0][0]
#                                                                  activation_70[0][0]
#                                                                  activation_73[0][0]
# __________________________________________________________________________________________________
# block35_2_conv (Conv2D)         (None, None, None, 3 41280       block35_2_mixed[0][0]
# __________________________________________________________________________________________________
# block35_2 (Lambda)              (None, None, None, 3 0           block35_1_ac[0][0]
#                                                                  block35_2_conv[0][0]
# __________________________________________________________________________________________________
# block35_2_ac (Activation)       (None, None, None, 3 0           block35_2[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, None, None, 3 10240       block35_2_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, None, None, 3 96          conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, None, None, 3 0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, None, None, 3 10240       block35_2_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, None, None, 4 13824       activation_77[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, None, None, 3 96          conv2d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, None, None, 4 144         conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_75 (Activation)      (None, None, None, 3 0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# activation_78 (Activation)      (None, None, None, 4 0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, None, None, 3 10240       block35_2_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, None, None, 3 9216        activation_75[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, None, None, 6 27648       activation_78[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, None, None, 3 96          conv2d_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, None, None, 3 96          conv2d_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, None, None, 6 192         conv2d_30[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, None, None, 3 0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# activation_76 (Activation)      (None, None, None, 3 0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, None, None, 6 0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# block35_3_mixed (Concatenate)   (None, None, None, 1 0           activation_74[0][0]
#                                                                  activation_76[0][0]
#                                                                  activation_79[0][0]
# __________________________________________________________________________________________________
# block35_3_conv (Conv2D)         (None, None, None, 3 41280       block35_3_mixed[0][0]
# __________________________________________________________________________________________________
# block35_3 (Lambda)              (None, None, None, 3 0           block35_2_ac[0][0]
#                                                                  block35_3_conv[0][0]
# __________________________________________________________________________________________________
# block35_3_ac (Activation)       (None, None, None, 3 0           block35_3[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, None, None, 3 10240       block35_3_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, None, None, 3 96          conv2d_34[0][0]
# __________________________________________________________________________________________________
# activation_83 (Activation)      (None, None, None, 3 0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, None, None, 3 10240       block35_3_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, None, None, 4 13824       activation_83[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, None, None, 3 96          conv2d_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, None, None, 4 144         conv2d_35[0][0]
# __________________________________________________________________________________________________
# activation_81 (Activation)      (None, None, None, 3 0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# activation_84 (Activation)      (None, None, None, 4 0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, None, None, 3 10240       block35_3_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, None, None, 3 9216        activation_81[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, None, None, 6 27648       activation_84[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, None, None, 3 96          conv2d_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, None, None, 3 96          conv2d_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, None, None, 6 192         conv2d_36[0][0]
# __________________________________________________________________________________________________
# activation_80 (Activation)      (None, None, None, 3 0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# activation_82 (Activation)      (None, None, None, 3 0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# activation_85 (Activation)      (None, None, None, 6 0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# block35_4_mixed (Concatenate)   (None, None, None, 1 0           activation_80[0][0]
#                                                                  activation_82[0][0]
#                                                                  activation_85[0][0]
# __________________________________________________________________________________________________
# block35_4_conv (Conv2D)         (None, None, None, 3 41280       block35_4_mixed[0][0]
# __________________________________________________________________________________________________
# block35_4 (Lambda)              (None, None, None, 3 0           block35_3_ac[0][0]
#                                                                  block35_4_conv[0][0]
# __________________________________________________________________________________________________
# block35_4_ac (Activation)       (None, None, None, 3 0           block35_4[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, None, None, 3 10240       block35_4_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, None, None, 3 96          conv2d_40[0][0]
# __________________________________________________________________________________________________
# activation_89 (Activation)      (None, None, None, 3 0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, None, None, 3 10240       block35_4_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, None, None, 4 13824       activation_89[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, None, None, 3 96          conv2d_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, None, None, 4 144         conv2d_41[0][0]
# __________________________________________________________________________________________________
# activation_87 (Activation)      (None, None, None, 3 0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# activation_90 (Activation)      (None, None, None, 4 0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, None, None, 3 10240       block35_4_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, None, None, 3 9216        activation_87[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, None, None, 6 27648       activation_90[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, None, None, 3 96          conv2d_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, None, None, 3 96          conv2d_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, None, None, 6 192         conv2d_42[0][0]
# __________________________________________________________________________________________________
# activation_86 (Activation)      (None, None, None, 3 0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# activation_88 (Activation)      (None, None, None, 3 0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# activation_91 (Activation)      (None, None, None, 6 0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# block35_5_mixed (Concatenate)   (None, None, None, 1 0           activation_86[0][0]
#                                                                  activation_88[0][0]
#                                                                  activation_91[0][0]
# __________________________________________________________________________________________________
# block35_5_conv (Conv2D)         (None, None, None, 3 41280       block35_5_mixed[0][0]
# __________________________________________________________________________________________________
# block35_5 (Lambda)              (None, None, None, 3 0           block35_4_ac[0][0]
#                                                                  block35_5_conv[0][0]
# __________________________________________________________________________________________________
# block35_5_ac (Activation)       (None, None, None, 3 0           block35_5[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, None, None, 3 10240       block35_5_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, None, None, 3 96          conv2d_46[0][0]
# __________________________________________________________________________________________________
# activation_95 (Activation)      (None, None, None, 3 0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, None, None, 3 10240       block35_5_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, None, None, 4 13824       activation_95[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, None, None, 3 96          conv2d_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, None, None, 4 144         conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_93 (Activation)      (None, None, None, 3 0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# activation_96 (Activation)      (None, None, None, 4 0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, None, None, 3 10240       block35_5_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, None, None, 3 9216        activation_93[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, None, None, 6 27648       activation_96[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, None, None, 3 96          conv2d_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, None, None, 3 96          conv2d_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, None, None, 6 192         conv2d_48[0][0]
# __________________________________________________________________________________________________
# activation_92 (Activation)      (None, None, None, 3 0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# activation_94 (Activation)      (None, None, None, 3 0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# activation_97 (Activation)      (None, None, None, 6 0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# block35_6_mixed (Concatenate)   (None, None, None, 1 0           activation_92[0][0]
#                                                                  activation_94[0][0]
#                                                                  activation_97[0][0]
# __________________________________________________________________________________________________
# block35_6_conv (Conv2D)         (None, None, None, 3 41280       block35_6_mixed[0][0]
# __________________________________________________________________________________________________
# block35_6 (Lambda)              (None, None, None, 3 0           block35_5_ac[0][0]
#                                                                  block35_6_conv[0][0]
# __________________________________________________________________________________________________
# block35_6_ac (Activation)       (None, None, None, 3 0           block35_6[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, None, None, 3 10240       block35_6_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, None, None, 3 96          conv2d_52[0][0]
# __________________________________________________________________________________________________
# activation_101 (Activation)     (None, None, None, 3 0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, None, None, 3 10240       block35_6_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, None, None, 4 13824       activation_101[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, None, None, 3 96          conv2d_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, None, None, 4 144         conv2d_53[0][0]
# __________________________________________________________________________________________________
# activation_99 (Activation)      (None, None, None, 3 0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# activation_102 (Activation)     (None, None, None, 4 0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, None, None, 3 10240       block35_6_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, None, None, 3 9216        activation_99[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, None, None, 6 27648       activation_102[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, None, None, 3 96          conv2d_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, None, None, 3 96          conv2d_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, None, None, 6 192         conv2d_54[0][0]
# __________________________________________________________________________________________________
# activation_98 (Activation)      (None, None, None, 3 0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# activation_100 (Activation)     (None, None, None, 3 0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# activation_103 (Activation)     (None, None, None, 6 0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# block35_7_mixed (Concatenate)   (None, None, None, 1 0           activation_98[0][0]
#                                                                  activation_100[0][0]
#                                                                  activation_103[0][0]
# __________________________________________________________________________________________________
# block35_7_conv (Conv2D)         (None, None, None, 3 41280       block35_7_mixed[0][0]
# __________________________________________________________________________________________________
# block35_7 (Lambda)              (None, None, None, 3 0           block35_6_ac[0][0]
#                                                                  block35_7_conv[0][0]
# __________________________________________________________________________________________________
# block35_7_ac (Activation)       (None, None, None, 3 0           block35_7[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, None, None, 3 10240       block35_7_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, None, None, 3 96          conv2d_58[0][0]
# __________________________________________________________________________________________________
# activation_107 (Activation)     (None, None, None, 3 0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, None, None, 3 10240       block35_7_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, None, None, 4 13824       activation_107[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, None, None, 3 96          conv2d_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, None, None, 4 144         conv2d_59[0][0]
# __________________________________________________________________________________________________
# activation_105 (Activation)     (None, None, None, 3 0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# activation_108 (Activation)     (None, None, None, 4 0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, None, None, 3 10240       block35_7_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, None, None, 3 9216        activation_105[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, None, None, 6 27648       activation_108[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, None, None, 3 96          conv2d_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, None, None, 3 96          conv2d_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, None, None, 6 192         conv2d_60[0][0]
# __________________________________________________________________________________________________
# activation_104 (Activation)     (None, None, None, 3 0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# activation_106 (Activation)     (None, None, None, 3 0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# activation_109 (Activation)     (None, None, None, 6 0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# block35_8_mixed (Concatenate)   (None, None, None, 1 0           activation_104[0][0]
#                                                                  activation_106[0][0]
#                                                                  activation_109[0][0]
# __________________________________________________________________________________________________
# block35_8_conv (Conv2D)         (None, None, None, 3 41280       block35_8_mixed[0][0]
# __________________________________________________________________________________________________
# block35_8 (Lambda)              (None, None, None, 3 0           block35_7_ac[0][0]
#                                                                  block35_8_conv[0][0]
# __________________________________________________________________________________________________
# block35_8_ac (Activation)       (None, None, None, 3 0           block35_8[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, None, None, 3 10240       block35_8_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, None, None, 3 96          conv2d_64[0][0]
# __________________________________________________________________________________________________
# activation_113 (Activation)     (None, None, None, 3 0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, None, None, 3 10240       block35_8_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, None, None, 4 13824       activation_113[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, None, None, 3 96          conv2d_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, None, None, 4 144         conv2d_65[0][0]
# __________________________________________________________________________________________________
# activation_111 (Activation)     (None, None, None, 3 0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# activation_114 (Activation)     (None, None, None, 4 0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, None, None, 3 10240       block35_8_ac[0][0]
# __________________________________________________________________________________________________
# ...
# __________________________________________________________________________________________________
# activation_236 (Activation)     (None, None, None, 2 0           batch_normalization_187[0][0]
# __________________________________________________________________________________________________
# block8_6_mixed (Concatenate)    (None, None, None, 4 0           activation_233[0][0]
#                                                                  activation_236[0][0]
# __________________________________________________________________________________________________
# block8_6_conv (Conv2D)          (None, None, None, 2 933920      block8_6_mixed[0][0]
# __________________________________________________________________________________________________
# block8_6 (Lambda)               (None, None, None, 2 0           block8_5_ac[0][0]
#                                                                  block8_6_conv[0][0]
# __________________________________________________________________________________________________
# block8_6_ac (Activation)        (None, None, None, 2 0           block8_6[0][0]
# __________________________________________________________________________________________________
# conv2d_189 (Conv2D)             (None, None, None, 1 399360      block8_6_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_189 (BatchN (None, None, None, 1 576         conv2d_189[0][0]
# __________________________________________________________________________________________________
# activation_238 (Activation)     (None, None, None, 1 0           batch_normalization_189[0][0]
# __________________________________________________________________________________________________
# conv2d_190 (Conv2D)             (None, None, None, 2 129024      activation_238[0][0]
# __________________________________________________________________________________________________
# batch_normalization_190 (BatchN (None, None, None, 2 672         conv2d_190[0][0]
# __________________________________________________________________________________________________
# activation_239 (Activation)     (None, None, None, 2 0           batch_normalization_190[0][0]
# __________________________________________________________________________________________________
# conv2d_188 (Conv2D)             (None, None, None, 1 399360      block8_6_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_191 (Conv2D)             (None, None, None, 2 172032      activation_239[0][0]
# __________________________________________________________________________________________________
# batch_normalization_188 (BatchN (None, None, None, 1 576         conv2d_188[0][0]
# __________________________________________________________________________________________________
# batch_normalization_191 (BatchN (None, None, None, 2 768         conv2d_191[0][0]
# __________________________________________________________________________________________________
# activation_237 (Activation)     (None, None, None, 1 0           batch_normalization_188[0][0]
# __________________________________________________________________________________________________
# activation_240 (Activation)     (None, None, None, 2 0           batch_normalization_191[0][0]
# __________________________________________________________________________________________________
# block8_7_mixed (Concatenate)    (None, None, None, 4 0           activation_237[0][0]
#                                                                  activation_240[0][0]
# __________________________________________________________________________________________________
# block8_7_conv (Conv2D)          (None, None, None, 2 933920      block8_7_mixed[0][0]
# __________________________________________________________________________________________________
# block8_7 (Lambda)               (None, None, None, 2 0           block8_6_ac[0][0]
#                                                                  block8_7_conv[0][0]
# __________________________________________________________________________________________________
# block8_7_ac (Activation)        (None, None, None, 2 0           block8_7[0][0]
# __________________________________________________________________________________________________
# conv2d_193 (Conv2D)             (None, None, None, 1 399360      block8_7_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_193 (BatchN (None, None, None, 1 576         conv2d_193[0][0]
# __________________________________________________________________________________________________
# activation_242 (Activation)     (None, None, None, 1 0           batch_normalization_193[0][0]
# __________________________________________________________________________________________________
# conv2d_194 (Conv2D)             (None, None, None, 2 129024      activation_242[0][0]
# __________________________________________________________________________________________________
# batch_normalization_194 (BatchN (None, None, None, 2 672         conv2d_194[0][0]
# __________________________________________________________________________________________________
# activation_243 (Activation)     (None, None, None, 2 0           batch_normalization_194[0][0]
# __________________________________________________________________________________________________
# conv2d_192 (Conv2D)             (None, None, None, 1 399360      block8_7_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_195 (Conv2D)             (None, None, None, 2 172032      activation_243[0][0]
# __________________________________________________________________________________________________
# batch_normalization_192 (BatchN (None, None, None, 1 576         conv2d_192[0][0]
# __________________________________________________________________________________________________
# batch_normalization_195 (BatchN (None, None, None, 2 768         conv2d_195[0][0]
# __________________________________________________________________________________________________
# activation_241 (Activation)     (None, None, None, 1 0           batch_normalization_192[0][0]
# __________________________________________________________________________________________________
# activation_244 (Activation)     (None, None, None, 2 0           batch_normalization_195[0][0]
# __________________________________________________________________________________________________
# block8_8_mixed (Concatenate)    (None, None, None, 4 0           activation_241[0][0]
#                                                                  activation_244[0][0]
# __________________________________________________________________________________________________
# block8_8_conv (Conv2D)          (None, None, None, 2 933920      block8_8_mixed[0][0]
# __________________________________________________________________________________________________
# block8_8 (Lambda)               (None, None, None, 2 0           block8_7_ac[0][0]
#                                                                  block8_8_conv[0][0]
# __________________________________________________________________________________________________
# block8_8_ac (Activation)        (None, None, None, 2 0           block8_8[0][0]
# __________________________________________________________________________________________________
# conv2d_197 (Conv2D)             (None, None, None, 1 399360      block8_8_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_197 (BatchN (None, None, None, 1 576         conv2d_197[0][0]
# __________________________________________________________________________________________________
# activation_246 (Activation)     (None, None, None, 1 0           batch_normalization_197[0][0]
# __________________________________________________________________________________________________
# conv2d_198 (Conv2D)             (None, None, None, 2 129024      activation_246[0][0]
# __________________________________________________________________________________________________
# batch_normalization_198 (BatchN (None, None, None, 2 672         conv2d_198[0][0]
# __________________________________________________________________________________________________
# activation_247 (Activation)     (None, None, None, 2 0           batch_normalization_198[0][0]
# __________________________________________________________________________________________________
# conv2d_196 (Conv2D)             (None, None, None, 1 399360      block8_8_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_199 (Conv2D)             (None, None, None, 2 172032      activation_247[0][0]
# __________________________________________________________________________________________________
# batch_normalization_196 (BatchN (None, None, None, 1 576         conv2d_196[0][0]
# __________________________________________________________________________________________________
# batch_normalization_199 (BatchN (None, None, None, 2 768         conv2d_199[0][0]
# __________________________________________________________________________________________________
# activation_245 (Activation)     (None, None, None, 1 0           batch_normalization_196[0][0]
# __________________________________________________________________________________________________
# activation_248 (Activation)     (None, None, None, 2 0           batch_normalization_199[0][0]
# __________________________________________________________________________________________________
# block8_9_mixed (Concatenate)    (None, None, None, 4 0           activation_245[0][0]
#                                                                  activation_248[0][0]
# __________________________________________________________________________________________________
# block8_9_conv (Conv2D)          (None, None, None, 2 933920      block8_9_mixed[0][0]
# __________________________________________________________________________________________________
# block8_9 (Lambda)               (None, None, None, 2 0           block8_8_ac[0][0]
#                                                                  block8_9_conv[0][0]
# __________________________________________________________________________________________________
# block8_9_ac (Activation)        (None, None, None, 2 0           block8_9[0][0]
# __________________________________________________________________________________________________
# conv2d_201 (Conv2D)             (None, None, None, 1 399360      block8_9_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_201 (BatchN (None, None, None, 1 576         conv2d_201[0][0]
# __________________________________________________________________________________________________
# activation_250 (Activation)     (None, None, None, 1 0           batch_normalization_201[0][0]
# __________________________________________________________________________________________________
# conv2d_202 (Conv2D)             (None, None, None, 2 129024      activation_250[0][0]
# __________________________________________________________________________________________________
# batch_normalization_202 (BatchN (None, None, None, 2 672         conv2d_202[0][0]
# __________________________________________________________________________________________________
# activation_251 (Activation)     (None, None, None, 2 0           batch_normalization_202[0][0]
# __________________________________________________________________________________________________
# conv2d_200 (Conv2D)             (None, None, None, 1 399360      block8_9_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_203 (Conv2D)             (None, None, None, 2 172032      activation_251[0][0]
# __________________________________________________________________________________________________
# batch_normalization_200 (BatchN (None, None, None, 1 576         conv2d_200[0][0]
# __________________________________________________________________________________________________
# batch_normalization_203 (BatchN (None, None, None, 2 768         conv2d_203[0][0]
# __________________________________________________________________________________________________
# activation_249 (Activation)     (None, None, None, 1 0           batch_normalization_200[0][0]
# __________________________________________________________________________________________________
# activation_252 (Activation)     (None, None, None, 2 0           batch_normalization_203[0][0]
# __________________________________________________________________________________________________
# block8_10_mixed (Concatenate)   (None, None, None, 4 0           activation_249[0][0]
#                                                                  activation_252[0][0]
# __________________________________________________________________________________________________
# block8_10_conv (Conv2D)         (None, None, None, 2 933920      block8_10_mixed[0][0]
# __________________________________________________________________________________________________
# block8_10 (Lambda)              (None, None, None, 2 0           block8_9_ac[0][0]
#                                                                  block8_10_conv[0][0]
# __________________________________________________________________________________________________
# conv_7b (Conv2D)                (None, None, None, 1 3194880     block8_10[0][0]
# __________________________________________________________________________________________________
# conv_7b_bn (BatchNormalization) (None, None, None, 1 4608        conv_7b[0][0]
# __________________________________________________________________________________________________
# conv_7b_ac (Activation)         (None, None, None, 1 0           conv_7b_bn[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_4 (Glo (None, 1536)         0           conv_7b_ac[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 128)          196736      global_average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 3)            387         dense_7[0][0]
# ==================================================================================================
# Total params: 54,533,859
# Trainable params: 197,123
# Non-trainable params: 54,336,736
# __________________________________________________________________________________________________

# %%
optimizer = keras.optimizers.Adam()
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=[precision_score, recall_score, f1_score])

# %%
history = model.fit_generator(generator=train_generator, 
                              epochs=qtde_epocas, 
                              validation_steps=5, 
                              steps_per_epoch=5, 
                              validation_data=val_generator)
# Out:
# Epoch 1/50
# 5/5 [==============================] - 29s 6s/step - loss: 1.2119 - precision_score: 0.3848 - recall_score: 0.1625 - f1_score: 0.2047 - val_loss: 471.3936 - val_precision_score: 0.2875 - val_recall_score: 0.2875 - val_f1_score: 0.2875
# Epoch 2/50
# 5/5 [==============================] - 15s 3s/step - loss: 1.0311 - precision_score: 0.5836 - recall_score: 0.3125 - f1_score: 0.3943 - val_loss: 386.5562 - val_precision_score: 0.3187 - val_recall_score: 0.3187 - val_f1_score: 0.3187
# Epoch 3/50
# 5/5 [==============================] - 20s 4s/step - loss: 0.9541 - precision_score: 0.5921 - recall_score: 0.2062 - f1_score: 0.3017 - val_loss: 238.9856 - val_precision_score: 0.3938 - val_recall_score: 0.3938 - val_f1_score: 0.3937
# Epoch 4/50
# 5/5 [==============================] - 15s 3s/step - loss: 0.9168 - precision_score: 0.7569 - recall_score: 0.3063 - f1_score: 0.4350 - val_loss: 67.9465 - val_precision_score: 0.2937 - val_recall_score: 0.2937 - val_f1_score: 0.2937
# Epoch 5/50
# 5/5 [==============================] - 17s 3s/step - loss: 0.9324 - precision_score: 0.6276 - recall_score: 0.3750 - f1_score: 0.4597 - val_loss: 180.8740 - val_precision_score: 0.3063 - val_recall_score: 0.3063 - val_f1_score: 0.3062
# Epoch 6/50
# 5/5 [==============================] - 19s 4s/step - loss: 0.8915 - precision_score: 0.7862 - recall_score: 0.4375 - f1_score: 0.5602 - val_loss: 364.4877 - val_precision_score: 0.3438 - val_recall_score: 0.3438 - val_f1_score: 0.3437
# Epoch 7/50
# 5/5 [==============================] - 15s 3s/step - loss: 0.9068 - precision_score: 0.6757 - recall_score: 0.3938 - f1_score: 0.4952 - val_loss: 193.8365 - val_precision_score: 0.4500 - val_recall_score: 0.4500 - val_f1_score: 0.4500
# Epoch 8/50
# 5/5 [==============================] - 19s 4s/step - loss: 0.7968 - precision_score: 0.7256 - recall_score: 0.4563 - f1_score: 0.5593 - val_loss: 235.7745 - val_precision_score: 0.2761 - val_recall_score: 0.2761 - val_f1_score: 0.2761
# Epoch 9/50
# 5/5 [==============================] - 16s 3s/step - loss: 0.7497 - precision_score: 0.7302 - recall_score: 0.5250 - f1_score: 0.6107 - val_loss: 82.2535 - val_precision_score: 0.3562 - val_recall_score: 0.3562 - val_f1_score: 0.3562
# Epoch 10/50
# 5/5 [==============================] - 15s 3s/step - loss: 0.7171 - precision_score: 0.7693 - recall_score: 0.5063 - f1_score: 0.6097 - val_loss: 354.0364 - val_precision_score: 0.2812 - val_recall_score: 0.2812 - val_f1_score: 0.2812
# Epoch 11/50
# 5/5 [==============================] - 15s 3s/step - loss: 0.8026 - precision_score: 0.7322 - recall_score: 0.5375 - f1_score: 0.6147 - val_loss: 549.0305 - val_precision_score: 0.3438 - val_recall_score: 0.3438 - val_f1_score: 0.3437
# Epoch 12/50
# 5/5 [==============================] - 15s 3s/step - loss: 0.6996 - precision_score: 0.7574 - recall_score: 0.5938 - f1_score: 0.6642 - val_loss: 247.8242 - val_precision_score: 0.3375 - val_recall_score: 0.3375 - val_f1_score: 0.3375
# Epoch 13/50
# 5/5 [==============================] - 20s 4s/step - loss: 0.6602 - precision_score: 0.7509 - recall_score: 0.6000 - f1_score: 0.6669 - val_loss: 78.0650 - val_precision_score: 0.3438 - val_recall_score: 0.3438 - val_f1_score: 0.3437
# Epoch 14/50
# 5/5 [==============================] - 15s 3s/step - loss: 0.6583 - precision_score: 0.7944 - recall_score: 0.5875 - f1_score: 0.6744 - val_loss: 356.3777 - val_precision_score: 0.3562 - val_recall_score: 0.3562 - val_f1_score: 0.3562
# Epoch 15/50
# 5/5 [==============================] - 17s 3s/step - loss: 0.6935 - precision_score: 0.7853 - recall_score: 0.6000 - f1_score: 0.6793 - val_loss: 316.4688 - val_precision_score: 0.3688 - val_recall_score: 0.3688 - val_f1_score: 0.3687
# Epoch 16/50
# 5/5 [==============================] - 15s 3s/step - loss: 0.6491 - precision_score: 0.8173 - recall_score: 0.6438 - f1_score: 0.7200 - val_loss: 274.3455 - val_precision_score: 0.2801 - val_recall_score: 0.2801 - val_f1_score: 0.2801
# Epoch 17/50
# 5/5 [==============================] - 20s 4s/step - loss: 0.6149 - precision_score: 0.7841 - recall_score: 0.6687 - f1_score: 0.7204 - val_loss: 728.6234 - val_precision_score: 0.3125 - val_recall_score: 0.3125 - val_f1_score: 0.3125
# Epoch 18/50
# 5/5 [==============================] - 19s 4s/step - loss: 0.6786 - precision_score: 0.7949 - recall_score: 0.6438 - f1_score: 0.7099 - val_loss: 296.0352 - val_precision_score: 0.3625 - val_recall_score: 0.3625 - val_f1_score: 0.3625
# Epoch 19/50
# 5/5 [==============================] - 20s 4s/step - loss: 0.6629 - precision_score: 0.7676 - recall_score: 0.6625 - f1_score: 0.7104 - val_loss: 105.0033 - val_precision_score: 0.3313 - val_recall_score: 0.3313 - val_f1_score: 0.3312
# Epoch 20/50
# 5/5 [==============================] - 16s 3s/step - loss: 0.7094 - precision_score: 0.7765 - recall_score: 0.6562 - f1_score: 0.7078 - val_loss: 940.9971 - val_precision_score: 0.3438 - val_recall_score: 0.3438 - val_f1_score: 0.3437
# Epoch 21/50
# 5/5 [==============================] - 15s 3s/step - loss: 0.7415 - precision_score: 0.7248 - recall_score: 0.5938 - f1_score: 0.6521 - val_loss: 775.9152 - val_precision_score: 0.3313 - val_recall_score: 0.3313 - val_f1_score: 0.3312
# Epoch 22/50
# 5/5 [==============================] - 16s 3s/step - loss: 0.6897 - precision_score: 0.7060 - recall_score: 0.6125 - f1_score: 0.6552 - val_loss: 355.5152 - val_precision_score: 0.3562 - val_recall_score: 0.3562 - val_f1_score: 0.3562
# Epoch 23/50
# 5/5 [==============================] - 15s 3s/step - loss: 0.7739 - precision_score: 0.7298 - recall_score: 0.6062 - f1_score: 0.6620 - val_loss: 966.2117 - val_precision_score: 0.3097 - val_recall_score: 0.3097 - val_f1_score: 0.3097
# Epoch 24/50
# 5/5 [==============================] - 19s 4s/step - loss: 0.6876 - precision_score: 0.6923 - recall_score: 0.6125 - f1_score: 0.6498 - val_loss: 437.6414 - val_precision_score: 0.3187 - val_recall_score: 0.3187 - val_f1_score: 0.3187
# Epoch 25/50
# 5/5 [==============================] - 15s 3s/step - loss: 0.6333 - precision_score: 0.7755 - recall_score: 0.6438 - f1_score: 0.7029 - val_loss: 259.0667 - val_precision_score: 0.3063 - val_recall_score: 0.3063 - val_f1_score: 0.3062
# Epoch 26/50
# 5/5 [==============================] - 17s 3s/step - loss: 0.6574 - precision_score: 0.7455 - recall_score: 0.6375 - f1_score: 0.6870 - val_loss: 450.1605 - val_precision_score: 0.3875 - val_recall_score: 0.3875 - val_f1_score: 0.3875
# Epoch 27/50
# 5/5 [==============================] - 19s 4s/step - loss: 0.5999 - precision_score: 0.7983 - recall_score: 0.6625 - f1_score: 0.7232 - val_loss: 374.5538 - val_precision_score: 0.3375 - val_recall_score: 0.3375 - val_f1_score: 0.3375
# Epoch 28/50
# 5/5 [==============================] - 17s 3s/step - loss: 0.6594 - precision_score: 0.7766 - recall_score: 0.7000 - f1_score: 0.7354 - val_loss: 911.9233 - val_precision_score: 0.3375 - val_recall_score: 0.3375 - val_f1_score: 0.3375
# Epoch 29/50
# 5/5 [==============================] - 15s 3s/step - loss: 0.6507 - precision_score: 0.7391 - recall_score: 0.6250 - f1_score: 0.6766 - val_loss: 395.0314 - val_precision_score: 0.3938 - val_recall_score: 0.3938 - val_f1_score: 0.3937
# Epoch 30/50
# 5/5 [==============================] - 16s 3s/step - loss: 0.6726 - precision_score: 0.7758 - recall_score: 0.6875 - f1_score: 0.7288 - val_loss: 397.5769 - val_precision_score: 0.2812 - val_recall_score: 0.2812 - val_f1_score: 0.2812
# Epoch 31/50
# 5/5 [==============================] - 15s 3s/step - loss: 0.6818 - precision_score: 0.7373 - recall_score: 0.6313 - f1_score: 0.6794 - val_loss: 675.1806 - val_precision_score: 0.3199 - val_recall_score: 0.3199 - val_f1_score: 0.3199
# Epoch 32/50
# 5/5 [==============================] - 20s 4s/step - loss: 0.5871 - precision_score: 0.7929 - recall_score: 0.6812 - f1_score: 0.7317 - val_loss: 330.5691 - val_precision_score: 0.3187 - val_recall_score: 0.3187 - val_f1_score: 0.3187
# Epoch 33/50
# 5/5 [==============================] - 15s 3s/step - loss: 0.5039 - precision_score: 0.8261 - recall_score: 0.7688 - f1_score: 0.7956 - val_loss: 358.2537 - val_precision_score: 0.3125 - val_recall_score: 0.3125 - val_f1_score: 0.3125
# Epoch 34/50
# 5/5 [==============================] - 19s 4s/step - loss: 0.6647 - precision_score: 0.7654 - recall_score: 0.6562 - f1_score: 0.7058 - val_loss: 890.7681 - val_precision_score: 0.3250 - val_recall_score: 0.3250 - val_f1_score: 0.3250
# Epoch 35/50
# 5/5 [==============================] - 15s 3s/step - loss: 0.6362 - precision_score: 0.7736 - recall_score: 0.6812 - f1_score: 0.7241 - val_loss: 390.7968 - val_precision_score: 0.3812 - val_recall_score: 0.3812 - val_f1_score: 0.3812
# Epoch 36/50
# 5/5 [==============================] - 20s 4s/step - loss: 0.5349 - precision_score: 0.7965 - recall_score: 0.7125 - f1_score: 0.7517 - val_loss: 826.2009 - val_precision_score: 0.3750 - val_recall_score: 0.3750 - val_f1_score: 0.3750
# Epoch 37/50
# 5/5 [==============================] - 19s 4s/step - loss: 0.7007 - precision_score: 0.7137 - recall_score: 0.6438 - f1_score: 0.6759 - val_loss: 479.9520 - val_precision_score: 0.3375 - val_recall_score: 0.3375 - val_f1_score: 0.3375
# Epoch 38/50
# 5/5 [==============================] - 18s 4s/step - loss: 0.6294 - precision_score: 0.7964 - recall_score: 0.7375 - f1_score: 0.7651 - val_loss: 551.4437 - val_precision_score: 0.3386 - val_recall_score: 0.3386 - val_f1_score: 0.3386
# Epoch 39/50
# 5/5 [==============================] - 15s 3s/step - loss: 0.5836 - precision_score: 0.7812 - recall_score: 0.6562 - f1_score: 0.7111 - val_loss: 739.0226 - val_precision_score: 0.3375 - val_recall_score: 0.3375 - val_f1_score: 0.3375
# Epoch 40/50
# 5/5 [==============================] - 17s 3s/step - loss: 0.5432 - precision_score: 0.7964 - recall_score: 0.6938 - f1_score: 0.7409 - val_loss: 678.3279 - val_precision_score: 0.3125 - val_recall_score: 0.3125 - val_f1_score: 0.3125
# Epoch 41/50
# 5/5 [==============================] - 18s 4s/step - loss: 0.6060 - precision_score: 0.7866 - recall_score: 0.7125 - f1_score: 0.7476 - val_loss: 944.5555 - val_precision_score: 0.3500 - val_recall_score: 0.3500 - val_f1_score: 0.3500
# Epoch 42/50
# 5/5 [==============================] - 15s 3s/step - loss: 0.6115 - precision_score: 0.8061 - recall_score: 0.7188 - f1_score: 0.7587 - val_loss: 290.2728 - val_precision_score: 0.3625 - val_recall_score: 0.3625 - val_f1_score: 0.3625
# Epoch 43/50
# 5/5 [==============================] - 17s 3s/step - loss: 0.5525 - precision_score: 0.8176 - recall_score: 0.7563 - f1_score: 0.7856 - val_loss: 578.5908 - val_precision_score: 0.3063 - val_recall_score: 0.3063 - val_f1_score: 0.3062
# Epoch 44/50
# 5/5 [==============================] - 15s 3s/step - loss: 0.5653 - precision_score: 0.7748 - recall_score: 0.7063 - f1_score: 0.7374 - val_loss: 986.8173 - val_precision_score: 0.2937 - val_recall_score: 0.2937 - val_f1_score: 0.2937
# Epoch 45/50
# 5/5 [==============================] - 19s 4s/step - loss: 0.5942 - precision_score: 0.7778 - recall_score: 0.6875 - f1_score: 0.7295 - val_loss: 588.2649 - val_precision_score: 0.3688 - val_recall_score: 0.3688 - val_f1_score: 0.3687
# Epoch 46/50
# 5/5 [==============================] - 15s 3s/step - loss: 0.5939 - precision_score: 0.7843 - recall_score: 0.7125 - f1_score: 0.7460 - val_loss: 529.5155 - val_precision_score: 0.3108 - val_recall_score: 0.3108 - val_f1_score: 0.3108
# Epoch 47/50
# 5/5 [==============================] - 20s 4s/step - loss: 0.5050 - precision_score: 0.8387 - recall_score: 0.7437 - f1_score: 0.7879 - val_loss: 561.6018 - val_precision_score: 0.3375 - val_recall_score: 0.3375 - val_f1_score: 0.3375
# Epoch 48/50
# 5/5 [==============================] - 16s 3s/step - loss: 0.6729 - precision_score: 0.7842 - recall_score: 0.6438 - f1_score: 0.6965 - val_loss: 1507.8262 - val_precision_score: 0.3375 - val_recall_score: 0.3375 - val_f1_score: 0.3375
# Epoch 49/50
# 5/5 [==============================] - 15s 3s/step - loss: 0.7258 - precision_score: 0.6966 - recall_score: 0.6625 - f1_score: 0.6789 - val_loss: 234.9218 - val_precision_score: 0.3125 - val_recall_score: 0.3125 - val_f1_score: 0.3125
# Epoch 50/50
# 5/5 [==============================] - 19s 4s/step - loss: 0.7227 - precision_score: 0.7381 - recall_score: 0.6750 - f1_score: 0.7047 - val_loss: 664.8501 - val_precision_score: 0.2812 - val_recall_score: 0.2812 - val_f1_score: 0.2812

# %%
# Exibindo dados de Precisão
plt.plot(history.history['precision_score'])
plt.plot(history.history['val_precision_score'])
plt.title('model precision')
plt.ylabel('precision')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de Sensibilidade
plt.plot(history.history['recall_score'])
plt.plot(history.history['val_recall_score'])
plt.title('model recall')
plt.ylabel('recall')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de F1 Score
plt.plot(history.history['f1_score'])
plt.plot(history.history['val_f1_score'])
plt.title('model f1_score')
plt.ylabel('f1_score')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de Perda
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
from keras.applications import InceptionV3
from keras.applications import ResNet50V2
from keras.applications import ResNet152V2

# %%
conv_base = conv_base = InceptionV3(include_top=False)

for layer in conv_base.layers:
    layer.trainable = False

x = conv_base.output
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(128, activation='relu')(x) 

predictions = layers.Dense(qtde_classes, activation='softmax')(x)
model = Model(conv_base.input, predictions)

model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, None, None, 3 0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, None, None, 3 864         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, None, None, 3 96          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, None, None, 3 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, None, None, 3 9216        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, None, None, 3 96          conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, None, None, 3 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, None, None, 6 18432       activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, None, None, 6 192         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, None, None, 6 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, None, None, 6 0           activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, None, None, 8 5120        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, None, None, 8 240         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, None, None, 8 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, None, None, 1 138240      activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, None, None, 1 576         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, None, None, 1 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, None, None, 1 0           activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, None, None, 6 12288       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, None, None, 6 192         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, None, None, 6 0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, None, None, 4 9216        max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, None, None, 9 55296       activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, None, None, 4 144         conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, None, None, 9 288         conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, None, None, 4 0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, None, None, 9 0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, None, None, 1 0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, None, None, 6 12288       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, None, None, 6 76800       activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, None, None, 9 82944       activation_10[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, None, None, 3 6144        average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, None, None, 6 192         conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, None, None, 6 192         conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, None, None, 9 288         conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, None, None, 3 96          conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, None, None, 6 0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, None, None, 6 0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, None, None, 9 0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, None, None, 3 0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# mixed0 (Concatenate)            (None, None, None, 2 0           activation_6[0][0]
#                                                                  activation_8[0][0]
#                                                                  activation_11[0][0]
#                                                                  activation_12[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, None, None, 6 16384       mixed0[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, None, None, 6 192         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, None, None, 6 0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, None, None, 4 12288       mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, None, None, 9 55296       activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, None, None, 4 144         conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, None, None, 9 288         conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, None, None, 4 0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, None, None, 9 0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, None, None, 2 0           mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, None, None, 6 16384       mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, None, None, 6 76800       activation_14[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, None, None, 9 82944       activation_17[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, None, None, 6 16384       average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, None, None, 6 192         conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, None, None, 6 192         conv2d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, None, None, 9 288         conv2d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, None, None, 6 192         conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, None, None, 6 0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, None, None, 6 0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, None, None, 9 0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, None, None, 6 0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# mixed1 (Concatenate)            (None, None, None, 2 0           activation_13[0][0]
#                                                                  activation_15[0][0]
#                                                                  activation_18[0][0]
#                                                                  activation_19[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, None, None, 6 18432       mixed1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, None, None, 6 192         conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, None, None, 6 0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, None, None, 4 13824       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, None, None, 9 55296       activation_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, None, None, 4 144         conv2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, None, None, 9 288         conv2d_24[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, None, None, 4 0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, None, None, 9 0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_3 (AveragePoo (None, None, None, 2 0           mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, None, None, 6 18432       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, None, None, 6 76800       activation_21[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, None, None, 9 82944       activation_24[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, None, None, 6 18432       average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, None, None, 6 192         conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, None, None, 6 192         conv2d_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, None, None, 9 288         conv2d_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, None, None, 6 192         conv2d_26[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, None, None, 6 0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, None, None, 6 0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, None, None, 9 0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, None, None, 6 0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# mixed2 (Concatenate)            (None, None, None, 2 0           activation_20[0][0]
#                                                                  activation_22[0][0]
#                                                                  activation_25[0][0]
#                                                                  activation_26[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, None, None, 6 18432       mixed2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, None, None, 6 192         conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, None, None, 6 0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, None, None, 9 55296       activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, None, None, 9 288         conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, None, None, 9 0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, None, None, 3 995328      mixed2[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, None, None, 9 82944       activation_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, None, None, 3 1152        conv2d_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, None, None, 9 288         conv2d_30[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, None, None, 3 0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, None, None, 9 0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, None, None, 2 0           mixed2[0][0]
# __________________________________________________________________________________________________
# mixed3 (Concatenate)            (None, None, None, 7 0           activation_27[0][0]
#                                                                  activation_30[0][0]
#                                                                  max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, None, None, 1 98304       mixed3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, None, None, 1 384         conv2d_35[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, None, None, 1 0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, None, None, 1 114688      activation_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, None, None, 1 384         conv2d_36[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, None, None, 1 0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, None, None, 1 98304       mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, None, None, 1 114688      activation_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, None, None, 1 384         conv2d_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, None, None, 1 384         conv2d_37[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, None, None, 1 0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, None, None, 1 0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, None, None, 1 114688      activation_32[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, None, None, 1 114688      activation_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, None, None, 1 384         conv2d_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, None, None, 1 384         conv2d_38[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, None, None, 1 0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, None, None, 1 0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_4 (AveragePoo (None, None, None, 7 0           mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, None, None, 1 147456      mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, None, None, 1 172032      activation_33[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, None, None, 1 172032      activation_38[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, None, None, 1 147456      average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, None, None, 1 576         conv2d_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, None, None, 1 576         conv2d_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, None, None, 1 576         conv2d_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, None, None, 1 576         conv2d_40[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, None, None, 1 0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, None, None, 1 0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, None, None, 1 0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, None, None, 1 0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# mixed4 (Concatenate)            (None, None, None, 7 0           activation_31[0][0]
#                                                                  activation_34[0][0]
#                                                                  activation_39[0][0]
#                                                                  activation_40[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, None, None, 1 122880      mixed4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, None, None, 1 480         conv2d_45[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, None, None, 1 0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, None, None, 1 179200      activation_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, None, None, 1 480         conv2d_46[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, None, None, 1 0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, None, None, 1 122880      mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, None, None, 1 179200      activation_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, None, None, 1 480         conv2d_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, None, None, 1 480         conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, None, None, 1 0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, None, None, 1 0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, None, None, 1 179200      activation_42[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, None, None, 1 179200      activation_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, None, None, 1 480         conv2d_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, None, None, 1 480         conv2d_48[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, None, None, 1 0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, None, None, 1 0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_5 (AveragePoo (None, None, None, 7 0           mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, None, None, 1 147456      mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, None, None, 1 215040      activation_43[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, None, None, 1 215040      activation_48[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, None, None, 1 147456      average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, None, None, 1 576         conv2d_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, None, None, 1 576         conv2d_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, None, None, 1 576         conv2d_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, None, None, 1 576         conv2d_50[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, None, None, 1 0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, None, None, 1 0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, None, None, 1 0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, None, None, 1 0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# mixed5 (Concatenate)            (None, None, None, 7 0           activation_41[0][0]
#                                                                  activation_44[0][0]
#                                                                  activation_49[0][0]
#                                                                  activation_50[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, None, None, 1 122880      mixed5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, None, None, 1 480         conv2d_55[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, None, None, 1 0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, None, None, 1 179200      activation_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, None, None, 1 480         conv2d_56[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, None, None, 1 0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, None, None, 1 122880      mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, None, None, 1 179200      activation_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, None, None, 1 480         conv2d_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, None, None, 1 480         conv2d_57[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, None, None, 1 0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, None, None, 1 0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, None, None, 1 179200      activation_52[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, None, None, 1 179200      activation_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, None, None, 1 480         conv2d_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, None, None, 1 480         conv2d_58[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, None, None, 1 0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, None, None, 1 0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_6 (AveragePoo (None, None, None, 7 0           mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, None, None, 1 147456      mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, None, None, 1 215040      activation_53[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, None, None, 1 215040      activation_58[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, None, None, 1 147456      average_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, None, None, 1 576         conv2d_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, None, None, 1 576         conv2d_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, None, None, 1 576         conv2d_59[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, None, None, 1 576         conv2d_60[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, None, None, 1 0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, None, None, 1 0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, None, None, 1 0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, None, None, 1 0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# mixed6 (Concatenate)            (None, None, None, 7 0           activation_51[0][0]
#                                                                  activation_54[0][0]
#                                                                  activation_59[0][0]
#                                                                  activation_60[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, None, None, 1 147456      mixed6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, None, None, 1 576         conv2d_65[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, None, None, 1 0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, None, None, 1 258048      activation_65[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, None, None, 1 576         conv2d_66[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, None, None, 1 0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, None, None, 1 147456      mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, None, None, 1 258048      activation_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, None, None, 1 576         conv2d_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, None, None, 1 576         conv2d_67[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, None, None, 1 0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, None, None, 1 0           batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, None, None, 1 258048      activation_62[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, None, None, 1 258048      activation_67[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, None, None, 1 576         conv2d_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, None, None, 1 576         conv2d_68[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, None, None, 1 0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, None, None, 1 0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_7 (AveragePoo (None, None, None, 7 0           mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, None, None, 1 147456      mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, None, None, 1 258048      activation_63[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, None, None, 1 258048      activation_68[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, None, None, 1 147456      average_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, None, None, 1 576         conv2d_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, None, None, 1 576         conv2d_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, None, None, 1 576         conv2d_69[0][0]
# __________________________________________________________________________________________________
# batch_normalization_70 (BatchNo (None, None, None, 1 576         conv2d_70[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, None, None, 1 0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, None, None, 1 0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, None, None, 1 0           batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, None, None, 1 0           batch_normalization_70[0][0]
# __________________________________________________________________________________________________
# mixed7 (Concatenate)            (None, None, None, 7 0           activation_61[0][0]
#                                                                  activation_64[0][0]
#                                                                  activation_69[0][0]
#                                                                  activation_70[0][0]
# __________________________________________________________________________________________________
# ...
# __________________________________________________________________________________________________
# conv2d_72 (Conv2D)              (None, None, None, 3 552960      activation_71[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, None, None, 1 331776      activation_75[0][0]
# __________________________________________________________________________________________________
# batch_normalization_72 (BatchNo (None, None, None, 3 960         conv2d_72[0][0]
# __________________________________________________________________________________________________
# batch_normalization_76 (BatchNo (None, None, None, 1 576         conv2d_76[0][0]
# __________________________________________________________________________________________________
# activation_72 (Activation)      (None, None, None, 3 0           batch_normalization_72[0][0]
# __________________________________________________________________________________________________
# activation_76 (Activation)      (None, None, None, 1 0           batch_normalization_76[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, None, None, 7 0           mixed7[0][0]
# __________________________________________________________________________________________________
# mixed8 (Concatenate)            (None, None, None, 1 0           activation_72[0][0]
#                                                                  activation_76[0][0]
#                                                                  max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, None, None, 4 573440      mixed8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_81 (BatchNo (None, None, None, 4 1344        conv2d_81[0][0]
# __________________________________________________________________________________________________
# activation_81 (Activation)      (None, None, None, 4 0           batch_normalization_81[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, None, None, 3 491520      mixed8[0][0]
# __________________________________________________________________________________________________
# conv2d_82 (Conv2D)              (None, None, None, 3 1548288     activation_81[0][0]
# __________________________________________________________________________________________________
# batch_normalization_78 (BatchNo (None, None, None, 3 1152        conv2d_78[0][0]
# __________________________________________________________________________________________________
# batch_normalization_82 (BatchNo (None, None, None, 3 1152        conv2d_82[0][0]
# __________________________________________________________________________________________________
# activation_78 (Activation)      (None, None, None, 3 0           batch_normalization_78[0][0]
# __________________________________________________________________________________________________
# activation_82 (Activation)      (None, None, None, 3 0           batch_normalization_82[0][0]
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, None, None, 3 442368      activation_78[0][0]
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, None, None, 3 442368      activation_78[0][0]
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, None, None, 3 442368      activation_82[0][0]
# __________________________________________________________________________________________________
# conv2d_84 (Conv2D)              (None, None, None, 3 442368      activation_82[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_8 (AveragePoo (None, None, None, 1 0           mixed8[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, None, None, 3 409600      mixed8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_79 (BatchNo (None, None, None, 3 1152        conv2d_79[0][0]
# __________________________________________________________________________________________________
# batch_normalization_80 (BatchNo (None, None, None, 3 1152        conv2d_80[0][0]
# __________________________________________________________________________________________________
# batch_normalization_83 (BatchNo (None, None, None, 3 1152        conv2d_83[0][0]
# __________________________________________________________________________________________________
# batch_normalization_84 (BatchNo (None, None, None, 3 1152        conv2d_84[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, None, None, 1 245760      average_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_77 (BatchNo (None, None, None, 3 960         conv2d_77[0][0]
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, None, None, 3 0           batch_normalization_79[0][0]
# __________________________________________________________________________________________________
# activation_80 (Activation)      (None, None, None, 3 0           batch_normalization_80[0][0]
# __________________________________________________________________________________________________
# activation_83 (Activation)      (None, None, None, 3 0           batch_normalization_83[0][0]
# __________________________________________________________________________________________________
# activation_84 (Activation)      (None, None, None, 3 0           batch_normalization_84[0][0]
# __________________________________________________________________________________________________
# batch_normalization_85 (BatchNo (None, None, None, 1 576         conv2d_85[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, None, None, 3 0           batch_normalization_77[0][0]
# __________________________________________________________________________________________________
# mixed9_0 (Concatenate)          (None, None, None, 7 0           activation_79[0][0]
#                                                                  activation_80[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, None, None, 7 0           activation_83[0][0]
#                                                                  activation_84[0][0]
# __________________________________________________________________________________________________
# activation_85 (Activation)      (None, None, None, 1 0           batch_normalization_85[0][0]
# __________________________________________________________________________________________________
# mixed9 (Concatenate)            (None, None, None, 2 0           activation_77[0][0]
#                                                                  mixed9_0[0][0]
#                                                                  concatenate_1[0][0]
#                                                                  activation_85[0][0]
# __________________________________________________________________________________________________
# conv2d_90 (Conv2D)              (None, None, None, 4 917504      mixed9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_90 (BatchNo (None, None, None, 4 1344        conv2d_90[0][0]
# __________________________________________________________________________________________________
# activation_90 (Activation)      (None, None, None, 4 0           batch_normalization_90[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, None, None, 3 786432      mixed9[0][0]
# __________________________________________________________________________________________________
# conv2d_91 (Conv2D)              (None, None, None, 3 1548288     activation_90[0][0]
# __________________________________________________________________________________________________
# batch_normalization_87 (BatchNo (None, None, None, 3 1152        conv2d_87[0][0]
# __________________________________________________________________________________________________
# batch_normalization_91 (BatchNo (None, None, None, 3 1152        conv2d_91[0][0]
# __________________________________________________________________________________________________
# activation_87 (Activation)      (None, None, None, 3 0           batch_normalization_87[0][0]
# __________________________________________________________________________________________________
# activation_91 (Activation)      (None, None, None, 3 0           batch_normalization_91[0][0]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, None, None, 3 442368      activation_87[0][0]
# __________________________________________________________________________________________________
# conv2d_89 (Conv2D)              (None, None, None, 3 442368      activation_87[0][0]
# __________________________________________________________________________________________________
# conv2d_92 (Conv2D)              (None, None, None, 3 442368      activation_91[0][0]
# __________________________________________________________________________________________________
# conv2d_93 (Conv2D)              (None, None, None, 3 442368      activation_91[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_9 (AveragePoo (None, None, None, 2 0           mixed9[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, None, None, 3 655360      mixed9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_88 (BatchNo (None, None, None, 3 1152        conv2d_88[0][0]
# __________________________________________________________________________________________________
# batch_normalization_89 (BatchNo (None, None, None, 3 1152        conv2d_89[0][0]
# __________________________________________________________________________________________________
# batch_normalization_92 (BatchNo (None, None, None, 3 1152        conv2d_92[0][0]
# __________________________________________________________________________________________________
# batch_normalization_93 (BatchNo (None, None, None, 3 1152        conv2d_93[0][0]
# __________________________________________________________________________________________________
# conv2d_94 (Conv2D)              (None, None, None, 1 393216      average_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_86 (BatchNo (None, None, None, 3 960         conv2d_86[0][0]
# __________________________________________________________________________________________________
# activation_88 (Activation)      (None, None, None, 3 0           batch_normalization_88[0][0]
# __________________________________________________________________________________________________
# activation_89 (Activation)      (None, None, None, 3 0           batch_normalization_89[0][0]
# __________________________________________________________________________________________________
# activation_92 (Activation)      (None, None, None, 3 0           batch_normalization_92[0][0]
# __________________________________________________________________________________________________
# activation_93 (Activation)      (None, None, None, 3 0           batch_normalization_93[0][0]
# __________________________________________________________________________________________________
# batch_normalization_94 (BatchNo (None, None, None, 1 576         conv2d_94[0][0]
# __________________________________________________________________________________________________
# activation_86 (Activation)      (None, None, None, 3 0           batch_normalization_86[0][0]
# __________________________________________________________________________________________________
# mixed9_1 (Concatenate)          (None, None, None, 7 0           activation_88[0][0]
#                                                                  activation_89[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, None, None, 7 0           activation_92[0][0]
#                                                                  activation_93[0][0]
# __________________________________________________________________________________________________
# activation_94 (Activation)      (None, None, None, 1 0           batch_normalization_94[0][0]
# __________________________________________________________________________________________________
# mixed10 (Concatenate)           (None, None, None, 2 0           activation_86[0][0]
#                                                                  mixed9_1[0][0]
#                                                                  concatenate_2[0][0]
#                                                                  activation_94[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 2048)         0           mixed10[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          262272      global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 3)            387         dense_1[0][0]
# ==================================================================================================
# Total params: 22,065,443
# Trainable params: 262,659
# Non-trainable params: 21,802,784
# __________________________________________________________________________________________________

# %%
optimizer = keras.optimizers.Adam()
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=[precision_score, recall_score, f1_score])

history = model.fit_generator(generator=train_generator, 
                              epochs=qtde_epocas, 
                              validation_steps=5, 
                              steps_per_epoch=5, 
                              validation_data=val_generator)
# Out:
# Epoch 1/50
# 5/5 [==============================] - 39s 8s/step - loss: 1.2012 - precision_score: 0.4459 - recall_score: 0.2438 - f1_score: 0.3013 - val_loss: 39.2109 - val_precision_score: 0.3125 - val_recall_score: 0.3125 - val_f1_score: 0.3125
# Epoch 2/50
# 5/5 [==============================] - 7s 1s/step - loss: 1.0426 - precision_score: 0.5810 - recall_score: 0.2500 - f1_score: 0.3400 - val_loss: 5.7350 - val_precision_score: 0.3411 - val_recall_score: 0.3375 - val_f1_score: 0.3393
# Epoch 3/50
# 5/5 [==============================] - 7s 1s/step - loss: 0.9806 - precision_score: 0.6489 - recall_score: 0.3438 - f1_score: 0.4363 - val_loss: 18.3124 - val_precision_score: 0.3187 - val_recall_score: 0.3187 - val_f1_score: 0.3187
# Epoch 4/50
# 5/5 [==============================] - 12s 2s/step - loss: 0.8367 - precision_score: 0.7474 - recall_score: 0.4625 - f1_score: 0.5692 - val_loss: 11.0666 - val_precision_score: 0.3313 - val_recall_score: 0.3313 - val_f1_score: 0.3312
# Epoch 5/50
# 5/5 [==============================] - 13s 3s/step - loss: 0.9398 - precision_score: 0.6117 - recall_score: 0.4625 - f1_score: 0.5251 - val_loss: 24.4574 - val_precision_score: 0.2688 - val_recall_score: 0.2688 - val_f1_score: 0.2687
# Epoch 6/50
# 5/5 [==============================] - 7s 1s/step - loss: 0.7814 - precision_score: 0.7854 - recall_score: 0.5375 - f1_score: 0.6370 - val_loss: 14.3245 - val_precision_score: 0.3187 - val_recall_score: 0.3187 - val_f1_score: 0.3187
# Epoch 7/50
# 5/5 [==============================] - 12s 2s/step - loss: 0.7784 - precision_score: 0.6886 - recall_score: 0.5063 - f1_score: 0.5833 - val_loss: 81.0440 - val_precision_score: 0.3000 - val_recall_score: 0.3000 - val_f1_score: 0.3000
# Epoch 8/50
# 5/5 [==============================] - 18s 4s/step - loss: 0.8473 - precision_score: 0.6605 - recall_score: 0.5375 - f1_score: 0.5919 - val_loss: 14.7602 - val_precision_score: 0.2148 - val_recall_score: 0.2148 - val_f1_score: 0.2148
# Epoch 9/50
# 5/5 [==============================] - 13s 3s/step - loss: 0.8899 - precision_score: 0.7014 - recall_score: 0.5312 - f1_score: 0.6042 - val_loss: 66.4515 - val_precision_score: 0.3250 - val_recall_score: 0.3250 - val_f1_score: 0.3250
# Epoch 10/50
# 5/5 [==============================] - 13s 3s/step - loss: 0.7615 - precision_score: 0.7030 - recall_score: 0.5625 - f1_score: 0.6241 - val_loss: 62.8649 - val_precision_score: 0.3313 - val_recall_score: 0.3313 - val_f1_score: 0.3312
# Epoch 11/50
# 5/5 [==============================] - 13s 3s/step - loss: 0.7794 - precision_score: 0.7548 - recall_score: 0.6313 - f1_score: 0.6860 - val_loss: 25.9488 - val_precision_score: 0.3750 - val_recall_score: 0.3750 - val_f1_score: 0.3750
# Epoch 12/50
# 5/5 [==============================] - 13s 3s/step - loss: 0.6987 - precision_score: 0.7651 - recall_score: 0.6187 - f1_score: 0.6835 - val_loss: 79.9711 - val_precision_score: 0.3438 - val_recall_score: 0.3438 - val_f1_score: 0.3437
# Epoch 13/50
# 5/5 [==============================] - 13s 3s/step - loss: 0.9117 - precision_score: 0.6276 - recall_score: 0.5000 - f1_score: 0.5560 - val_loss: 40.7078 - val_precision_score: 0.3375 - val_recall_score: 0.3375 - val_f1_score: 0.3375
# Epoch 14/50
# 5/5 [==============================] - 13s 3s/step - loss: 0.9207 - precision_score: 0.6418 - recall_score: 0.5500 - f1_score: 0.5916 - val_loss: 63.9025 - val_precision_score: 0.3375 - val_recall_score: 0.3375 - val_f1_score: 0.3375
# Epoch 15/50
# 5/5 [==============================] - 13s 3s/step - loss: 0.8227 - precision_score: 0.6223 - recall_score: 0.5312 - f1_score: 0.5718 - val_loss: 68.7675 - val_precision_score: 0.3000 - val_recall_score: 0.3000 - val_f1_score: 0.3000
# Epoch 16/50
# 5/5 [==============================] - 13s 3s/step - loss: 0.7009 - precision_score: 0.7874 - recall_score: 0.6750 - f1_score: 0.7264 - val_loss: 30.5794 - val_precision_score: 0.3080 - val_recall_score: 0.3080 - val_f1_score: 0.3080
# Epoch 17/50
# 5/5 [==============================] - 16s 3s/step - loss: 0.6711 - precision_score: 0.8015 - recall_score: 0.7125 - f1_score: 0.7522 - val_loss: 55.0029 - val_precision_score: 0.3313 - val_recall_score: 0.3313 - val_f1_score: 0.3312
# Epoch 18/50
# 5/5 [==============================] - 13s 3s/step - loss: 0.6558 - precision_score: 0.7274 - recall_score: 0.6687 - f1_score: 0.6968 - val_loss: 37.6807 - val_precision_score: 0.3063 - val_recall_score: 0.3063 - val_f1_score: 0.3062
# Epoch 19/50
# 5/5 [==============================] - 13s 3s/step - loss: 0.6097 - precision_score: 0.8080 - recall_score: 0.7250 - f1_score: 0.7637 - val_loss: 24.4369 - val_precision_score: 0.4000 - val_recall_score: 0.4000 - val_f1_score: 0.4000
# Epoch 20/50
# 5/5 [==============================] - 13s 3s/step - loss: 0.5709 - precision_score: 0.8409 - recall_score: 0.7375 - f1_score: 0.7853 - val_loss: 56.9621 - val_precision_score: 0.2562 - val_recall_score: 0.2562 - val_f1_score: 0.2562
# Epoch 21/50
# 5/5 [==============================] - 13s 3s/step - loss: 0.5475 - precision_score: 0.7957 - recall_score: 0.7063 - f1_score: 0.7477 - val_loss: 39.3944 - val_precision_score: 0.3500 - val_recall_score: 0.3500 - val_f1_score: 0.3500
# Epoch 22/50
# 5/5 [==============================] - 13s 3s/step - loss: 0.5876 - precision_score: 0.8209 - recall_score: 0.7312 - f1_score: 0.7721 - val_loss: 58.5201 - val_precision_score: 0.3500 - val_recall_score: 0.3500 - val_f1_score: 0.3500
# Epoch 23/50
# 5/5 [==============================] - 21s 4s/step - loss: 0.6926 - precision_score: 0.7553 - recall_score: 0.6562 - f1_score: 0.7017 - val_loss: 41.3810 - val_precision_score: 0.3165 - val_recall_score: 0.3165 - val_f1_score: 0.3165
# Epoch 24/50
# 5/5 [==============================] - 17s 3s/step - loss: 0.6370 - precision_score: 0.8095 - recall_score: 0.7188 - f1_score: 0.7597 - val_loss: 41.6729 - val_precision_score: 0.3313 - val_recall_score: 0.3313 - val_f1_score: 0.3312
# Epoch 25/50
# 5/5 [==============================] - 13s 3s/step - loss: 0.6371 - precision_score: 0.7539 - recall_score: 0.6812 - f1_score: 0.7154 - val_loss: 53.0853 - val_precision_score: 0.3375 - val_recall_score: 0.3375 - val_f1_score: 0.3375
# Epoch 26/50
# 5/5 [==============================] - 13s 3s/step - loss: 0.6339 - precision_score: 0.8436 - recall_score: 0.7063 - f1_score: 0.7683 - val_loss: 49.6913 - val_precision_score: 0.3250 - val_recall_score: 0.3250 - val_f1_score: 0.3250
# Epoch 27/50
# 5/5 [==============================] - 13s 3s/step - loss: 0.5962 - precision_score: 0.7532 - recall_score: 0.6687 - f1_score: 0.7082 - val_loss: 38.9989 - val_precision_score: 0.3000 - val_recall_score: 0.3000 - val_f1_score: 0.3000
# Epoch 28/50
# 5/5 [==============================] - 13s 3s/step - loss: 0.5495 - precision_score: 0.8556 - recall_score: 0.7750 - f1_score: 0.8132 - val_loss: 43.6974 - val_precision_score: 0.3125 - val_recall_score: 0.3125 - val_f1_score: 0.3125
# Epoch 29/50
# 5/5 [==============================] - 15s 3s/step - loss: 0.5942 - precision_score: 0.7792 - recall_score: 0.7125 - f1_score: 0.7435 - val_loss: 39.6622 - val_precision_score: 0.3562 - val_recall_score: 0.3562 - val_f1_score: 0.3562
# Epoch 30/50
# 5/5 [==============================] - 23s 5s/step - loss: 0.6135 - precision_score: 0.7710 - recall_score: 0.6938 - f1_score: 0.7301 - val_loss: 29.0840 - val_precision_score: 0.3562 - val_recall_score: 0.3562 - val_f1_score: 0.3562
# Epoch 31/50
# 5/5 [==============================] - 13s 3s/step - loss: 0.5758 - precision_score: 0.8157 - recall_score: 0.7500 - f1_score: 0.7812 - val_loss: 52.1288 - val_precision_score: 0.3386 - val_recall_score: 0.3386 - val_f1_score: 0.3386
# Epoch 32/50
# 5/5 [==============================] - 21s 4s/step - loss: 0.6403 - precision_score: 0.7647 - recall_score: 0.6875 - f1_score: 0.7239 - val_loss: 18.3136 - val_precision_score: 0.2812 - val_recall_score: 0.2812 - val_f1_score: 0.2812
# Epoch 33/50
# 5/5 [==============================] - 13s 3s/step - loss: 0.5816 - precision_score: 0.8001 - recall_score: 0.7188 - f1_score: 0.7561 - val_loss: 58.0457 - val_precision_score: 0.3063 - val_recall_score: 0.3063 - val_f1_score: 0.3062
# Epoch 34/50
# 5/5 [==============================] - 19s 4s/step - loss: 0.7385 - precision_score: 0.6955 - recall_score: 0.6313 - f1_score: 0.6614 - val_loss: 13.1456 - val_precision_score: 0.2600 - val_recall_score: 0.2562 - val_f1_score: 0.2581
# Epoch 35/50
# 5/5 [==============================] - 12s 2s/step - loss: 0.8257 - precision_score: 0.6638 - recall_score: 0.5938 - f1_score: 0.6261 - val_loss: 49.0911 - val_precision_score: 0.3438 - val_recall_score: 0.3438 - val_f1_score: 0.3437
# Epoch 36/50
# 5/5 [==============================] - 13s 3s/step - loss: 0.7230 - precision_score: 0.7711 - recall_score: 0.6750 - f1_score: 0.7184 - val_loss: 32.2049 - val_precision_score: 0.3125 - val_recall_score: 0.3125 - val_f1_score: 0.3125
# Epoch 37/50
# 5/5 [==============================] - 21s 4s/step - loss: 0.7347 - precision_score: 0.6905 - recall_score: 0.6438 - f1_score: 0.6660 - val_loss: 52.3716 - val_precision_score: 0.3750 - val_recall_score: 0.3750 - val_f1_score: 0.3750
# Epoch 38/50
# 5/5 [==============================] - 13s 3s/step - loss: 0.6640 - precision_score: 0.7884 - recall_score: 0.7250 - f1_score: 0.7552 - val_loss: 17.4677 - val_precision_score: 0.2795 - val_recall_score: 0.2795 - val_f1_score: 0.2795
# Epoch 39/50
# 5/5 [==============================] - 13s 3s/step - loss: 0.4861 - precision_score: 0.8572 - recall_score: 0.7937 - f1_score: 0.8234 - val_loss: 23.8579 - val_precision_score: 0.3000 - val_recall_score: 0.3000 - val_f1_score: 0.3000
# Epoch 40/50
# 5/5 [==============================] - 22s 4s/step - loss: 0.4997 - precision_score: 0.8113 - recall_score: 0.7312 - f1_score: 0.7689 - val_loss: 64.7417 - val_precision_score: 0.3500 - val_recall_score: 0.3500 - val_f1_score: 0.3500
# Epoch 41/50
# 5/5 [==============================] - 13s 3s/step - loss: 0.5191 - precision_score: 0.8409 - recall_score: 0.7375 - f1_score: 0.7853 - val_loss: 16.3626 - val_precision_score: 0.3250 - val_recall_score: 0.3250 - val_f1_score: 0.3250
# Epoch 42/50
# 5/5 [==============================] - 20s 4s/step - loss: 0.5183 - precision_score: 0.7858 - recall_score: 0.7125 - f1_score: 0.7470 - val_loss: 39.7490 - val_precision_score: 0.3063 - val_recall_score: 0.3063 - val_f1_score: 0.3062
# Epoch 43/50
# 5/5 [==============================] - 13s 3s/step - loss: 0.4567 - precision_score: 0.8559 - recall_score: 0.8125 - f1_score: 0.8336 - val_loss: 61.2856 - val_precision_score: 0.3250 - val_recall_score: 0.3250 - val_f1_score: 0.3250
# Epoch 44/50
# 5/5 [==============================] - 17s 3s/step - loss: 0.5727 - precision_score: 0.7826 - recall_score: 0.7437 - f1_score: 0.7626 - val_loss: 38.1983 - val_precision_score: 0.3562 - val_recall_score: 0.3562 - val_f1_score: 0.3562
# Epoch 45/50
# 5/5 [==============================] - 13s 3s/step - loss: 0.4777 - precision_score: 0.8533 - recall_score: 0.7625 - f1_score: 0.8050 - val_loss: 27.8564 - val_precision_score: 0.2688 - val_recall_score: 0.2688 - val_f1_score: 0.2687
# Epoch 46/50
# 5/5 [==============================] - 13s 3s/step - loss: 0.5784 - precision_score: 0.7810 - recall_score: 0.7000 - f1_score: 0.7376 - val_loss: 43.4221 - val_precision_score: 0.3330 - val_recall_score: 0.3330 - val_f1_score: 0.3330
# Epoch 47/50
# 5/5 [==============================] - 19s 4s/step - loss: 0.6381 - precision_score: 0.7418 - recall_score: 0.6687 - f1_score: 0.7028 - val_loss: 54.5653 - val_precision_score: 0.3625 - val_recall_score: 0.3625 - val_f1_score: 0.3625
# Epoch 48/50
# 5/5 [==============================] - 13s 3s/step - loss: 0.5572 - precision_score: 0.8105 - recall_score: 0.7375 - f1_score: 0.7719 - val_loss: 41.0859 - val_precision_score: 0.3438 - val_recall_score: 0.3438 - val_f1_score: 0.3437
# Epoch 49/50
# 5/5 [==============================] - 24s 5s/step - loss: 0.6508 - precision_score: 0.8033 - recall_score: 0.7063 - f1_score: 0.7514 - val_loss: 32.6701 - val_precision_score: 0.3313 - val_recall_score: 0.3313 - val_f1_score: 0.3312
# Epoch 50/50
# 5/5 [==============================] - 13s 3s/step - loss: 0.5752 - precision_score: 0.8026 - recall_score: 0.7312 - f1_score: 0.7647 - val_loss: 54.3143 - val_precision_score: 0.3438 - val_recall_score: 0.3438 - val_f1_score: 0.3437

# %%
# Exibindo dados de Precisão
plt.plot(history.history['precision_score'])
plt.plot(history.history['val_precision_score'])
plt.title('model precision')
plt.ylabel('precision')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de Sensibilidade
plt.plot(history.history['recall_score'])
plt.plot(history.history['val_recall_score'])
plt.title('model recall')
plt.ylabel('recall')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de F1 Score
plt.plot(history.history['f1_score'])
plt.plot(history.history['val_f1_score'])
plt.title('model f1_score')
plt.ylabel('f1_score')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de Perda
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
conv_base = conv_base = ResNet50V2(include_top=False)

for layer in conv_base.layers:
    layer.trainable = False

x = conv_base.output
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(128, activation='relu')(x) 

predictions = layers.Dense(qtde_classes, activation='softmax')(x)
model = Model(conv_base.input, predictions)

model.summary()
# Out:
# Downloading data from https://github.com/keras-team/keras-applications/releases/download/resnet/resnet50v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94674944/94668760 [==============================] - 39s 0us/step
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, None, None, 3 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, None, None, 3 0           input_2[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, None, None, 6 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, None, None, 6 0           conv1_conv[0][0]
# __________________________________________________________________________________________________
# pool1_pool (MaxPooling2D)       (None, None, None, 6 0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block1_preact_bn (BatchNo (None, None, None, 6 256         pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_preact_relu (Activ (None, None, None, 6 0           conv2_block1_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, None, None, 6 4096        conv2_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, None, None, 6 256         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, None, None, 6 0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_pad (ZeroPadding (None, None, None, 6 0           conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, None, None, 6 36864       conv2_block1_2_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_bn (BatchNormali (None, None, None, 6 256         conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_relu (Activation (None, None, None, 6 0           conv2_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_conv (Conv2D)    (None, None, None, 2 16640       conv2_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_conv (Conv2D)    (None, None, None, 2 16640       conv2_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_out (Add)          (None, None, None, 2 0           conv2_block1_0_conv[0][0]
#                                                                  conv2_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_preact_bn (BatchNo (None, None, None, 2 1024        conv2_block1_out[0][0]
# __________________________________________________________________________________________________
# conv2_block2_preact_relu (Activ (None, None, None, 2 0           conv2_block2_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, None, None, 6 16384       conv2_block2_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, None, None, 6 256         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, None, None, 6 0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_pad (ZeroPadding (None, None, None, 6 0           conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, None, None, 6 36864       conv2_block2_2_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_bn (BatchNormali (None, None, None, 6 256         conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_relu (Activation (None, None, None, 6 0           conv2_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_conv (Conv2D)    (None, None, None, 2 16640       conv2_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_out (Add)          (None, None, None, 2 0           conv2_block1_out[0][0]
#                                                                  conv2_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_preact_bn (BatchNo (None, None, None, 2 1024        conv2_block2_out[0][0]
# __________________________________________________________________________________________________
# conv2_block3_preact_relu (Activ (None, None, None, 2 0           conv2_block3_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, None, None, 6 16384       conv2_block3_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, None, None, 6 256         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, None, None, 6 0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_pad (ZeroPadding (None, None, None, 6 0           conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, None, None, 6 36864       conv2_block3_2_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_bn (BatchNormali (None, None, None, 6 256         conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_relu (Activation (None, None, None, 6 0           conv2_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, None, None, 2 0           conv2_block2_out[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_conv (Conv2D)    (None, None, None, 2 16640       conv2_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_out (Add)          (None, None, None, 2 0           max_pooling2d_5[0][0]
#                                                                  conv2_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_preact_bn (BatchNo (None, None, None, 2 1024        conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_preact_relu (Activ (None, None, None, 2 0           conv3_block1_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, None, None, 1 32768       conv3_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, None, None, 1 512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (Activation (None, None, None, 1 0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_pad (ZeroPadding (None, None, None, 1 0           conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, None, None, 1 147456      conv3_block1_2_pad[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_bn (BatchNormali (None, None, None, 1 512         conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_relu (Activation (None, None, None, 1 0           conv3_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_conv (Conv2D)    (None, None, None, 5 131584      conv3_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_conv (Conv2D)    (None, None, None, 5 66048       conv3_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_out (Add)          (None, None, None, 5 0           conv3_block1_0_conv[0][0]
#                                                                  conv3_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_preact_bn (BatchNo (None, None, None, 5 2048        conv3_block1_out[0][0]
# __________________________________________________________________________________________________
# conv3_block2_preact_relu (Activ (None, None, None, 5 0           conv3_block2_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, None, None, 1 65536       conv3_block2_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, None, None, 1 512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (Activation (None, None, None, 1 0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_pad (ZeroPadding (None, None, None, 1 0           conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, None, None, 1 147456      conv3_block2_2_pad[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_bn (BatchNormali (None, None, None, 1 512         conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_relu (Activation (None, None, None, 1 0           conv3_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_conv (Conv2D)    (None, None, None, 5 66048       conv3_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_out (Add)          (None, None, None, 5 0           conv3_block1_out[0][0]
#                                                                  conv3_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_preact_bn (BatchNo (None, None, None, 5 2048        conv3_block2_out[0][0]
# __________________________________________________________________________________________________
# conv3_block3_preact_relu (Activ (None, None, None, 5 0           conv3_block3_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, None, None, 1 65536       conv3_block3_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, None, None, 1 512         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (Activation (None, None, None, 1 0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_pad (ZeroPadding (None, None, None, 1 0           conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, None, None, 1 147456      conv3_block3_2_pad[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_bn (BatchNormali (None, None, None, 1 512         conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_relu (Activation (None, None, None, 1 0           conv3_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_conv (Conv2D)    (None, None, None, 5 66048       conv3_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_out (Add)          (None, None, None, 5 0           conv3_block2_out[0][0]
#                                                                  conv3_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_preact_bn (BatchNo (None, None, None, 5 2048        conv3_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block4_preact_relu (Activ (None, None, None, 5 0           conv3_block4_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, None, None, 1 65536       conv3_block4_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, None, None, 1 512         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (Activation (None, None, None, 1 0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_pad (ZeroPadding (None, None, None, 1 0           conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, None, None, 1 147456      conv3_block4_2_pad[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_bn (BatchNormali (None, None, None, 1 512         conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_relu (Activation (None, None, None, 1 0           conv3_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, None, None, 5 0           conv3_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_conv (Conv2D)    (None, None, None, 5 66048       conv3_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_out (Add)          (None, None, None, 5 0           max_pooling2d_6[0][0]
#                                                                  conv3_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_preact_bn (BatchNo (None, None, None, 5 2048        conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_preact_relu (Activ (None, None, None, 5 0           conv4_block1_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, None, None, 2 131072      conv4_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, None, None, 2 1024        conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (Activation (None, None, None, 2 0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_pad (ZeroPadding (None, None, None, 2 0           conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, None, None, 2 589824      conv4_block1_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_bn (BatchNormali (None, None, None, 2 1024        conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_relu (Activation (None, None, None, 2 0           conv4_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_conv (Conv2D)    (None, None, None, 1 525312      conv4_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_conv (Conv2D)    (None, None, None, 1 263168      conv4_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_out (Add)          (None, None, None, 1 0           conv4_block1_0_conv[0][0]
#                                                                  conv4_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_preact_bn (BatchNo (None, None, None, 1 4096        conv4_block1_out[0][0]
# __________________________________________________________________________________________________
# conv4_block2_preact_relu (Activ (None, None, None, 1 0           conv4_block2_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, None, None, 2 262144      conv4_block2_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, None, None, 2 1024        conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, None, None, 2 0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_pad (ZeroPadding (None, None, None, 2 0           conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, None, None, 2 589824      conv4_block2_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_bn (BatchNormali (None, None, None, 2 1024        conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_relu (Activation (None, None, None, 2 0           conv4_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_conv (Conv2D)    (None, None, None, 1 263168      conv4_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_out (Add)          (None, None, None, 1 0           conv4_block1_out[0][0]
#                                                                  conv4_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_preact_bn (BatchNo (None, None, None, 1 4096        conv4_block2_out[0][0]
# __________________________________________________________________________________________________
# conv4_block3_preact_relu (Activ (None, None, None, 1 0           conv4_block3_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, None, None, 2 262144      conv4_block3_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, None, None, 2 1024        conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, None, None, 2 0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_pad (ZeroPadding (None, None, None, 2 0           conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, None, None, 2 589824      conv4_block3_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_bn (BatchNormali (None, None, None, 2 1024        conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_relu (Activation (None, None, None, 2 0           conv4_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_conv (Conv2D)    (None, None, None, 1 263168      conv4_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_out (Add)          (None, None, None, 1 0           conv4_block2_out[0][0]
#                                                                  conv4_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_preact_bn (BatchNo (None, None, None, 1 4096        conv4_block3_out[0][0]
# __________________________________________________________________________________________________
# conv4_block4_preact_relu (Activ (None, None, None, 1 0           conv4_block4_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, None, None, 2 262144      conv4_block4_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, None, None, 2 1024        conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, None, None, 2 0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_pad (ZeroPadding (None, None, None, 2 0           conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, None, None, 2 589824      conv4_block4_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_bn (BatchNormali (None, None, None, 2 1024        conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_relu (Activation (None, None, None, 2 0           conv4_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_conv (Conv2D)    (None, None, None, 1 263168      conv4_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_out (Add)          (None, None, None, 1 0           conv4_block3_out[0][0]
#                                                                  conv4_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_preact_bn (BatchNo (None, None, None, 1 4096        conv4_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block5_preact_relu (Activ (None, None, None, 1 0           conv4_block5_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, None, None, 2 262144      conv4_block5_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, None, None, 2 1024        conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, None, None, 2 0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_pad (ZeroPadding (None, None, None, 2 0           conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, None, None, 2 589824      conv4_block5_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_bn (BatchNormali (None, None, None, 2 1024        conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_relu (Activation (None, None, None, 2 0           conv4_block5_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_conv (Conv2D)    (None, None, None, 1 263168      conv4_block5_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_out (Add)          (None, None, None, 1 0           conv4_block4_out[0][0]
#                                                                  conv4_block5_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_preact_bn (BatchNo (None, None, None, 1 4096        conv4_block5_out[0][0]
# __________________________________________________________________________________________________
# conv4_block6_preact_relu (Activ (None, None, None, 1 0           conv4_block6_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, None, None, 2 262144      conv4_block6_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, None, None, 2 1024        conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (Activation (None, None, None, 2 0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_pad (ZeroPadding (None, None, None, 2 0           conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, None, None, 2 589824      conv4_block6_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_bn (BatchNormali (None, None, None, 2 1024        conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_relu (Activation (None, None, None, 2 0           conv4_block6_2_bn[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, None, None, 1 0           conv4_block5_out[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_conv (Conv2D)    (None, None, None, 1 263168      conv4_block6_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_out (Add)          (None, None, None, 1 0           max_pooling2d_7[0][0]
#                                                                  conv4_block6_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_preact_bn (BatchNo (None, None, None, 1 4096        conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_preact_relu (Activ (None, None, None, 1 0           conv5_block1_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_conv (Conv2D)    (None, None, None, 5 524288      conv5_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_bn (BatchNormali (None, None, None, 5 2048        conv5_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_relu (Activation (None, None, None, 5 0           conv5_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_pad (ZeroPadding (None, None, None, 5 0           conv5_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_conv (Conv2D)    (None, None, None, 5 2359296     conv5_block1_2_pad[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_bn (BatchNormali (None, None, None, 5 2048        conv5_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_relu (Activation (None, None, None, 5 0           conv5_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_conv (Conv2D)    (None, None, None, 2 2099200     conv5_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_conv (Conv2D)    (None, None, None, 2 1050624     conv5_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_out (Add)          (None, None, None, 2 0           conv5_block1_0_conv[0][0]
#                                                                  conv5_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_preact_bn (BatchNo (None, None, None, 2 8192        conv5_block1_out[0][0]
# __________________________________________________________________________________________________
# conv5_block2_preact_relu (Activ (None, None, None, 2 0           conv5_block2_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_conv (Conv2D)    (None, None, None, 5 1048576     conv5_block2_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_bn (BatchNormali (None, None, None, 5 2048        conv5_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_relu (Activation (None, None, None, 5 0           conv5_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_pad (ZeroPadding (None, None, None, 5 0           conv5_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_conv (Conv2D)    (None, None, None, 5 2359296     conv5_block2_2_pad[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_bn (BatchNormali (None, None, None, 5 2048        conv5_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_relu (Activation (None, None, None, 5 0           conv5_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_conv (Conv2D)    (None, None, None, 2 1050624     conv5_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_out (Add)          (None, None, None, 2 0           conv5_block1_out[0][0]
#                                                                  conv5_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_preact_bn (BatchNo (None, None, None, 2 8192        conv5_block2_out[0][0]
# __________________________________________________________________________________________________
# conv5_block3_preact_relu (Activ (None, None, None, 2 0           conv5_block3_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_conv (Conv2D)    (None, None, None, 5 1048576     conv5_block3_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_bn (BatchNormali (None, None, None, 5 2048        conv5_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_relu (Activation (None, None, None, 5 0           conv5_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_pad (ZeroPadding (None, None, None, 5 0           conv5_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_conv (Conv2D)    (None, None, None, 5 2359296     conv5_block3_2_pad[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_bn (BatchNormali (None, None, None, 5 2048        conv5_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_relu (Activation (None, None, None, 5 0           conv5_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_conv (Conv2D)    (None, None, None, 2 1050624     conv5_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_out (Add)          (None, None, None, 2 0           conv5_block2_out[0][0]
#                                                                  conv5_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# post_bn (BatchNormalization)    (None, None, None, 2 8192        conv5_block3_out[0][0]
# __________________________________________________________________________________________________
# post_relu (Activation)          (None, None, None, 2 0           post_bn[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_2 (Glo (None, 2048)         0           post_relu[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 128)          262272      global_average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 3)            387         dense_3[0][0]
# ==================================================================================================
# Total params: 23,827,459
# Trainable params: 262,659
# Non-trainable params: 23,564,800
# __________________________________________________________________________________________________

# %%
optimizer = keras.optimizers.Adam()
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=[precision_score, recall_score, f1_score])

history = model.fit_generator(generator=train_generator, 
                              epochs=qtde_epocas, 
                              validation_steps=5, 
                              steps_per_epoch=5, 
                              validation_data=val_generator)
# Out:
# Epoch 1/50
# 5/5 [==============================] - 19s 4s/step - loss: 1.2271 - precision_score: 0.3762 - recall_score: 0.2125 - f1_score: 0.2604 - val_loss: 120.0106 - val_precision_score: 0.3625 - val_recall_score: 0.3625 - val_f1_score: 0.3625
# Epoch 2/50
# 5/5 [==============================] - 20s 4s/step - loss: 0.9186 - precision_score: 0.6611 - recall_score: 0.4500 - f1_score: 0.5354 - val_loss: 48.5057 - val_precision_score: 0.3812 - val_recall_score: 0.3812 - val_f1_score: 0.3812
# Epoch 3/50
# 5/5 [==============================] - 20s 4s/step - loss: 0.6004 - precision_score: 0.8039 - recall_score: 0.7000 - f1_score: 0.7479 - val_loss: 106.1219 - val_precision_score: 0.3125 - val_recall_score: 0.3125 - val_f1_score: 0.3125
# Epoch 4/50
# 5/5 [==============================] - 20s 4s/step - loss: 0.5895 - precision_score: 0.7428 - recall_score: 0.6812 - f1_score: 0.7103 - val_loss: 139.3626 - val_precision_score: 0.3125 - val_recall_score: 0.3125 - val_f1_score: 0.3125
# Epoch 5/50
# 5/5 [==============================] - 20s 4s/step - loss: 0.6293 - precision_score: 0.7509 - recall_score: 0.6875 - f1_score: 0.7172 - val_loss: 129.1346 - val_precision_score: 0.3438 - val_recall_score: 0.3438 - val_f1_score: 0.3437
# Epoch 6/50
# 5/5 [==============================] - 20s 4s/step - loss: 0.5078 - precision_score: 0.7906 - recall_score: 0.7312 - f1_score: 0.7594 - val_loss: 138.8992 - val_precision_score: 0.3187 - val_recall_score: 0.3187 - val_f1_score: 0.3187
# Epoch 7/50
# 5/5 [==============================] - 20s 4s/step - loss: 0.6265 - precision_score: 0.7537 - recall_score: 0.7063 - f1_score: 0.7291 - val_loss: 165.6402 - val_precision_score: 0.3438 - val_recall_score: 0.3438 - val_f1_score: 0.3437
# Epoch 8/50
# 5/5 [==============================] - 34s 7s/step - loss: 0.6624 - precision_score: 0.6672 - recall_score: 0.6313 - f1_score: 0.6485 - val_loss: 192.1660 - val_precision_score: 0.3205 - val_recall_score: 0.3205 - val_f1_score: 0.3205
# Epoch 9/50
# 5/5 [==============================] - 20s 4s/step - loss: 0.5643 - precision_score: 0.7887 - recall_score: 0.7500 - f1_score: 0.7686 - val_loss: 139.2130 - val_precision_score: 0.3000 - val_recall_score: 0.3000 - val_f1_score: 0.3000
# Epoch 10/50
# 5/5 [==============================] - 20s 4s/step - loss: 0.4352 - precision_score: 0.8464 - recall_score: 0.7937 - f1_score: 0.8189 - val_loss: 244.3822 - val_precision_score: 0.3562 - val_recall_score: 0.3562 - val_f1_score: 0.3562
# Epoch 11/50
# 5/5 [==============================] - 31s 6s/step - loss: 0.6076 - precision_score: 0.7810 - recall_score: 0.7375 - f1_score: 0.7585 - val_loss: 233.3605 - val_precision_score: 0.3250 - val_recall_score: 0.3250 - val_f1_score: 0.3250
# Epoch 12/50
# 5/5 [==============================] - 23s 5s/step - loss: 0.5645 - precision_score: 0.8188 - recall_score: 0.7563 - f1_score: 0.7857 - val_loss: 216.7195 - val_precision_score: 0.3250 - val_recall_score: 0.3250 - val_f1_score: 0.3250
# Epoch 13/50
# 5/5 [==============================] - 20s 4s/step - loss: 0.4345 - precision_score: 0.8269 - recall_score: 0.8000 - f1_score: 0.8131 - val_loss: 172.0711 - val_precision_score: 0.2750 - val_recall_score: 0.2750 - val_f1_score: 0.2750
# Epoch 14/50
# 5/5 [==============================] - 32s 6s/step - loss: 0.4271 - precision_score: 0.8445 - recall_score: 0.7812 - f1_score: 0.8115 - val_loss: 190.6184 - val_precision_score: 0.3812 - val_recall_score: 0.3812 - val_f1_score: 0.3812
# Epoch 15/50
# 5/5 [==============================] - 20s 4s/step - loss: 0.4973 - precision_score: 0.8003 - recall_score: 0.7500 - f1_score: 0.7741 - val_loss: 150.2892 - val_precision_score: 0.3812 - val_recall_score: 0.3812 - val_f1_score: 0.3812
# Epoch 16/50
# 5/5 [==============================] - 26s 5s/step - loss: 0.4770 - precision_score: 0.7850 - recall_score: 0.7500 - f1_score: 0.7669 - val_loss: 189.0144 - val_precision_score: 0.3875 - val_recall_score: 0.3875 - val_f1_score: 0.3875
# Epoch 17/50
# 5/5 [==============================] - 20s 4s/step - loss: 0.5189 - precision_score: 0.7934 - recall_score: 0.7437 - f1_score: 0.7676 - val_loss: 157.7771 - val_precision_score: 0.3125 - val_recall_score: 0.3125 - val_f1_score: 0.3125
# Epoch 18/50
# 5/5 [==============================] - 20s 4s/step - loss: 0.3719 - precision_score: 0.8719 - recall_score: 0.8438 - f1_score: 0.8574 - val_loss: 110.1925 - val_precision_score: 0.3812 - val_recall_score: 0.3812 - val_f1_score: 0.3812
# Epoch 19/50
# 5/5 [==============================] - 20s 4s/step - loss: 0.3738 - precision_score: 0.8466 - recall_score: 0.8250 - f1_score: 0.8356 - val_loss: 166.1620 - val_precision_score: 0.2688 - val_recall_score: 0.2688 - val_f1_score: 0.2687
# Epoch 20/50
# 5/5 [==============================] - 25s 5s/step - loss: 0.5022 - precision_score: 0.7951 - recall_score: 0.7563 - f1_score: 0.7748 - val_loss: 136.9841 - val_precision_score: 0.3438 - val_recall_score: 0.3438 - val_f1_score: 0.3437
# Epoch 21/50
# 5/5 [==============================] - 19s 4s/step - loss: 0.2938 - precision_score: 0.9282 - recall_score: 0.8938 - f1_score: 0.9103 - val_loss: 168.3585 - val_precision_score: 0.3938 - val_recall_score: 0.3938 - val_f1_score: 0.3937
# Epoch 22/50
# 5/5 [==============================] - 20s 4s/step - loss: 0.4651 - precision_score: 0.8175 - recall_score: 0.7812 - f1_score: 0.7987 - val_loss: 249.1826 - val_precision_score: 0.3000 - val_recall_score: 0.3000 - val_f1_score: 0.3000
# Epoch 23/50
# 5/5 [==============================] - 29s 6s/step - loss: 0.5465 - precision_score: 0.7781 - recall_score: 0.7500 - f1_score: 0.7637 - val_loss: 136.5302 - val_precision_score: 0.3165 - val_recall_score: 0.3165 - val_f1_score: 0.3165
# Epoch 24/50
# 5/5 [==============================] - 20s 4s/step - loss: 0.4497 - precision_score: 0.8279 - recall_score: 0.8000 - f1_score: 0.8135 - val_loss: 168.6962 - val_precision_score: 0.3000 - val_recall_score: 0.3000 - val_f1_score: 0.3000
# Epoch 25/50
# 5/5 [==============================] - 31s 6s/step - loss: 0.3992 - precision_score: 0.8433 - recall_score: 0.8000 - f1_score: 0.8209 - val_loss: 300.2043 - val_precision_score: 0.3187 - val_recall_score: 0.3187 - val_f1_score: 0.3187
# Epoch 26/50
# 5/5 [==============================] - 20s 4s/step - loss: 0.3519 - precision_score: 0.8872 - recall_score: 0.8375 - f1_score: 0.8613 - val_loss: 227.2920 - val_precision_score: 0.3375 - val_recall_score: 0.3375 - val_f1_score: 0.3375
# Epoch 27/50
# 5/5 [==============================] - 20s 4s/step - loss: 0.4129 - precision_score: 0.8668 - recall_score: 0.8188 - f1_score: 0.8419 - val_loss: 236.5447 - val_precision_score: 0.3625 - val_recall_score: 0.3625 - val_f1_score: 0.3625
# Epoch 28/50
# 5/5 [==============================] - 20s 4s/step - loss: 0.3690 - precision_score: 0.8875 - recall_score: 0.8438 - f1_score: 0.8647 - val_loss: 183.5433 - val_precision_score: 0.3250 - val_recall_score: 0.3250 - val_f1_score: 0.3250
# Epoch 29/50
# 5/5 [==============================] - 20s 4s/step - loss: 0.3949 - precision_score: 0.8626 - recall_score: 0.8188 - f1_score: 0.8400 - val_loss: 215.9519 - val_precision_score: 0.3187 - val_recall_score: 0.3187 - val_f1_score: 0.3187
# Epoch 30/50
# 5/5 [==============================] - 35s 7s/step - loss: 0.5159 - precision_score: 0.8051 - recall_score: 0.7750 - f1_score: 0.7896 - val_loss: 166.9630 - val_precision_score: 0.3750 - val_recall_score: 0.3750 - val_f1_score: 0.3750
# Epoch 31/50
# 5/5 [==============================] - 20s 4s/step - loss: 0.4169 - precision_score: 0.8526 - recall_score: 0.8313 - f1_score: 0.8417 - val_loss: 245.3313 - val_precision_score: 0.3574 - val_recall_score: 0.3574 - val_f1_score: 0.3574
# Epoch 32/50
# 5/5 [==============================] - 20s 4s/step - loss: 0.4255 - precision_score: 0.8178 - recall_score: 0.7875 - f1_score: 0.8021 - val_loss: 246.2610 - val_precision_score: 0.3688 - val_recall_score: 0.3688 - val_f1_score: 0.3687
# Epoch 33/50
# 5/5 [==============================] - 30s 6s/step - loss: 0.3699 - precision_score: 0.8369 - recall_score: 0.8000 - f1_score: 0.8176 - val_loss: 274.9027 - val_precision_score: 0.3750 - val_recall_score: 0.3750 - val_f1_score: 0.3750
# Epoch 34/50
# 5/5 [==============================] - 20s 4s/step - loss: 0.3624 - precision_score: 0.8534 - recall_score: 0.7937 - f1_score: 0.8223 - val_loss: 270.8468 - val_precision_score: 0.3000 - val_recall_score: 0.3000 - val_f1_score: 0.3000
# Epoch 35/50
# 5/5 [==============================] - 20s 4s/step - loss: 0.4635 - precision_score: 0.8259 - recall_score: 0.7937 - f1_score: 0.8093 - val_loss: 169.1768 - val_precision_score: 0.3313 - val_recall_score: 0.3313 - val_f1_score: 0.3312
# Epoch 36/50
# 5/5 [==============================] - 26s 5s/step - loss: 0.3485 - precision_score: 0.8524 - recall_score: 0.8313 - f1_score: 0.8415 - val_loss: 199.6328 - val_precision_score: 0.3438 - val_recall_score: 0.3438 - val_f1_score: 0.3437
# Epoch 37/50
# 5/5 [==============================] - 20s 4s/step - loss: 0.2836 - precision_score: 0.9084 - recall_score: 0.8750 - f1_score: 0.8912 - val_loss: 179.4267 - val_precision_score: 0.3063 - val_recall_score: 0.3063 - val_f1_score: 0.3062
# Epoch 38/50
# 5/5 [==============================] - 18s 4s/step - loss: 0.6260 - precision_score: 0.7655 - recall_score: 0.7188 - f1_score: 0.7412 - val_loss: 183.8509 - val_precision_score: 0.3108 - val_recall_score: 0.3108 - val_f1_score: 0.3108
# Epoch 39/50
# 5/5 [==============================] - 25s 5s/step - loss: 0.3976 - precision_score: 0.8553 - recall_score: 0.8250 - f1_score: 0.8396 - val_loss: 244.2442 - val_precision_score: 0.3313 - val_recall_score: 0.3313 - val_f1_score: 0.3312
# Epoch 40/50
# 5/5 [==============================] - 31s 6s/step - loss: 0.3631 - precision_score: 0.8325 - recall_score: 0.8062 - f1_score: 0.8190 - val_loss: 207.9585 - val_precision_score: 0.3063 - val_recall_score: 0.3063 - val_f1_score: 0.3062
# Epoch 41/50
# 5/5 [==============================] - 20s 4s/step - loss: 0.3685 - precision_score: 0.8288 - recall_score: 0.8125 - f1_score: 0.8205 - val_loss: 226.4910 - val_precision_score: 0.3250 - val_recall_score: 0.3250 - val_f1_score: 0.3250
# Epoch 42/50
# 5/5 [==============================] - 20s 4s/step - loss: 0.3154 - precision_score: 0.8661 - recall_score: 0.8500 - f1_score: 0.8578 - val_loss: 226.8258 - val_precision_score: 0.3063 - val_recall_score: 0.3063 - val_f1_score: 0.3062
# Epoch 43/50
# 5/5 [==============================] - 20s 4s/step - loss: 0.4364 - precision_score: 0.8343 - recall_score: 0.8188 - f1_score: 0.8261 - val_loss: 154.1797 - val_precision_score: 0.3938 - val_recall_score: 0.3938 - val_f1_score: 0.3937
# Epoch 44/50
# 5/5 [==============================] - 35s 7s/step - loss: 0.3592 - precision_score: 0.8815 - recall_score: 0.8375 - f1_score: 0.8585 - val_loss: 220.1814 - val_precision_score: 0.3375 - val_recall_score: 0.3375 - val_f1_score: 0.3375
# Epoch 45/50
# 5/5 [==============================] - 20s 4s/step - loss: 0.4044 - precision_score: 0.8351 - recall_score: 0.8000 - f1_score: 0.8170 - val_loss: 357.9077 - val_precision_score: 0.3125 - val_recall_score: 0.3125 - val_f1_score: 0.3125
# Epoch 46/50
# 5/5 [==============================] - 27s 5s/step - loss: 0.5203 - precision_score: 0.7820 - recall_score: 0.7625 - f1_score: 0.7720 - val_loss: 220.4875 - val_precision_score: 0.3670 - val_recall_score: 0.3670 - val_f1_score: 0.3670
# Epoch 47/50
# 5/5 [==============================] - 20s 4s/step - loss: 0.3662 - precision_score: 0.8521 - recall_score: 0.8062 - f1_score: 0.8279 - val_loss: 219.9995 - val_precision_score: 0.3375 - val_recall_score: 0.3375 - val_f1_score: 0.3375
# Epoch 48/50
# 5/5 [==============================] - 20s 4s/step - loss: 0.3474 - precision_score: 0.8430 - recall_score: 0.8062 - f1_score: 0.8241 - val_loss: 280.2779 - val_precision_score: 0.3500 - val_recall_score: 0.3500 - val_f1_score: 0.3500
# Epoch 49/50
# 5/5 [==============================] - 26s 5s/step - loss: 0.3186 - precision_score: 0.8909 - recall_score: 0.8687 - f1_score: 0.8797 - val_loss: 229.8403 - val_precision_score: 0.3250 - val_recall_score: 0.3250 - val_f1_score: 0.3250
# Epoch 50/50
# 5/5 [==============================] - 23s 5s/step - loss: 0.3432 - precision_score: 0.8511 - recall_score: 0.8250 - f1_score: 0.8377 - val_loss: 260.2495 - val_precision_score: 0.3250 - val_recall_score: 0.3250 - val_f1_score: 0.3250

# %%
# Exibindo dados de Precisão
plt.plot(history.history['precision_score'])
plt.plot(history.history['val_precision_score'])
plt.title('model precision')
plt.ylabel('precision')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de Sensibilidade
plt.plot(history.history['recall_score'])
plt.plot(history.history['val_recall_score'])
plt.title('model recall')
plt.ylabel('recall')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de F1 Score
plt.plot(history.history['f1_score'])
plt.plot(history.history['val_f1_score'])
plt.title('model f1_score')
plt.ylabel('f1_score')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de Perda
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
conv_base = conv_base = ResNet50V2(include_top=False)

for layer in conv_base.layers:
    layer.trainable = False

x = conv_base.output
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(128, activation='relu')(x) 

predictions = layers.Dense(qtde_classes, activation='softmax')(x)
model = Model(conv_base.input, predictions)

model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            (None, None, None, 3 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, None, None, 3 0           input_3[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, None, None, 6 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, None, None, 6 0           conv1_conv[0][0]
# __________________________________________________________________________________________________
# pool1_pool (MaxPooling2D)       (None, None, None, 6 0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block1_preact_bn (BatchNo (None, None, None, 6 256         pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_preact_relu (Activ (None, None, None, 6 0           conv2_block1_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, None, None, 6 4096        conv2_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, None, None, 6 256         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, None, None, 6 0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_pad (ZeroPadding (None, None, None, 6 0           conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, None, None, 6 36864       conv2_block1_2_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_bn (BatchNormali (None, None, None, 6 256         conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_relu (Activation (None, None, None, 6 0           conv2_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_conv (Conv2D)    (None, None, None, 2 16640       conv2_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_conv (Conv2D)    (None, None, None, 2 16640       conv2_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_out (Add)          (None, None, None, 2 0           conv2_block1_0_conv[0][0]
#                                                                  conv2_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_preact_bn (BatchNo (None, None, None, 2 1024        conv2_block1_out[0][0]
# __________________________________________________________________________________________________
# conv2_block2_preact_relu (Activ (None, None, None, 2 0           conv2_block2_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, None, None, 6 16384       conv2_block2_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, None, None, 6 256         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, None, None, 6 0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_pad (ZeroPadding (None, None, None, 6 0           conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, None, None, 6 36864       conv2_block2_2_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_bn (BatchNormali (None, None, None, 6 256         conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_relu (Activation (None, None, None, 6 0           conv2_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_conv (Conv2D)    (None, None, None, 2 16640       conv2_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_out (Add)          (None, None, None, 2 0           conv2_block1_out[0][0]
#                                                                  conv2_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_preact_bn (BatchNo (None, None, None, 2 1024        conv2_block2_out[0][0]
# __________________________________________________________________________________________________
# conv2_block3_preact_relu (Activ (None, None, None, 2 0           conv2_block3_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, None, None, 6 16384       conv2_block3_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, None, None, 6 256         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, None, None, 6 0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_pad (ZeroPadding (None, None, None, 6 0           conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, None, None, 6 36864       conv2_block3_2_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_bn (BatchNormali (None, None, None, 6 256         conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_relu (Activation (None, None, None, 6 0           conv2_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, None, None, 2 0           conv2_block2_out[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_conv (Conv2D)    (None, None, None, 2 16640       conv2_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_out (Add)          (None, None, None, 2 0           max_pooling2d_8[0][0]
#                                                                  conv2_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_preact_bn (BatchNo (None, None, None, 2 1024        conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_preact_relu (Activ (None, None, None, 2 0           conv3_block1_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, None, None, 1 32768       conv3_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, None, None, 1 512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (Activation (None, None, None, 1 0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_pad (ZeroPadding (None, None, None, 1 0           conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, None, None, 1 147456      conv3_block1_2_pad[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_bn (BatchNormali (None, None, None, 1 512         conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_relu (Activation (None, None, None, 1 0           conv3_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_conv (Conv2D)    (None, None, None, 5 131584      conv3_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_conv (Conv2D)    (None, None, None, 5 66048       conv3_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_out (Add)          (None, None, None, 5 0           conv3_block1_0_conv[0][0]
#                                                                  conv3_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_preact_bn (BatchNo (None, None, None, 5 2048        conv3_block1_out[0][0]
# __________________________________________________________________________________________________
# conv3_block2_preact_relu (Activ (None, None, None, 5 0           conv3_block2_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, None, None, 1 65536       conv3_block2_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, None, None, 1 512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (Activation (None, None, None, 1 0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_pad (ZeroPadding (None, None, None, 1 0           conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, None, None, 1 147456      conv3_block2_2_pad[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_bn (BatchNormali (None, None, None, 1 512         conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_relu (Activation (None, None, None, 1 0           conv3_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_conv (Conv2D)    (None, None, None, 5 66048       conv3_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_out (Add)          (None, None, None, 5 0           conv3_block1_out[0][0]
#                                                                  conv3_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_preact_bn (BatchNo (None, None, None, 5 2048        conv3_block2_out[0][0]
# __________________________________________________________________________________________________
# conv3_block3_preact_relu (Activ (None, None, None, 5 0           conv3_block3_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, None, None, 1 65536       conv3_block3_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, None, None, 1 512         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (Activation (None, None, None, 1 0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_pad (ZeroPadding (None, None, None, 1 0           conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, None, None, 1 147456      conv3_block3_2_pad[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_bn (BatchNormali (None, None, None, 1 512         conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_relu (Activation (None, None, None, 1 0           conv3_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_conv (Conv2D)    (None, None, None, 5 66048       conv3_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_out (Add)          (None, None, None, 5 0           conv3_block2_out[0][0]
#                                                                  conv3_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_preact_bn (BatchNo (None, None, None, 5 2048        conv3_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block4_preact_relu (Activ (None, None, None, 5 0           conv3_block4_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, None, None, 1 65536       conv3_block4_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, None, None, 1 512         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (Activation (None, None, None, 1 0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_pad (ZeroPadding (None, None, None, 1 0           conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, None, None, 1 147456      conv3_block4_2_pad[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_bn (BatchNormali (None, None, None, 1 512         conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_relu (Activation (None, None, None, 1 0           conv3_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, None, None, 5 0           conv3_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_conv (Conv2D)    (None, None, None, 5 66048       conv3_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_out (Add)          (None, None, None, 5 0           max_pooling2d_9[0][0]
#                                                                  conv3_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_preact_bn (BatchNo (None, None, None, 5 2048        conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_preact_relu (Activ (None, None, None, 5 0           conv4_block1_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, None, None, 2 131072      conv4_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, None, None, 2 1024        conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (Activation (None, None, None, 2 0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_pad (ZeroPadding (None, None, None, 2 0           conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, None, None, 2 589824      conv4_block1_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_bn (BatchNormali (None, None, None, 2 1024        conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_relu (Activation (None, None, None, 2 0           conv4_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_conv (Conv2D)    (None, None, None, 1 525312      conv4_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_conv (Conv2D)    (None, None, None, 1 263168      conv4_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_out (Add)          (None, None, None, 1 0           conv4_block1_0_conv[0][0]
#                                                                  conv4_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_preact_bn (BatchNo (None, None, None, 1 4096        conv4_block1_out[0][0]
# __________________________________________________________________________________________________
# conv4_block2_preact_relu (Activ (None, None, None, 1 0           conv4_block2_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, None, None, 2 262144      conv4_block2_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, None, None, 2 1024        conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, None, None, 2 0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_pad (ZeroPadding (None, None, None, 2 0           conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, None, None, 2 589824      conv4_block2_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_bn (BatchNormali (None, None, None, 2 1024        conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_relu (Activation (None, None, None, 2 0           conv4_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_conv (Conv2D)    (None, None, None, 1 263168      conv4_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_out (Add)          (None, None, None, 1 0           conv4_block1_out[0][0]
#                                                                  conv4_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_preact_bn (BatchNo (None, None, None, 1 4096        conv4_block2_out[0][0]
# __________________________________________________________________________________________________
# conv4_block3_preact_relu (Activ (None, None, None, 1 0           conv4_block3_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, None, None, 2 262144      conv4_block3_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, None, None, 2 1024        conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, None, None, 2 0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_pad (ZeroPadding (None, None, None, 2 0           conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, None, None, 2 589824      conv4_block3_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_bn (BatchNormali (None, None, None, 2 1024        conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_relu (Activation (None, None, None, 2 0           conv4_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_conv (Conv2D)    (None, None, None, 1 263168      conv4_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_out (Add)          (None, None, None, 1 0           conv4_block2_out[0][0]
#                                                                  conv4_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_preact_bn (BatchNo (None, None, None, 1 4096        conv4_block3_out[0][0]
# __________________________________________________________________________________________________
# conv4_block4_preact_relu (Activ (None, None, None, 1 0           conv4_block4_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, None, None, 2 262144      conv4_block4_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, None, None, 2 1024        conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, None, None, 2 0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_pad (ZeroPadding (None, None, None, 2 0           conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, None, None, 2 589824      conv4_block4_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_bn (BatchNormali (None, None, None, 2 1024        conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_relu (Activation (None, None, None, 2 0           conv4_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_conv (Conv2D)    (None, None, None, 1 263168      conv4_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_out (Add)          (None, None, None, 1 0           conv4_block3_out[0][0]
#                                                                  conv4_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_preact_bn (BatchNo (None, None, None, 1 4096        conv4_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block5_preact_relu (Activ (None, None, None, 1 0           conv4_block5_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, None, None, 2 262144      conv4_block5_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, None, None, 2 1024        conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, None, None, 2 0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_pad (ZeroPadding (None, None, None, 2 0           conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, None, None, 2 589824      conv4_block5_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_bn (BatchNormali (None, None, None, 2 1024        conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_relu (Activation (None, None, None, 2 0           conv4_block5_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_conv (Conv2D)    (None, None, None, 1 263168      conv4_block5_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_out (Add)          (None, None, None, 1 0           conv4_block4_out[0][0]
#                                                                  conv4_block5_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_preact_bn (BatchNo (None, None, None, 1 4096        conv4_block5_out[0][0]
# __________________________________________________________________________________________________
# conv4_block6_preact_relu (Activ (None, None, None, 1 0           conv4_block6_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, None, None, 2 262144      conv4_block6_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, None, None, 2 1024        conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (Activation (None, None, None, 2 0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_pad (ZeroPadding (None, None, None, 2 0           conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, None, None, 2 589824      conv4_block6_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_bn (BatchNormali (None, None, None, 2 1024        conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_relu (Activation (None, None, None, 2 0           conv4_block6_2_bn[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D) (None, None, None, 1 0           conv4_block5_out[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_conv (Conv2D)    (None, None, None, 1 263168      conv4_block6_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_out (Add)          (None, None, None, 1 0           max_pooling2d_10[0][0]
#                                                                  conv4_block6_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_preact_bn (BatchNo (None, None, None, 1 4096        conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_preact_relu (Activ (None, None, None, 1 0           conv5_block1_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_conv (Conv2D)    (None, None, None, 5 524288      conv5_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_bn (BatchNormali (None, None, None, 5 2048        conv5_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_relu (Activation (None, None, None, 5 0           conv5_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_pad (ZeroPadding (None, None, None, 5 0           conv5_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_conv (Conv2D)    (None, None, None, 5 2359296     conv5_block1_2_pad[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_bn (BatchNormali (None, None, None, 5 2048        conv5_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_relu (Activation (None, None, None, 5 0           conv5_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_conv (Conv2D)    (None, None, None, 2 2099200     conv5_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_conv (Conv2D)    (None, None, None, 2 1050624     conv5_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_out (Add)          (None, None, None, 2 0           conv5_block1_0_conv[0][0]
#                                                                  conv5_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_preact_bn (BatchNo (None, None, None, 2 8192        conv5_block1_out[0][0]
# __________________________________________________________________________________________________
# conv5_block2_preact_relu (Activ (None, None, None, 2 0           conv5_block2_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_conv (Conv2D)    (None, None, None, 5 1048576     conv5_block2_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_bn (BatchNormali (None, None, None, 5 2048        conv5_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_relu (Activation (None, None, None, 5 0           conv5_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_pad (ZeroPadding (None, None, None, 5 0           conv5_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_conv (Conv2D)    (None, None, None, 5 2359296     conv5_block2_2_pad[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_bn (BatchNormali (None, None, None, 5 2048        conv5_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_relu (Activation (None, None, None, 5 0           conv5_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_conv (Conv2D)    (None, None, None, 2 1050624     conv5_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_out (Add)          (None, None, None, 2 0           conv5_block1_out[0][0]
#                                                                  conv5_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_preact_bn (BatchNo (None, None, None, 2 8192        conv5_block2_out[0][0]
# __________________________________________________________________________________________________
# conv5_block3_preact_relu (Activ (None, None, None, 2 0           conv5_block3_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_conv (Conv2D)    (None, None, None, 5 1048576     conv5_block3_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_bn (BatchNormali (None, None, None, 5 2048        conv5_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_relu (Activation (None, None, None, 5 0           conv5_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_pad (ZeroPadding (None, None, None, 5 0           conv5_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_conv (Conv2D)    (None, None, None, 5 2359296     conv5_block3_2_pad[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_bn (BatchNormali (None, None, None, 5 2048        conv5_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_relu (Activation (None, None, None, 5 0           conv5_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_conv (Conv2D)    (None, None, None, 2 1050624     conv5_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_out (Add)          (None, None, None, 2 0           conv5_block2_out[0][0]
#                                                                  conv5_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# post_bn (BatchNormalization)    (None, None, None, 2 8192        conv5_block3_out[0][0]
# __________________________________________________________________________________________________
# post_relu (Activation)          (None, None, None, 2 0           post_bn[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_3 (Glo (None, 2048)         0           post_relu[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 128)          262272      global_average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 3)            387         dense_5[0][0]
# ==================================================================================================
# Total params: 23,827,459
# Trainable params: 262,659
# Non-trainable params: 23,564,800
# __________________________________________________________________________________________________

# %%
optimizer = keras.optimizers.Adam()
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=[precision_score, recall_score, f1_score])

history = model.fit_generator(generator=train_generator, 
                              epochs=qtde_epocas, 
                              validation_steps=5, 
                              steps_per_epoch=5, 
                              validation_data=val_generator)
# Out:
# Epoch 1/50
# 5/5 [==============================] - 21s 4s/step - loss: 1.1832 - precision_score: 0.3144 - recall_score: 0.2250 - f1_score: 0.2551 - val_loss: 186.4356 - val_precision_score: 0.3438 - val_recall_score: 0.3438 - val_f1_score: 0.3437
# Epoch 2/50
# 5/5 [==============================] - 20s 4s/step - loss: 1.0543 - precision_score: 0.4492 - recall_score: 0.3812 - f1_score: 0.4114 - val_loss: 150.8375 - val_precision_score: 0.3063 - val_recall_score: 0.3063 - val_f1_score: 0.3062
# Epoch 3/50
# 5/5 [==============================] - 32s 6s/step - loss: 0.6930 - precision_score: 0.7597 - recall_score: 0.6187 - f1_score: 0.6814 - val_loss: 88.4413 - val_precision_score: 0.3438 - val_recall_score: 0.3438 - val_f1_score: 0.3437
# Epoch 4/50
# 5/5 [==============================] - 20s 4s/step - loss: 0.5484 - precision_score: 0.8334 - recall_score: 0.7375 - f1_score: 0.7821 - val_loss: 100.7933 - val_precision_score: 0.3250 - val_recall_score: 0.3250 - val_f1_score: 0.3250
# Epoch 5/50
# 5/5 [==============================] - 20s 4s/step - loss: 0.6425 - precision_score: 0.7330 - recall_score: 0.6562 - f1_score: 0.6921 - val_loss: 149.0191 - val_precision_score: 0.3250 - val_recall_score: 0.3250 - val_f1_score: 0.3250
# Epoch 6/50
# 5/5 [==============================] - 25s 5s/step - loss: 0.5565 - precision_score: 0.7320 - recall_score: 0.6625 - f1_score: 0.6952 - val_loss: 179.3881 - val_precision_score: 0.3500 - val_recall_score: 0.3500 - val_f1_score: 0.3500
# Epoch 7/50
# 5/5 [==============================] - 34s 7s/step - loss: 0.5692 - precision_score: 0.8036 - recall_score: 0.7000 - f1_score: 0.7475 - val_loss: 178.5237 - val_precision_score: 0.3375 - val_recall_score: 0.3375 - val_f1_score: 0.3375
# Epoch 8/50
# 5/5 [==============================] - 20s 4s/step - loss: 0.6077 - precision_score: 0.7846 - recall_score: 0.7563 - f1_score: 0.7700 - val_loss: 210.1237 - val_precision_score: 0.3131 - val_recall_score: 0.3131 - val_f1_score: 0.3131
# Epoch 9/50
# 5/5 [==============================] - 20s 4s/step - loss: 0.5300 - precision_score: 0.8132 - recall_score: 0.7625 - f1_score: 0.7860 - val_loss: 136.8033 - val_precision_score: 0.3625 - val_recall_score: 0.3625 - val_f1_score: 0.3625
# Epoch 10/50
# 5/5 [==============================] - 20s 4s/step - loss: 0.4881 - precision_score: 0.7893 - recall_score: 0.7188 - f1_score: 0.7516 - val_loss: 131.5752 - val_precision_score: 0.3187 - val_recall_score: 0.3187 - val_f1_score: 0.3187
# Epoch 11/50
# 5/5 [==============================] - 20s 4s/step - loss: 0.4400 - precision_score: 0.8645 - recall_score: 0.8250 - f1_score: 0.8439 - val_loss: 176.0972 - val_precision_score: 0.3187 - val_recall_score: 0.3187 - val_f1_score: 0.3187
# Epoch 12/50
# 5/5 [==============================] - 29s 6s/step - loss: 0.4703 - precision_score: 0.8330 - recall_score: 0.7937 - f1_score: 0.8125 - val_loss: 210.3869 - val_precision_score: 0.3313 - val_recall_score: 0.3313 - val_f1_score: 0.3312
# Epoch 13/50
# 5/5 [==============================] - 20s 4s/step - loss: 0.5045 - precision_score: 0.8067 - recall_score: 0.7812 - f1_score: 0.7936 - val_loss: 135.4725 - val_precision_score: 0.3125 - val_recall_score: 0.3125 - val_f1_score: 0.3125
# Epoch 14/50
# 5/5 [==============================] - 20s 4s/step - loss: 0.6486 - precision_score: 0.7349 - recall_score: 0.7000 - f1_score: 0.7165 - val_loss: 71.1881 - val_precision_score: 0.2188 - val_recall_score: 0.2188 - val_f1_score: 0.2187
# Epoch 15/50
# 5/5 [==============================] - 20s 4s/step - loss: 0.5352 - precision_score: 0.7791 - recall_score: 0.7312 - f1_score: 0.7540 - val_loss: 183.7835 - val_precision_score: 0.3000 - val_recall_score: 0.3000 - val_f1_score: 0.3000
# Epoch 16/50
# 5/5 [==============================] - 25s 5s/step - loss: 0.5686 - precision_score: 0.7977 - recall_score: 0.7375 - f1_score: 0.7662 - val_loss: 239.1733 - val_precision_score: 0.2545 - val_recall_score: 0.2545 - val_f1_score: 0.2545
# Epoch 17/50
# 5/5 [==============================] - 23s 5s/step - loss: 0.4644 - precision_score: 0.8409 - recall_score: 0.7875 - f1_score: 0.8130 - val_loss: 232.6467 - val_precision_score: 0.3187 - val_recall_score: 0.3187 - val_f1_score: 0.3187
# Epoch 18/50
# 5/5 [==============================] - 20s 4s/step - loss: 0.4434 - precision_score: 0.8017 - recall_score: 0.7563 - f1_score: 0.7783 - val_loss: 245.6517 - val_precision_score: 0.3313 - val_recall_score: 0.3313 - val_f1_score: 0.3312
# Epoch 19/50
# 5/5 [==============================] - 20s 4s/step - loss: 0.4528 - precision_score: 0.8370 - recall_score: 0.7937 - f1_score: 0.8146 - val_loss: 177.6859 - val_precision_score: 0.3000 - val_recall_score: 0.3000 - val_f1_score: 0.3000
# Epoch 20/50
# 5/5 [==============================] - 34s 7s/step - loss: 0.3234 - precision_score: 0.9023 - recall_score: 0.8750 - f1_score: 0.8881 - val_loss: 213.2686 - val_precision_score: 0.3750 - val_recall_score: 0.3750 - val_f1_score: 0.3750
# Epoch 21/50
# 5/5 [==============================] - 19s 4s/step - loss: 0.4360 - precision_score: 0.8570 - recall_score: 0.8313 - f1_score: 0.8434 - val_loss: 181.0274 - val_precision_score: 0.3688 - val_recall_score: 0.3688 - val_f1_score: 0.3687
# Epoch 22/50
# 5/5 [==============================] - 20s 4s/step - loss: 0.3293 - precision_score: 0.8642 - recall_score: 0.8313 - f1_score: 0.8472 - val_loss: 174.5063 - val_precision_score: 0.3313 - val_recall_score: 0.3313 - val_f1_score: 0.3312
# Epoch 23/50
# 5/5 [==============================] - 20s 4s/step - loss: 0.5933 - precision_score: 0.7634 - recall_score: 0.7188 - f1_score: 0.7395 - val_loss: 87.4625 - val_precision_score: 0.4381 - val_recall_score: 0.4381 - val_f1_score: 0.4381
# Epoch 24/50
# 5/5 [==============================] - 20s 4s/step - loss: 0.4415 - precision_score: 0.8167 - recall_score: 0.7937 - f1_score: 0.8048 - val_loss: 183.4321 - val_precision_score: 0.3562 - val_recall_score: 0.3562 - val_f1_score: 0.3562
# Epoch 25/50
# 5/5 [==============================] - 20s 4s/step - loss: 0.4149 - precision_score: 0.8389 - recall_score: 0.8062 - f1_score: 0.8220 - val_loss: 283.0470 - val_precision_score: 0.3375 - val_recall_score: 0.3375 - val_f1_score: 0.3375
# Epoch 26/50
# 5/5 [==============================] - 35s 7s/step - loss: 0.4055 - precision_score: 0.8527 - recall_score: 0.8250 - f1_score: 0.8385 - val_loss: 177.8566 - val_precision_score: 0.2937 - val_recall_score: 0.2937 - val_f1_score: 0.2937
# Epoch 27/50
# 5/5 [==============================] - 20s 4s/step - loss: 0.4424 - precision_score: 0.8393 - recall_score: 0.8188 - f1_score: 0.8289 - val_loss: 223.0051 - val_precision_score: 0.3562 - val_recall_score: 0.3562 - val_f1_score: 0.3562
# Epoch 28/50
# 5/5 [==============================] - 20s 4s/step - loss: 0.4767 - precision_score: 0.8287 - recall_score: 0.7937 - f1_score: 0.8106 - val_loss: 200.0229 - val_precision_score: 0.2937 - val_recall_score: 0.2937 - val_f1_score: 0.2937
# Epoch 29/50
# 5/5 [==============================] - 20s 4s/step - loss: 0.4000 - precision_score: 0.8239 - recall_score: 0.7875 - f1_score: 0.8051 - val_loss: 262.7960 - val_precision_score: 0.3500 - val_recall_score: 0.3500 - val_f1_score: 0.3500
# Epoch 30/50
# 5/5 [==============================] - 26s 5s/step - loss: 0.5223 - precision_score: 0.8062 - recall_score: 0.7812 - f1_score: 0.7934 - val_loss: 209.1395 - val_precision_score: 0.3187 - val_recall_score: 0.3187 - val_f1_score: 0.3187
# Epoch 31/50
# 5/5 [==============================] - 20s 4s/step - loss: 0.4841 - precision_score: 0.8313 - recall_score: 0.8062 - f1_score: 0.8184 - val_loss: 185.0926 - val_precision_score: 0.3295 - val_recall_score: 0.3295 - val_f1_score: 0.3295
# Epoch 32/50
# 5/5 [==============================] - 29s 6s/step - loss: 0.4611 - precision_score: 0.8436 - recall_score: 0.8188 - f1_score: 0.8308 - val_loss: 287.9825 - val_precision_score: 0.3000 - val_recall_score: 0.3000 - val_f1_score: 0.3000
# Epoch 33/50
# 5/5 [==============================] - 20s 4s/step - loss: 0.4992 - precision_score: 0.7967 - recall_score: 0.7375 - f1_score: 0.7657 - val_loss: 152.6792 - val_precision_score: 0.3438 - val_recall_score: 0.3438 - val_f1_score: 0.3437
# Epoch 34/50
# 5/5 [==============================] - 30s 6s/step - loss: 0.3714 - precision_score: 0.8650 - recall_score: 0.8438 - f1_score: 0.8541 - val_loss: 152.8247 - val_precision_score: 0.3750 - val_recall_score: 0.3750 - val_f1_score: 0.3750
# Epoch 35/50
# 5/5 [==============================] - 20s 4s/step - loss: 0.4621 - precision_score: 0.7887 - recall_score: 0.7625 - f1_score: 0.7753 - val_loss: 194.7434 - val_precision_score: 0.3438 - val_recall_score: 0.3438 - val_f1_score: 0.3437
# Epoch 36/50
# 5/5 [==============================] - 20s 4s/step - loss: 0.4257 - precision_score: 0.8657 - recall_score: 0.8438 - f1_score: 0.8546 - val_loss: 208.6060 - val_precision_score: 0.3313 - val_recall_score: 0.3313 - val_f1_score: 0.3312
# Epoch 37/50
# 5/5 [==============================] - 28s 6s/step - loss: 0.3201 - precision_score: 0.8842 - recall_score: 0.8500 - f1_score: 0.8664 - val_loss: 228.0121 - val_precision_score: 0.3438 - val_recall_score: 0.3438 - val_f1_score: 0.3437
# Epoch 38/50
# 5/5 [==============================] - 20s 4s/step - loss: 0.3927 - precision_score: 0.8358 - recall_score: 0.8250 - f1_score: 0.8302 - val_loss: 235.4938 - val_precision_score: 0.3097 - val_recall_score: 0.3097 - val_f1_score: 0.3097
# Epoch 39/50
# 5/5 [==============================] - 20s 4s/step - loss: 0.3738 - precision_score: 0.8538 - recall_score: 0.8375 - f1_score: 0.8455 - val_loss: 280.5202 - val_precision_score: 0.3125 - val_recall_score: 0.3125 - val_f1_score: 0.3125
# Epoch 40/50
# 5/5 [==============================] - 20s 4s/step - loss: 0.4186 - precision_score: 0.8479 - recall_score: 0.8062 - f1_score: 0.8264 - val_loss: 215.1083 - val_precision_score: 0.3938 - val_recall_score: 0.3938 - val_f1_score: 0.3937
# Epoch 41/50
# 5/5 [==============================] - 28s 6s/step - loss: 0.2958 - precision_score: 0.8892 - recall_score: 0.8562 - f1_score: 0.8723 - val_loss: 225.4808 - val_precision_score: 0.3250 - val_recall_score: 0.3250 - val_f1_score: 0.3250
# Epoch 42/50
# 5/5 [==============================] - 20s 4s/step - loss: 0.3075 - precision_score: 0.8844 - recall_score: 0.8625 - f1_score: 0.8732 - val_loss: 333.3369 - val_precision_score: 0.3375 - val_recall_score: 0.3375 - val_f1_score: 0.3375
# Epoch 43/50
# 5/5 [==============================] - 20s 4s/step - loss: 0.4072 - precision_score: 0.8353 - recall_score: 0.7937 - f1_score: 0.8139 - val_loss: 224.1349 - val_precision_score: 0.3000 - val_recall_score: 0.3000 - val_f1_score: 0.3000
# Epoch 44/50
# 5/5 [==============================] - 20s 4s/step - loss: 0.3267 - precision_score: 0.9042 - recall_score: 0.8813 - f1_score: 0.8926 - val_loss: 138.2442 - val_precision_score: 0.3938 - val_recall_score: 0.3938 - val_f1_score: 0.3937
# Epoch 45/50
# 5/5 [==============================] - 35s 7s/step - loss: 0.4292 - precision_score: 0.8242 - recall_score: 0.7937 - f1_score: 0.8086 - val_loss: 225.9680 - val_precision_score: 0.3250 - val_recall_score: 0.3250 - val_f1_score: 0.3250
# Epoch 46/50
# 5/5 [==============================] - 19s 4s/step - loss: 0.3161 - precision_score: 0.8902 - recall_score: 0.8687 - f1_score: 0.8787 - val_loss: 267.8238 - val_precision_score: 0.2580 - val_recall_score: 0.2580 - val_f1_score: 0.2580
# Epoch 47/50
# 5/5 [==============================] - 20s 4s/step - loss: 0.4360 - precision_score: 0.8413 - recall_score: 0.8188 - f1_score: 0.8298 - val_loss: 174.2728 - val_precision_score: 0.3438 - val_recall_score: 0.3438 - val_f1_score: 0.3437
# Epoch 48/50
# 5/5 [==============================] - 20s 4s/step - loss: 0.3442 - precision_score: 0.8366 - recall_score: 0.8062 - f1_score: 0.8208 - val_loss: 126.0653 - val_precision_score: 0.4313 - val_recall_score: 0.4313 - val_f1_score: 0.4312
# Epoch 49/50
# 5/5 [==============================] - 33s 7s/step - loss: 0.4022 - precision_score: 0.7988 - recall_score: 0.7937 - f1_score: 0.7962 - val_loss: 326.5579 - val_precision_score: 0.3313 - val_recall_score: 0.3313 - val_f1_score: 0.3312
# Epoch 50/50
# 5/5 [==============================] - 20s 4s/step - loss: 0.4131 - precision_score: 0.8454 - recall_score: 0.8188 - f1_score: 0.8317 - val_loss: 279.2697 - val_precision_score: 0.3500 - val_recall_score: 0.3500 - val_f1_score: 0.3500

# %%
# Exibindo dados de Precisão
plt.plot(history.history['precision_score'])
plt.plot(history.history['val_precision_score'])
plt.title('model precision')
plt.ylabel('precision')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de Sensibilidade
plt.plot(history.history['recall_score'])
plt.plot(history.history['val_recall_score'])
plt.title('model recall')
plt.ylabel('recall')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de F1 Score
plt.plot(history.history['f1_score'])
plt.plot(history.history['val_f1_score'])
plt.title('model f1_score')
plt.ylabel('f1_score')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de Perda
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# ### 4.8.1 Conclusões sobre a abordagem extra
#
# Como seu modelo performou em comparação com os demais modelos anteriores? Justifique sua resposta levando em consideração a arquitetura respectiva.

# %% [markdown]
# **Resposta**:
