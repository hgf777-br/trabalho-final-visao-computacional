# %% [markdown]
# # MBA FIAP Inteligência Artificial & Machine Learning
#
# ## Visão Computacional: Análise de Imagens Médicas
#
# ## 1. Introdução
#
# As tecnologias de imagens médicas estão cada vez mais integradas aos sitemas de visão computacional, incluindo as imagens de raio-x.
#
# Modelos de equipamentos modernos geram imagens digitais deste tipo de exame, proporcionando análises mais completas e menos _ad-hoc_, com isso algumas pré-análises podem ser realizadas por aplicações baseadas em inteligência artificial para confirmar ou sugerir diagnósticos ao profissional responsável pelo exame.
#
# No campo dos diagósticos por raios-x, a pnenumonia é uma das enfermidades onde seu uso é um dos mais aplicados para determinar o curso de tratamento.
#
# <p align="center">
#     <img src="imagens/NORMAL2-IM-1422-0001.jpeg">
# </p>
#
# ## 2. Instruções
#
# Este projeto final tem como objetivo explorar os conhecimentos adquiridos nas aulas práticas.
#
# Por meio de uma trilha guiada, iremos constuir um modelo que seja capaz de classificar imagens de raio-x para determinar se a determinada pessoa está com alguma condição que necessita maiores cuidados.
#
# De acordo com as imagens disponíveis para o treinamento e validação, será de critério do grupo selecionar as quantidades ideais ou até mesmo pré-processar as imagens para obter o melhor resultado, nos principais indicadores de performance, como precisão, sensibilidade e pontuação F1.
#
# Este projeto poderá ser feita por grupos de até 4 pessoas.
# Caso este projeto seja substitutivo, deverá ser realizado por apenas uma pessoa.
#
# | Nome dos Integrantes     | RM            | Turma |
# | :----------------------- | :------------- | :-----: |
# | Camila Okamura           | RM 339624      | `17IA` |
# | Cleiton Lima             | RM 339656      | `17IA` |
# | Henrique Faria           | RM 340214      | `17IA` |
#
# Por ser um projeto guiado, fique atento quando houver as marcações **Implementação** indica que é necessário realizar alguma implementação em Python no bloco a seguir onde há a inscrição ```##IMPLEMENTAR``` e **Resposta** indica que é esperado uma resposta objetiva relacionado a algum questionamento.
#
# **Cada grupo pode utilizar nas respostas objetivas quaisquer itens necessários que enriqueçam seu ponto vista, como gráficos, fotos e, até mesmo, trechos de código-fonte.**
#
# Pode-se utilizar quantos blocos forem necessários para realizar determinadas implementações ou utilizá-las para justificar as respostas. Não é obrigatório utilizar somente o bloco indicado.
#
# Ao final não se esqueça de subir os arquivos do projeto nas contas do GitHub de cada membro, ou subir na do representante do grupo e os membros realizarem o fork do projeto.
#
# A avaliação terá mais ênfase nos seguintes tópicos de desenvolvimento do projeto:
#
# 1. __Pré-Processamento__
# 2. __Classificação__
# 3. __Performance__
# 4. __Conclusões Finais__

# %% [markdown]
# ## 3.1 Detalhe do problema: a pneunomia
#
# Fonte: [artigo](https://drauziovarella.uol.com.br/doencas-e-sintomas/pneumonia) do Dr. Drauzio Varella.
#
# Pneumonias são infecções que se instalam nos pulmões, órgãos duplos localizados um de cada lado da caixa torácica. Podem acometer a região dos alvéolos pulmonares onde desembocam as ramificações terminais dos brônquios e, às vezes, os interstícios (espaço entre um alvéolo e outro).
#
# Basicamente, pneumonia é provocada pela penetração de um agente infeccioso ou irritante (bactérias, vírus, fungos e por reações alérgicas) no espaço alveolar, onde ocorre a troca gasosa. Esse local deve estar sempre muito limpo, livre de substâncias que possam impedir o contato do ar com o sangue.
#
# Exame clínico, auscultação dos pulmões e radiografias de tórax são recursos essenciais para o diagnóstico de pneumonia.
#
# <p align="center">
#     <img src="imagens/pneumonia.jpeg">
# </p>

# %% [markdown]
# ## 3.2 Diagnóstico por raio-x

# %% [markdown]
# O exame de raio-x traz diferenças em cada tipo de diagnóstico, sendo considerado os seguintes grupos de análise: **normal** (ou controle) onde não há nenhuma condição de infeção, **bacterial pneumonia** (pneumonia bacteriana) que representa a condição de infecção bacteriana e **viral pneumonia** que indica a condição de infecção vira.

# %% [markdown]
# <p align="center">
# <img src="imagens/raiox.png" height="60%" width="60%">
# </p>

# %% [markdown]
# As imagens de controle não são mais brancas ao centro que é onde fica o coração. Já nas imagens com pneumonia é possível notar regiões brancas ao redor dos pulmões, que é como o exame identifica as secreções responsáveis pela infeçcão.
#
# Quando mais regiões brancas ao redor do pulmão mais severa é a inflamação e menos se observa dos detalhes dos pulmões, ficando um pouco esmaecido diante desta condição.

# %% [markdown]
# ## 4.1 Problema
#
# Construir um classificador utilizando _transfer learning_ para identificar as seguintes classes: **controle**, **pneumonia bacteriana** e **pneumonia viral**.
#
# Para construir este classificador, utilize o dataset do [Kaggle Chest Ray Pneumonia](https://www.kaggle.com/paultimothymooney/chest-xray-pneumonia) e organize os dados de forma a separar em cada uma das classes que já estão definidas no diretório ```raiox```, sendo ```controle``` para as imagens normais (sem inflamação), ```bacteria``` para as imagens de pneumonia bacteriana e ```viral``` para as imagens de pneumonia viral.
#
# Determine a quantidade de imagens a serem treinadas e validadas. Utiliza pelo menos, 100 imagens para cada classe.
#
# Compare os resultados com pelo menos 3 classificadores, obtendo os valores de **precisão (precision)**, **sensibilidade (recall)** e **pontuação F1 (F1 Score)**. No guia abaixo, foi indicado os seguintes modelos: ResNet50, VGG16 e VGG19.
#
# >Importante: a escolha do número de imagens devem ser o suficiente para alcançar o valor de **precisão** mínima de 70%.
#
# A construção do modelo será utilizada o framework Keras.

# %% [markdown]
# **Pergunta**: Qual o número de imagens que foram selecionadas para cada classe?

# %% [markdown]
# **Resposta**:
#
# controle
# bacteria
# viral

# %% [markdown]
# ## 4.2 Componentes obrigatórios
#
# Este projeto requer a instalação dos seguintes componentes, via ```conda install```:
#
# * Keras
# * Tensorflow
# * Pillow
# * Matplotlib

# %%
import shutil
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import glob
import cv2
from PIL import Image

# %matplotlib inline

import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.applications import ResNet50, vgg16, vgg19, Xception
from keras.applications import Xception
from keras.applications.xception import preprocess_input
from keras.applications.resnet import preprocess_input as res_pre_input
from keras.applications.vgg16 import preprocess_input as vgg16_pre_input
from keras.applications.vgg19 import preprocess_input as vgg19_pre_input
from keras import Model, layers, Sequential
from keras.models import load_model, model_from_json

import keras.backend as K

plt.style.use('seaborn')
sns.set_style("whitegrid")

# %% [markdown]
# # Funções Auxiliares

# %% [markdown]
# ## 4.3 Carregando imagens de treinamento e validação
#
# Selecione a melhor divisão entre dados de treinamento e validação. O número deverá ser representado em número fracionário, 5% equivale a 0.05, por exemplo.

# %% [markdown]
# ### Analisando a base de dados original encontramos 3 pastas: train, test and val. A pasta val, de validação tem apenas 8 imagens normais e 8 imagens com pneumonia. Por ser muito pouco decidimos juntá-las a pasta de treino.<BR>Depois separamos os dados de treino e teste em 3 pastas, uma para cada uma das nossas classes.

# %%
train_path = "./raiox/train/"
test_path = "./raiox/test/"

# %% [markdown]
# ## Plotamos a distribuição das classses de treino e percebemos que temos uma quantidade muito maior da classe bactéria o que pode enviesar o nosso estudo.

# %%
normal = glob.glob(train_path + "normal/*.jpeg")
virus = glob.glob(train_path + "virus/*.jpeg")
bacteria = glob.glob(train_path + "bacteria/*.jpeg")

sns.barplot(x = ["normal", "virus", "bacteria"], y = [len(normal), len(virus), len(bacteria)])
plt.show()

# %% [markdown]
# ### Vamos retirar as imagens da classe bacteria que possuem uma razão entre X e Y menor que 0.67 para equalizarmos a quantidade das três classes.

# %%
bacteria_shape = []
count = 0
for idx, file in enumerate(bacteria):
    imagem = cv2.imread(file)
    shape = imagem.shape[0]/imagem.shape[1]
    if shape < 0.67:
        bacteria_shape.append(idx)
        count += 1
print(count)
# Out:
# 1208

# %%
# Rodar apenas na primeira vez para separar as imagens
#for idx in bacteria_shape:
#    shutil.move(bacteria[idx], train_path + "../bacteria_retirados/")

# %%
bacteria = glob.glob(train_path + "bacteria/*.jpeg")
sns.barplot(x = ["normal", "virus", "bacteria"], y = [len(normal), len(virus), len(bacteria)])
plt.show()

# %%
normal = glob.glob(test_path + "normal/*.jpeg")
virus = glob.glob(test_path + "virus/*.jpeg")
bacteria = glob.glob(test_path + "bacteria/*.jpeg")

sns.barplot(x = ["normal", "virus", "bacteria"], y = [len(normal), len(virus), len(bacteria)])
plt.show()

# %%
#divisao_treino_validacao = 0.2

# %%
train_datagen = ImageDataGenerator(
    preprocessing_function=res_pre_input,
    zoom_range=0.2,
    rotation_range=0.2,
    horizontal_flip=True,)

train_generator = train_datagen.flow_from_directory(
    "raiox/train/",
    seed=42,
    batch_size=32,
    class_mode="categorical",
    color_mode="rgb",
    target_size=(224,224))

STEP_SIZE_TRAIN = train_generator.n // train_generator.batch_size
print(STEP_SIZE_TRAIN)
# Out:
# Found 5232 images belonging to 3 classes.
# 163

# %%
val_datagen = ImageDataGenerator(preprocessing_function=res_pre_input)

val_generator = val_datagen.flow_from_directory(
    "raiox/test/",
    seed=42,
    batch_size=32,
    class_mode="categorical",
    color_mode="rgb",
    target_size=(224,224))

STEP_SIZE_VALID = val_generator.n // val_generator.batch_size
print(STEP_SIZE_VALID)
# Out:
# Found 624 images belonging to 3 classes.
# 19

# %%
train_generator.class_indices, val_generator.class_indices
# Out:
# ({'bacteria': 0, 'normal': 1, 'virus': 2},
#  {'bacteria': 0, 'normal': 1, 'virus': 2})

# %% [markdown]
# ## 4.4 Modelos de transfer learning
#
# O Keras já possui classes especializadas para os seguintes modelos de deep-learning treinados com o conjunto de dados [ImageNet](http://www.image-net.org/):
#
# * Xception
# * VGG16
# * VGG19
# * ResNet50
# * InceptionV3
# * InceptionResNetV2
# * MobileNet
# * DenseNet
# * NASNet
# * MobileNetV2
#
# Mais detalhes, veja na [documentação do Keras](https://keras.io/applications/).

# %% [markdown]
# Para este estudo, vamos utilizar para avaliação as seguintes arquiteturas: RestNet50, VGG16 e VGG19.

# %% [markdown]
# ## 4.5 Indicadores de desempenho
#
# O Keras não possui os indicadores de desempenho como precisão, sensibilidade e pontuação f1 por padrão, portanto precisamos implementar externamente.

# %%
def recall_score(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision_score(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1_score(y_true, y_pred):
    precision = precision_score(y_true, y_pred)
    recall = recall_score(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

class ModelCheckpoint_tweaked(tf.keras.callbacks.ModelCheckpoint):
    def __init__(self,
                   filepath,
                   monitor='val_loss',
                   verbose=0,
                   save_best_only=False,
                   save_weights_only=False,
                   mode='auto',
                   save_freq='epoch',
                   options=None,
                   **kwargs):
        
        #Change tf_utils source package.
        from tensorflow.python.keras.utils import tf_utils
        
        super(ModelCheckpoint_tweaked, self).__init__(filepath,
                   monitor,
                   verbose,
                   save_best_only,
                   save_weights_only,
                   mode,
                   save_freq,
                   options,
                   **kwargs)

# %% [markdown]
# ### 4.5.1 Arquitetura ResNet50

# %% [markdown]
# **Pergunta**: Explique como é constituída a arquitetura do ResNet50? *Utilize, se necessário, gráficos, projetos que utilizam essa arquitetura. Detalhe também sua topologia em camadas e mostre quais as situações essa arquitetura pode ter mais êxito e quais cenários não tem.*

# %% [markdown]
# **Resposta**:

# %% [markdown]
# A técnica de transfer learning consiste de utilizar o mesmo modelo e treiná-lo para outas imagens. Por tal motivo, excluímos a última camada para modelar com as classes que definimos, ou seja, **controle**, **bacteriana** e **viral**.

# %% [markdown]
# Informe a quantidade de classes a serem classificadas.

# %%
## IMPLEMENTE

qtde_classes = 3

# %%
conv_base = ResNet50(weights="imagenet", include_top=False)

for layer in conv_base.layers:
    layer.trainable = False

# %%
x = conv_base.output
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(128, activation='relu')(x) 

predictions = layers.Dense(qtde_classes, activation='softmax')(x)
model = Model(conv_base.input, predictions)

model.summary()
# Out:
# Model: "functional_7"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_6 (InputLayer)            [(None, None, None,  0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, None, None, 3 0           input_6[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, None, None, 6 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, None, None, 6 256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, None, None, 6 0           conv1_bn[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, None, None, 6 0           conv1_relu[0][0]
# __________________________________________________________________________________________________
# pool1_pool (MaxPooling2D)       (None, None, None, 6 0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, None, None, 6 4160        pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, None, None, 6 256         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, None, None, 6 0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, None, None, 6 36928       conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_bn (BatchNormali (None, None, None, 6 256         conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_relu (Activation (None, None, None, 6 0           conv2_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_conv (Conv2D)    (None, None, None, 2 16640       pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_conv (Conv2D)    (None, None, None, 2 16640       conv2_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_bn (BatchNormali (None, None, None, 2 1024        conv2_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_bn (BatchNormali (None, None, None, 2 1024        conv2_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_add (Add)          (None, None, None, 2 0           conv2_block1_0_bn[0][0]
#                                                                  conv2_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_out (Activation)   (None, None, None, 2 0           conv2_block1_add[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, None, None, 6 16448       conv2_block1_out[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, None, None, 6 256         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, None, None, 6 0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, None, None, 6 36928       conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_bn (BatchNormali (None, None, None, 6 256         conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_relu (Activation (None, None, None, 6 0           conv2_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_conv (Conv2D)    (None, None, None, 2 16640       conv2_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_bn (BatchNormali (None, None, None, 2 1024        conv2_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_add (Add)          (None, None, None, 2 0           conv2_block1_out[0][0]
#                                                                  conv2_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_out (Activation)   (None, None, None, 2 0           conv2_block2_add[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, None, None, 6 16448       conv2_block2_out[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, None, None, 6 256         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, None, None, 6 0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, None, None, 6 36928       conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_bn (BatchNormali (None, None, None, 6 256         conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_relu (Activation (None, None, None, 6 0           conv2_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_conv (Conv2D)    (None, None, None, 2 16640       conv2_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_bn (BatchNormali (None, None, None, 2 1024        conv2_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_add (Add)          (None, None, None, 2 0           conv2_block2_out[0][0]
#                                                                  conv2_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_out (Activation)   (None, None, None, 2 0           conv2_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, None, None, 1 32896       conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, None, None, 1 512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (Activation (None, None, None, 1 0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, None, None, 1 147584      conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_bn (BatchNormali (None, None, None, 1 512         conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_relu (Activation (None, None, None, 1 0           conv3_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_conv (Conv2D)    (None, None, None, 5 131584      conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_conv (Conv2D)    (None, None, None, 5 66048       conv3_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_bn (BatchNormali (None, None, None, 5 2048        conv3_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_bn (BatchNormali (None, None, None, 5 2048        conv3_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_add (Add)          (None, None, None, 5 0           conv3_block1_0_bn[0][0]
#                                                                  conv3_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_out (Activation)   (None, None, None, 5 0           conv3_block1_add[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, None, None, 1 65664       conv3_block1_out[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, None, None, 1 512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (Activation (None, None, None, 1 0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, None, None, 1 147584      conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_bn (BatchNormali (None, None, None, 1 512         conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_relu (Activation (None, None, None, 1 0           conv3_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_conv (Conv2D)    (None, None, None, 5 66048       conv3_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_bn (BatchNormali (None, None, None, 5 2048        conv3_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_add (Add)          (None, None, None, 5 0           conv3_block1_out[0][0]
#                                                                  conv3_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_out (Activation)   (None, None, None, 5 0           conv3_block2_add[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, None, None, 1 65664       conv3_block2_out[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, None, None, 1 512         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (Activation (None, None, None, 1 0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, None, None, 1 147584      conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_bn (BatchNormali (None, None, None, 1 512         conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_relu (Activation (None, None, None, 1 0           conv3_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_conv (Conv2D)    (None, None, None, 5 66048       conv3_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_bn (BatchNormali (None, None, None, 5 2048        conv3_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_add (Add)          (None, None, None, 5 0           conv3_block2_out[0][0]
#                                                                  conv3_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_out (Activation)   (None, None, None, 5 0           conv3_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, None, None, 1 65664       conv3_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, None, None, 1 512         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (Activation (None, None, None, 1 0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, None, None, 1 147584      conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_bn (BatchNormali (None, None, None, 1 512         conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_relu (Activation (None, None, None, 1 0           conv3_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_conv (Conv2D)    (None, None, None, 5 66048       conv3_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_bn (BatchNormali (None, None, None, 5 2048        conv3_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_add (Add)          (None, None, None, 5 0           conv3_block3_out[0][0]
#                                                                  conv3_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_out (Activation)   (None, None, None, 5 0           conv3_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, None, None, 2 131328      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, None, None, 2 1024        conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (Activation (None, None, None, 2 0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, None, None, 2 590080      conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_bn (BatchNormali (None, None, None, 2 1024        conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_relu (Activation (None, None, None, 2 0           conv4_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_conv (Conv2D)    (None, None, None, 1 525312      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_conv (Conv2D)    (None, None, None, 1 263168      conv4_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_bn (BatchNormali (None, None, None, 1 4096        conv4_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_bn (BatchNormali (None, None, None, 1 4096        conv4_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_add (Add)          (None, None, None, 1 0           conv4_block1_0_bn[0][0]
#                                                                  conv4_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_out (Activation)   (None, None, None, 1 0           conv4_block1_add[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, None, None, 2 262400      conv4_block1_out[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, None, None, 2 1024        conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, None, None, 2 0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, None, None, 2 590080      conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_bn (BatchNormali (None, None, None, 2 1024        conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_relu (Activation (None, None, None, 2 0           conv4_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_conv (Conv2D)    (None, None, None, 1 263168      conv4_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_bn (BatchNormali (None, None, None, 1 4096        conv4_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_add (Add)          (None, None, None, 1 0           conv4_block1_out[0][0]
#                                                                  conv4_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_out (Activation)   (None, None, None, 1 0           conv4_block2_add[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, None, None, 2 262400      conv4_block2_out[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, None, None, 2 1024        conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, None, None, 2 0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, None, None, 2 590080      conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_bn (BatchNormali (None, None, None, 2 1024        conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_relu (Activation (None, None, None, 2 0           conv4_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_conv (Conv2D)    (None, None, None, 1 263168      conv4_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_bn (BatchNormali (None, None, None, 1 4096        conv4_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_add (Add)          (None, None, None, 1 0           conv4_block2_out[0][0]
#                                                                  conv4_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_out (Activation)   (None, None, None, 1 0           conv4_block3_add[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, None, None, 2 262400      conv4_block3_out[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, None, None, 2 1024        conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, None, None, 2 0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, None, None, 2 590080      conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_bn (BatchNormali (None, None, None, 2 1024        conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_relu (Activation (None, None, None, 2 0           conv4_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_conv (Conv2D)    (None, None, None, 1 263168      conv4_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_bn (BatchNormali (None, None, None, 1 4096        conv4_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_add (Add)          (None, None, None, 1 0           conv4_block3_out[0][0]
#                                                                  conv4_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_out (Activation)   (None, None, None, 1 0           conv4_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, None, None, 2 262400      conv4_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, None, None, 2 1024        conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, None, None, 2 0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, None, None, 2 590080      conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_bn (BatchNormali (None, None, None, 2 1024        conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_relu (Activation (None, None, None, 2 0           conv4_block5_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_conv (Conv2D)    (None, None, None, 1 263168      conv4_block5_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_bn (BatchNormali (None, None, None, 1 4096        conv4_block5_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_add (Add)          (None, None, None, 1 0           conv4_block4_out[0][0]
#                                                                  conv4_block5_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_out (Activation)   (None, None, None, 1 0           conv4_block5_add[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, None, None, 2 262400      conv4_block5_out[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, None, None, 2 1024        conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (Activation (None, None, None, 2 0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, None, None, 2 590080      conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_bn (BatchNormali (None, None, None, 2 1024        conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_relu (Activation (None, None, None, 2 0           conv4_block6_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_conv (Conv2D)    (None, None, None, 1 263168      conv4_block6_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_bn (BatchNormali (None, None, None, 1 4096        conv4_block6_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_add (Add)          (None, None, None, 1 0           conv4_block5_out[0][0]
#                                                                  conv4_block6_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_out (Activation)   (None, None, None, 1 0           conv4_block6_add[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_conv (Conv2D)    (None, None, None, 5 524800      conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_bn (BatchNormali (None, None, None, 5 2048        conv5_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_relu (Activation (None, None, None, 5 0           conv5_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_conv (Conv2D)    (None, None, None, 5 2359808     conv5_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_bn (BatchNormali (None, None, None, 5 2048        conv5_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_relu (Activation (None, None, None, 5 0           conv5_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_conv (Conv2D)    (None, None, None, 2 2099200     conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_conv (Conv2D)    (None, None, None, 2 1050624     conv5_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_bn (BatchNormali (None, None, None, 2 8192        conv5_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_bn (BatchNormali (None, None, None, 2 8192        conv5_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_add (Add)          (None, None, None, 2 0           conv5_block1_0_bn[0][0]
#                                                                  conv5_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_out (Activation)   (None, None, None, 2 0           conv5_block1_add[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_conv (Conv2D)    (None, None, None, 5 1049088     conv5_block1_out[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_bn (BatchNormali (None, None, None, 5 2048        conv5_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_relu (Activation (None, None, None, 5 0           conv5_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_conv (Conv2D)    (None, None, None, 5 2359808     conv5_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_bn (BatchNormali (None, None, None, 5 2048        conv5_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_relu (Activation (None, None, None, 5 0           conv5_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_conv (Conv2D)    (None, None, None, 2 1050624     conv5_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_bn (BatchNormali (None, None, None, 2 8192        conv5_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_add (Add)          (None, None, None, 2 0           conv5_block1_out[0][0]
#                                                                  conv5_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_out (Activation)   (None, None, None, 2 0           conv5_block2_add[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_conv (Conv2D)    (None, None, None, 5 1049088     conv5_block2_out[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_bn (BatchNormali (None, None, None, 5 2048        conv5_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_relu (Activation (None, None, None, 5 0           conv5_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_conv (Conv2D)    (None, None, None, 5 2359808     conv5_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_bn (BatchNormali (None, None, None, 5 2048        conv5_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_relu (Activation (None, None, None, 5 0           conv5_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_conv (Conv2D)    (None, None, None, 2 1050624     conv5_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_bn (BatchNormali (None, None, None, 2 8192        conv5_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_add (Add)          (None, None, None, 2 0           conv5_block2_out[0][0]
#                                                                  conv5_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_out (Activation)   (None, None, None, 2 0           conv5_block3_add[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_3 (Glo (None, 2048)         0           conv5_block3_out[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 128)          262272      global_average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 3)            387         dense_6[0][0]
# ==================================================================================================
# Total params: 23,850,371
# Trainable params: 262,659
# Non-trainable params: 23,587,712
# __________________________________________________________________________________________________

# %%
optimizer = keras.optimizers.Adam()
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=[precision_score, recall_score, f1_score])

# %% [markdown]
# O número de épocas define quantas vezes o modelo irá treinar e validar o erro, assim ajustando os pesos para melhor convergência.
# Escolha o número adequado de épocas para alcançarmos pelo menos **70% de precisão de validação**.

# %%
## IMPLEMENTE

qtde_epocas = 100

# %%
checkpointer = ModelCheckpoint_tweaked(filepath='./modelo_resnet50.hdf5', verbose=1,  mode='max', save_best_only=True, monitor='val_f1_score')

history = model.fit(train_generator, 
                    epochs=qtde_epocas,
                    validation_steps=5,
                    steps_per_epoch=5,
                    validation_data=val_generator,
                    callbacks=[checkpointer])

#history = model.fit(train_generator, 
 #                           epochs=qtde_epocas,
 #                           batch_size=128,   
 #                           validation_data=val_generator,
 #                           callbacks=[checkpointer])
# Out:
# Epoch 1/100
# 5/5 [==============================] - ETA: 0s - loss: 1.3021 - precision_score: 0.4978 - recall_score: 0.4062 - f1_score: 0.4456
# Epoch 00001: val_f1_score improved from -inf to 0.57139, saving model to .\modelo_resnet50.hdf5
# 5/5 [==============================] - 6s 1s/step - loss: 1.3021 - precision_score: 0.4978 - recall_score: 0.4062 - f1_score: 0.4456 - val_loss: 0.9938 - val_precision_score: 0.5807 - val_recall_score: 0.5625 - val_f1_score: 0.5714
# Epoch 2/100
# 5/5 [==============================] - ETA: 0s - loss: 0.8026 - precision_score: 0.6689 - recall_score: 0.6125 - f1_score: 0.6385
# Epoch 00002: val_f1_score improved from 0.57139 to 0.66504, saving model to .\modelo_resnet50.hdf5
# 5/5 [==============================] - 5s 1s/step - loss: 0.8026 - precision_score: 0.6689 - recall_score: 0.6125 - f1_score: 0.6385 - val_loss: 0.7899 - val_precision_score: 0.6969 - val_recall_score: 0.6375 - val_f1_score: 0.6650
# Epoch 3/100
# 5/5 [==============================] - ETA: 0s - loss: 0.7156 - precision_score: 0.7261 - recall_score: 0.6875 - f1_score: 0.7051
# Epoch 00003: val_f1_score improved from 0.66504 to 0.66919, saving model to .\modelo_resnet50.hdf5
# 5/5 [==============================] - 5s 966ms/step - loss: 0.7156 - precision_score: 0.7261 - recall_score: 0.6875 - f1_score: 0.7051 - val_loss: 0.7726 - val_precision_score: 0.7206 - val_recall_score: 0.6250 - val_f1_score: 0.6692
# Epoch 4/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5772 - precision_score: 0.7632 - recall_score: 0.7437 - f1_score: 0.7533
# Epoch 00004: val_f1_score improved from 0.66919 to 0.68998, saving model to .\modelo_resnet50.hdf5
# 5/5 [==============================] - 5s 1s/step - loss: 0.5772 - precision_score: 0.7632 - recall_score: 0.7437 - f1_score: 0.7533 - val_loss: 0.7008 - val_precision_score: 0.7132 - val_recall_score: 0.6687 - val_f1_score: 0.6900
# Epoch 5/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5874 - precision_score: 0.7571 - recall_score: 0.7063 - f1_score: 0.7306
# Epoch 00005: val_f1_score improved from 0.68998 to 0.71858, saving model to .\modelo_resnet50.hdf5
# 5/5 [==============================] - 5s 1s/step - loss: 0.5874 - precision_score: 0.7571 - recall_score: 0.7063 - f1_score: 0.7306 - val_loss: 0.7180 - val_precision_score: 0.7532 - val_recall_score: 0.6875 - val_f1_score: 0.7186
# Epoch 6/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5775 - precision_score: 0.7834 - recall_score: 0.7250 - f1_score: 0.7526
# Epoch 00006: val_f1_score improved from 0.71858 to 0.79833, saving model to .\modelo_resnet50.hdf5
# 5/5 [==============================] - 5s 1s/step - loss: 0.5775 - precision_score: 0.7834 - recall_score: 0.7250 - f1_score: 0.7526 - val_loss: 0.4693 - val_precision_score: 0.8460 - val_recall_score: 0.7563 - val_f1_score: 0.7983
# Epoch 7/100
# 5/5 [==============================] - ETA: 0s - loss: 0.6110 - precision_score: 0.7768 - recall_score: 0.7625 - f1_score: 0.7695
# Epoch 00007: val_f1_score did not improve from 0.79833
# 5/5 [==============================] - 4s 828ms/step - loss: 0.6110 - precision_score: 0.7768 - recall_score: 0.7625 - f1_score: 0.7695 - val_loss: 0.6990 - val_precision_score: 0.7616 - val_recall_score: 0.7000 - val_f1_score: 0.7293
# Epoch 8/100
# 5/5 [==============================] - ETA: 0s - loss: 0.6346 - precision_score: 0.7832 - recall_score: 0.7437 - f1_score: 0.7627
# Epoch 00008: val_f1_score did not improve from 0.79833
# 5/5 [==============================] - 4s 873ms/step - loss: 0.6346 - precision_score: 0.7832 - recall_score: 0.7437 - f1_score: 0.7627 - val_loss: 0.5730 - val_precision_score: 0.8046 - val_recall_score: 0.7437 - val_f1_score: 0.7729
# Epoch 9/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5091 - precision_score: 0.8319 - recall_score: 0.7688 - f1_score: 0.7988
# Epoch 00009: val_f1_score did not improve from 0.79833
# 5/5 [==============================] - 4s 798ms/step - loss: 0.5091 - precision_score: 0.8319 - recall_score: 0.7688 - f1_score: 0.7988 - val_loss: 0.6343 - val_precision_score: 0.7913 - val_recall_score: 0.7312 - val_f1_score: 0.7599
# Epoch 10/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5724 - precision_score: 0.7964 - recall_score: 0.7375 - f1_score: 0.7649
# Epoch 00010: val_f1_score did not improve from 0.79833
# 5/5 [==============================] - 4s 740ms/step - loss: 0.5724 - precision_score: 0.7964 - recall_score: 0.7375 - f1_score: 0.7649 - val_loss: 0.6257 - val_precision_score: 0.8209 - val_recall_score: 0.7750 - val_f1_score: 0.7972
# Epoch 11/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5118 - precision_score: 0.8430 - recall_score: 0.7937 - f1_score: 0.8173
# Epoch 00011: val_f1_score did not improve from 0.79833
# 5/5 [==============================] - 4s 742ms/step - loss: 0.5118 - precision_score: 0.8430 - recall_score: 0.7937 - f1_score: 0.8173 - val_loss: 0.4916 - val_precision_score: 0.8060 - val_recall_score: 0.7563 - val_f1_score: 0.7802
# Epoch 12/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4958 - precision_score: 0.7847 - recall_score: 0.7375 - f1_score: 0.7600
# Epoch 00012: val_f1_score improved from 0.79833 to 0.80000, saving model to .\modelo_resnet50.hdf5
# 5/5 [==============================] - 5s 981ms/step - loss: 0.4958 - precision_score: 0.7847 - recall_score: 0.7375 - f1_score: 0.7600 - val_loss: 0.5393 - val_precision_score: 0.8267 - val_recall_score: 0.7750 - val_f1_score: 0.8000
# Epoch 13/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5228 - precision_score: 0.8221 - recall_score: 0.7563 - f1_score: 0.7873
# Epoch 00013: val_f1_score did not improve from 0.80000
# 5/5 [==============================] - 4s 766ms/step - loss: 0.5228 - precision_score: 0.8221 - recall_score: 0.7563 - f1_score: 0.7873 - val_loss: 0.7735 - val_precision_score: 0.7465 - val_recall_score: 0.6875 - val_f1_score: 0.7153
# Epoch 14/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5835 - precision_score: 0.7543 - recall_score: 0.7125 - f1_score: 0.7324
# Epoch 00014: val_f1_score did not improve from 0.80000
# 5/5 [==============================] - 4s 724ms/step - loss: 0.5835 - precision_score: 0.7543 - recall_score: 0.7125 - f1_score: 0.7324 - val_loss: 0.5147 - val_precision_score: 0.7977 - val_recall_score: 0.7188 - val_f1_score: 0.7557
# Epoch 15/100
# 5/5 [==============================] - ETA: 0s - loss: 0.6279 - precision_score: 0.7997 - recall_score: 0.7812 - f1_score: 0.7902
# Epoch 00015: val_f1_score did not improve from 0.80000
# 5/5 [==============================] - 4s 761ms/step - loss: 0.6279 - precision_score: 0.7997 - recall_score: 0.7812 - f1_score: 0.7902 - val_loss: 0.5600 - val_precision_score: 0.8165 - val_recall_score: 0.7500 - val_f1_score: 0.7811
# Epoch 16/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5717 - precision_score: 0.7555 - recall_score: 0.7188 - f1_score: 0.7366
# Epoch 00016: val_f1_score did not improve from 0.80000
# 5/5 [==============================] - 4s 749ms/step - loss: 0.5717 - precision_score: 0.7555 - recall_score: 0.7188 - f1_score: 0.7366 - val_loss: 0.5269 - val_precision_score: 0.8332 - val_recall_score: 0.7500 - val_f1_score: 0.7893
# Epoch 17/100
# 5/5 [==============================] - ETA: 0s - loss: 0.6666 - precision_score: 0.7290 - recall_score: 0.6812 - f1_score: 0.7039
# Epoch 00017: val_f1_score did not improve from 0.80000
# 5/5 [==============================] - 4s 743ms/step - loss: 0.6666 - precision_score: 0.7290 - recall_score: 0.6812 - f1_score: 0.7039 - val_loss: 0.5623 - val_precision_score: 0.8233 - val_recall_score: 0.7500 - val_f1_score: 0.7844
# Epoch 18/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5656 - precision_score: 0.7844 - recall_score: 0.7250 - f1_score: 0.7531
# Epoch 00018: val_f1_score improved from 0.80000 to 0.80385, saving model to .\modelo_resnet50.hdf5
# 5/5 [==============================] - 5s 939ms/step - loss: 0.5656 - precision_score: 0.7844 - recall_score: 0.7250 - f1_score: 0.7531 - val_loss: 0.6165 - val_precision_score: 0.8283 - val_recall_score: 0.7812 - val_f1_score: 0.8039
# Epoch 19/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5381 - precision_score: 0.7653 - recall_score: 0.7500 - f1_score: 0.7575
# Epoch 00019: val_f1_score improved from 0.80385 to 0.82766, saving model to .\modelo_resnet50.hdf5
# 5/5 [==============================] - 5s 947ms/step - loss: 0.5381 - precision_score: 0.7653 - recall_score: 0.7500 - f1_score: 0.7575 - val_loss: 0.5228 - val_precision_score: 0.8580 - val_recall_score: 0.8000 - val_f1_score: 0.8277
# Epoch 20/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5308 - precision_score: 0.7798 - recall_score: 0.7563 - f1_score: 0.7677
# Epoch 00020: val_f1_score did not improve from 0.82766
# 5/5 [==============================] - 4s 739ms/step - loss: 0.5308 - precision_score: 0.7798 - recall_score: 0.7563 - f1_score: 0.7677 - val_loss: 0.5520 - val_precision_score: 0.8504 - val_recall_score: 0.8062 - val_f1_score: 0.8275
# Epoch 21/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4860 - precision_score: 0.8064 - recall_score: 0.7812 - f1_score: 0.7931
# Epoch 00021: val_f1_score improved from 0.82766 to 0.89696, saving model to .\modelo_resnet50.hdf5
# 5/5 [==============================] - 4s 868ms/step - loss: 0.4860 - precision_score: 0.8064 - recall_score: 0.7812 - f1_score: 0.7931 - val_loss: 0.3776 - val_precision_score: 0.9204 - val_recall_score: 0.8750 - val_f1_score: 0.8970
# Epoch 22/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5196 - precision_score: 0.8003 - recall_score: 0.7750 - f1_score: 0.7873
# Epoch 00022: val_f1_score did not improve from 0.89696
# 5/5 [==============================] - 4s 744ms/step - loss: 0.5196 - precision_score: 0.8003 - recall_score: 0.7750 - f1_score: 0.7873 - val_loss: 0.5150 - val_precision_score: 0.8278 - val_recall_score: 0.8062 - val_f1_score: 0.8167
# Epoch 23/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5689 - precision_score: 0.7360 - recall_score: 0.7063 - f1_score: 0.7205
# Epoch 00023: val_f1_score did not improve from 0.89696
# 5/5 [==============================] - 4s 766ms/step - loss: 0.5689 - precision_score: 0.7360 - recall_score: 0.7063 - f1_score: 0.7205 - val_loss: 0.4444 - val_precision_score: 0.8595 - val_recall_score: 0.8125 - val_f1_score: 0.8346
# Epoch 24/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5018 - precision_score: 0.8281 - recall_score: 0.8125 - f1_score: 0.8201
# Epoch 00024: val_f1_score did not improve from 0.89696
# 5/5 [==============================] - 4s 720ms/step - loss: 0.5018 - precision_score: 0.8281 - recall_score: 0.8125 - f1_score: 0.8201 - val_loss: 0.6595 - val_precision_score: 0.7702 - val_recall_score: 0.7375 - val_f1_score: 0.7534
# Epoch 25/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5823 - precision_score: 0.7865 - recall_score: 0.7625 - f1_score: 0.7741
# Epoch 00025: val_f1_score did not improve from 0.89696
# 5/5 [==============================] - 4s 734ms/step - loss: 0.5823 - precision_score: 0.7865 - recall_score: 0.7625 - f1_score: 0.7741 - val_loss: 0.5489 - val_precision_score: 0.8090 - val_recall_score: 0.7688 - val_f1_score: 0.7881
# Epoch 26/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5035 - precision_score: 0.7847 - recall_score: 0.7563 - f1_score: 0.7701
# Epoch 00026: val_f1_score did not improve from 0.89696
# 5/5 [==============================] - 4s 773ms/step - loss: 0.5035 - precision_score: 0.7847 - recall_score: 0.7563 - f1_score: 0.7701 - val_loss: 0.5322 - val_precision_score: 0.8636 - val_recall_score: 0.8313 - val_f1_score: 0.8470
# Epoch 27/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5307 - precision_score: 0.8195 - recall_score: 0.7937 - f1_score: 0.8063
# Epoch 00027: val_f1_score did not improve from 0.89696
# 5/5 [==============================] - 4s 747ms/step - loss: 0.5307 - precision_score: 0.8195 - recall_score: 0.7937 - f1_score: 0.8063 - val_loss: 0.5562 - val_precision_score: 0.8248 - val_recall_score: 0.7875 - val_f1_score: 0.8055
# Epoch 28/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4780 - precision_score: 0.8003 - recall_score: 0.7500 - f1_score: 0.7743
# Epoch 00028: val_f1_score did not improve from 0.89696
# 5/5 [==============================] - 4s 789ms/step - loss: 0.4780 - precision_score: 0.8003 - recall_score: 0.7500 - f1_score: 0.7743 - val_loss: 0.5445 - val_precision_score: 0.7944 - val_recall_score: 0.7750 - val_f1_score: 0.7845
# Epoch 29/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5119 - precision_score: 0.8010 - recall_score: 0.7812 - f1_score: 0.7910
# Epoch 00029: val_f1_score did not improve from 0.89696
# 5/5 [==============================] - 4s 735ms/step - loss: 0.5119 - precision_score: 0.8010 - recall_score: 0.7812 - f1_score: 0.7910 - val_loss: 0.5266 - val_precision_score: 0.8728 - val_recall_score: 0.8062 - val_f1_score: 0.8379
# Epoch 30/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4817 - precision_score: 0.7899 - recall_score: 0.7563 - f1_score: 0.7722
# Epoch 00030: val_f1_score did not improve from 0.89696
# 5/5 [==============================] - 4s 752ms/step - loss: 0.4817 - precision_score: 0.7899 - recall_score: 0.7563 - f1_score: 0.7722 - val_loss: 0.4738 - val_precision_score: 0.8570 - val_recall_score: 0.8250 - val_f1_score: 0.8404
# Epoch 31/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4664 - precision_score: 0.7856 - recall_score: 0.7500 - f1_score: 0.7669
# Epoch 00031: val_f1_score did not improve from 0.89696
# 5/5 [==============================] - 4s 726ms/step - loss: 0.4664 - precision_score: 0.7856 - recall_score: 0.7500 - f1_score: 0.7669 - val_loss: 0.3795 - val_precision_score: 0.8839 - val_recall_score: 0.8562 - val_f1_score: 0.8698
# Epoch 32/100
# 5/5 [==============================] - ETA: 0s - loss: 0.3951 - precision_score: 0.8496 - recall_score: 0.8125 - f1_score: 0.8302
# Epoch 00032: val_f1_score did not improve from 0.89696
# 5/5 [==============================] - 4s 733ms/step - loss: 0.3951 - precision_score: 0.8496 - recall_score: 0.8125 - f1_score: 0.8302 - val_loss: 0.4668 - val_precision_score: 0.8469 - val_recall_score: 0.8313 - val_f1_score: 0.8389
# Epoch 33/100
# 5/5 [==============================] - ETA: 0s - loss: 0.3955 - precision_score: 0.8578 - recall_score: 0.8313 - f1_score: 0.8442
# Epoch 00033: val_f1_score did not improve from 0.89696
# 5/5 [==============================] - 4s 723ms/step - loss: 0.3955 - precision_score: 0.8578 - recall_score: 0.8313 - f1_score: 0.8442 - val_loss: 0.4507 - val_precision_score: 0.8600 - val_recall_score: 0.8313 - val_f1_score: 0.8451
# Epoch 34/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5307 - precision_score: 0.7886 - recall_score: 0.7563 - f1_score: 0.7717
# Epoch 00034: val_f1_score did not improve from 0.89696
# 5/5 [==============================] - 3s 693ms/step - loss: 0.5307 - precision_score: 0.7886 - recall_score: 0.7563 - f1_score: 0.7717 - val_loss: 0.5281 - val_precision_score: 0.8655 - val_recall_score: 0.8125 - val_f1_score: 0.8378
# Epoch 35/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4419 - precision_score: 0.7947 - recall_score: 0.7750 - f1_score: 0.7846
# Epoch 00035: val_f1_score did not improve from 0.89696
# 5/5 [==============================] - 4s 768ms/step - loss: 0.4419 - precision_score: 0.7947 - recall_score: 0.7750 - f1_score: 0.7846 - val_loss: 0.4420 - val_precision_score: 0.8632 - val_recall_score: 0.8250 - val_f1_score: 0.8434
# Epoch 36/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4759 - precision_score: 0.8121 - recall_score: 0.7750 - f1_score: 0.7930
# Epoch 00036: val_f1_score did not improve from 0.89696
# 5/5 [==============================] - 4s 703ms/step - loss: 0.4759 - precision_score: 0.8121 - recall_score: 0.7750 - f1_score: 0.7930 - val_loss: 0.5091 - val_precision_score: 0.8240 - val_recall_score: 0.7812 - val_f1_score: 0.8013
# Epoch 37/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4438 - precision_score: 0.8276 - recall_score: 0.8125 - f1_score: 0.8199
# Epoch 00037: val_f1_score did not improve from 0.89696
# 5/5 [==============================] - 4s 732ms/step - loss: 0.4438 - precision_score: 0.8276 - recall_score: 0.8125 - f1_score: 0.8199 - val_loss: 0.3986 - val_precision_score: 0.8663 - val_recall_score: 0.8562 - val_f1_score: 0.8612
# Epoch 38/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5419 - precision_score: 0.7482 - recall_score: 0.7188 - f1_score: 0.7331
# Epoch 00038: val_f1_score did not improve from 0.89696
# 5/5 [==============================] - 4s 798ms/step - loss: 0.5419 - precision_score: 0.7482 - recall_score: 0.7188 - f1_score: 0.7331 - val_loss: 0.5096 - val_precision_score: 0.8564 - val_recall_score: 0.7937 - val_f1_score: 0.8234
# Epoch 39/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4825 - precision_score: 0.7970 - recall_score: 0.7875 - f1_score: 0.7922
# Epoch 00039: val_f1_score did not improve from 0.89696
# 5/5 [==============================] - 4s 743ms/step - loss: 0.4825 - precision_score: 0.7970 - recall_score: 0.7875 - f1_score: 0.7922 - val_loss: 0.5046 - val_precision_score: 0.8796 - val_recall_score: 0.8250 - val_f1_score: 0.8511
# Epoch 40/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4769 - precision_score: 0.7816 - recall_score: 0.7563 - f1_score: 0.7686
# Epoch 00040: val_f1_score did not improve from 0.89696
# 5/5 [==============================] - 4s 738ms/step - loss: 0.4769 - precision_score: 0.7816 - recall_score: 0.7563 - f1_score: 0.7686 - val_loss: 0.3910 - val_precision_score: 0.8963 - val_recall_score: 0.8625 - val_f1_score: 0.8789
# Epoch 41/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4038 - precision_score: 0.8376 - recall_score: 0.8125 - f1_score: 0.8243
# Epoch 00041: val_f1_score did not improve from 0.89696
# 5/5 [==============================] - 4s 716ms/step - loss: 0.4038 - precision_score: 0.8376 - recall_score: 0.8125 - f1_score: 0.8243 - val_loss: 0.4465 - val_precision_score: 0.8832 - val_recall_score: 0.8500 - val_f1_score: 0.8661
# Epoch 42/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5933 - precision_score: 0.7671 - recall_score: 0.7375 - f1_score: 0.7518
# Epoch 00042: val_f1_score did not improve from 0.89696
# 5/5 [==============================] - 4s 721ms/step - loss: 0.5933 - precision_score: 0.7671 - recall_score: 0.7375 - f1_score: 0.7518 - val_loss: 0.5450 - val_precision_score: 0.8313 - val_recall_score: 0.8000 - val_f1_score: 0.8152
# Epoch 43/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4942 - precision_score: 0.7694 - recall_score: 0.7437 - f1_score: 0.7562
# Epoch 00043: val_f1_score did not improve from 0.89696
# 5/5 [==============================] - 4s 709ms/step - loss: 0.4942 - precision_score: 0.7694 - recall_score: 0.7437 - f1_score: 0.7562 - val_loss: 0.4559 - val_precision_score: 0.8709 - val_recall_score: 0.8438 - val_f1_score: 0.8570
# Epoch 44/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5238 - precision_score: 0.7957 - recall_score: 0.7688 - f1_score: 0.7818
# Epoch 00044: val_f1_score did not improve from 0.89696
# 5/5 [==============================] - 4s 701ms/step - loss: 0.5238 - precision_score: 0.7957 - recall_score: 0.7688 - f1_score: 0.7818 - val_loss: 0.6378 - val_precision_score: 0.8246 - val_recall_score: 0.7812 - val_f1_score: 0.8020
# Epoch 45/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5602 - precision_score: 0.7920 - recall_score: 0.7625 - f1_score: 0.7768
# Epoch 00045: val_f1_score did not improve from 0.89696
# 5/5 [==============================] - 4s 722ms/step - loss: 0.5602 - precision_score: 0.7920 - recall_score: 0.7625 - f1_score: 0.7768 - val_loss: 0.5106 - val_precision_score: 0.8386 - val_recall_score: 0.8125 - val_f1_score: 0.8253
# Epoch 46/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5416 - precision_score: 0.7983 - recall_score: 0.7875 - f1_score: 0.7927
# Epoch 00046: val_f1_score did not improve from 0.89696
# 5/5 [==============================] - 4s 752ms/step - loss: 0.5416 - precision_score: 0.7983 - recall_score: 0.7875 - f1_score: 0.7927 - val_loss: 0.5596 - val_precision_score: 0.7991 - val_recall_score: 0.7688 - val_f1_score: 0.7833
# Epoch 47/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5088 - precision_score: 0.7655 - recall_score: 0.7563 - f1_score: 0.7608
# Epoch 00047: val_f1_score did not improve from 0.89696
# 5/5 [==============================] - 4s 748ms/step - loss: 0.5088 - precision_score: 0.7655 - recall_score: 0.7563 - f1_score: 0.7608 - val_loss: 0.5538 - val_precision_score: 0.8132 - val_recall_score: 0.7625 - val_f1_score: 0.7866
# Epoch 48/100
# 5/5 [==============================] - ETA: 0s - loss: 0.3471 - precision_score: 0.8783 - recall_score: 0.8687 - f1_score: 0.8734
# Epoch 00048: val_f1_score did not improve from 0.89696
# 5/5 [==============================] - 4s 737ms/step - loss: 0.3471 - precision_score: 0.8783 - recall_score: 0.8687 - f1_score: 0.8734 - val_loss: 0.4516 - val_precision_score: 0.8639 - val_recall_score: 0.8313 - val_f1_score: 0.8472
# Epoch 49/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4898 - precision_score: 0.7751 - recall_score: 0.7437 - f1_score: 0.7587
# Epoch 00049: val_f1_score did not improve from 0.89696
# 5/5 [==============================] - 3s 670ms/step - loss: 0.4898 - precision_score: 0.7751 - recall_score: 0.7437 - f1_score: 0.7587 - val_loss: 0.5293 - val_precision_score: 0.7909 - val_recall_score: 0.7250 - val_f1_score: 0.7563
# Epoch 50/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4794 - precision_score: 0.8115 - recall_score: 0.8062 - f1_score: 0.8088
# Epoch 00050: val_f1_score did not improve from 0.89696
# 5/5 [==============================] - 4s 723ms/step - loss: 0.4794 - precision_score: 0.8115 - recall_score: 0.8062 - f1_score: 0.8088 - val_loss: 0.4070 - val_precision_score: 0.8694 - val_recall_score: 0.8375 - val_f1_score: 0.8530
# Epoch 51/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5014 - precision_score: 0.7780 - recall_score: 0.7625 - f1_score: 0.7700
# Epoch 00051: val_f1_score did not improve from 0.89696
# 5/5 [==============================] - 4s 731ms/step - loss: 0.5014 - precision_score: 0.7780 - recall_score: 0.7625 - f1_score: 0.7700 - val_loss: 0.3898 - val_precision_score: 0.8738 - val_recall_score: 0.8625 - val_f1_score: 0.8681
# Epoch 52/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4882 - precision_score: 0.7717 - recall_score: 0.7563 - f1_score: 0.7638
# Epoch 00052: val_f1_score did not improve from 0.89696
# 5/5 [==============================] - 4s 767ms/step - loss: 0.4882 - precision_score: 0.7717 - recall_score: 0.7563 - f1_score: 0.7638 - val_loss: 0.4139 - val_precision_score: 0.8725 - val_recall_score: 0.8562 - val_f1_score: 0.8642
# Epoch 53/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4853 - precision_score: 0.7689 - recall_score: 0.7500 - f1_score: 0.7592
# Epoch 00053: val_f1_score did not improve from 0.89696
# 5/5 [==============================] - 4s 700ms/step - loss: 0.4853 - precision_score: 0.7689 - recall_score: 0.7500 - f1_score: 0.7592 - val_loss: 0.4835 - val_precision_score: 0.8546 - val_recall_score: 0.8062 - val_f1_score: 0.8293
# Epoch 54/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4481 - precision_score: 0.8019 - recall_score: 0.7812 - f1_score: 0.7913
# Epoch 00054: val_f1_score did not improve from 0.89696
# 5/5 [==============================] - 4s 735ms/step - loss: 0.4481 - precision_score: 0.8019 - recall_score: 0.7812 - f1_score: 0.7913 - val_loss: 0.5055 - val_precision_score: 0.8487 - val_recall_score: 0.8062 - val_f1_score: 0.8267
# Epoch 55/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4498 - precision_score: 0.7959 - recall_score: 0.7812 - f1_score: 0.7884
# Epoch 00055: val_f1_score did not improve from 0.89696
# 5/5 [==============================] - 4s 758ms/step - loss: 0.4498 - precision_score: 0.7959 - recall_score: 0.7812 - f1_score: 0.7884 - val_loss: 0.4102 - val_precision_score: 0.8876 - val_recall_score: 0.8438 - val_f1_score: 0.8648
# Epoch 56/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4842 - precision_score: 0.8404 - recall_score: 0.8000 - f1_score: 0.8191
# Epoch 00056: val_f1_score did not improve from 0.89696
# 5/5 [==============================] - 4s 724ms/step - loss: 0.4842 - precision_score: 0.8404 - recall_score: 0.8000 - f1_score: 0.8191 - val_loss: 0.4533 - val_precision_score: 0.8482 - val_recall_score: 0.8375 - val_f1_score: 0.8428
# Epoch 57/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5064 - precision_score: 0.7791 - recall_score: 0.7500 - f1_score: 0.7643
# Epoch 00057: val_f1_score did not improve from 0.89696
# 5/5 [==============================] - 4s 733ms/step - loss: 0.5064 - precision_score: 0.7791 - recall_score: 0.7500 - f1_score: 0.7643 - val_loss: 0.4373 - val_precision_score: 0.8774 - val_recall_score: 0.8500 - val_f1_score: 0.8634
# Epoch 58/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4912 - precision_score: 0.8282 - recall_score: 0.8062 - f1_score: 0.8170
# Epoch 00058: val_f1_score did not improve from 0.89696
# 5/5 [==============================] - 4s 717ms/step - loss: 0.4912 - precision_score: 0.8282 - recall_score: 0.8062 - f1_score: 0.8170 - val_loss: 0.5646 - val_precision_score: 0.8421 - val_recall_score: 0.8000 - val_f1_score: 0.8201
# Epoch 59/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4577 - precision_score: 0.7878 - recall_score: 0.7750 - f1_score: 0.7812
# Epoch 00059: val_f1_score did not improve from 0.89696
# 5/5 [==============================] - 4s 802ms/step - loss: 0.4577 - precision_score: 0.7878 - recall_score: 0.7750 - f1_score: 0.7812 - val_loss: 0.4202 - val_precision_score: 0.8820 - val_recall_score: 0.8375 - val_f1_score: 0.8586
# Epoch 60/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4681 - precision_score: 0.8205 - recall_score: 0.8000 - f1_score: 0.8100
# Epoch 00060: val_f1_score did not improve from 0.89696
# 5/5 [==============================] - 4s 710ms/step - loss: 0.4681 - precision_score: 0.8205 - recall_score: 0.8000 - f1_score: 0.8100 - val_loss: 0.5730 - val_precision_score: 0.7636 - val_recall_score: 0.7312 - val_f1_score: 0.7467
# Epoch 61/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4596 - precision_score: 0.8008 - recall_score: 0.7750 - f1_score: 0.7876
# Epoch 00061: val_f1_score did not improve from 0.89696
# 5/5 [==============================] - 4s 744ms/step - loss: 0.4596 - precision_score: 0.8008 - recall_score: 0.7750 - f1_score: 0.7876 - val_loss: 0.4457 - val_precision_score: 0.8618 - val_recall_score: 0.8313 - val_f1_score: 0.8459
# Epoch 62/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4790 - precision_score: 0.8025 - recall_score: 0.7875 - f1_score: 0.7948
# Epoch 00062: val_f1_score did not improve from 0.89696
# 5/5 [==============================] - 4s 760ms/step - loss: 0.4790 - precision_score: 0.8025 - recall_score: 0.7875 - f1_score: 0.7948 - val_loss: 0.4612 - val_precision_score: 0.8539 - val_recall_score: 0.8125 - val_f1_score: 0.8323
# Epoch 63/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4796 - precision_score: 0.7828 - recall_score: 0.7688 - f1_score: 0.7756
# Epoch 00063: val_f1_score did not improve from 0.89696
# 5/5 [==============================] - 3s 681ms/step - loss: 0.4796 - precision_score: 0.7828 - recall_score: 0.7688 - f1_score: 0.7756 - val_loss: 0.4197 - val_precision_score: 0.8855 - val_recall_score: 0.8250 - val_f1_score: 0.8536
# Epoch 64/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4191 - precision_score: 0.8885 - recall_score: 0.8562 - f1_score: 0.8719
# Epoch 00064: val_f1_score did not improve from 0.89696
# 5/5 [==============================] - 4s 776ms/step - loss: 0.4191 - precision_score: 0.8885 - recall_score: 0.8562 - f1_score: 0.8719 - val_loss: 0.4517 - val_precision_score: 0.8773 - val_recall_score: 0.8000 - val_f1_score: 0.8364
# Epoch 65/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5316 - precision_score: 0.7458 - recall_score: 0.6875 - f1_score: 0.7152
# Epoch 00065: val_f1_score did not improve from 0.89696
# 5/5 [==============================] - 4s 795ms/step - loss: 0.5316 - precision_score: 0.7458 - recall_score: 0.6875 - f1_score: 0.7152 - val_loss: 0.6459 - val_precision_score: 0.8287 - val_recall_score: 0.7688 - val_f1_score: 0.7972
# Epoch 66/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4635 - precision_score: 0.7568 - recall_score: 0.7375 - f1_score: 0.7468
# Epoch 00066: val_f1_score did not improve from 0.89696
# 5/5 [==============================] - 4s 782ms/step - loss: 0.4635 - precision_score: 0.7568 - recall_score: 0.7375 - f1_score: 0.7468 - val_loss: 0.3804 - val_precision_score: 0.8890 - val_recall_score: 0.8500 - val_f1_score: 0.8689
# Epoch 67/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4659 - precision_score: 0.8274 - recall_score: 0.8062 - f1_score: 0.8165
# Epoch 00067: val_f1_score did not improve from 0.89696
# 5/5 [==============================] - 4s 709ms/step - loss: 0.4659 - precision_score: 0.8274 - recall_score: 0.8062 - f1_score: 0.8165 - val_loss: 0.4562 - val_precision_score: 0.8646 - val_recall_score: 0.8375 - val_f1_score: 0.8507
# Epoch 68/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4425 - precision_score: 0.8397 - recall_score: 0.8188 - f1_score: 0.8291
# Epoch 00068: val_f1_score did not improve from 0.89696
# 5/5 [==============================] - 4s 734ms/step - loss: 0.4425 - precision_score: 0.8397 - recall_score: 0.8188 - f1_score: 0.8291 - val_loss: 0.4929 - val_precision_score: 0.8516 - val_recall_score: 0.7875 - val_f1_score: 0.8180
# Epoch 69/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4589 - precision_score: 0.8195 - recall_score: 0.7937 - f1_score: 0.8063
# Epoch 00069: val_f1_score did not improve from 0.89696
# 5/5 [==============================] - 4s 749ms/step - loss: 0.4589 - precision_score: 0.8195 - recall_score: 0.7937 - f1_score: 0.8063 - val_loss: 0.4068 - val_precision_score: 0.8890 - val_recall_score: 0.8500 - val_f1_score: 0.8689
# Epoch 70/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4374 - precision_score: 0.8049 - recall_score: 0.7750 - f1_score: 0.7894
# Epoch 00070: val_f1_score improved from 0.89696 to 0.90023, saving model to .\modelo_resnet50.hdf5
# 5/5 [==============================] - 5s 917ms/step - loss: 0.4374 - precision_score: 0.8049 - recall_score: 0.7750 - f1_score: 0.7894 - val_loss: 0.3277 - val_precision_score: 0.9279 - val_recall_score: 0.8750 - val_f1_score: 0.9002
# Epoch 71/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5921 - precision_score: 0.7592 - recall_score: 0.7250 - f1_score: 0.7416
# Epoch 00071: val_f1_score did not improve from 0.90023
# 5/5 [==============================] - 4s 730ms/step - loss: 0.5921 - precision_score: 0.7592 - recall_score: 0.7250 - f1_score: 0.7416 - val_loss: 0.4983 - val_precision_score: 0.8666 - val_recall_score: 0.8062 - val_f1_score: 0.8352
# Epoch 72/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4198 - precision_score: 0.8107 - recall_score: 0.8000 - f1_score: 0.8053
# Epoch 00072: val_f1_score improved from 0.90023 to 0.90128, saving model to .\modelo_resnet50.hdf5
# 5/5 [==============================] - 4s 870ms/step - loss: 0.4198 - precision_score: 0.8107 - recall_score: 0.8000 - f1_score: 0.8053 - val_loss: 0.3517 - val_precision_score: 0.9224 - val_recall_score: 0.8813 - val_f1_score: 0.9013
# Epoch 73/100
# 5/5 [==============================] - ETA: 0s - loss: 0.3846 - precision_score: 0.8538 - recall_score: 0.8438 - f1_score: 0.8486
# Epoch 00073: val_f1_score did not improve from 0.90128
# 5/5 [==============================] - 4s 729ms/step - loss: 0.3846 - precision_score: 0.8538 - recall_score: 0.8438 - f1_score: 0.8486 - val_loss: 0.5693 - val_precision_score: 0.8033 - val_recall_score: 0.7625 - val_f1_score: 0.7820
# Epoch 74/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4963 - precision_score: 0.8213 - recall_score: 0.8062 - f1_score: 0.8136
# Epoch 00074: val_f1_score did not improve from 0.90128
# 5/5 [==============================] - 4s 707ms/step - loss: 0.4963 - precision_score: 0.8213 - recall_score: 0.8062 - f1_score: 0.8136 - val_loss: 0.5611 - val_precision_score: 0.8321 - val_recall_score: 0.7812 - val_f1_score: 0.8058
# Epoch 75/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5285 - precision_score: 0.7878 - recall_score: 0.7625 - f1_score: 0.7748
# Epoch 00075: val_f1_score did not improve from 0.90128
# 5/5 [==============================] - 4s 748ms/step - loss: 0.5285 - precision_score: 0.7878 - recall_score: 0.7625 - f1_score: 0.7748 - val_loss: 0.5655 - val_precision_score: 0.8573 - val_recall_score: 0.8250 - val_f1_score: 0.8405
# Epoch 76/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4460 - precision_score: 0.8448 - recall_score: 0.8125 - f1_score: 0.8280
# Epoch 00076: val_f1_score did not improve from 0.90128
# 5/5 [==============================] - 4s 722ms/step - loss: 0.4460 - precision_score: 0.8448 - recall_score: 0.8125 - f1_score: 0.8280 - val_loss: 0.6749 - val_precision_score: 0.7991 - val_recall_score: 0.7625 - val_f1_score: 0.7795
# Epoch 77/100
# 5/5 [==============================] - ETA: 0s - loss: 0.6149 - precision_score: 0.7520 - recall_score: 0.7188 - f1_score: 0.7348
# Epoch 00077: val_f1_score did not improve from 0.90128
# 5/5 [==============================] - 4s 736ms/step - loss: 0.6149 - precision_score: 0.7520 - recall_score: 0.7188 - f1_score: 0.7348 - val_loss: 0.5301 - val_precision_score: 0.8531 - val_recall_score: 0.8000 - val_f1_score: 0.8254
# Epoch 78/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5665 - precision_score: 0.8017 - recall_score: 0.7563 - f1_score: 0.7776
# Epoch 00078: val_f1_score did not improve from 0.90128
# 5/5 [==============================] - 4s 718ms/step - loss: 0.5665 - precision_score: 0.8017 - recall_score: 0.7563 - f1_score: 0.7776 - val_loss: 0.5375 - val_precision_score: 0.8706 - val_recall_score: 0.8313 - val_f1_score: 0.8504
# Epoch 79/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4841 - precision_score: 0.7912 - recall_score: 0.7688 - f1_score: 0.7795
# Epoch 00079: val_f1_score did not improve from 0.90128
# 5/5 [==============================] - 4s 734ms/step - loss: 0.4841 - precision_score: 0.7912 - recall_score: 0.7688 - f1_score: 0.7795 - val_loss: 0.4902 - val_precision_score: 0.8692 - val_recall_score: 0.8188 - val_f1_score: 0.8425
# Epoch 80/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4777 - precision_score: 0.8464 - recall_score: 0.7937 - f1_score: 0.8191
# Epoch 00080: val_f1_score did not improve from 0.90128
# 5/5 [==============================] - 4s 755ms/step - loss: 0.4777 - precision_score: 0.8464 - recall_score: 0.7937 - f1_score: 0.8191 - val_loss: 0.6479 - val_precision_score: 0.8343 - val_recall_score: 0.7875 - val_f1_score: 0.8101
# Epoch 81/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4439 - precision_score: 0.8183 - recall_score: 0.7875 - f1_score: 0.8024
# Epoch 00081: val_f1_score did not improve from 0.90128
# 5/5 [==============================] - 4s 733ms/step - loss: 0.4439 - precision_score: 0.8183 - recall_score: 0.7875 - f1_score: 0.8024 - val_loss: 0.4169 - val_precision_score: 0.8957 - val_recall_score: 0.8500 - val_f1_score: 0.8721
# Epoch 82/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4304 - precision_score: 0.8245 - recall_score: 0.7937 - f1_score: 0.8087
# Epoch 00082: val_f1_score did not improve from 0.90128
# 5/5 [==============================] - 4s 737ms/step - loss: 0.4304 - precision_score: 0.8245 - recall_score: 0.7937 - f1_score: 0.8087 - val_loss: 0.4804 - val_precision_score: 0.8835 - val_recall_score: 0.8500 - val_f1_score: 0.8661
# Epoch 83/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4928 - precision_score: 0.7810 - recall_score: 0.7563 - f1_score: 0.7682
# Epoch 00083: val_f1_score did not improve from 0.90128
# 5/5 [==============================] - 4s 753ms/step - loss: 0.4928 - precision_score: 0.7810 - recall_score: 0.7563 - f1_score: 0.7682 - val_loss: 0.6522 - val_precision_score: 0.7863 - val_recall_score: 0.7312 - val_f1_score: 0.7574
# Epoch 84/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4164 - precision_score: 0.8592 - recall_score: 0.8375 - f1_score: 0.8480
# Epoch 00084: val_f1_score did not improve from 0.90128
# 5/5 [==============================] - 4s 751ms/step - loss: 0.4164 - precision_score: 0.8592 - recall_score: 0.8375 - f1_score: 0.8480 - val_loss: 0.5663 - val_precision_score: 0.8657 - val_recall_score: 0.8438 - val_f1_score: 0.8546
# Epoch 85/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4840 - precision_score: 0.8100 - recall_score: 0.7937 - f1_score: 0.8017
# Epoch 00085: val_f1_score did not improve from 0.90128
# 5/5 [==============================] - 4s 740ms/step - loss: 0.4840 - precision_score: 0.8100 - recall_score: 0.7937 - f1_score: 0.8017 - val_loss: 0.3927 - val_precision_score: 0.8849 - val_recall_score: 0.8625 - val_f1_score: 0.8734
# Epoch 86/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5796 - precision_score: 0.7684 - recall_score: 0.7500 - f1_score: 0.7590
# Epoch 00086: val_f1_score did not improve from 0.90128
# 5/5 [==============================] - 4s 794ms/step - loss: 0.5796 - precision_score: 0.7684 - recall_score: 0.7500 - f1_score: 0.7590 - val_loss: 0.5802 - val_precision_score: 0.8462 - val_recall_score: 0.8250 - val_f1_score: 0.8353
# Epoch 87/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5017 - precision_score: 0.8056 - recall_score: 0.7750 - f1_score: 0.7897
# Epoch 00087: val_f1_score did not improve from 0.90128
# 5/5 [==============================] - 4s 738ms/step - loss: 0.5017 - precision_score: 0.8056 - recall_score: 0.7750 - f1_score: 0.7897 - val_loss: 0.4302 - val_precision_score: 0.8967 - val_recall_score: 0.8687 - val_f1_score: 0.8824
# Epoch 88/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4995 - precision_score: 0.8224 - recall_score: 0.8125 - f1_score: 0.8174
# Epoch 00088: val_f1_score did not improve from 0.90128
# 5/5 [==============================] - 4s 748ms/step - loss: 0.4995 - precision_score: 0.8224 - recall_score: 0.8125 - f1_score: 0.8174 - val_loss: 0.6284 - val_precision_score: 0.7205 - val_recall_score: 0.6938 - val_f1_score: 0.7066
# Epoch 89/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4821 - precision_score: 0.7907 - recall_score: 0.7750 - f1_score: 0.7827
# Epoch 00089: val_f1_score did not improve from 0.90128
# 5/5 [==============================] - 4s 734ms/step - loss: 0.4821 - precision_score: 0.7907 - recall_score: 0.7750 - f1_score: 0.7827 - val_loss: 0.5495 - val_precision_score: 0.7770 - val_recall_score: 0.7188 - val_f1_score: 0.7464
# Epoch 90/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4363 - precision_score: 0.8105 - recall_score: 0.7750 - f1_score: 0.7923
# Epoch 00090: val_f1_score did not improve from 0.90128
# 5/5 [==============================] - 4s 714ms/step - loss: 0.4363 - precision_score: 0.8105 - recall_score: 0.7750 - f1_score: 0.7923 - val_loss: 0.4599 - val_precision_score: 0.8779 - val_recall_score: 0.8188 - val_f1_score: 0.8472
# Epoch 91/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4789 - precision_score: 0.8155 - recall_score: 0.8000 - f1_score: 0.8075
# Epoch 00091: val_f1_score did not improve from 0.90128
# 5/5 [==============================] - 4s 723ms/step - loss: 0.4789 - precision_score: 0.8155 - recall_score: 0.8000 - f1_score: 0.8075 - val_loss: 0.4609 - val_precision_score: 0.8806 - val_recall_score: 0.8750 - val_f1_score: 0.8778
# Epoch 92/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4303 - precision_score: 0.8501 - recall_score: 0.8188 - f1_score: 0.8340
# Epoch 00092: val_f1_score did not improve from 0.90128
# 5/5 [==============================] - 4s 731ms/step - loss: 0.4303 - precision_score: 0.8501 - recall_score: 0.8188 - f1_score: 0.8340 - val_loss: 0.5369 - val_precision_score: 0.8249 - val_recall_score: 0.7937 - val_f1_score: 0.8089
# Epoch 93/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4100 - precision_score: 0.8228 - recall_score: 0.8125 - f1_score: 0.8176
# Epoch 00093: val_f1_score did not improve from 0.90128
# 5/5 [==============================] - 4s 703ms/step - loss: 0.4100 - precision_score: 0.8228 - recall_score: 0.8125 - f1_score: 0.8176 - val_loss: 0.4049 - val_precision_score: 0.9035 - val_recall_score: 0.8750 - val_f1_score: 0.8887
# Epoch 94/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4035 - precision_score: 0.8582 - recall_score: 0.8375 - f1_score: 0.8476
# Epoch 00094: val_f1_score did not improve from 0.90128
# 5/5 [==============================] - 4s 737ms/step - loss: 0.4035 - precision_score: 0.8582 - recall_score: 0.8375 - f1_score: 0.8476 - val_loss: 0.5167 - val_precision_score: 0.8725 - val_recall_score: 0.8000 - val_f1_score: 0.8340
# Epoch 95/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4896 - precision_score: 0.7737 - recall_score: 0.7500 - f1_score: 0.7616
# Epoch 00095: val_f1_score did not improve from 0.90128
# 5/5 [==============================] - 4s 708ms/step - loss: 0.4896 - precision_score: 0.7737 - recall_score: 0.7500 - f1_score: 0.7616 - val_loss: 0.5093 - val_precision_score: 0.8692 - val_recall_score: 0.8313 - val_f1_score: 0.8498
# Epoch 96/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4417 - precision_score: 0.8161 - recall_score: 0.8000 - f1_score: 0.8079
# Epoch 00096: val_f1_score did not improve from 0.90128
# 5/5 [==============================] - 4s 732ms/step - loss: 0.4417 - precision_score: 0.8161 - recall_score: 0.8000 - f1_score: 0.8079 - val_loss: 0.4644 - val_precision_score: 0.8717 - val_recall_score: 0.8562 - val_f1_score: 0.8638
# Epoch 97/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4389 - precision_score: 0.8156 - recall_score: 0.7750 - f1_score: 0.7944
# Epoch 00097: val_f1_score did not improve from 0.90128
# 5/5 [==============================] - 4s 771ms/step - loss: 0.4389 - precision_score: 0.8156 - recall_score: 0.7750 - f1_score: 0.7944 - val_loss: 0.5180 - val_precision_score: 0.8441 - val_recall_score: 0.8125 - val_f1_score: 0.8280
# Epoch 98/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5042 - precision_score: 0.8026 - recall_score: 0.7875 - f1_score: 0.7949
# Epoch 00098: val_f1_score did not improve from 0.90128
# 5/5 [==============================] - 4s 746ms/step - loss: 0.5042 - precision_score: 0.8026 - recall_score: 0.7875 - f1_score: 0.7949 - val_loss: 0.4562 - val_precision_score: 0.8500 - val_recall_score: 0.8125 - val_f1_score: 0.8307
# Epoch 99/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4549 - precision_score: 0.8244 - recall_score: 0.8125 - f1_score: 0.8184
# Epoch 00099: val_f1_score did not improve from 0.90128
# 5/5 [==============================] - 4s 747ms/step - loss: 0.4549 - precision_score: 0.8244 - recall_score: 0.8125 - f1_score: 0.8184 - val_loss: 0.5489 - val_precision_score: 0.8541 - val_recall_score: 0.7937 - val_f1_score: 0.8222
# Epoch 100/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4861 - precision_score: 0.8176 - recall_score: 0.7750 - f1_score: 0.7952
# Epoch 00100: val_f1_score did not improve from 0.90128
# 5/5 [==============================] - 4s 729ms/step - loss: 0.4861 - precision_score: 0.8176 - recall_score: 0.7750 - f1_score: 0.7952 - val_loss: 0.3826 - val_precision_score: 0.8829 - val_recall_score: 0.8438 - val_f1_score: 0.8622

# %% [markdown]
# Um modelo que converge bem possui o gráfico de perda (*loss*) descendente e os gráfico de precisão (*precision*), sensibilidade (*recall*) e pontuação f1 (*f1 score*) em acendente.

# %%
# Exibindo dados de Precisão
plt.plot(history.history['precision_score'])
plt.plot(history.history['val_precision_score'])
plt.title('model precision')
plt.ylabel('precision')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de Sensibilidade
plt.plot(history.history['recall_score'])
plt.plot(history.history['val_recall_score'])
plt.title('model recall')
plt.ylabel('recall')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de F1 Score
plt.plot(history.history['f1_score'])
plt.plot(history.history['val_f1_score'])
plt.title('model f1_score')
plt.ylabel('f1_score')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de Perda
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# **Pergunta**: Avalie os gráficos de perda (*loss*), precisão (*precision*), sensibilidade (*recall*) e pontuação f1 (*f1 score*)  e explique o comportamento de ambos no que tange a convergência do modelo.

# %% [markdown]
# **Resposta**:

# %% [markdown]
# **Pergunta**: Quais são os valores de **precisão (precision)**, **sensibilidade (recall)** de validação?
#
# *Estes valores são exibidos durante o treinamento, utilize a última saída, exemplo:*
#
# ```
# Epoch 10/10 [==============================] - 45s 9s/step - loss: 0.1234 - precision_score: 0.9742 - recall_score: 0.9683 - f1_score: 0.9712 - val_loss: 0.8819 - val_precision_score: 0.6912 - val_recall_score: 0.5649 - val_f1_score: 0.6216```
#
# No caso acima, o valor de precisão, sensibilidade e pontuação de validação são, respectivamente, 69,12%, 56,49% e 62,16%.

# %%
model = load_model("./modelo_resnet50.hdf5", custom_objects={'f1_score': f1_score, 'precision_score': precision_score, 'recall_score': recall_score})

scores = model.evaluate(val_generator)
print()
print(f"Precision Score: {round(scores[1]*100,2)}%")
print(f"Recall Score: {round(scores[2]*100,2)}%")
print(f"F1 Score: {round(scores[3]*100,2)}%")
# Out:
# 20/20 [==============================] - 5s 238ms/step - loss: 0.4271 - precision_score: 0.8783 - recall_score: 0.8375 - f1_score: 0.8566
#
# Precision Score: 87.83%
# Recall Score: 83.75%
# F1 Score: 85.66%

# %% [markdown]
# **Resposta**:

# %% [markdown]
# ### 4.5.2 Arquitetura VGG16

# %% [markdown]
# **Pergunta**: Explique como é constituída a arquitetura do VGG16? *Utilize, se necessário, gráficos, projetos que utilizam essa arquitetura. Detalhe também sua topologia em camadas e mostre quais as situações essa arquitetura pode ter mais êxito e quais cenários não tem.*

# %% [markdown]
# **Resposta**:

# %%
conv_base = vgg16.VGG16(include_top=False) 

for layer in conv_base.layers:
    layer.trainable = False

# %%
x = conv_base.output
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(128, activation='relu')(x) 

predictions = layers.Dense(qtde_classes, activation='softmax')(x)
model = Model(conv_base.input, predictions)

model.summary()
# Out:
# Model: "functional_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_7 (InputLayer)         [(None, None, None, 3)]   0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, None, None, 64)    1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, None, None, 64)    36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, None, None, 64)    0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, None, None, 128)   73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, None, None, 128)   147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, None, None, 128)   0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, None, None, 256)   295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, None, None, 256)   590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, None, None, 256)   590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, None, None, 256)   0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, None, None, 512)   1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, None, None, 512)   0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, None, None, 512)   0
# _________________________________________________________________
# global_average_pooling2d_4 ( (None, 512)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 128)               65664
# _________________________________________________________________
# dense_9 (Dense)              (None, 3)                 387
# =================================================================
# Total params: 14,780,739
# Trainable params: 66,051
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
optimizer = keras.optimizers.Adam()
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=[precision_score, recall_score, f1_score])

# %%
checkpointer = ModelCheckpoint_tweaked(filepath='./modelo_vgg16.hdf5', verbose=1,  mode='max', save_best_only=True, monitor='val_f1_score')

history = model.fit_generator(generator=train_generator, 
                              epochs=qtde_epocas, 
                              validation_steps=5, 
                              steps_per_epoch=5, 
                              validation_data=val_generator,
                              callbacks=[checkpointer])
# Out:
# Epoch 1/100
# 5/5 [==============================] - ETA: 0s - loss: 2.0215 - precision_score: 0.4522 - recall_score: 0.4437 - f1_score: 0.4479
# Epoch 00001: val_f1_score improved from -inf to 0.65605, saving model to .\modelo_vgg16.hdf5
# 5/5 [==============================] - 5s 924ms/step - loss: 2.0215 - precision_score: 0.4522 - recall_score: 0.4437 - f1_score: 0.4479 - val_loss: 1.1529 - val_precision_score: 0.6830 - val_recall_score: 0.6313 - val_f1_score: 0.6561
# Epoch 2/100
# 5/5 [==============================] - ETA: 0s - loss: 1.1235 - precision_score: 0.6574 - recall_score: 0.6375 - f1_score: 0.6472
# Epoch 00002: val_f1_score did not improve from 0.65605
# 5/5 [==============================] - 4s 739ms/step - loss: 1.1235 - precision_score: 0.6574 - recall_score: 0.6375 - f1_score: 0.6472 - val_loss: 1.2468 - val_precision_score: 0.6153 - val_recall_score: 0.5813 - val_f1_score: 0.5975
# Epoch 3/100
# 5/5 [==============================] - ETA: 0s - loss: 1.0663 - precision_score: 0.6767 - recall_score: 0.6500 - f1_score: 0.6627
# Epoch 00003: val_f1_score did not improve from 0.65605
# 5/5 [==============================] - 3s 656ms/step - loss: 1.0663 - precision_score: 0.6767 - recall_score: 0.6500 - f1_score: 0.6627 - val_loss: 1.3808 - val_precision_score: 0.6176 - val_recall_score: 0.6062 - val_f1_score: 0.6118
# Epoch 4/100
# 5/5 [==============================] - ETA: 0s - loss: 0.8504 - precision_score: 0.6978 - recall_score: 0.6750 - f1_score: 0.6857
# Epoch 00004: val_f1_score improved from 0.65605 to 0.75146, saving model to .\modelo_vgg16.hdf5
# 5/5 [==============================] - 4s 791ms/step - loss: 0.8504 - precision_score: 0.6978 - recall_score: 0.6750 - f1_score: 0.6857 - val_loss: 0.9047 - val_precision_score: 0.7660 - val_recall_score: 0.7375 - val_f1_score: 0.7515
# Epoch 5/100
# 5/5 [==============================] - ETA: 0s - loss: 0.9723 - precision_score: 0.6638 - recall_score: 0.6438 - f1_score: 0.6535
# Epoch 00005: val_f1_score did not improve from 0.75146
# 5/5 [==============================] - 4s 741ms/step - loss: 0.9723 - precision_score: 0.6638 - recall_score: 0.6438 - f1_score: 0.6535 - val_loss: 1.4088 - val_precision_score: 0.6101 - val_recall_score: 0.5813 - val_f1_score: 0.5952
# Epoch 6/100
# 5/5 [==============================] - ETA: 0s - loss: 0.9598 - precision_score: 0.6772 - recall_score: 0.6687 - f1_score: 0.6729
# Epoch 00006: val_f1_score did not improve from 0.75146
# 5/5 [==============================] - 4s 757ms/step - loss: 0.9598 - precision_score: 0.6772 - recall_score: 0.6687 - f1_score: 0.6729 - val_loss: 0.8669 - val_precision_score: 0.7135 - val_recall_score: 0.7000 - val_f1_score: 0.7066
# Epoch 7/100
# 5/5 [==============================] - ETA: 0s - loss: 0.9135 - precision_score: 0.7361 - recall_score: 0.7063 - f1_score: 0.7205
# Epoch 00007: val_f1_score did not improve from 0.75146
# 5/5 [==============================] - 4s 734ms/step - loss: 0.9135 - precision_score: 0.7361 - recall_score: 0.7063 - f1_score: 0.7205 - val_loss: 0.7501 - val_precision_score: 0.7405 - val_recall_score: 0.7063 - val_f1_score: 0.7225
# Epoch 8/100
# 5/5 [==============================] - ETA: 0s - loss: 0.7749 - precision_score: 0.7332 - recall_score: 0.7188 - f1_score: 0.7258
# Epoch 00008: val_f1_score did not improve from 0.75146
# 5/5 [==============================] - 4s 704ms/step - loss: 0.7749 - precision_score: 0.7332 - recall_score: 0.7188 - f1_score: 0.7258 - val_loss: 1.1981 - val_precision_score: 0.6393 - val_recall_score: 0.6187 - val_f1_score: 0.6287
# Epoch 9/100
# 5/5 [==============================] - ETA: 0s - loss: 0.7453 - precision_score: 0.7052 - recall_score: 0.6875 - f1_score: 0.6961
# Epoch 00009: val_f1_score improved from 0.75146 to 0.77843, saving model to .\modelo_vgg16.hdf5
# 5/5 [==============================] - 4s 810ms/step - loss: 0.7453 - precision_score: 0.7052 - recall_score: 0.6875 - f1_score: 0.6961 - val_loss: 0.5766 - val_precision_score: 0.7888 - val_recall_score: 0.7688 - val_f1_score: 0.7784
# Epoch 10/100
# 5/5 [==============================] - ETA: 0s - loss: 0.7885 - precision_score: 0.7137 - recall_score: 0.6625 - f1_score: 0.6867
# Epoch 00010: val_f1_score did not improve from 0.77843
# 5/5 [==============================] - 4s 718ms/step - loss: 0.7885 - precision_score: 0.7137 - recall_score: 0.6625 - f1_score: 0.6867 - val_loss: 0.7188 - val_precision_score: 0.7830 - val_recall_score: 0.7375 - val_f1_score: 0.7587
# Epoch 11/100
# 5/5 [==============================] - ETA: 0s - loss: 0.7835 - precision_score: 0.6916 - recall_score: 0.6562 - f1_score: 0.6731
# Epoch 00011: val_f1_score did not improve from 0.77843
# 5/5 [==============================] - 4s 706ms/step - loss: 0.7835 - precision_score: 0.6916 - recall_score: 0.6562 - f1_score: 0.6731 - val_loss: 0.7874 - val_precision_score: 0.7853 - val_recall_score: 0.7563 - val_f1_score: 0.7701
# Epoch 12/100
# 5/5 [==============================] - ETA: 0s - loss: 0.8555 - precision_score: 0.6967 - recall_score: 0.6750 - f1_score: 0.6856
# Epoch 00012: val_f1_score did not improve from 0.77843
# 5/5 [==============================] - 4s 747ms/step - loss: 0.8555 - precision_score: 0.6967 - recall_score: 0.6750 - f1_score: 0.6856 - val_loss: 0.6553 - val_precision_score: 0.7633 - val_recall_score: 0.7437 - val_f1_score: 0.7532
# Epoch 13/100
# 5/5 [==============================] - ETA: 0s - loss: 0.6429 - precision_score: 0.7398 - recall_score: 0.7063 - f1_score: 0.7224
# Epoch 00013: val_f1_score did not improve from 0.77843
# 5/5 [==============================] - 4s 751ms/step - loss: 0.6429 - precision_score: 0.7398 - recall_score: 0.7063 - f1_score: 0.7224 - val_loss: 0.9376 - val_precision_score: 0.6769 - val_recall_score: 0.6562 - val_f1_score: 0.6661
# Epoch 14/100
# 5/5 [==============================] - ETA: 0s - loss: 0.8901 - precision_score: 0.6806 - recall_score: 0.6562 - f1_score: 0.6680
# Epoch 00014: val_f1_score did not improve from 0.77843
# 5/5 [==============================] - 4s 753ms/step - loss: 0.8901 - precision_score: 0.6806 - recall_score: 0.6562 - f1_score: 0.6680 - val_loss: 0.8594 - val_precision_score: 0.7226 - val_recall_score: 0.7063 - val_f1_score: 0.7142
# Epoch 15/100
# 5/5 [==============================] - ETA: 0s - loss: 0.6759 - precision_score: 0.7417 - recall_score: 0.7188 - f1_score: 0.7299
# Epoch 00015: val_f1_score did not improve from 0.77843
# 5/5 [==============================] - 4s 771ms/step - loss: 0.6759 - precision_score: 0.7417 - recall_score: 0.7188 - f1_score: 0.7299 - val_loss: 0.6632 - val_precision_score: 0.7896 - val_recall_score: 0.7500 - val_f1_score: 0.7692
# Epoch 16/100
# 5/5 [==============================] - ETA: 0s - loss: 0.7312 - precision_score: 0.7595 - recall_score: 0.7500 - f1_score: 0.7547
# Epoch 00016: val_f1_score did not improve from 0.77843
# 5/5 [==============================] - 4s 761ms/step - loss: 0.7312 - precision_score: 0.7595 - recall_score: 0.7500 - f1_score: 0.7547 - val_loss: 0.9591 - val_precision_score: 0.6774 - val_recall_score: 0.6562 - val_f1_score: 0.6665
# Epoch 17/100
# 5/5 [==============================] - ETA: 0s - loss: 0.7177 - precision_score: 0.7061 - recall_score: 0.6750 - f1_score: 0.6901
# Epoch 00017: val_f1_score improved from 0.77843 to 0.80149, saving model to .\modelo_vgg16.hdf5
# 5/5 [==============================] - 4s 787ms/step - loss: 0.7177 - precision_score: 0.7061 - recall_score: 0.6750 - f1_score: 0.6901 - val_loss: 0.6010 - val_precision_score: 0.8095 - val_recall_score: 0.7937 - val_f1_score: 0.8015
# Epoch 18/100
# 5/5 [==============================] - ETA: 0s - loss: 0.7237 - precision_score: 0.7477 - recall_score: 0.7000 - f1_score: 0.7230
# Epoch 00018: val_f1_score did not improve from 0.80149
# 5/5 [==============================] - 4s 747ms/step - loss: 0.7237 - precision_score: 0.7477 - recall_score: 0.7000 - f1_score: 0.7230 - val_loss: 0.9218 - val_precision_score: 0.7315 - val_recall_score: 0.6938 - val_f1_score: 0.7119
# Epoch 19/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4483 - precision_score: 0.8194 - recall_score: 0.7750 - f1_score: 0.7959
# Epoch 00019: val_f1_score did not improve from 0.80149
# 5/5 [==============================] - 4s 775ms/step - loss: 0.4483 - precision_score: 0.8194 - recall_score: 0.7750 - f1_score: 0.7959 - val_loss: 0.5898 - val_precision_score: 0.8212 - val_recall_score: 0.7750 - val_f1_score: 0.7973
# Epoch 20/100
# 5/5 [==============================] - ETA: 0s - loss: 0.9542 - precision_score: 0.6204 - recall_score: 0.5938 - f1_score: 0.6065
# Epoch 00020: val_f1_score did not improve from 0.80149
# 5/5 [==============================] - 4s 746ms/step - loss: 0.9542 - precision_score: 0.6204 - recall_score: 0.5938 - f1_score: 0.6065 - val_loss: 0.7547 - val_precision_score: 0.7436 - val_recall_score: 0.7063 - val_f1_score: 0.7241
# Epoch 21/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5203 - precision_score: 0.8129 - recall_score: 0.7937 - f1_score: 0.8030
# Epoch 00021: val_f1_score did not improve from 0.80149
# 5/5 [==============================] - 4s 745ms/step - loss: 0.5203 - precision_score: 0.8129 - recall_score: 0.7937 - f1_score: 0.8030 - val_loss: 0.6805 - val_precision_score: 0.7560 - val_recall_score: 0.7375 - val_f1_score: 0.7466
# Epoch 22/100
# 5/5 [==============================] - ETA: 0s - loss: 0.6244 - precision_score: 0.7055 - recall_score: 0.6875 - f1_score: 0.6963
# Epoch 00022: val_f1_score did not improve from 0.80149
# 5/5 [==============================] - 4s 738ms/step - loss: 0.6244 - precision_score: 0.7055 - recall_score: 0.6875 - f1_score: 0.6963 - val_loss: 0.7443 - val_precision_score: 0.7468 - val_recall_score: 0.7063 - val_f1_score: 0.7258
# Epoch 23/100
# 5/5 [==============================] - ETA: 0s - loss: 0.6580 - precision_score: 0.7868 - recall_score: 0.7375 - f1_score: 0.7611
# Epoch 00023: val_f1_score did not improve from 0.80149
# 5/5 [==============================] - 4s 772ms/step - loss: 0.6580 - precision_score: 0.7868 - recall_score: 0.7375 - f1_score: 0.7611 - val_loss: 0.6939 - val_precision_score: 0.7819 - val_recall_score: 0.7375 - val_f1_score: 0.7586
# Epoch 24/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5959 - precision_score: 0.7171 - recall_score: 0.7000 - f1_score: 0.7083
# Epoch 00024: val_f1_score did not improve from 0.80149
# 5/5 [==============================] - 4s 751ms/step - loss: 0.5959 - precision_score: 0.7171 - recall_score: 0.7000 - f1_score: 0.7083 - val_loss: 0.5752 - val_precision_score: 0.7970 - val_recall_score: 0.7563 - val_f1_score: 0.7759
# Epoch 25/100
# 5/5 [==============================] - ETA: 0s - loss: 0.6195 - precision_score: 0.7756 - recall_score: 0.7563 - f1_score: 0.7658
# Epoch 00025: val_f1_score did not improve from 0.80149
# 5/5 [==============================] - 4s 708ms/step - loss: 0.6195 - precision_score: 0.7756 - recall_score: 0.7563 - f1_score: 0.7658 - val_loss: 0.7306 - val_precision_score: 0.7419 - val_recall_score: 0.7000 - val_f1_score: 0.7196
# Epoch 26/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5369 - precision_score: 0.7670 - recall_score: 0.7437 - f1_score: 0.7551
# Epoch 00026: val_f1_score did not improve from 0.80149
# 5/5 [==============================] - 4s 780ms/step - loss: 0.5369 - precision_score: 0.7670 - recall_score: 0.7437 - f1_score: 0.7551 - val_loss: 0.6596 - val_precision_score: 0.7563 - val_recall_score: 0.7188 - val_f1_score: 0.7370
# Epoch 27/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4078 - precision_score: 0.8284 - recall_score: 0.8125 - f1_score: 0.8203
# Epoch 00027: val_f1_score did not improve from 0.80149
# 5/5 [==============================] - 3s 688ms/step - loss: 0.4078 - precision_score: 0.8284 - recall_score: 0.8125 - f1_score: 0.8203 - val_loss: 0.7835 - val_precision_score: 0.7583 - val_recall_score: 0.7250 - val_f1_score: 0.7412
# Epoch 28/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5333 - precision_score: 0.8245 - recall_score: 0.8000 - f1_score: 0.8118
# Epoch 00028: val_f1_score did not improve from 0.80149
# 5/5 [==============================] - 4s 752ms/step - loss: 0.5333 - precision_score: 0.8245 - recall_score: 0.8000 - f1_score: 0.8118 - val_loss: 0.5989 - val_precision_score: 0.7938 - val_recall_score: 0.7750 - val_f1_score: 0.7842
# Epoch 29/100
# 5/5 [==============================] - ETA: 0s - loss: 0.6894 - precision_score: 0.7837 - recall_score: 0.7688 - f1_score: 0.7761
# Epoch 00029: val_f1_score did not improve from 0.80149
# 5/5 [==============================] - 4s 762ms/step - loss: 0.6894 - precision_score: 0.7837 - recall_score: 0.7688 - f1_score: 0.7761 - val_loss: 0.6381 - val_precision_score: 0.7839 - val_recall_score: 0.7688 - val_f1_score: 0.7762
# Epoch 30/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5739 - precision_score: 0.7738 - recall_score: 0.7500 - f1_score: 0.7616
# Epoch 00030: val_f1_score did not improve from 0.80149
# 5/5 [==============================] - 4s 738ms/step - loss: 0.5739 - precision_score: 0.7738 - recall_score: 0.7500 - f1_score: 0.7616 - val_loss: 0.6932 - val_precision_score: 0.7781 - val_recall_score: 0.7500 - val_f1_score: 0.7636
# Epoch 31/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5850 - precision_score: 0.7400 - recall_score: 0.7125 - f1_score: 0.7260
# Epoch 00031: val_f1_score improved from 0.80149 to 0.83125, saving model to .\modelo_vgg16.hdf5
# 5/5 [==============================] - 4s 844ms/step - loss: 0.5850 - precision_score: 0.7400 - recall_score: 0.7125 - f1_score: 0.7260 - val_loss: 0.6603 - val_precision_score: 0.8520 - val_recall_score: 0.8125 - val_f1_score: 0.8313
# Epoch 32/100
# 5/5 [==============================] - ETA: 0s - loss: 0.6308 - precision_score: 0.7405 - recall_score: 0.7125 - f1_score: 0.7261
# Epoch 00032: val_f1_score did not improve from 0.83125
# 5/5 [==============================] - 4s 785ms/step - loss: 0.6308 - precision_score: 0.7405 - recall_score: 0.7125 - f1_score: 0.7261 - val_loss: 0.6036 - val_precision_score: 0.8279 - val_recall_score: 0.8062 - val_f1_score: 0.8167
# Epoch 33/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5755 - precision_score: 0.7956 - recall_score: 0.7750 - f1_score: 0.7851
# Epoch 00033: val_f1_score did not improve from 0.83125
# 5/5 [==============================] - 4s 731ms/step - loss: 0.5755 - precision_score: 0.7956 - recall_score: 0.7750 - f1_score: 0.7851 - val_loss: 0.6030 - val_precision_score: 0.8236 - val_recall_score: 0.7875 - val_f1_score: 0.8050
# Epoch 34/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5049 - precision_score: 0.8149 - recall_score: 0.7937 - f1_score: 0.8040
# Epoch 00034: val_f1_score did not improve from 0.83125
# 5/5 [==============================] - 3s 680ms/step - loss: 0.5049 - precision_score: 0.8149 - recall_score: 0.7937 - f1_score: 0.8040 - val_loss: 0.6793 - val_precision_score: 0.8125 - val_recall_score: 0.7875 - val_f1_score: 0.7995
# Epoch 35/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5738 - precision_score: 0.7764 - recall_score: 0.7563 - f1_score: 0.7662
# Epoch 00035: val_f1_score did not improve from 0.83125
# 5/5 [==============================] - 4s 731ms/step - loss: 0.5738 - precision_score: 0.7764 - recall_score: 0.7563 - f1_score: 0.7662 - val_loss: 0.7479 - val_precision_score: 0.8011 - val_recall_score: 0.7875 - val_f1_score: 0.7941
# Epoch 36/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5462 - precision_score: 0.7761 - recall_score: 0.7563 - f1_score: 0.7660
# Epoch 00036: val_f1_score did not improve from 0.83125
# 5/5 [==============================] - 4s 722ms/step - loss: 0.5462 - precision_score: 0.7761 - recall_score: 0.7563 - f1_score: 0.7660 - val_loss: 0.6619 - val_precision_score: 0.7463 - val_recall_score: 0.7375 - val_f1_score: 0.7417
# Epoch 37/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5610 - precision_score: 0.7720 - recall_score: 0.7625 - f1_score: 0.7672
# Epoch 00037: val_f1_score did not improve from 0.83125
# 5/5 [==============================] - 4s 762ms/step - loss: 0.5610 - precision_score: 0.7720 - recall_score: 0.7625 - f1_score: 0.7672 - val_loss: 0.5791 - val_precision_score: 0.8076 - val_recall_score: 0.7875 - val_f1_score: 0.7973
# Epoch 38/100
# 5/5 [==============================] - ETA: 0s - loss: 0.6581 - precision_score: 0.7772 - recall_score: 0.7437 - f1_score: 0.7601
# Epoch 00038: val_f1_score did not improve from 0.83125
# 5/5 [==============================] - 4s 766ms/step - loss: 0.6581 - precision_score: 0.7772 - recall_score: 0.7437 - f1_score: 0.7601 - val_loss: 1.1511 - val_precision_score: 0.6604 - val_recall_score: 0.6313 - val_f1_score: 0.6455
# Epoch 39/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4664 - precision_score: 0.8024 - recall_score: 0.7875 - f1_score: 0.7947
# Epoch 00039: val_f1_score did not improve from 0.83125
# 5/5 [==============================] - 4s 769ms/step - loss: 0.4664 - precision_score: 0.8024 - recall_score: 0.7875 - f1_score: 0.7947 - val_loss: 0.6479 - val_precision_score: 0.7591 - val_recall_score: 0.7250 - val_f1_score: 0.7416
# Epoch 40/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5485 - precision_score: 0.7909 - recall_score: 0.7563 - f1_score: 0.7730
# Epoch 00040: val_f1_score did not improve from 0.83125
# 5/5 [==============================] - 4s 766ms/step - loss: 0.5485 - precision_score: 0.7909 - recall_score: 0.7563 - f1_score: 0.7730 - val_loss: 0.5993 - val_precision_score: 0.7849 - val_recall_score: 0.7750 - val_f1_score: 0.7799
# Epoch 41/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5719 - precision_score: 0.7661 - recall_score: 0.7563 - f1_score: 0.7611
# Epoch 00041: val_f1_score did not improve from 0.83125
# 5/5 [==============================] - 4s 756ms/step - loss: 0.5719 - precision_score: 0.7661 - recall_score: 0.7563 - f1_score: 0.7611 - val_loss: 0.4664 - val_precision_score: 0.8393 - val_recall_score: 0.8125 - val_f1_score: 0.8256
# Epoch 42/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4991 - precision_score: 0.7780 - recall_score: 0.7688 - f1_score: 0.7733
# Epoch 00042: val_f1_score did not improve from 0.83125
# 5/5 [==============================] - 4s 731ms/step - loss: 0.4991 - precision_score: 0.7780 - recall_score: 0.7688 - f1_score: 0.7733 - val_loss: 0.7810 - val_precision_score: 0.6886 - val_recall_score: 0.6687 - val_f1_score: 0.6784
# Epoch 43/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5378 - precision_score: 0.7833 - recall_score: 0.7688 - f1_score: 0.7759
# Epoch 00043: val_f1_score did not improve from 0.83125
# 5/5 [==============================] - 4s 803ms/step - loss: 0.5378 - precision_score: 0.7833 - recall_score: 0.7688 - f1_score: 0.7759 - val_loss: 0.7883 - val_precision_score: 0.7575 - val_recall_score: 0.7375 - val_f1_score: 0.7471
# Epoch 44/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5242 - precision_score: 0.7667 - recall_score: 0.7625 - f1_score: 0.7646
# Epoch 00044: val_f1_score did not improve from 0.83125
# 5/5 [==============================] - 4s 748ms/step - loss: 0.5242 - precision_score: 0.7667 - recall_score: 0.7625 - f1_score: 0.7646 - val_loss: 0.6410 - val_precision_score: 0.7596 - val_recall_score: 0.7250 - val_f1_score: 0.7417
# Epoch 45/100
# 5/5 [==============================] - ETA: 0s - loss: 0.6229 - precision_score: 0.7189 - recall_score: 0.7000 - f1_score: 0.7092
# Epoch 00045: val_f1_score did not improve from 0.83125
# 5/5 [==============================] - 4s 722ms/step - loss: 0.6229 - precision_score: 0.7189 - recall_score: 0.7000 - f1_score: 0.7092 - val_loss: 0.7442 - val_precision_score: 0.7794 - val_recall_score: 0.7437 - val_f1_score: 0.7609
# Epoch 46/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5124 - precision_score: 0.8246 - recall_score: 0.8000 - f1_score: 0.8120
# Epoch 00046: val_f1_score did not improve from 0.83125
# 5/5 [==============================] - 4s 766ms/step - loss: 0.5124 - precision_score: 0.8246 - recall_score: 0.8000 - f1_score: 0.8120 - val_loss: 0.6557 - val_precision_score: 0.7677 - val_recall_score: 0.7437 - val_f1_score: 0.7556
# Epoch 47/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4412 - precision_score: 0.8179 - recall_score: 0.8125 - f1_score: 0.8152
# Epoch 00047: val_f1_score did not improve from 0.83125
# 5/5 [==============================] - 4s 723ms/step - loss: 0.4412 - precision_score: 0.8179 - recall_score: 0.8125 - f1_score: 0.8152 - val_loss: 0.5696 - val_precision_score: 0.8153 - val_recall_score: 0.7937 - val_f1_score: 0.8043
# Epoch 48/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5326 - precision_score: 0.7417 - recall_score: 0.7312 - f1_score: 0.7363
# Epoch 00048: val_f1_score did not improve from 0.83125
# 5/5 [==============================] - 4s 746ms/step - loss: 0.5326 - precision_score: 0.7417 - recall_score: 0.7312 - f1_score: 0.7363 - val_loss: 0.5802 - val_precision_score: 0.7960 - val_recall_score: 0.7812 - val_f1_score: 0.7885
# Epoch 49/100
# 5/5 [==============================] - ETA: 0s - loss: 0.6005 - precision_score: 0.7697 - recall_score: 0.7375 - f1_score: 0.7530
# Epoch 00049: val_f1_score did not improve from 0.83125
# 5/5 [==============================] - 4s 783ms/step - loss: 0.6005 - precision_score: 0.7697 - recall_score: 0.7375 - f1_score: 0.7530 - val_loss: 0.7805 - val_precision_score: 0.7721 - val_recall_score: 0.7437 - val_f1_score: 0.7575
# Epoch 50/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4772 - precision_score: 0.8065 - recall_score: 0.7750 - f1_score: 0.7902
# Epoch 00050: val_f1_score did not improve from 0.83125
# 5/5 [==============================] - 4s 719ms/step - loss: 0.4772 - precision_score: 0.8065 - recall_score: 0.7750 - f1_score: 0.7902 - val_loss: 0.5604 - val_precision_score: 0.8206 - val_recall_score: 0.8000 - val_f1_score: 0.8101
# Epoch 51/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5988 - precision_score: 0.7786 - recall_score: 0.7688 - f1_score: 0.7736
# Epoch 00051: val_f1_score did not improve from 0.83125
# 5/5 [==============================] - 4s 726ms/step - loss: 0.5988 - precision_score: 0.7786 - recall_score: 0.7688 - f1_score: 0.7736 - val_loss: 0.7209 - val_precision_score: 0.7643 - val_recall_score: 0.7375 - val_f1_score: 0.7505
# Epoch 52/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5530 - precision_score: 0.7697 - recall_score: 0.7500 - f1_score: 0.7596
# Epoch 00052: val_f1_score did not improve from 0.83125
# 5/5 [==============================] - 4s 764ms/step - loss: 0.5530 - precision_score: 0.7697 - recall_score: 0.7500 - f1_score: 0.7596 - val_loss: 0.5543 - val_precision_score: 0.8192 - val_recall_score: 0.7937 - val_f1_score: 0.8061
# Epoch 53/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5694 - precision_score: 0.7792 - recall_score: 0.7500 - f1_score: 0.7641
# Epoch 00053: val_f1_score did not improve from 0.83125
# 5/5 [==============================] - 4s 769ms/step - loss: 0.5694 - precision_score: 0.7792 - recall_score: 0.7500 - f1_score: 0.7641 - val_loss: 0.6842 - val_precision_score: 0.7331 - val_recall_score: 0.7000 - val_f1_score: 0.7160
# Epoch 54/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5067 - precision_score: 0.7851 - recall_score: 0.7750 - f1_score: 0.7800
# Epoch 00054: val_f1_score did not improve from 0.83125
# 5/5 [==============================] - 4s 791ms/step - loss: 0.5067 - precision_score: 0.7851 - recall_score: 0.7750 - f1_score: 0.7800 - val_loss: 0.6033 - val_precision_score: 0.7824 - val_recall_score: 0.7625 - val_f1_score: 0.7720
# Epoch 55/100
# 5/5 [==============================] - ETA: 0s - loss: 0.6555 - precision_score: 0.7258 - recall_score: 0.7125 - f1_score: 0.7190
# Epoch 00055: val_f1_score did not improve from 0.83125
# 5/5 [==============================] - 4s 745ms/step - loss: 0.6555 - precision_score: 0.7258 - recall_score: 0.7125 - f1_score: 0.7190 - val_loss: 0.5110 - val_precision_score: 0.8190 - val_recall_score: 0.7875 - val_f1_score: 0.8027
# Epoch 56/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5696 - precision_score: 0.8087 - recall_score: 0.7937 - f1_score: 0.8011
# Epoch 00056: val_f1_score did not improve from 0.83125
# 5/5 [==============================] - 4s 738ms/step - loss: 0.5696 - precision_score: 0.8087 - recall_score: 0.7937 - f1_score: 0.8011 - val_loss: 0.6099 - val_precision_score: 0.7718 - val_recall_score: 0.7375 - val_f1_score: 0.7542
# Epoch 57/100
# 5/5 [==============================] - ETA: 0s - loss: 0.8049 - precision_score: 0.6806 - recall_score: 0.6500 - f1_score: 0.6648
# Epoch 00057: val_f1_score did not improve from 0.83125
# 5/5 [==============================] - 4s 771ms/step - loss: 0.8049 - precision_score: 0.6806 - recall_score: 0.6500 - f1_score: 0.6648 - val_loss: 1.2673 - val_precision_score: 0.6821 - val_recall_score: 0.6438 - val_f1_score: 0.6619
# Epoch 58/100
# 5/5 [==============================] - ETA: 0s - loss: 0.6523 - precision_score: 0.7219 - recall_score: 0.6938 - f1_score: 0.7075
# Epoch 00058: val_f1_score did not improve from 0.83125
# 5/5 [==============================] - 4s 759ms/step - loss: 0.6523 - precision_score: 0.7219 - recall_score: 0.6938 - f1_score: 0.7075 - val_loss: 0.5422 - val_precision_score: 0.8010 - val_recall_score: 0.7563 - val_f1_score: 0.7779
# Epoch 59/100
# 5/5 [==============================] - ETA: 0s - loss: 0.6086 - precision_score: 0.7566 - recall_score: 0.7312 - f1_score: 0.7436
# Epoch 00059: val_f1_score improved from 0.83125 to 0.85806, saving model to .\modelo_vgg16.hdf5
# 5/5 [==============================] - 5s 909ms/step - loss: 0.6086 - precision_score: 0.7566 - recall_score: 0.7312 - f1_score: 0.7436 - val_loss: 0.4155 - val_precision_score: 0.8867 - val_recall_score: 0.8313 - val_f1_score: 0.8581
# Epoch 60/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5448 - precision_score: 0.7614 - recall_score: 0.7375 - f1_score: 0.7492
# Epoch 00060: val_f1_score did not improve from 0.85806
# 5/5 [==============================] - 4s 776ms/step - loss: 0.5448 - precision_score: 0.7614 - recall_score: 0.7375 - f1_score: 0.7492 - val_loss: 0.7854 - val_precision_score: 0.7693 - val_recall_score: 0.7188 - val_f1_score: 0.7428
# Epoch 61/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5764 - precision_score: 0.7750 - recall_score: 0.7750 - f1_score: 0.7750
# Epoch 00061: val_f1_score did not improve from 0.85806
# 5/5 [==============================] - 4s 771ms/step - loss: 0.5764 - precision_score: 0.7750 - recall_score: 0.7750 - f1_score: 0.7750 - val_loss: 0.6248 - val_precision_score: 0.8213 - val_recall_score: 0.7875 - val_f1_score: 0.8032
# Epoch 62/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5667 - precision_score: 0.7579 - recall_score: 0.7188 - f1_score: 0.7374
# Epoch 00062: val_f1_score did not improve from 0.85806
# 5/5 [==============================] - 4s 751ms/step - loss: 0.5667 - precision_score: 0.7579 - recall_score: 0.7188 - f1_score: 0.7374 - val_loss: 0.5164 - val_precision_score: 0.8342 - val_recall_score: 0.8188 - val_f1_score: 0.8263
# Epoch 63/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4106 - precision_score: 0.8262 - recall_score: 0.8062 - f1_score: 0.8159
# Epoch 00063: val_f1_score did not improve from 0.85806
# 5/5 [==============================] - 4s 711ms/step - loss: 0.4106 - precision_score: 0.8262 - recall_score: 0.8062 - f1_score: 0.8159 - val_loss: 0.5556 - val_precision_score: 0.8636 - val_recall_score: 0.8313 - val_f1_score: 0.8470
# Epoch 64/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5665 - precision_score: 0.8101 - recall_score: 0.8000 - f1_score: 0.8050
# Epoch 00064: val_f1_score did not improve from 0.85806
# 5/5 [==============================] - 4s 746ms/step - loss: 0.5665 - precision_score: 0.8101 - recall_score: 0.8000 - f1_score: 0.8050 - val_loss: 0.5513 - val_precision_score: 0.8134 - val_recall_score: 0.7688 - val_f1_score: 0.7903
# Epoch 65/100
# 5/5 [==============================] - ETA: 0s - loss: 0.3908 - precision_score: 0.8274 - recall_score: 0.8062 - f1_score: 0.8165
# Epoch 00065: val_f1_score did not improve from 0.85806
# 5/5 [==============================] - 4s 755ms/step - loss: 0.3908 - precision_score: 0.8274 - recall_score: 0.8062 - f1_score: 0.8165 - val_loss: 0.6352 - val_precision_score: 0.7853 - val_recall_score: 0.7500 - val_f1_score: 0.7671
# Epoch 66/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4935 - precision_score: 0.8208 - recall_score: 0.8000 - f1_score: 0.8101
# Epoch 00066: val_f1_score did not improve from 0.85806
# 5/5 [==============================] - 4s 745ms/step - loss: 0.4935 - precision_score: 0.8208 - recall_score: 0.8000 - f1_score: 0.8101 - val_loss: 0.5746 - val_precision_score: 0.8067 - val_recall_score: 0.7563 - val_f1_score: 0.7806
# Epoch 67/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5570 - precision_score: 0.7703 - recall_score: 0.7563 - f1_score: 0.7631
# Epoch 00067: val_f1_score did not improve from 0.85806
# 5/5 [==============================] - 4s 780ms/step - loss: 0.5570 - precision_score: 0.7703 - recall_score: 0.7563 - f1_score: 0.7631 - val_loss: 0.5295 - val_precision_score: 0.7857 - val_recall_score: 0.7500 - val_f1_score: 0.7672
# Epoch 68/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4357 - precision_score: 0.8219 - recall_score: 0.7812 - f1_score: 0.8010
# Epoch 00068: val_f1_score did not improve from 0.85806
# 5/5 [==============================] - 4s 731ms/step - loss: 0.4357 - precision_score: 0.8219 - recall_score: 0.7812 - f1_score: 0.8010 - val_loss: 0.5765 - val_precision_score: 0.7786 - val_recall_score: 0.7500 - val_f1_score: 0.7636
# Epoch 69/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5150 - precision_score: 0.8012 - recall_score: 0.7625 - f1_score: 0.7812
# Epoch 00069: val_f1_score did not improve from 0.85806
# 5/5 [==============================] - 4s 771ms/step - loss: 0.5150 - precision_score: 0.8012 - recall_score: 0.7625 - f1_score: 0.7812 - val_loss: 0.8477 - val_precision_score: 0.7727 - val_recall_score: 0.7250 - val_f1_score: 0.7478
# Epoch 70/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5599 - precision_score: 0.7689 - recall_score: 0.7500 - f1_score: 0.7592
# Epoch 00070: val_f1_score did not improve from 0.85806
# 5/5 [==============================] - 4s 789ms/step - loss: 0.5599 - precision_score: 0.7689 - recall_score: 0.7500 - f1_score: 0.7592 - val_loss: 0.5825 - val_precision_score: 0.8161 - val_recall_score: 0.8000 - val_f1_score: 0.8078
# Epoch 71/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5124 - precision_score: 0.8367 - recall_score: 0.8062 - f1_score: 0.8211
# Epoch 00071: val_f1_score did not improve from 0.85806
# 5/5 [==============================] - 4s 746ms/step - loss: 0.5124 - precision_score: 0.8367 - recall_score: 0.8062 - f1_score: 0.8211 - val_loss: 0.5893 - val_precision_score: 0.8013 - val_recall_score: 0.7812 - val_f1_score: 0.7910
# Epoch 72/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4077 - precision_score: 0.8298 - recall_score: 0.7875 - f1_score: 0.8074
# Epoch 00072: val_f1_score did not improve from 0.85806
# 5/5 [==============================] - 4s 770ms/step - loss: 0.4077 - precision_score: 0.8298 - recall_score: 0.7875 - f1_score: 0.8074 - val_loss: 0.5993 - val_precision_score: 0.7874 - val_recall_score: 0.7500 - val_f1_score: 0.7680
# Epoch 73/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4556 - precision_score: 0.8054 - recall_score: 0.7750 - f1_score: 0.7897
# Epoch 00073: val_f1_score did not improve from 0.85806
# 5/5 [==============================] - 4s 795ms/step - loss: 0.4556 - precision_score: 0.8054 - recall_score: 0.7750 - f1_score: 0.7897 - val_loss: 0.6333 - val_precision_score: 0.7989 - val_recall_score: 0.7688 - val_f1_score: 0.7835
# Epoch 74/100
# 5/5 [==============================] - ETA: 0s - loss: 0.6095 - precision_score: 0.7872 - recall_score: 0.7625 - f1_score: 0.7746
# Epoch 00074: val_f1_score did not improve from 0.85806
# 5/5 [==============================] - 4s 783ms/step - loss: 0.6095 - precision_score: 0.7872 - recall_score: 0.7625 - f1_score: 0.7746 - val_loss: 0.8304 - val_precision_score: 0.7827 - val_recall_score: 0.7437 - val_f1_score: 0.7626
# Epoch 75/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4591 - precision_score: 0.7915 - recall_score: 0.7688 - f1_score: 0.7798
# Epoch 00075: val_f1_score did not improve from 0.85806
# 5/5 [==============================] - 4s 770ms/step - loss: 0.4591 - precision_score: 0.7915 - recall_score: 0.7688 - f1_score: 0.7798 - val_loss: 0.5539 - val_precision_score: 0.8459 - val_recall_score: 0.8250 - val_f1_score: 0.8352
# Epoch 76/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5802 - precision_score: 0.8121 - recall_score: 0.7812 - f1_score: 0.7962
# Epoch 00076: val_f1_score did not improve from 0.85806
# 5/5 [==============================] - 4s 769ms/step - loss: 0.5802 - precision_score: 0.8121 - recall_score: 0.7812 - f1_score: 0.7962 - val_loss: 0.8121 - val_precision_score: 0.7443 - val_recall_score: 0.7063 - val_f1_score: 0.7244
# Epoch 77/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5713 - precision_score: 0.7328 - recall_score: 0.7188 - f1_score: 0.7256
# Epoch 00077: val_f1_score did not improve from 0.85806
# 5/5 [==============================] - 4s 769ms/step - loss: 0.5713 - precision_score: 0.7328 - recall_score: 0.7188 - f1_score: 0.7256 - val_loss: 0.7370 - val_precision_score: 0.7726 - val_recall_score: 0.7625 - val_f1_score: 0.7675
# Epoch 78/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4773 - precision_score: 0.7841 - recall_score: 0.7750 - f1_score: 0.7795
# Epoch 00078: val_f1_score did not improve from 0.85806
# 5/5 [==============================] - 4s 748ms/step - loss: 0.4773 - precision_score: 0.7841 - recall_score: 0.7750 - f1_score: 0.7795 - val_loss: 0.7134 - val_precision_score: 0.7183 - val_recall_score: 0.7000 - val_f1_score: 0.7089
# Epoch 79/100
# 5/5 [==============================] - ETA: 0s - loss: 0.6269 - precision_score: 0.7657 - recall_score: 0.7500 - f1_score: 0.7576
# Epoch 00079: val_f1_score did not improve from 0.85806
# 5/5 [==============================] - 3s 699ms/step - loss: 0.6269 - precision_score: 0.7657 - recall_score: 0.7500 - f1_score: 0.7576 - val_loss: 0.5534 - val_precision_score: 0.8444 - val_recall_score: 0.8250 - val_f1_score: 0.8345
# Epoch 80/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5372 - precision_score: 0.7708 - recall_score: 0.7563 - f1_score: 0.7634
# Epoch 00080: val_f1_score did not improve from 0.85806
# 5/5 [==============================] - 4s 786ms/step - loss: 0.5372 - precision_score: 0.7708 - recall_score: 0.7563 - f1_score: 0.7634 - val_loss: 0.6115 - val_precision_score: 0.8196 - val_recall_score: 0.8000 - val_f1_score: 0.8096
# Epoch 81/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5193 - precision_score: 0.7795 - recall_score: 0.7500 - f1_score: 0.7643
# Epoch 00081: val_f1_score did not improve from 0.85806
# 5/5 [==============================] - 4s 717ms/step - loss: 0.5193 - precision_score: 0.7795 - recall_score: 0.7500 - f1_score: 0.7643 - val_loss: 0.6287 - val_precision_score: 0.7941 - val_recall_score: 0.7750 - val_f1_score: 0.7843
# Epoch 82/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4441 - precision_score: 0.8259 - recall_score: 0.8000 - f1_score: 0.8126
# Epoch 00082: val_f1_score did not improve from 0.85806
# 5/5 [==============================] - 4s 740ms/step - loss: 0.4441 - precision_score: 0.8259 - recall_score: 0.8000 - f1_score: 0.8126 - val_loss: 0.5145 - val_precision_score: 0.8172 - val_recall_score: 0.7875 - val_f1_score: 0.8019
# Epoch 83/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5961 - precision_score: 0.7642 - recall_score: 0.7250 - f1_score: 0.7437
# Epoch 00083: val_f1_score did not improve from 0.85806
# 5/5 [==============================] - 4s 737ms/step - loss: 0.5961 - precision_score: 0.7642 - recall_score: 0.7250 - f1_score: 0.7437 - val_loss: 0.5856 - val_precision_score: 0.7939 - val_recall_score: 0.7688 - val_f1_score: 0.7810
# Epoch 84/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4647 - precision_score: 0.8351 - recall_score: 0.8188 - f1_score: 0.8268
# Epoch 00084: val_f1_score did not improve from 0.85806
# 5/5 [==============================] - 4s 758ms/step - loss: 0.4647 - precision_score: 0.8351 - recall_score: 0.8188 - f1_score: 0.8268 - val_loss: 0.6581 - val_precision_score: 0.7938 - val_recall_score: 0.7688 - val_f1_score: 0.7809
# Epoch 85/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5245 - precision_score: 0.8010 - recall_score: 0.7437 - f1_score: 0.7706
# Epoch 00085: val_f1_score did not improve from 0.85806
# 5/5 [==============================] - 4s 744ms/step - loss: 0.5245 - precision_score: 0.8010 - recall_score: 0.7437 - f1_score: 0.7706 - val_loss: 0.6557 - val_precision_score: 0.7754 - val_recall_score: 0.7312 - val_f1_score: 0.7526
# Epoch 86/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5251 - precision_score: 0.7965 - recall_score: 0.7812 - f1_score: 0.7887
# Epoch 00086: val_f1_score did not improve from 0.85806
# 5/5 [==============================] - 4s 750ms/step - loss: 0.5251 - precision_score: 0.7965 - recall_score: 0.7812 - f1_score: 0.7887 - val_loss: 0.5477 - val_precision_score: 0.8148 - val_recall_score: 0.8000 - val_f1_score: 0.8072
# Epoch 87/100
# 5/5 [==============================] - ETA: 0s - loss: 0.6255 - precision_score: 0.7678 - recall_score: 0.7500 - f1_score: 0.7587
# Epoch 00087: val_f1_score did not improve from 0.85806
# 5/5 [==============================] - 4s 773ms/step - loss: 0.6255 - precision_score: 0.7678 - recall_score: 0.7500 - f1_score: 0.7587 - val_loss: 0.8189 - val_precision_score: 0.7331 - val_recall_score: 0.7188 - val_f1_score: 0.7258
# Epoch 88/100
# 5/5 [==============================] - ETA: 0s - loss: 0.6553 - precision_score: 0.7270 - recall_score: 0.7000 - f1_score: 0.7131
# Epoch 00088: val_f1_score did not improve from 0.85806
# 5/5 [==============================] - 4s 789ms/step - loss: 0.6553 - precision_score: 0.7270 - recall_score: 0.7000 - f1_score: 0.7131 - val_loss: 0.4865 - val_precision_score: 0.8261 - val_recall_score: 0.8062 - val_f1_score: 0.8159
# Epoch 89/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4750 - precision_score: 0.8173 - recall_score: 0.7500 - f1_score: 0.7818
# Epoch 00089: val_f1_score did not improve from 0.85806
# 5/5 [==============================] - 4s 743ms/step - loss: 0.4750 - precision_score: 0.8173 - recall_score: 0.7500 - f1_score: 0.7818 - val_loss: 0.5539 - val_precision_score: 0.8316 - val_recall_score: 0.7750 - val_f1_score: 0.8022
# Epoch 90/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5625 - precision_score: 0.7534 - recall_score: 0.7437 - f1_score: 0.7485
# Epoch 00090: val_f1_score did not improve from 0.85806
# 5/5 [==============================] - 4s 728ms/step - loss: 0.5625 - precision_score: 0.7534 - recall_score: 0.7437 - f1_score: 0.7485 - val_loss: 1.2157 - val_precision_score: 0.6824 - val_recall_score: 0.6562 - val_f1_score: 0.6690
# Epoch 91/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5795 - precision_score: 0.7820 - recall_score: 0.7625 - f1_score: 0.7720
# Epoch 00091: val_f1_score did not improve from 0.85806
# 5/5 [==============================] - 4s 749ms/step - loss: 0.5795 - precision_score: 0.7820 - recall_score: 0.7625 - f1_score: 0.7720 - val_loss: 0.8412 - val_precision_score: 0.7318 - val_recall_score: 0.7125 - val_f1_score: 0.7219
# Epoch 92/100
# 5/5 [==============================] - ETA: 0s - loss: 0.6398 - precision_score: 0.7476 - recall_score: 0.7063 - f1_score: 0.7261
# Epoch 00092: val_f1_score did not improve from 0.85806
# 5/5 [==============================] - 4s 770ms/step - loss: 0.6398 - precision_score: 0.7476 - recall_score: 0.7063 - f1_score: 0.7261 - val_loss: 0.5186 - val_precision_score: 0.8536 - val_recall_score: 0.8313 - val_f1_score: 0.8422
# Epoch 93/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4553 - precision_score: 0.8375 - recall_score: 0.8375 - f1_score: 0.8375
# Epoch 00093: val_f1_score did not improve from 0.85806
# 5/5 [==============================] - 4s 763ms/step - loss: 0.4553 - precision_score: 0.8375 - recall_score: 0.8375 - f1_score: 0.8375 - val_loss: 0.9257 - val_precision_score: 0.7132 - val_recall_score: 0.6875 - val_f1_score: 0.7000
# Epoch 94/100
# 5/5 [==============================] - ETA: 0s - loss: 0.6104 - precision_score: 0.7665 - recall_score: 0.7437 - f1_score: 0.7548
# Epoch 00094: val_f1_score did not improve from 0.85806
# 5/5 [==============================] - 4s 745ms/step - loss: 0.6104 - precision_score: 0.7665 - recall_score: 0.7437 - f1_score: 0.7548 - val_loss: 0.8771 - val_precision_score: 0.7694 - val_recall_score: 0.7500 - val_f1_score: 0.7595
# Epoch 95/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5773 - precision_score: 0.7224 - recall_score: 0.7125 - f1_score: 0.7174
# Epoch 00095: val_f1_score did not improve from 0.85806
# 5/5 [==============================] - 4s 738ms/step - loss: 0.5773 - precision_score: 0.7224 - recall_score: 0.7125 - f1_score: 0.7174 - val_loss: 0.4526 - val_precision_score: 0.8561 - val_recall_score: 0.8250 - val_f1_score: 0.8401
# Epoch 96/100
# 5/5 [==============================] - ETA: 0s - loss: 0.6580 - precision_score: 0.7934 - recall_score: 0.7688 - f1_score: 0.7806
# Epoch 00096: val_f1_score did not improve from 0.85806
# 5/5 [==============================] - 4s 748ms/step - loss: 0.6580 - precision_score: 0.7934 - recall_score: 0.7688 - f1_score: 0.7806 - val_loss: 0.6845 - val_precision_score: 0.7623 - val_recall_score: 0.7375 - val_f1_score: 0.7494
# Epoch 97/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5401 - precision_score: 0.7641 - recall_score: 0.7500 - f1_score: 0.7569
# Epoch 00097: val_f1_score did not improve from 0.85806
# 5/5 [==============================] - 4s 763ms/step - loss: 0.5401 - precision_score: 0.7641 - recall_score: 0.7500 - f1_score: 0.7569 - val_loss: 0.7029 - val_precision_score: 0.7656 - val_recall_score: 0.7375 - val_f1_score: 0.7511
# Epoch 98/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4607 - precision_score: 0.8062 - recall_score: 0.8062 - f1_score: 0.8062
# Epoch 00098: val_f1_score did not improve from 0.85806
# 5/5 [==============================] - 4s 749ms/step - loss: 0.4607 - precision_score: 0.8062 - recall_score: 0.8062 - f1_score: 0.8062 - val_loss: 0.8035 - val_precision_score: 0.7536 - val_recall_score: 0.7500 - val_f1_score: 0.7518
# Epoch 99/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4641 - precision_score: 0.8077 - recall_score: 0.7625 - f1_score: 0.7842
# Epoch 00099: val_f1_score did not improve from 0.85806
# 5/5 [==============================] - 4s 760ms/step - loss: 0.4641 - precision_score: 0.8077 - recall_score: 0.7625 - f1_score: 0.7842 - val_loss: 0.6910 - val_precision_score: 0.7651 - val_recall_score: 0.7500 - val_f1_score: 0.7573
# Epoch 100/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4902 - precision_score: 0.7986 - recall_score: 0.7937 - f1_score: 0.7961
# Epoch 00100: val_f1_score did not improve from 0.85806
# 5/5 [==============================] - 4s 714ms/step - loss: 0.4902 - precision_score: 0.7986 - recall_score: 0.7937 - f1_score: 0.7961 - val_loss: 0.8694 - val_precision_score: 0.6949 - val_recall_score: 0.6812 - val_f1_score: 0.6879

# %% [markdown]
# Um modelo que converge bem possui o gráfico de perda (*loss*) descendente e os gráfico de precisão (*precision*), sensibilidade (*recall*) e pontuação f1 (*f1 score*) em acendente.

# %%
# Exibindo dados de Precisão
plt.plot(history.history['precision_score'])
plt.plot(history.history['val_precision_score'])
plt.title('model precision')
plt.ylabel('precision')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de Sensibilidade
plt.plot(history.history['recall_score'])
plt.plot(history.history['val_recall_score'])
plt.title('model recall')
plt.ylabel('recall')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de F1 Score
plt.plot(history.history['f1_score'])
plt.plot(history.history['val_f1_score'])
plt.title('model f1_score')
plt.ylabel('f1_score')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de Perda
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# **Pergunta**: Avalie os gráficos de perda (*loss*), precisão (*precision*), sensibilidade (*recall*) e pontuação f1 (*f1 score*)  e explique o comportamento de ambos no que tange a convergência do modelo.

# %% [markdown]
# **Resposta**:

# %% [markdown]
# **Pergunta**: Quais são os valores de **precisão (precision)**, **sensibilidade (recall)** de validação?
#
# *Estes valores são exibidos durante o treinamento, utilize a última saída, exemplo:*
#
# ```
# Epoch 10/10 [==============================] - 45s 9s/step - loss: 0.1234 - precision_score: 0.9742 - recall_score: 0.9683 - f1_score: 0.9712 - val_loss: 0.8819 - val_precision_score: 0.6912 - val_recall_score: 0.5649 - val_f1_score: 0.6216```
#
# No caso acima, o valor de precisão, sensibilidade e pontuação de validação são, respectivamente, 69,12%, 56,49% e 62,16%.

# %% [markdown]
# **Resposta**:

# %%
model = load_model("./modelo_vgg16.hdf5", custom_objects={'f1_score': f1_score, 'precision_score': precision_score, 'recall_score': recall_score})

scores = model.evaluate(val_generator)
print()
print(f"Precision Score: {round(scores[1]*100,2)}%")
print(f"Recall Score: {round(scores[2]*100,2)}%")
print(f"F1 Score: {round(scores[3]*100,2)}%")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-79-522c9edffb4d> in <module>
#       1 model = load_model("./modelo_vgg16.hdf5", custom_objects={'f1_score': f1_score, 'precision_score': precision_score, 'recall_score': recall_score})
#       2
# ----> 3 scores = model.evaluate(val_generator,
#       4                         validation_steps=5,
#       5                         steps_per_epoch=5)
#
# ~\anaconda3\envs\tf-gpu\lib\site-packages\tensorflow\python\keras\engine\training.py in _method_wrapper(self, *args, **kwargs)
#     106   def _method_wrapper(self, *args, **kwargs):
#     107     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108       return method(self, *args, **kwargs)
#     109
#     110     # Running inside `run_distribute_coordinator` already.
#
# TypeError: evaluate() got an unexpected keyword argument 'validation_steps'

# %% [markdown]
# ### 4.5.3 Arquitetura VGG19

# %% [markdown]
# **Pergunta**: Explique como é constituída a arquitetura do VGG19? *Utilize, se necessário, gráficos, projetos que utilizam essa arquitetura. Detalhe também sua topologia em camadas e mostre quais as situações essa arquitetura pode ter mais êxito e quais cenários não tem.*

# %% [markdown]
# **Resposta**:

# %%
conv_base = vgg19.VGG19(include_top=False)

for layer in conv_base.layers:
    layer.trainable = False

# %%
x = conv_base.output
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(128, activation='relu')(x) 

predictions = layers.Dense(qtde_classes, activation='softmax')(x)
model = Model(conv_base.input, predictions)

model.summary()
# Out:
# Model: "functional_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_8 (InputLayer)         [(None, None, None, 3)]   0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, None, None, 64)    1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, None, None, 64)    36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, None, None, 64)    0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, None, None, 128)   73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, None, None, 128)   147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, None, None, 128)   0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, None, None, 256)   295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, None, None, 256)   590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, None, None, 256)   590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, None, None, 256)   590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, None, None, 256)   0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, None, None, 512)   1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, None, None, 512)   0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, None, None, 512)   0
# _________________________________________________________________
# global_average_pooling2d_5 ( (None, 512)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 128)               65664
# _________________________________________________________________
# dense_11 (Dense)             (None, 3)                 387
# =================================================================
# Total params: 20,090,435
# Trainable params: 66,051
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
optimizer = keras.optimizers.Adam()
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=[precision_score, recall_score, f1_score])

# %%
checkpointer = ModelCheckpoint_tweaked(filepath='./modelo_vgg19.hdf5', verbose=1,  mode='max', save_best_only=True, monitor='val_f1_score')

history = model.fit_generator(generator=train_generator, 
                              epochs=qtde_epocas, 
                              validation_steps=5, 
                              steps_per_epoch=5, 
                              validation_data=val_generator,
                              callbacks=[checkpointer])
# Out:
# Epoch 1/100
# 5/5 [==============================] - ETA: 0s - loss: 2.8896 - precision_score: 0.3671 - recall_score: 0.3562 - f1_score: 0.3615
# Epoch 00001: val_f1_score improved from -inf to 0.40744, saving model to .\modelo_vgg19.hdf5
# 5/5 [==============================] - 5s 1s/step - loss: 2.8896 - precision_score: 0.3671 - recall_score: 0.3562 - f1_score: 0.3615 - val_loss: 2.7308 - val_precision_score: 0.4087 - val_recall_score: 0.4062 - val_f1_score: 0.4074
# Epoch 2/100
# 5/5 [==============================] - ETA: 0s - loss: 1.4200 - precision_score: 0.5234 - recall_score: 0.4875 - f1_score: 0.5046
# Epoch 00002: val_f1_score improved from 0.40744 to 0.63038, saving model to .\modelo_vgg19.hdf5
# 5/5 [==============================] - 4s 825ms/step - loss: 1.4200 - precision_score: 0.5234 - recall_score: 0.4875 - f1_score: 0.5046 - val_loss: 1.0510 - val_precision_score: 0.6426 - val_recall_score: 0.6187 - val_f1_score: 0.6304
# Epoch 3/100
# 5/5 [==============================] - ETA: 0s - loss: 1.1752 - precision_score: 0.5602 - recall_score: 0.5375 - f1_score: 0.5483
# Epoch 00003: val_f1_score did not improve from 0.63038
# 5/5 [==============================] - 4s 770ms/step - loss: 1.1752 - precision_score: 0.5602 - recall_score: 0.5375 - f1_score: 0.5483 - val_loss: 1.5161 - val_precision_score: 0.6149 - val_recall_score: 0.6000 - val_f1_score: 0.6073
# Epoch 4/100
# 5/5 [==============================] - ETA: 0s - loss: 1.3490 - precision_score: 0.6315 - recall_score: 0.6250 - f1_score: 0.6282
# Epoch 00004: val_f1_score improved from 0.63038 to 0.72466, saving model to .\modelo_vgg19.hdf5
# 5/5 [==============================] - 4s 825ms/step - loss: 1.3490 - precision_score: 0.6315 - recall_score: 0.6250 - f1_score: 0.6282 - val_loss: 0.8756 - val_precision_score: 0.7309 - val_recall_score: 0.7188 - val_f1_score: 0.7247
# Epoch 5/100
# 5/5 [==============================] - ETA: 0s - loss: 0.9802 - precision_score: 0.6870 - recall_score: 0.6625 - f1_score: 0.6744
# Epoch 00005: val_f1_score improved from 0.72466 to 0.80893, saving model to .\modelo_vgg19.hdf5
# 5/5 [==============================] - 4s 830ms/step - loss: 0.9802 - precision_score: 0.6870 - recall_score: 0.6625 - f1_score: 0.6744 - val_loss: 0.6036 - val_precision_score: 0.8117 - val_recall_score: 0.8062 - val_f1_score: 0.8089
# Epoch 6/100
# 5/5 [==============================] - ETA: 0s - loss: 1.0026 - precision_score: 0.7044 - recall_score: 0.7000 - f1_score: 0.7022
# Epoch 00006: val_f1_score did not improve from 0.80893
# 5/5 [==============================] - 4s 804ms/step - loss: 1.0026 - precision_score: 0.7044 - recall_score: 0.7000 - f1_score: 0.7022 - val_loss: 1.0639 - val_precision_score: 0.6663 - val_recall_score: 0.6375 - val_f1_score: 0.6514
# Epoch 7/100
# 5/5 [==============================] - ETA: 0s - loss: 0.7602 - precision_score: 0.7006 - recall_score: 0.6875 - f1_score: 0.6939
# Epoch 00007: val_f1_score did not improve from 0.80893
# 5/5 [==============================] - 4s 779ms/step - loss: 0.7602 - precision_score: 0.7006 - recall_score: 0.6875 - f1_score: 0.6939 - val_loss: 0.8025 - val_precision_score: 0.7520 - val_recall_score: 0.7375 - val_f1_score: 0.7446
# Epoch 8/100
# 5/5 [==============================] - ETA: 0s - loss: 0.7250 - precision_score: 0.7153 - recall_score: 0.6812 - f1_score: 0.6978
# Epoch 00008: val_f1_score improved from 0.80893 to 0.83304, saving model to .\modelo_vgg19.hdf5
# 5/5 [==============================] - 4s 829ms/step - loss: 0.7250 - precision_score: 0.7153 - recall_score: 0.6812 - f1_score: 0.6978 - val_loss: 0.5825 - val_precision_score: 0.8413 - val_recall_score: 0.8250 - val_f1_score: 0.8330
# Epoch 9/100
# 5/5 [==============================] - ETA: 0s - loss: 0.9115 - precision_score: 0.6438 - recall_score: 0.6250 - f1_score: 0.6341
# Epoch 00009: val_f1_score did not improve from 0.83304
# 5/5 [==============================] - 4s 791ms/step - loss: 0.9115 - precision_score: 0.6438 - recall_score: 0.6250 - f1_score: 0.6341 - val_loss: 1.2236 - val_precision_score: 0.6345 - val_recall_score: 0.6187 - val_f1_score: 0.6264
# Epoch 10/100
# 5/5 [==============================] - ETA: 0s - loss: 0.7181 - precision_score: 0.7500 - recall_score: 0.7500 - f1_score: 0.7500
# Epoch 00010: val_f1_score did not improve from 0.83304
# 5/5 [==============================] - 4s 776ms/step - loss: 0.7181 - precision_score: 0.7500 - recall_score: 0.7500 - f1_score: 0.7500 - val_loss: 0.7150 - val_precision_score: 0.7280 - val_recall_score: 0.7188 - val_f1_score: 0.7233
# Epoch 11/100
# 5/5 [==============================] - ETA: 0s - loss: 0.7033 - precision_score: 0.7102 - recall_score: 0.6875 - f1_score: 0.6985
# Epoch 00011: val_f1_score did not improve from 0.83304
# 5/5 [==============================] - 4s 796ms/step - loss: 0.7033 - precision_score: 0.7102 - recall_score: 0.6875 - f1_score: 0.6985 - val_loss: 1.0289 - val_precision_score: 0.6962 - val_recall_score: 0.6875 - val_f1_score: 0.6918
# Epoch 12/100
# 5/5 [==============================] - ETA: 0s - loss: 0.8065 - precision_score: 0.7111 - recall_score: 0.6938 - f1_score: 0.7021
# Epoch 00012: val_f1_score did not improve from 0.83304
# 5/5 [==============================] - 4s 805ms/step - loss: 0.8065 - precision_score: 0.7111 - recall_score: 0.6938 - f1_score: 0.7021 - val_loss: 1.0098 - val_precision_score: 0.6422 - val_recall_score: 0.6313 - val_f1_score: 0.6366
# Epoch 13/100
# 5/5 [==============================] - ETA: 0s - loss: 0.7733 - precision_score: 0.6940 - recall_score: 0.6812 - f1_score: 0.6875
# Epoch 00013: val_f1_score did not improve from 0.83304
# 5/5 [==============================] - 4s 770ms/step - loss: 0.7733 - precision_score: 0.6940 - recall_score: 0.6812 - f1_score: 0.6875 - val_loss: 1.0360 - val_precision_score: 0.6923 - val_recall_score: 0.6875 - val_f1_score: 0.6899
# Epoch 14/100
# 5/5 [==============================] - ETA: 0s - loss: 0.7918 - precision_score: 0.7712 - recall_score: 0.7188 - f1_score: 0.7436
# Epoch 00014: val_f1_score did not improve from 0.83304
# 5/5 [==============================] - 4s 718ms/step - loss: 0.7918 - precision_score: 0.7712 - recall_score: 0.7188 - f1_score: 0.7436 - val_loss: 0.6503 - val_precision_score: 0.7644 - val_recall_score: 0.7437 - val_f1_score: 0.7538
# Epoch 15/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5226 - precision_score: 0.7992 - recall_score: 0.7937 - f1_score: 0.7964
# Epoch 00015: val_f1_score did not improve from 0.83304
# 5/5 [==============================] - 4s 782ms/step - loss: 0.5226 - precision_score: 0.7992 - recall_score: 0.7937 - f1_score: 0.7964 - val_loss: 0.6674 - val_precision_score: 0.8235 - val_recall_score: 0.7875 - val_f1_score: 0.8049
# Epoch 16/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5550 - precision_score: 0.7859 - recall_score: 0.7812 - f1_score: 0.7835
# Epoch 00016: val_f1_score did not improve from 0.83304
# 5/5 [==============================] - 4s 774ms/step - loss: 0.5550 - precision_score: 0.7859 - recall_score: 0.7812 - f1_score: 0.7835 - val_loss: 0.6806 - val_precision_score: 0.7483 - val_recall_score: 0.7188 - val_f1_score: 0.7330
# Epoch 17/100
# 5/5 [==============================] - ETA: 0s - loss: 0.7317 - precision_score: 0.6970 - recall_score: 0.6687 - f1_score: 0.6823
# Epoch 00017: val_f1_score did not improve from 0.83304
# 5/5 [==============================] - 4s 772ms/step - loss: 0.7317 - precision_score: 0.6970 - recall_score: 0.6687 - f1_score: 0.6823 - val_loss: 0.6936 - val_precision_score: 0.7937 - val_recall_score: 0.7437 - val_f1_score: 0.7678
# Epoch 18/100
# 5/5 [==============================] - ETA: 0s - loss: 0.7342 - precision_score: 0.7188 - recall_score: 0.7063 - f1_score: 0.7124
# Epoch 00018: val_f1_score did not improve from 0.83304
# 5/5 [==============================] - 4s 809ms/step - loss: 0.7342 - precision_score: 0.7188 - recall_score: 0.7063 - f1_score: 0.7124 - val_loss: 0.7465 - val_precision_score: 0.7572 - val_recall_score: 0.7375 - val_f1_score: 0.7470
# Epoch 19/100
# 5/5 [==============================] - ETA: 0s - loss: 0.7637 - precision_score: 0.6440 - recall_score: 0.6313 - f1_score: 0.6375
# Epoch 00019: val_f1_score did not improve from 0.83304
# 5/5 [==============================] - 4s 761ms/step - loss: 0.7637 - precision_score: 0.6440 - recall_score: 0.6313 - f1_score: 0.6375 - val_loss: 0.5172 - val_precision_score: 0.8257 - val_recall_score: 0.8000 - val_f1_score: 0.8126
# Epoch 20/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5937 - precision_score: 0.8125 - recall_score: 0.7875 - f1_score: 0.7997
# Epoch 00020: val_f1_score did not improve from 0.83304
# 5/5 [==============================] - 4s 772ms/step - loss: 0.5937 - precision_score: 0.8125 - recall_score: 0.7875 - f1_score: 0.7997 - val_loss: 0.7077 - val_precision_score: 0.7506 - val_recall_score: 0.7375 - val_f1_score: 0.7439
# Epoch 21/100
# 5/5 [==============================] - ETA: 0s - loss: 0.7200 - precision_score: 0.7563 - recall_score: 0.7375 - f1_score: 0.7465
# Epoch 00021: val_f1_score improved from 0.83304 to 0.88393, saving model to .\modelo_vgg19.hdf5
# 5/5 [==============================] - 5s 932ms/step - loss: 0.7200 - precision_score: 0.7563 - recall_score: 0.7375 - f1_score: 0.7465 - val_loss: 0.4631 - val_precision_score: 0.8867 - val_recall_score: 0.8813 - val_f1_score: 0.8839
# Epoch 22/100
# 5/5 [==============================] - ETA: 0s - loss: 0.6278 - precision_score: 0.7603 - recall_score: 0.7500 - f1_score: 0.7551
# Epoch 00022: val_f1_score did not improve from 0.88393
# 5/5 [==============================] - 4s 808ms/step - loss: 0.6278 - precision_score: 0.7603 - recall_score: 0.7500 - f1_score: 0.7551 - val_loss: 0.7684 - val_precision_score: 0.7577 - val_recall_score: 0.7437 - val_f1_score: 0.7506
# Epoch 23/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5695 - precision_score: 0.7552 - recall_score: 0.7312 - f1_score: 0.7429
# Epoch 00023: val_f1_score did not improve from 0.88393
# 5/5 [==============================] - 4s 792ms/step - loss: 0.5695 - precision_score: 0.7552 - recall_score: 0.7312 - f1_score: 0.7429 - val_loss: 0.6272 - val_precision_score: 0.8275 - val_recall_score: 0.7625 - val_f1_score: 0.7923
# Epoch 24/100
# 5/5 [==============================] - ETA: 0s - loss: 0.7234 - precision_score: 0.7332 - recall_score: 0.7188 - f1_score: 0.7258
# Epoch 00024: val_f1_score improved from 0.88393 to 0.90278, saving model to .\modelo_vgg19.hdf5
# 5/5 [==============================] - 4s 830ms/step - loss: 0.7234 - precision_score: 0.7332 - recall_score: 0.7188 - f1_score: 0.7258 - val_loss: 0.3981 - val_precision_score: 0.9056 - val_recall_score: 0.9000 - val_f1_score: 0.9028
# Epoch 25/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5399 - precision_score: 0.7667 - recall_score: 0.7563 - f1_score: 0.7613
# Epoch 00025: val_f1_score did not improve from 0.90278
# 5/5 [==============================] - 4s 813ms/step - loss: 0.5399 - precision_score: 0.7667 - recall_score: 0.7563 - f1_score: 0.7613 - val_loss: 0.8298 - val_precision_score: 0.6937 - val_recall_score: 0.6687 - val_f1_score: 0.6809
# Epoch 26/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5717 - precision_score: 0.7578 - recall_score: 0.7250 - f1_score: 0.7410
# Epoch 00026: val_f1_score did not improve from 0.90278
# 5/5 [==============================] - 4s 777ms/step - loss: 0.5717 - precision_score: 0.7578 - recall_score: 0.7250 - f1_score: 0.7410 - val_loss: 0.7797 - val_precision_score: 0.7797 - val_recall_score: 0.7500 - val_f1_score: 0.7644
# Epoch 27/100
# 5/5 [==============================] - ETA: 0s - loss: 0.6607 - precision_score: 0.7316 - recall_score: 0.7125 - f1_score: 0.7218
# Epoch 00027: val_f1_score did not improve from 0.90278
# 5/5 [==============================] - 4s 796ms/step - loss: 0.6607 - precision_score: 0.7316 - recall_score: 0.7125 - f1_score: 0.7218 - val_loss: 1.0776 - val_precision_score: 0.6938 - val_recall_score: 0.6687 - val_f1_score: 0.6810
# Epoch 28/100
# 5/5 [==============================] - ETA: 0s - loss: 0.6138 - precision_score: 0.7987 - recall_score: 0.7688 - f1_score: 0.7834
# Epoch 00028: val_f1_score did not improve from 0.90278
# 5/5 [==============================] - 4s 774ms/step - loss: 0.6138 - precision_score: 0.7987 - recall_score: 0.7688 - f1_score: 0.7834 - val_loss: 0.5842 - val_precision_score: 0.8115 - val_recall_score: 0.8062 - val_f1_score: 0.8088
# Epoch 29/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5842 - precision_score: 0.7820 - recall_score: 0.7437 - f1_score: 0.7623
# Epoch 00029: val_f1_score did not improve from 0.90278
# 5/5 [==============================] - 4s 812ms/step - loss: 0.5842 - precision_score: 0.7820 - recall_score: 0.7437 - f1_score: 0.7623 - val_loss: 0.6213 - val_precision_score: 0.8067 - val_recall_score: 0.7812 - val_f1_score: 0.7935
# Epoch 30/100
# 5/5 [==============================] - ETA: 0s - loss: 0.8384 - precision_score: 0.7020 - recall_score: 0.6938 - f1_score: 0.6978
# Epoch 00030: val_f1_score did not improve from 0.90278
# 5/5 [==============================] - 4s 801ms/step - loss: 0.8384 - precision_score: 0.7020 - recall_score: 0.6938 - f1_score: 0.6978 - val_loss: 0.8064 - val_precision_score: 0.7394 - val_recall_score: 0.7063 - val_f1_score: 0.7224
# Epoch 31/100
# 5/5 [==============================] - ETA: 0s - loss: 0.7113 - precision_score: 0.7232 - recall_score: 0.6875 - f1_score: 0.7047
# Epoch 00031: val_f1_score did not improve from 0.90278
# 5/5 [==============================] - 4s 837ms/step - loss: 0.7113 - precision_score: 0.7232 - recall_score: 0.6875 - f1_score: 0.7047 - val_loss: 0.6886 - val_precision_score: 0.7492 - val_recall_score: 0.7250 - val_f1_score: 0.7366
# Epoch 32/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5907 - precision_score: 0.7296 - recall_score: 0.7125 - f1_score: 0.7208
# Epoch 00032: val_f1_score did not improve from 0.90278
# 5/5 [==============================] - 4s 768ms/step - loss: 0.5907 - precision_score: 0.7296 - recall_score: 0.7125 - f1_score: 0.7208 - val_loss: 0.7424 - val_precision_score: 0.7043 - val_recall_score: 0.6875 - val_f1_score: 0.6955
# Epoch 33/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5329 - precision_score: 0.8257 - recall_score: 0.8000 - f1_score: 0.8125
# Epoch 00033: val_f1_score did not improve from 0.90278
# 5/5 [==============================] - 4s 784ms/step - loss: 0.5329 - precision_score: 0.8257 - recall_score: 0.8000 - f1_score: 0.8125 - val_loss: 1.0884 - val_precision_score: 0.6520 - val_recall_score: 0.6438 - val_f1_score: 0.6478
# Epoch 34/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4850 - precision_score: 0.8230 - recall_score: 0.8125 - f1_score: 0.8177
# Epoch 00034: val_f1_score did not improve from 0.90278
# 5/5 [==============================] - 4s 791ms/step - loss: 0.4850 - precision_score: 0.8230 - recall_score: 0.8125 - f1_score: 0.8177 - val_loss: 0.4980 - val_precision_score: 0.8135 - val_recall_score: 0.7875 - val_f1_score: 0.8002
# Epoch 35/100
# 5/5 [==============================] - ETA: 0s - loss: 0.6457 - precision_score: 0.6854 - recall_score: 0.6625 - f1_score: 0.6737
# Epoch 00035: val_f1_score did not improve from 0.90278
# 5/5 [==============================] - 4s 769ms/step - loss: 0.6457 - precision_score: 0.6854 - recall_score: 0.6625 - f1_score: 0.6737 - val_loss: 0.6185 - val_precision_score: 0.7441 - val_recall_score: 0.7250 - val_f1_score: 0.7341
# Epoch 36/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4557 - precision_score: 0.8188 - recall_score: 0.8188 - f1_score: 0.8187
# Epoch 00036: val_f1_score did not improve from 0.90278
# 5/5 [==============================] - 4s 753ms/step - loss: 0.4557 - precision_score: 0.8188 - recall_score: 0.8188 - f1_score: 0.8187 - val_loss: 0.7258 - val_precision_score: 0.7419 - val_recall_score: 0.7188 - val_f1_score: 0.7302
# Epoch 37/100
# 5/5 [==============================] - ETA: 0s - loss: 0.6754 - precision_score: 0.7161 - recall_score: 0.6938 - f1_score: 0.7048
# Epoch 00037: val_f1_score did not improve from 0.90278
# 5/5 [==============================] - 4s 789ms/step - loss: 0.6754 - precision_score: 0.7161 - recall_score: 0.6938 - f1_score: 0.7048 - val_loss: 0.6519 - val_precision_score: 0.7907 - val_recall_score: 0.7500 - val_f1_score: 0.7696
# Epoch 38/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4479 - precision_score: 0.8140 - recall_score: 0.8000 - f1_score: 0.8068
# Epoch 00038: val_f1_score did not improve from 0.90278
# 5/5 [==============================] - 4s 837ms/step - loss: 0.4479 - precision_score: 0.8140 - recall_score: 0.8000 - f1_score: 0.8068 - val_loss: 0.8186 - val_precision_score: 0.7374 - val_recall_score: 0.7188 - val_f1_score: 0.7278
# Epoch 39/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5145 - precision_score: 0.7930 - recall_score: 0.7625 - f1_score: 0.7773
# Epoch 00039: val_f1_score did not improve from 0.90278
# 5/5 [==============================] - 4s 799ms/step - loss: 0.5145 - precision_score: 0.7930 - recall_score: 0.7625 - f1_score: 0.7773 - val_loss: 0.4987 - val_precision_score: 0.7796 - val_recall_score: 0.7750 - val_f1_score: 0.7773
# Epoch 40/100
# 5/5 [==============================] - ETA: 0s - loss: 0.6132 - precision_score: 0.7616 - recall_score: 0.7188 - f1_score: 0.7394
# Epoch 00040: val_f1_score did not improve from 0.90278
# 5/5 [==============================] - 4s 808ms/step - loss: 0.6132 - precision_score: 0.7616 - recall_score: 0.7188 - f1_score: 0.7394 - val_loss: 0.6821 - val_precision_score: 0.7410 - val_recall_score: 0.7188 - val_f1_score: 0.7296
# Epoch 41/100
# 5/5 [==============================] - ETA: 0s - loss: 0.7191 - precision_score: 0.7337 - recall_score: 0.7250 - f1_score: 0.7293
# Epoch 00041: val_f1_score did not improve from 0.90278
# 5/5 [==============================] - 4s 777ms/step - loss: 0.7191 - precision_score: 0.7337 - recall_score: 0.7250 - f1_score: 0.7293 - val_loss: 0.6022 - val_precision_score: 0.8103 - val_recall_score: 0.8000 - val_f1_score: 0.8051
# Epoch 42/100
# 5/5 [==============================] - ETA: 0s - loss: 0.6137 - precision_score: 0.7517 - recall_score: 0.7375 - f1_score: 0.7443
# Epoch 00042: val_f1_score did not improve from 0.90278
# 5/5 [==============================] - 4s 765ms/step - loss: 0.6137 - precision_score: 0.7517 - recall_score: 0.7375 - f1_score: 0.7443 - val_loss: 0.6742 - val_precision_score: 0.8026 - val_recall_score: 0.7563 - val_f1_score: 0.7784
# Epoch 43/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5482 - precision_score: 0.7932 - recall_score: 0.7688 - f1_score: 0.7806
# Epoch 00043: val_f1_score did not improve from 0.90278
# 5/5 [==============================] - 4s 787ms/step - loss: 0.5482 - precision_score: 0.7932 - recall_score: 0.7688 - f1_score: 0.7806 - val_loss: 0.6801 - val_precision_score: 0.8122 - val_recall_score: 0.7812 - val_f1_score: 0.7959
# Epoch 44/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5386 - precision_score: 0.7851 - recall_score: 0.7750 - f1_score: 0.7800
# Epoch 00044: val_f1_score did not improve from 0.90278
# 5/5 [==============================] - 4s 804ms/step - loss: 0.5386 - precision_score: 0.7851 - recall_score: 0.7750 - f1_score: 0.7800 - val_loss: 0.6665 - val_precision_score: 0.8024 - val_recall_score: 0.7812 - val_f1_score: 0.7916
# Epoch 45/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5683 - precision_score: 0.7759 - recall_score: 0.7375 - f1_score: 0.7562
# Epoch 00045: val_f1_score did not improve from 0.90278
# 5/5 [==============================] - 4s 778ms/step - loss: 0.5683 - precision_score: 0.7759 - recall_score: 0.7375 - f1_score: 0.7562 - val_loss: 0.6830 - val_precision_score: 0.7977 - val_recall_score: 0.7563 - val_f1_score: 0.7762
# Epoch 46/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5428 - precision_score: 0.7628 - recall_score: 0.7437 - f1_score: 0.7530
# Epoch 00046: val_f1_score did not improve from 0.90278
# 5/5 [==============================] - 4s 766ms/step - loss: 0.5428 - precision_score: 0.7628 - recall_score: 0.7437 - f1_score: 0.7530 - val_loss: 0.6441 - val_precision_score: 0.8137 - val_recall_score: 0.7875 - val_f1_score: 0.8003
# Epoch 47/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5623 - precision_score: 0.8184 - recall_score: 0.7875 - f1_score: 0.8025
# Epoch 00047: val_f1_score did not improve from 0.90278
# 5/5 [==============================] - 4s 781ms/step - loss: 0.5623 - precision_score: 0.8184 - recall_score: 0.7875 - f1_score: 0.8025 - val_loss: 0.4824 - val_precision_score: 0.8141 - val_recall_score: 0.7937 - val_f1_score: 0.8038
# Epoch 48/100
# 5/5 [==============================] - ETA: 0s - loss: 0.6228 - precision_score: 0.7203 - recall_score: 0.6938 - f1_score: 0.7067
# Epoch 00048: val_f1_score did not improve from 0.90278
# 5/5 [==============================] - 4s 810ms/step - loss: 0.6228 - precision_score: 0.7203 - recall_score: 0.6938 - f1_score: 0.7067 - val_loss: 0.6120 - val_precision_score: 0.8117 - val_recall_score: 0.8062 - val_f1_score: 0.8089
# Epoch 49/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5435 - precision_score: 0.7763 - recall_score: 0.7563 - f1_score: 0.7659
# Epoch 00049: val_f1_score did not improve from 0.90278
# 5/5 [==============================] - 4s 775ms/step - loss: 0.5435 - precision_score: 0.7763 - recall_score: 0.7563 - f1_score: 0.7659 - val_loss: 0.7089 - val_precision_score: 0.7579 - val_recall_score: 0.7437 - val_f1_score: 0.7507
# Epoch 50/100
# 5/5 [==============================] - ETA: 0s - loss: 0.7201 - precision_score: 0.6593 - recall_score: 0.6313 - f1_score: 0.6448
# Epoch 00050: val_f1_score did not improve from 0.90278
# 5/5 [==============================] - 4s 774ms/step - loss: 0.7201 - precision_score: 0.6593 - recall_score: 0.6313 - f1_score: 0.6448 - val_loss: 0.6317 - val_precision_score: 0.7927 - val_recall_score: 0.7875 - val_f1_score: 0.7901
# Epoch 51/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5551 - precision_score: 0.7841 - recall_score: 0.7500 - f1_score: 0.7665
# Epoch 00051: val_f1_score did not improve from 0.90278
# 5/5 [==============================] - 4s 800ms/step - loss: 0.5551 - precision_score: 0.7841 - recall_score: 0.7500 - f1_score: 0.7665 - val_loss: 0.9297 - val_precision_score: 0.6866 - val_recall_score: 0.6562 - val_f1_score: 0.6709
# Epoch 52/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5784 - precision_score: 0.7723 - recall_score: 0.7563 - f1_score: 0.7641
# Epoch 00052: val_f1_score did not improve from 0.90278
# 5/5 [==============================] - 4s 768ms/step - loss: 0.5784 - precision_score: 0.7723 - recall_score: 0.7563 - f1_score: 0.7641 - val_loss: 0.4677 - val_precision_score: 0.8357 - val_recall_score: 0.8250 - val_f1_score: 0.8303
# Epoch 53/100
# 5/5 [==============================] - ETA: 0s - loss: 0.6296 - precision_score: 0.7872 - recall_score: 0.7625 - f1_score: 0.7746
# Epoch 00053: val_f1_score did not improve from 0.90278
# 5/5 [==============================] - 4s 783ms/step - loss: 0.6296 - precision_score: 0.7872 - recall_score: 0.7625 - f1_score: 0.7746 - val_loss: 0.5353 - val_precision_score: 0.8072 - val_recall_score: 0.7812 - val_f1_score: 0.7939
# Epoch 54/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5564 - precision_score: 0.7553 - recall_score: 0.7250 - f1_score: 0.7396
# Epoch 00054: val_f1_score did not improve from 0.90278
# 5/5 [==============================] - 4s 792ms/step - loss: 0.5564 - precision_score: 0.7553 - recall_score: 0.7250 - f1_score: 0.7396 - val_loss: 0.5161 - val_precision_score: 0.8558 - val_recall_score: 0.8125 - val_f1_score: 0.8335
# Epoch 55/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5240 - precision_score: 0.7983 - recall_score: 0.7688 - f1_score: 0.7832
# Epoch 00055: val_f1_score did not improve from 0.90278
# 5/5 [==============================] - 4s 758ms/step - loss: 0.5240 - precision_score: 0.7983 - recall_score: 0.7688 - f1_score: 0.7832 - val_loss: 0.5645 - val_precision_score: 0.7706 - val_recall_score: 0.7563 - val_f1_score: 0.7633
# Epoch 56/100
# 5/5 [==============================] - ETA: 0s - loss: 0.6172 - precision_score: 0.7900 - recall_score: 0.7750 - f1_score: 0.7823
# Epoch 00056: val_f1_score did not improve from 0.90278
# 5/5 [==============================] - 4s 757ms/step - loss: 0.6172 - precision_score: 0.7900 - recall_score: 0.7750 - f1_score: 0.7823 - val_loss: 0.6290 - val_precision_score: 0.8214 - val_recall_score: 0.7812 - val_f1_score: 0.8007
# Epoch 57/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5779 - precision_score: 0.7097 - recall_score: 0.6875 - f1_score: 0.6983
# Epoch 00057: val_f1_score did not improve from 0.90278
# 5/5 [==============================] - 4s 779ms/step - loss: 0.5779 - precision_score: 0.7097 - recall_score: 0.6875 - f1_score: 0.6983 - val_loss: 0.5776 - val_precision_score: 0.7969 - val_recall_score: 0.7812 - val_f1_score: 0.7889
# Epoch 58/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5855 - precision_score: 0.7454 - recall_score: 0.7312 - f1_score: 0.7382
# Epoch 00058: val_f1_score did not improve from 0.90278
# 5/5 [==============================] - 4s 849ms/step - loss: 0.5855 - precision_score: 0.7454 - recall_score: 0.7312 - f1_score: 0.7382 - val_loss: 0.7822 - val_precision_score: 0.7234 - val_recall_score: 0.6938 - val_f1_score: 0.7081
# Epoch 59/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5532 - precision_score: 0.7355 - recall_score: 0.7063 - f1_score: 0.7205
# Epoch 00059: val_f1_score did not improve from 0.90278
# 5/5 [==============================] - 4s 789ms/step - loss: 0.5532 - precision_score: 0.7355 - recall_score: 0.7063 - f1_score: 0.7205 - val_loss: 0.5849 - val_precision_score: 0.8139 - val_recall_score: 0.7812 - val_f1_score: 0.7970
# Epoch 60/100
# 5/5 [==============================] - ETA: 0s - loss: 0.6809 - precision_score: 0.7116 - recall_score: 0.6938 - f1_score: 0.7025
# Epoch 00060: val_f1_score did not improve from 0.90278
# 5/5 [==============================] - 4s 810ms/step - loss: 0.6809 - precision_score: 0.7116 - recall_score: 0.6938 - f1_score: 0.7025 - val_loss: 0.6485 - val_precision_score: 0.7337 - val_recall_score: 0.7063 - val_f1_score: 0.7196
# Epoch 61/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5876 - precision_score: 0.7542 - recall_score: 0.7437 - f1_score: 0.7489
# Epoch 00061: val_f1_score did not improve from 0.90278
# 5/5 [==============================] - 4s 809ms/step - loss: 0.5876 - precision_score: 0.7542 - recall_score: 0.7437 - f1_score: 0.7489 - val_loss: 0.7542 - val_precision_score: 0.7398 - val_recall_score: 0.7125 - val_f1_score: 0.7259
# Epoch 62/100
# 5/5 [==============================] - ETA: 0s - loss: 0.6593 - precision_score: 0.7333 - recall_score: 0.7250 - f1_score: 0.7291
# Epoch 00062: val_f1_score did not improve from 0.90278
# 5/5 [==============================] - 4s 776ms/step - loss: 0.6593 - precision_score: 0.7333 - recall_score: 0.7250 - f1_score: 0.7291 - val_loss: 0.8240 - val_precision_score: 0.6751 - val_recall_score: 0.6625 - val_f1_score: 0.6686
# Epoch 63/100
# 5/5 [==============================] - ETA: 0s - loss: 0.6649 - precision_score: 0.6923 - recall_score: 0.6875 - f1_score: 0.6899
# Epoch 00063: val_f1_score did not improve from 0.90278
# 5/5 [==============================] - 4s 780ms/step - loss: 0.6649 - precision_score: 0.6923 - recall_score: 0.6875 - f1_score: 0.6899 - val_loss: 1.0163 - val_precision_score: 0.6454 - val_recall_score: 0.6313 - val_f1_score: 0.6381
# Epoch 64/100
# 5/5 [==============================] - ETA: 0s - loss: 0.6426 - precision_score: 0.7512 - recall_score: 0.7375 - f1_score: 0.7442
# Epoch 00064: val_f1_score did not improve from 0.90278
# 5/5 [==============================] - 4s 811ms/step - loss: 0.6426 - precision_score: 0.7512 - recall_score: 0.7375 - f1_score: 0.7442 - val_loss: 0.5059 - val_precision_score: 0.8404 - val_recall_score: 0.8250 - val_f1_score: 0.8325
# Epoch 65/100
# 5/5 [==============================] - ETA: 0s - loss: 0.6371 - precision_score: 0.7290 - recall_score: 0.7250 - f1_score: 0.7270
# Epoch 00065: val_f1_score did not improve from 0.90278
# 5/5 [==============================] - 4s 783ms/step - loss: 0.6371 - precision_score: 0.7290 - recall_score: 0.7250 - f1_score: 0.7270 - val_loss: 0.4515 - val_precision_score: 0.8478 - val_recall_score: 0.8313 - val_f1_score: 0.8394
# Epoch 66/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5937 - precision_score: 0.7636 - recall_score: 0.7312 - f1_score: 0.7468
# Epoch 00066: val_f1_score did not improve from 0.90278
# 5/5 [==============================] - 4s 838ms/step - loss: 0.5937 - precision_score: 0.7636 - recall_score: 0.7312 - f1_score: 0.7468 - val_loss: 0.7036 - val_precision_score: 0.7888 - val_recall_score: 0.7625 - val_f1_score: 0.7753
# Epoch 67/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4641 - precision_score: 0.8253 - recall_score: 0.8000 - f1_score: 0.8124
# Epoch 00067: val_f1_score did not improve from 0.90278
# 5/5 [==============================] - 4s 821ms/step - loss: 0.4641 - precision_score: 0.8253 - recall_score: 0.8000 - f1_score: 0.8124 - val_loss: 0.5941 - val_precision_score: 0.7934 - val_recall_score: 0.7625 - val_f1_score: 0.7775
# Epoch 68/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5096 - precision_score: 0.8117 - recall_score: 0.7812 - f1_score: 0.7961
# Epoch 00068: val_f1_score did not improve from 0.90278
# 5/5 [==============================] - 4s 753ms/step - loss: 0.5096 - precision_score: 0.8117 - recall_score: 0.7812 - f1_score: 0.7961 - val_loss: 0.6294 - val_precision_score: 0.8231 - val_recall_score: 0.7875 - val_f1_score: 0.8047
# Epoch 69/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4907 - precision_score: 0.8152 - recall_score: 0.8000 - f1_score: 0.8074
# Epoch 00069: val_f1_score did not improve from 0.90278
# 5/5 [==============================] - 4s 816ms/step - loss: 0.4907 - precision_score: 0.8152 - recall_score: 0.8000 - f1_score: 0.8074 - val_loss: 0.5757 - val_precision_score: 0.7943 - val_recall_score: 0.7625 - val_f1_score: 0.7778
# Epoch 70/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5087 - precision_score: 0.8044 - recall_score: 0.7812 - f1_score: 0.7925
# Epoch 00070: val_f1_score did not improve from 0.90278
# 5/5 [==============================] - 4s 811ms/step - loss: 0.5087 - precision_score: 0.8044 - recall_score: 0.7812 - f1_score: 0.7925 - val_loss: 0.6476 - val_precision_score: 0.7707 - val_recall_score: 0.7437 - val_f1_score: 0.7569
# Epoch 71/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5847 - precision_score: 0.7412 - recall_score: 0.7125 - f1_score: 0.7264
# Epoch 00071: val_f1_score did not improve from 0.90278
# 5/5 [==============================] - 4s 755ms/step - loss: 0.5847 - precision_score: 0.7412 - recall_score: 0.7125 - f1_score: 0.7264 - val_loss: 0.5718 - val_precision_score: 0.8251 - val_recall_score: 0.7937 - val_f1_score: 0.8090
# Epoch 72/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4886 - precision_score: 0.8435 - recall_score: 0.8375 - f1_score: 0.8405
# Epoch 00072: val_f1_score did not improve from 0.90278
# 5/5 [==============================] - 4s 786ms/step - loss: 0.4886 - precision_score: 0.8435 - recall_score: 0.8375 - f1_score: 0.8405 - val_loss: 0.7929 - val_precision_score: 0.7811 - val_recall_score: 0.7625 - val_f1_score: 0.7714
# Epoch 73/100
# 5/5 [==============================] - ETA: 0s - loss: 0.7215 - precision_score: 0.7126 - recall_score: 0.6938 - f1_score: 0.7029
# Epoch 00073: val_f1_score did not improve from 0.90278
# 5/5 [==============================] - 4s 787ms/step - loss: 0.7215 - precision_score: 0.7126 - recall_score: 0.6938 - f1_score: 0.7029 - val_loss: 0.6795 - val_precision_score: 0.7747 - val_recall_score: 0.7500 - val_f1_score: 0.7621
# Epoch 74/100
# 5/5 [==============================] - ETA: 0s - loss: 0.6619 - precision_score: 0.7728 - recall_score: 0.7625 - f1_score: 0.7676
# Epoch 00074: val_f1_score did not improve from 0.90278
# 5/5 [==============================] - 4s 790ms/step - loss: 0.6619 - precision_score: 0.7728 - recall_score: 0.7625 - f1_score: 0.7676 - val_loss: 1.0047 - val_precision_score: 0.7052 - val_recall_score: 0.6875 - val_f1_score: 0.6962
# Epoch 75/100
# 5/5 [==============================] - ETA: 0s - loss: 0.6835 - precision_score: 0.7736 - recall_score: 0.7688 - f1_score: 0.7711
# Epoch 00075: val_f1_score did not improve from 0.90278
# 5/5 [==============================] - 4s 801ms/step - loss: 0.6835 - precision_score: 0.7736 - recall_score: 0.7688 - f1_score: 0.7711 - val_loss: 0.6050 - val_precision_score: 0.8222 - val_recall_score: 0.8000 - val_f1_score: 0.8108
# Epoch 76/100
# 5/5 [==============================] - ETA: 0s - loss: 0.6193 - precision_score: 0.7375 - recall_score: 0.7250 - f1_score: 0.7312
# Epoch 00076: val_f1_score did not improve from 0.90278
# 5/5 [==============================] - 4s 763ms/step - loss: 0.6193 - precision_score: 0.7375 - recall_score: 0.7250 - f1_score: 0.7312 - val_loss: 0.8633 - val_precision_score: 0.7294 - val_recall_score: 0.7250 - val_f1_score: 0.7272
# Epoch 77/100
# 5/5 [==============================] - ETA: 0s - loss: 0.6555 - precision_score: 0.7583 - recall_score: 0.7437 - f1_score: 0.7509
# Epoch 00077: val_f1_score did not improve from 0.90278
# 5/5 [==============================] - 4s 775ms/step - loss: 0.6555 - precision_score: 0.7583 - recall_score: 0.7437 - f1_score: 0.7509 - val_loss: 0.4783 - val_precision_score: 0.8423 - val_recall_score: 0.8250 - val_f1_score: 0.8334
# Epoch 78/100
# 5/5 [==============================] - ETA: 0s - loss: 0.6752 - precision_score: 0.7299 - recall_score: 0.7125 - f1_score: 0.7210
# Epoch 00078: val_f1_score did not improve from 0.90278
# 5/5 [==============================] - 4s 788ms/step - loss: 0.6752 - precision_score: 0.7299 - recall_score: 0.7125 - f1_score: 0.7210 - val_loss: 0.4372 - val_precision_score: 0.8331 - val_recall_score: 0.8125 - val_f1_score: 0.8226
# Epoch 79/100
# 5/5 [==============================] - ETA: 0s - loss: 0.6942 - precision_score: 0.7366 - recall_score: 0.7188 - f1_score: 0.7274
# Epoch 00079: val_f1_score did not improve from 0.90278
# 5/5 [==============================] - 4s 779ms/step - loss: 0.6942 - precision_score: 0.7366 - recall_score: 0.7188 - f1_score: 0.7274 - val_loss: 0.7336 - val_precision_score: 0.7485 - val_recall_score: 0.7250 - val_f1_score: 0.7363
# Epoch 80/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5191 - precision_score: 0.7911 - recall_score: 0.7750 - f1_score: 0.7828
# Epoch 00080: val_f1_score did not improve from 0.90278
# 5/5 [==============================] - 4s 775ms/step - loss: 0.5191 - precision_score: 0.7911 - recall_score: 0.7750 - f1_score: 0.7828 - val_loss: 0.4648 - val_precision_score: 0.8349 - val_recall_score: 0.8250 - val_f1_score: 0.8299
# Epoch 81/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5298 - precision_score: 0.8048 - recall_score: 0.7812 - f1_score: 0.7927
# Epoch 00081: val_f1_score did not improve from 0.90278
# 5/5 [==============================] - 4s 799ms/step - loss: 0.5298 - precision_score: 0.8048 - recall_score: 0.7812 - f1_score: 0.7927 - val_loss: 0.5621 - val_precision_score: 0.8151 - val_recall_score: 0.7875 - val_f1_score: 0.8009
# Epoch 82/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4545 - precision_score: 0.7898 - recall_score: 0.7750 - f1_score: 0.7822
# Epoch 00082: val_f1_score did not improve from 0.90278
# 5/5 [==============================] - 4s 773ms/step - loss: 0.4545 - precision_score: 0.7898 - recall_score: 0.7750 - f1_score: 0.7822 - val_loss: 0.4850 - val_precision_score: 0.8444 - val_recall_score: 0.8125 - val_f1_score: 0.8278
# Epoch 83/100
# 5/5 [==============================] - ETA: 0s - loss: 0.6429 - precision_score: 0.7432 - recall_score: 0.7250 - f1_score: 0.7339
# Epoch 00083: val_f1_score did not improve from 0.90278
# 5/5 [==============================] - 4s 763ms/step - loss: 0.6429 - precision_score: 0.7432 - recall_score: 0.7250 - f1_score: 0.7339 - val_loss: 0.6712 - val_precision_score: 0.7815 - val_recall_score: 0.7625 - val_f1_score: 0.7718
# Epoch 84/100
# 5/5 [==============================] - ETA: 0s - loss: 0.7469 - precision_score: 0.7102 - recall_score: 0.6875 - f1_score: 0.6986
# Epoch 00084: val_f1_score did not improve from 0.90278
# 5/5 [==============================] - 4s 786ms/step - loss: 0.7469 - precision_score: 0.7102 - recall_score: 0.6875 - f1_score: 0.6986 - val_loss: 0.6483 - val_precision_score: 0.8060 - val_recall_score: 0.7563 - val_f1_score: 0.7799
# Epoch 85/100
# 5/5 [==============================] - ETA: 0s - loss: 0.6332 - precision_score: 0.7274 - recall_score: 0.7125 - f1_score: 0.7196
# Epoch 00085: val_f1_score did not improve from 0.90278
# 5/5 [==============================] - 4s 781ms/step - loss: 0.6332 - precision_score: 0.7274 - recall_score: 0.7125 - f1_score: 0.7196 - val_loss: 0.5494 - val_precision_score: 0.8342 - val_recall_score: 0.8000 - val_f1_score: 0.8163
# Epoch 86/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5906 - precision_score: 0.7814 - recall_score: 0.7563 - f1_score: 0.7684
# Epoch 00086: val_f1_score did not improve from 0.90278
# 5/5 [==============================] - 4s 769ms/step - loss: 0.5906 - precision_score: 0.7814 - recall_score: 0.7563 - f1_score: 0.7684 - val_loss: 0.6057 - val_precision_score: 0.8053 - val_recall_score: 0.7750 - val_f1_score: 0.7897
# Epoch 87/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4529 - precision_score: 0.8263 - recall_score: 0.8000 - f1_score: 0.8129
# Epoch 00087: val_f1_score did not improve from 0.90278
# 5/5 [==============================] - 4s 779ms/step - loss: 0.4529 - precision_score: 0.8263 - recall_score: 0.8000 - f1_score: 0.8129 - val_loss: 0.4824 - val_precision_score: 0.8258 - val_recall_score: 0.8000 - val_f1_score: 0.8124
# Epoch 88/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5204 - precision_score: 0.7638 - recall_score: 0.7312 - f1_score: 0.7470
# Epoch 00088: val_f1_score did not improve from 0.90278
# 5/5 [==============================] - 4s 829ms/step - loss: 0.5204 - precision_score: 0.7638 - recall_score: 0.7312 - f1_score: 0.7470 - val_loss: 0.8081 - val_precision_score: 0.7369 - val_recall_score: 0.7125 - val_f1_score: 0.7244
# Epoch 89/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5004 - precision_score: 0.7851 - recall_score: 0.7750 - f1_score: 0.7800
# Epoch 00089: val_f1_score did not improve from 0.90278
# 5/5 [==============================] - 4s 802ms/step - loss: 0.5004 - precision_score: 0.7851 - recall_score: 0.7750 - f1_score: 0.7800 - val_loss: 0.4966 - val_precision_score: 0.8299 - val_recall_score: 0.7937 - val_f1_score: 0.8111
# Epoch 90/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5043 - precision_score: 0.7974 - recall_score: 0.7875 - f1_score: 0.7924
# Epoch 00090: val_f1_score did not improve from 0.90278
# 5/5 [==============================] - 4s 794ms/step - loss: 0.5043 - precision_score: 0.7974 - recall_score: 0.7875 - f1_score: 0.7924 - val_loss: 0.5536 - val_precision_score: 0.8367 - val_recall_score: 0.7688 - val_f1_score: 0.8010
# Epoch 91/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5184 - precision_score: 0.7810 - recall_score: 0.7437 - f1_score: 0.7616
# Epoch 00091: val_f1_score did not improve from 0.90278
# 5/5 [==============================] - 4s 803ms/step - loss: 0.5184 - precision_score: 0.7810 - recall_score: 0.7437 - f1_score: 0.7616 - val_loss: 0.5561 - val_precision_score: 0.8157 - val_recall_score: 0.7750 - val_f1_score: 0.7944
# Epoch 92/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4928 - precision_score: 0.8113 - recall_score: 0.7875 - f1_score: 0.7990
# Epoch 00092: val_f1_score did not improve from 0.90278
# 5/5 [==============================] - 4s 758ms/step - loss: 0.4928 - precision_score: 0.8113 - recall_score: 0.7875 - f1_score: 0.7990 - val_loss: 0.5071 - val_precision_score: 0.8334 - val_recall_score: 0.8125 - val_f1_score: 0.8227
# Epoch 93/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4321 - precision_score: 0.8494 - recall_score: 0.8188 - f1_score: 0.8337
# Epoch 00093: val_f1_score did not improve from 0.90278
# 5/5 [==============================] - 4s 788ms/step - loss: 0.4321 - precision_score: 0.8494 - recall_score: 0.8188 - f1_score: 0.8337 - val_loss: 0.6418 - val_precision_score: 0.7805 - val_recall_score: 0.7375 - val_f1_score: 0.7581
# Epoch 94/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5293 - precision_score: 0.7838 - recall_score: 0.7688 - f1_score: 0.7761
# Epoch 00094: val_f1_score did not improve from 0.90278
# 5/5 [==============================] - 4s 776ms/step - loss: 0.5293 - precision_score: 0.7838 - recall_score: 0.7688 - f1_score: 0.7761 - val_loss: 0.5547 - val_precision_score: 0.8337 - val_recall_score: 0.8062 - val_f1_score: 0.8194
# Epoch 95/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4182 - precision_score: 0.8260 - recall_score: 0.8000 - f1_score: 0.8127
# Epoch 00095: val_f1_score did not improve from 0.90278
# 5/5 [==============================] - 4s 777ms/step - loss: 0.4182 - precision_score: 0.8260 - recall_score: 0.8000 - f1_score: 0.8127 - val_loss: 0.5793 - val_precision_score: 0.8326 - val_recall_score: 0.8000 - val_f1_score: 0.8158
# Epoch 96/100
# 5/5 [==============================] - ETA: 0s - loss: 0.6302 - precision_score: 0.7476 - recall_score: 0.7188 - f1_score: 0.7328
# Epoch 00096: val_f1_score did not improve from 0.90278
# 5/5 [==============================] - 4s 763ms/step - loss: 0.6302 - precision_score: 0.7476 - recall_score: 0.7188 - f1_score: 0.7328 - val_loss: 0.8403 - val_precision_score: 0.7303 - val_recall_score: 0.7000 - val_f1_score: 0.7144
# Epoch 97/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5348 - precision_score: 0.7550 - recall_score: 0.7250 - f1_score: 0.7394
# Epoch 00097: val_f1_score did not improve from 0.90278
# 5/5 [==============================] - 4s 798ms/step - loss: 0.5348 - precision_score: 0.7550 - recall_score: 0.7250 - f1_score: 0.7394 - val_loss: 0.5555 - val_precision_score: 0.8193 - val_recall_score: 0.7875 - val_f1_score: 0.8029
# Epoch 98/100
# 5/5 [==============================] - ETA: 0s - loss: 0.4607 - precision_score: 0.8147 - recall_score: 0.7937 - f1_score: 0.8040
# Epoch 00098: val_f1_score did not improve from 0.90278
# 5/5 [==============================] - 4s 782ms/step - loss: 0.4607 - precision_score: 0.8147 - recall_score: 0.7937 - f1_score: 0.8040 - val_loss: 0.7767 - val_precision_score: 0.7555 - val_recall_score: 0.7375 - val_f1_score: 0.7463
# Epoch 99/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5172 - precision_score: 0.8052 - recall_score: 0.7812 - f1_score: 0.7929
# Epoch 00099: val_f1_score did not improve from 0.90278
# 5/5 [==============================] - 4s 800ms/step - loss: 0.5172 - precision_score: 0.8052 - recall_score: 0.7812 - f1_score: 0.7929 - val_loss: 0.7132 - val_precision_score: 0.7808 - val_recall_score: 0.7563 - val_f1_score: 0.7682
# Epoch 100/100
# 5/5 [==============================] - ETA: 0s - loss: 0.6042 - precision_score: 0.7605 - recall_score: 0.7563 - f1_score: 0.7583
# Epoch 00100: val_f1_score did not improve from 0.90278
# 5/5 [==============================] - 4s 806ms/step - loss: 0.6042 - precision_score: 0.7605 - recall_score: 0.7563 - f1_score: 0.7583 - val_loss: 0.5565 - val_precision_score: 0.8734 - val_recall_score: 0.8250 - val_f1_score: 0.8482

# %% [markdown]
# Um modelo que converge bem possui o gráfico de perda (*loss*) descendente e os gráfico de precisão (*precision*), sensibilidade (*recall*) e pontuação f1 (*f1 score*) em acendente.

# %%
# Exibindo dados de Precisão
plt.plot(history.history['precision_score'])
plt.plot(history.history['val_precision_score'])
plt.title('model precision')
plt.ylabel('precision')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de Sensibilidade
plt.plot(history.history['recall_score'])
plt.plot(history.history['val_recall_score'])
plt.title('model recall')
plt.ylabel('recall')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de F1 Score
plt.plot(history.history['f1_score'])
plt.plot(history.history['val_f1_score'])
plt.title('model f1_score')
plt.ylabel('f1_score')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de Perda
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# **Pergunta**: Avalie os gráficos de perda (*loss*), precisão (*precision*), sensibilidade (*recall*) e pontuação f1 (*f1 score*)  e explique o comportamento de ambos no que tange a convergência do modelo.

# %% [markdown]
# **Resposta**:

# %% [markdown]
# **Pergunta**: Quais são os valores de **precisão (precision)**, **sensibilidade (recall)** de validação?
#
# *Estes valores são exibidos durante o treinamento, utilize a última saída, exemplo:*
#
# ```
# Epoch 10/10 [==============================] - 45s 9s/step - loss: 0.1234 - precision_score: 0.9742 - recall_score: 0.9683 - f1_score: 0.9712 - val_loss: 0.8819 - val_precision_score: 0.6912 - val_recall_score: 0.5649 - val_f1_score: 0.6216```
#
# No caso acima, o valor de precisão, sensibilidade e pontuação de validação são, respectivamente, 69,12%, 56,49% e 62,16%.

# %%
model = load_model("./modelo_vgg19.hdf5", custom_objects={'f1_score': f1_score, 'precision_score': precision_score, 'recall_score': recall_score})

scores = model.evaluate(val_generator)
print()
print(f"Precision Score: {round(scores[1]*100,2)}%")
print(f"Recall Score: {round(scores[2]*100,2)}%")
print(f"F1 Score: {round(scores[3]*100,2)}%")
# Out:
# 20/20 [==============================] - 5s 271ms/step - loss: 0.4828 - precision_score: 0.8532 - recall_score: 0.8391 - f1_score: 0.8459
#
# Precision Score: 85.32%
# Recall Score: 83.91%
# F1 Score: 84.59%

# %% [markdown]
# **Resposta**:

# %% [markdown]
# ## 4.6 Compartivo de arquiteturas
#
# Preencha a tabela abaixo com os valores dos indicadores de performance apresentados.
#
# _O cálculo do F1-Score é dado por 2 * (Precisão * Sensibilidade) / (Precisão + Sensibilidade)._

# %% [markdown]
# | Modelo   | Precisão (*Precision*) | Sensibilidade (*Recall*) | F1-Score |
# |----------|----------|---------------|----------|
# | ResNet50 | XX %     | XX %          | XX %     |
# | VGG16    | XX %     | XX %          | XX %     |
# | VGG19    | XX %     | XX %          | XX %     |

# %% [markdown]
# ## 4.7 Conclusões
#
# Analise os resultados da tabela de indicadores do comparativo de arquiteturas e explique os principais motivos pelos quais cada modelo obteve cada resultado.

# %% [markdown]
# **Respota**:

# %% [markdown]
# ## 4.8 Abordagem Extra
#
# Considerando os outros classificadores, escolha outro que ainda não foi utilizado, implemente abaixo. Ao final compare os resultados e explique os resultados.
#
# _Não se esquece de utilizar as importações adequadas para cada modelo.
# A forma de implementação deve respeitar as mesmas condições como valor de split e quantidade de imagens para poder comparar os modelos._

# %%
conv_base = Xception(include_top=False)

for layer in conv_base.layers:
    layer.trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83689472/83683744 [==============================] - 2s 0us/step

# %%
x = conv_base.output
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(128, activation='relu')(x) 

predictions = layers.Dense(qtde_classes, activation='softmax')(x)
model = Model(conv_base.input, predictions)

model.summary()
# Out:
# Model: "functional_13"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_9 (InputLayer)            [(None, None, None,  0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, None, None, 3 864         input_9[0][0]
# __________________________________________________________________________________________________
# block1_conv1_bn (BatchNormaliza (None, None, None, 3 128         block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_act (Activation)   (None, None, None, 3 0           block1_conv1_bn[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, None, None, 6 18432       block1_conv1_act[0][0]
# __________________________________________________________________________________________________
# block1_conv2_bn (BatchNormaliza (None, None, None, 6 256         block1_conv2[0][0]
# __________________________________________________________________________________________________
# block1_conv2_act (Activation)   (None, None, None, 6 0           block1_conv2_bn[0][0]
# __________________________________________________________________________________________________
# block2_sepconv1 (SeparableConv2 (None, None, None, 1 8768        block1_conv2_act[0][0]
# __________________________________________________________________________________________________
# block2_sepconv1_bn (BatchNormal (None, None, None, 1 512         block2_sepconv1[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2_act (Activation (None, None, None, 1 0           block2_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2 (SeparableConv2 (None, None, None, 1 17536       block2_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2_bn (BatchNormal (None, None, None, 1 512         block2_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, None, None, 1 8192        block1_conv2_act[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, None, None, 1 0           block2_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, None, None, 1 512         conv2d[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, None, None, 1 0           block2_pool[0][0]
#                                                                  batch_normalization[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1_act (Activation (None, None, None, 1 0           add[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1 (SeparableConv2 (None, None, None, 2 33920       block3_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1_bn (BatchNormal (None, None, None, 2 1024        block3_sepconv1[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2_act (Activation (None, None, None, 2 0           block3_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2 (SeparableConv2 (None, None, None, 2 67840       block3_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2_bn (BatchNormal (None, None, None, 2 1024        block3_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, None, None, 2 32768       add[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, None, None, 2 0           block3_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, None, None, 2 1024        conv2d_1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, None, None, 2 0           block3_pool[0][0]
#                                                                  batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1_act (Activation (None, None, None, 2 0           add_1[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1 (SeparableConv2 (None, None, None, 7 188672      block4_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1_bn (BatchNormal (None, None, None, 7 2912        block4_sepconv1[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2_act (Activation (None, None, None, 7 0           block4_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2 (SeparableConv2 (None, None, None, 7 536536      block4_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2_bn (BatchNormal (None, None, None, 7 2912        block4_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, None, None, 7 186368      add_1[0][0]
# __________________________________________________________________________________________________
# block4_pool (MaxPooling2D)      (None, None, None, 7 0           block4_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, None, None, 7 2912        conv2d_2[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, None, None, 7 0           block4_pool[0][0]
#                                                                  batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1_act (Activation (None, None, None, 7 0           add_2[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1 (SeparableConv2 (None, None, None, 7 536536      block5_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1_bn (BatchNormal (None, None, None, 7 2912        block5_sepconv1[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2_act (Activation (None, None, None, 7 0           block5_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2 (SeparableConv2 (None, None, None, 7 536536      block5_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2_bn (BatchNormal (None, None, None, 7 2912        block5_sepconv2[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3_act (Activation (None, None, None, 7 0           block5_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3 (SeparableConv2 (None, None, None, 7 536536      block5_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3_bn (BatchNormal (None, None, None, 7 2912        block5_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, None, None, 7 0           block5_sepconv3_bn[0][0]
#                                                                  add_2[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1_act (Activation (None, None, None, 7 0           add_3[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1 (SeparableConv2 (None, None, None, 7 536536      block6_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1_bn (BatchNormal (None, None, None, 7 2912        block6_sepconv1[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2_act (Activation (None, None, None, 7 0           block6_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2 (SeparableConv2 (None, None, None, 7 536536      block6_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2_bn (BatchNormal (None, None, None, 7 2912        block6_sepconv2[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3_act (Activation (None, None, None, 7 0           block6_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3 (SeparableConv2 (None, None, None, 7 536536      block6_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3_bn (BatchNormal (None, None, None, 7 2912        block6_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, None, None, 7 0           block6_sepconv3_bn[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1_act (Activation (None, None, None, 7 0           add_4[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1 (SeparableConv2 (None, None, None, 7 536536      block7_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1_bn (BatchNormal (None, None, None, 7 2912        block7_sepconv1[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2_act (Activation (None, None, None, 7 0           block7_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2 (SeparableConv2 (None, None, None, 7 536536      block7_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2_bn (BatchNormal (None, None, None, 7 2912        block7_sepconv2[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3_act (Activation (None, None, None, 7 0           block7_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3 (SeparableConv2 (None, None, None, 7 536536      block7_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3_bn (BatchNormal (None, None, None, 7 2912        block7_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, None, None, 7 0           block7_sepconv3_bn[0][0]
#                                                                  add_4[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1_act (Activation (None, None, None, 7 0           add_5[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1 (SeparableConv2 (None, None, None, 7 536536      block8_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1_bn (BatchNormal (None, None, None, 7 2912        block8_sepconv1[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2_act (Activation (None, None, None, 7 0           block8_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2 (SeparableConv2 (None, None, None, 7 536536      block8_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2_bn (BatchNormal (None, None, None, 7 2912        block8_sepconv2[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3_act (Activation (None, None, None, 7 0           block8_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3 (SeparableConv2 (None, None, None, 7 536536      block8_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3_bn (BatchNormal (None, None, None, 7 2912        block8_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, None, None, 7 0           block8_sepconv3_bn[0][0]
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1_act (Activation (None, None, None, 7 0           add_6[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1 (SeparableConv2 (None, None, None, 7 536536      block9_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1_bn (BatchNormal (None, None, None, 7 2912        block9_sepconv1[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2_act (Activation (None, None, None, 7 0           block9_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2 (SeparableConv2 (None, None, None, 7 536536      block9_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2_bn (BatchNormal (None, None, None, 7 2912        block9_sepconv2[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3_act (Activation (None, None, None, 7 0           block9_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3 (SeparableConv2 (None, None, None, 7 536536      block9_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3_bn (BatchNormal (None, None, None, 7 2912        block9_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, None, None, 7 0           block9_sepconv3_bn[0][0]
#                                                                  add_6[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1_act (Activatio (None, None, None, 7 0           add_7[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1 (SeparableConv (None, None, None, 7 536536      block10_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1_bn (BatchNorma (None, None, None, 7 2912        block10_sepconv1[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2_act (Activatio (None, None, None, 7 0           block10_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2 (SeparableConv (None, None, None, 7 536536      block10_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2_bn (BatchNorma (None, None, None, 7 2912        block10_sepconv2[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3_act (Activatio (None, None, None, 7 0           block10_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3 (SeparableConv (None, None, None, 7 536536      block10_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3_bn (BatchNorma (None, None, None, 7 2912        block10_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, None, None, 7 0           block10_sepconv3_bn[0][0]
#                                                                  add_7[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1_act (Activatio (None, None, None, 7 0           add_8[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1 (SeparableConv (None, None, None, 7 536536      block11_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1_bn (BatchNorma (None, None, None, 7 2912        block11_sepconv1[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2_act (Activatio (None, None, None, 7 0           block11_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2 (SeparableConv (None, None, None, 7 536536      block11_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2_bn (BatchNorma (None, None, None, 7 2912        block11_sepconv2[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3_act (Activatio (None, None, None, 7 0           block11_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3 (SeparableConv (None, None, None, 7 536536      block11_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3_bn (BatchNorma (None, None, None, 7 2912        block11_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, None, None, 7 0           block11_sepconv3_bn[0][0]
#                                                                  add_8[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1_act (Activatio (None, None, None, 7 0           add_9[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1 (SeparableConv (None, None, None, 7 536536      block12_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1_bn (BatchNorma (None, None, None, 7 2912        block12_sepconv1[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2_act (Activatio (None, None, None, 7 0           block12_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2 (SeparableConv (None, None, None, 7 536536      block12_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2_bn (BatchNorma (None, None, None, 7 2912        block12_sepconv2[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3_act (Activatio (None, None, None, 7 0           block12_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3 (SeparableConv (None, None, None, 7 536536      block12_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3_bn (BatchNorma (None, None, None, 7 2912        block12_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, None, None, 7 0           block12_sepconv3_bn[0][0]
#                                                                  add_9[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1_act (Activatio (None, None, None, 7 0           add_10[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1 (SeparableConv (None, None, None, 7 536536      block13_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1_bn (BatchNorma (None, None, None, 7 2912        block13_sepconv1[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2_act (Activatio (None, None, None, 7 0           block13_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2 (SeparableConv (None, None, None, 1 752024      block13_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2_bn (BatchNorma (None, None, None, 1 4096        block13_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, None, None, 1 745472      add_10[0][0]
# __________________________________________________________________________________________________
# block13_pool (MaxPooling2D)     (None, None, None, 1 0           block13_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, None, None, 1 4096        conv2d_3[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, None, None, 1 0           block13_pool[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1 (SeparableConv (None, None, None, 1 1582080     add_11[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1_bn (BatchNorma (None, None, None, 1 6144        block14_sepconv1[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1_act (Activatio (None, None, None, 1 0           block14_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2 (SeparableConv (None, None, None, 2 3159552     block14_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2_bn (BatchNorma (None, None, None, 2 8192        block14_sepconv2[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2_act (Activatio (None, None, None, 2 0           block14_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_6 (Glo (None, 2048)         0           block14_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 128)          262272      global_average_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 3)            387         dense_12[0][0]
# ==================================================================================================
# Total params: 21,124,139
# Trainable params: 262,659
# Non-trainable params: 20,861,480
# __________________________________________________________________________________________________

# %%
optimizer = keras.optimizers.Adam()
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=[precision_score, recall_score, f1_score])

# %%
checkpointer = ModelCheckpoint_tweaked(filepath='./modelo_xception.hdf5', verbose=1,  mode='max', save_best_only=True, monitor='val_f1_score')

history = model.fit_generator(generator=train_generator, 
                              epochs=qtde_epocas, 
                              validation_steps=5, 
                              steps_per_epoch=5, 
                              validation_data=val_generator,
                              callbacks=[checkpointer])
# Out:
# Epoch 1/100
# 5/5 [==============================] - ETA: 0s - loss: 3.8538 - precision_score: 0.4554 - recall_score: 0.4437 - f1_score: 0.4494
# Epoch 00001: val_f1_score improved from -inf to 0.27573, saving model to .\modelo_xception.hdf5
# 5/5 [==============================] - 5s 995ms/step - loss: 3.8538 - precision_score: 0.4554 - recall_score: 0.4437 - f1_score: 0.4494 - val_loss: 2.9546 - val_precision_score: 0.2833 - val_recall_score: 0.2688 - val_f1_score: 0.2757
# Epoch 2/100
# 5/5 [==============================] - ETA: 0s - loss: 2.4141 - precision_score: 0.4362 - recall_score: 0.4125 - f1_score: 0.4239
# Epoch 00002: val_f1_score improved from 0.27573 to 0.52500, saving model to .\modelo_xception.hdf5
# 5/5 [==============================] - 4s 897ms/step - loss: 2.4141 - precision_score: 0.4362 - recall_score: 0.4125 - f1_score: 0.4239 - val_loss: 2.4323 - val_precision_score: 0.5250 - val_recall_score: 0.5250 - val_f1_score: 0.5250
# Epoch 3/100
# 5/5 [==============================] - ETA: 0s - loss: 1.2715 - precision_score: 0.6536 - recall_score: 0.6500 - f1_score: 0.6518
# Epoch 00003: val_f1_score improved from 0.52500 to 0.54247, saving model to .\modelo_xception.hdf5
# 5/5 [==============================] - 5s 948ms/step - loss: 1.2715 - precision_score: 0.6536 - recall_score: 0.6500 - f1_score: 0.6518 - val_loss: 1.1030 - val_precision_score: 0.5948 - val_recall_score: 0.5000 - val_f1_score: 0.5425
# Epoch 4/100
# 5/5 [==============================] - ETA: 0s - loss: 1.2357 - precision_score: 0.5298 - recall_score: 0.5000 - f1_score: 0.5141
# Epoch 00004: val_f1_score did not improve from 0.54247
# 5/5 [==============================] - 4s 788ms/step - loss: 1.2357 - precision_score: 0.5298 - recall_score: 0.5000 - f1_score: 0.5141 - val_loss: 1.1766 - val_precision_score: 0.5074 - val_recall_score: 0.4500 - val_f1_score: 0.4766
# Epoch 5/100
# 5/5 [==============================] - ETA: 0s - loss: 0.8688 - precision_score: 0.6634 - recall_score: 0.6313 - f1_score: 0.6466
# Epoch 00005: val_f1_score improved from 0.54247 to 0.61591, saving model to .\modelo_xception.hdf5
# 5/5 [==============================] - 5s 1s/step - loss: 0.8688 - precision_score: 0.6634 - recall_score: 0.6313 - f1_score: 0.6466 - val_loss: 0.9187 - val_precision_score: 0.6641 - val_recall_score: 0.5750 - val_f1_score: 0.6159
# Epoch 6/100
# 5/5 [==============================] - ETA: 0s - loss: 1.0335 - precision_score: 0.6005 - recall_score: 0.5562 - f1_score: 0.5774
# Epoch 00006: val_f1_score improved from 0.61591 to 0.65711, saving model to .\modelo_xception.hdf5
# 5/5 [==============================] - 5s 979ms/step - loss: 1.0335 - precision_score: 0.6005 - recall_score: 0.5562 - f1_score: 0.5774 - val_loss: 0.8950 - val_precision_score: 0.7011 - val_recall_score: 0.6187 - val_f1_score: 0.6571
# Epoch 7/100
# 5/5 [==============================] - ETA: 0s - loss: 0.9896 - precision_score: 0.6382 - recall_score: 0.6187 - f1_score: 0.6280
# Epoch 00007: val_f1_score did not improve from 0.65711
# 5/5 [==============================] - 4s 800ms/step - loss: 0.9896 - precision_score: 0.6382 - recall_score: 0.6187 - f1_score: 0.6280 - val_loss: 0.8109 - val_precision_score: 0.7065 - val_recall_score: 0.5938 - val_f1_score: 0.6434
# Epoch 8/100
# 5/5 [==============================] - ETA: 0s - loss: 0.8548 - precision_score: 0.6247 - recall_score: 0.5813 - f1_score: 0.6018
# Epoch 00008: val_f1_score did not improve from 0.65711
# 5/5 [==============================] - 4s 772ms/step - loss: 0.8548 - precision_score: 0.6247 - recall_score: 0.5813 - f1_score: 0.6018 - val_loss: 0.9165 - val_precision_score: 0.6596 - val_recall_score: 0.5312 - val_f1_score: 0.5879
# Epoch 9/100
# 5/5 [==============================] - ETA: 0s - loss: 0.7257 - precision_score: 0.6836 - recall_score: 0.6375 - f1_score: 0.6594
# Epoch 00009: val_f1_score improved from 0.65711 to 0.69058, saving model to .\modelo_xception.hdf5
# 5/5 [==============================] - 5s 912ms/step - loss: 0.7257 - precision_score: 0.6836 - recall_score: 0.6375 - f1_score: 0.6594 - val_loss: 0.7690 - val_precision_score: 0.7142 - val_recall_score: 0.6687 - val_f1_score: 0.6906
# Epoch 10/100
# 5/5 [==============================] - ETA: 0s - loss: 0.8401 - precision_score: 0.6897 - recall_score: 0.6313 - f1_score: 0.6589
# Epoch 00010: val_f1_score did not improve from 0.69058
# 5/5 [==============================] - 4s 822ms/step - loss: 0.8401 - precision_score: 0.6897 - recall_score: 0.6313 - f1_score: 0.6589 - val_loss: 0.9357 - val_precision_score: 0.7750 - val_recall_score: 0.6125 - val_f1_score: 0.6828
# Epoch 11/100
# 5/5 [==============================] - ETA: 0s - loss: 0.7195 - precision_score: 0.6757 - recall_score: 0.6187 - f1_score: 0.6452
# Epoch 00011: val_f1_score improved from 0.69058 to 0.77712, saving model to .\modelo_xception.hdf5
# 5/5 [==============================] - 5s 957ms/step - loss: 0.7195 - precision_score: 0.6757 - recall_score: 0.6187 - f1_score: 0.6452 - val_loss: 0.5905 - val_precision_score: 0.8503 - val_recall_score: 0.7188 - val_f1_score: 0.7771
# Epoch 12/100
# 5/5 [==============================] - ETA: 0s - loss: 0.8303 - precision_score: 0.6572 - recall_score: 0.6000 - f1_score: 0.6269
# Epoch 00012: val_f1_score did not improve from 0.77712
# 5/5 [==============================] - 4s 769ms/step - loss: 0.8303 - precision_score: 0.6572 - recall_score: 0.6000 - f1_score: 0.6269 - val_loss: 0.8157 - val_precision_score: 0.7173 - val_recall_score: 0.6313 - val_f1_score: 0.6707
# Epoch 13/100
# 5/5 [==============================] - ETA: 0s - loss: 0.8302 - precision_score: 0.6505 - recall_score: 0.6187 - f1_score: 0.6340
# Epoch 00013: val_f1_score did not improve from 0.77712
# 5/5 [==============================] - 4s 744ms/step - loss: 0.8302 - precision_score: 0.6505 - recall_score: 0.6187 - f1_score: 0.6340 - val_loss: 0.6823 - val_precision_score: 0.8029 - val_recall_score: 0.7188 - val_f1_score: 0.7569
# Epoch 14/100
# 5/5 [==============================] - ETA: 0s - loss: 0.7271 - precision_score: 0.7388 - recall_score: 0.6938 - f1_score: 0.7155
# Epoch 00014: val_f1_score did not improve from 0.77712
# 5/5 [==============================] - 4s 811ms/step - loss: 0.7271 - precision_score: 0.7388 - recall_score: 0.6938 - f1_score: 0.7155 - val_loss: 0.7929 - val_precision_score: 0.7934 - val_recall_score: 0.7000 - val_f1_score: 0.7435
# Epoch 15/100
# 5/5 [==============================] - ETA: 0s - loss: 0.7520 - precision_score: 0.6588 - recall_score: 0.6187 - f1_score: 0.6381
# Epoch 00015: val_f1_score did not improve from 0.77712
# 5/5 [==============================] - 4s 764ms/step - loss: 0.7520 - precision_score: 0.6588 - recall_score: 0.6187 - f1_score: 0.6381 - val_loss: 0.6704 - val_precision_score: 0.7825 - val_recall_score: 0.6687 - val_f1_score: 0.7210
# Epoch 16/100
# 5/5 [==============================] - ETA: 0s - loss: 0.7303 - precision_score: 0.6947 - recall_score: 0.6438 - f1_score: 0.6676
# Epoch 00016: val_f1_score did not improve from 0.77712
# 5/5 [==============================] - 4s 726ms/step - loss: 0.7303 - precision_score: 0.6947 - recall_score: 0.6438 - f1_score: 0.6676 - val_loss: 0.8126 - val_precision_score: 0.7106 - val_recall_score: 0.5813 - val_f1_score: 0.6387
# Epoch 17/100
# 5/5 [==============================] - ETA: 0s - loss: 0.8498 - precision_score: 0.6635 - recall_score: 0.5688 - f1_score: 0.6121
# Epoch 00017: val_f1_score did not improve from 0.77712
# 5/5 [==============================] - 4s 795ms/step - loss: 0.8498 - precision_score: 0.6635 - recall_score: 0.5688 - f1_score: 0.6121 - val_loss: 0.8526 - val_precision_score: 0.7561 - val_recall_score: 0.6375 - val_f1_score: 0.6916
# Epoch 18/100
# 5/5 [==============================] - ETA: 0s - loss: 0.8333 - precision_score: 0.6616 - recall_score: 0.6125 - f1_score: 0.6358
# Epoch 00018: val_f1_score did not improve from 0.77712
# 5/5 [==============================] - 4s 795ms/step - loss: 0.8333 - precision_score: 0.6616 - recall_score: 0.6125 - f1_score: 0.6358 - val_loss: 0.7946 - val_precision_score: 0.7755 - val_recall_score: 0.6812 - val_f1_score: 0.7249
# Epoch 19/100
# 5/5 [==============================] - ETA: 0s - loss: 0.9199 - precision_score: 0.6714 - recall_score: 0.6125 - f1_score: 0.6400
# Epoch 00019: val_f1_score did not improve from 0.77712
# 5/5 [==============================] - 4s 780ms/step - loss: 0.9199 - precision_score: 0.6714 - recall_score: 0.6125 - f1_score: 0.6400 - val_loss: 1.3513 - val_precision_score: 0.5069 - val_recall_score: 0.4812 - val_f1_score: 0.4936
# Epoch 20/100
# 5/5 [==============================] - ETA: 0s - loss: 0.9827 - precision_score: 0.5641 - recall_score: 0.5188 - f1_score: 0.5398
# Epoch 00020: val_f1_score did not improve from 0.77712
# 5/5 [==============================] - 4s 771ms/step - loss: 0.9827 - precision_score: 0.5641 - recall_score: 0.5188 - f1_score: 0.5398 - val_loss: 0.7278 - val_precision_score: 0.7663 - val_recall_score: 0.6750 - val_f1_score: 0.7170
# Epoch 21/100
# 5/5 [==============================] - ETA: 0s - loss: 0.7769 - precision_score: 0.7310 - recall_score: 0.7000 - f1_score: 0.7147
# Epoch 00021: val_f1_score did not improve from 0.77712
# 5/5 [==============================] - 4s 766ms/step - loss: 0.7769 - precision_score: 0.7310 - recall_score: 0.7000 - f1_score: 0.7147 - val_loss: 0.9515 - val_precision_score: 0.7703 - val_recall_score: 0.7125 - val_f1_score: 0.7399
# Epoch 22/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5986 - precision_score: 0.7710 - recall_score: 0.7312 - f1_score: 0.7504
# Epoch 00022: val_f1_score did not improve from 0.77712
# 5/5 [==============================] - 4s 783ms/step - loss: 0.5986 - precision_score: 0.7710 - recall_score: 0.7312 - f1_score: 0.7504 - val_loss: 0.8638 - val_precision_score: 0.7689 - val_recall_score: 0.7063 - val_f1_score: 0.7361
# Epoch 23/100
# 5/5 [==============================] - ETA: 0s - loss: 0.7327 - precision_score: 0.7190 - recall_score: 0.6562 - f1_score: 0.6852
# Epoch 00023: val_f1_score did not improve from 0.77712
# 5/5 [==============================] - 4s 754ms/step - loss: 0.7327 - precision_score: 0.7190 - recall_score: 0.6562 - f1_score: 0.6852 - val_loss: 0.8365 - val_precision_score: 0.7291 - val_recall_score: 0.6562 - val_f1_score: 0.6903
# Epoch 24/100
# 5/5 [==============================] - ETA: 0s - loss: 0.7117 - precision_score: 0.7020 - recall_score: 0.6125 - f1_score: 0.6535
# Epoch 00024: val_f1_score did not improve from 0.77712
# 5/5 [==============================] - 4s 753ms/step - loss: 0.7117 - precision_score: 0.7020 - recall_score: 0.6125 - f1_score: 0.6535 - val_loss: 0.8313 - val_precision_score: 0.6721 - val_recall_score: 0.5938 - val_f1_score: 0.6300
# Epoch 25/100
# 5/5 [==============================] - ETA: 0s - loss: 0.7951 - precision_score: 0.6763 - recall_score: 0.6313 - f1_score: 0.6527
# Epoch 00025: val_f1_score did not improve from 0.77712
# 5/5 [==============================] - 4s 751ms/step - loss: 0.7951 - precision_score: 0.6763 - recall_score: 0.6313 - f1_score: 0.6527 - val_loss: 0.7488 - val_precision_score: 0.7746 - val_recall_score: 0.7125 - val_f1_score: 0.7417
# Epoch 26/100
# 5/5 [==============================] - ETA: 0s - loss: 0.7785 - precision_score: 0.7263 - recall_score: 0.6625 - f1_score: 0.6928
# Epoch 00026: val_f1_score did not improve from 0.77712
# 5/5 [==============================] - 4s 767ms/step - loss: 0.7785 - precision_score: 0.7263 - recall_score: 0.6625 - f1_score: 0.6928 - val_loss: 0.8109 - val_precision_score: 0.7297 - val_recall_score: 0.6625 - val_f1_score: 0.6939
# Epoch 27/100
# 5/5 [==============================] - ETA: 0s - loss: 0.6942 - precision_score: 0.7312 - recall_score: 0.7125 - f1_score: 0.7216
# Epoch 00027: val_f1_score did not improve from 0.77712
# 5/5 [==============================] - 4s 761ms/step - loss: 0.6942 - precision_score: 0.7312 - recall_score: 0.7125 - f1_score: 0.7216 - val_loss: 0.9156 - val_precision_score: 0.6785 - val_recall_score: 0.6125 - val_f1_score: 0.6432
# Epoch 28/100
# 5/5 [==============================] - ETA: 0s - loss: 0.6963 - precision_score: 0.7695 - recall_score: 0.7375 - f1_score: 0.7528
# Epoch 00028: val_f1_score did not improve from 0.77712
# 5/5 [==============================] - 4s 770ms/step - loss: 0.6963 - precision_score: 0.7695 - recall_score: 0.7375 - f1_score: 0.7528 - val_loss: 1.0120 - val_precision_score: 0.6445 - val_recall_score: 0.5875 - val_f1_score: 0.6143
# Epoch 29/100
# 5/5 [==============================] - ETA: 0s - loss: 0.8065 - precision_score: 0.6618 - recall_score: 0.6375 - f1_score: 0.6493
# Epoch 00029: val_f1_score did not improve from 0.77712
# 5/5 [==============================] - 4s 765ms/step - loss: 0.8065 - precision_score: 0.6618 - recall_score: 0.6375 - f1_score: 0.6493 - val_loss: 0.9557 - val_precision_score: 0.7489 - val_recall_score: 0.6625 - val_f1_score: 0.7026
# Epoch 30/100
# 5/5 [==============================] - ETA: 0s - loss: 0.6238 - precision_score: 0.7495 - recall_score: 0.6875 - f1_score: 0.7159
# Epoch 00030: val_f1_score did not improve from 0.77712
# 5/5 [==============================] - 4s 787ms/step - loss: 0.6238 - precision_score: 0.7495 - recall_score: 0.6875 - f1_score: 0.7159 - val_loss: 0.8514 - val_precision_score: 0.7958 - val_recall_score: 0.7188 - val_f1_score: 0.7547
# Epoch 31/100
# 5/5 [==============================] - ETA: 0s - loss: 0.6214 - precision_score: 0.7267 - recall_score: 0.6938 - f1_score: 0.7097
# Epoch 00031: val_f1_score improved from 0.77712 to 0.78071, saving model to .\modelo_xception.hdf5
# 5/5 [==============================] - 5s 972ms/step - loss: 0.6214 - precision_score: 0.7267 - recall_score: 0.6938 - f1_score: 0.7097 - val_loss: 0.7428 - val_precision_score: 0.8072 - val_recall_score: 0.7563 - val_f1_score: 0.7807
# Epoch 32/100
# 5/5 [==============================] - ETA: 0s - loss: 0.7592 - precision_score: 0.7259 - recall_score: 0.6750 - f1_score: 0.6992
# Epoch 00032: val_f1_score did not improve from 0.78071
# 5/5 [==============================] - 4s 751ms/step - loss: 0.7592 - precision_score: 0.7259 - recall_score: 0.6750 - f1_score: 0.6992 - val_loss: 0.7610 - val_precision_score: 0.7772 - val_recall_score: 0.6875 - val_f1_score: 0.7279
# Epoch 33/100
# 5/5 [==============================] - ETA: 0s - loss: 0.7279 - precision_score: 0.6711 - recall_score: 0.5938 - f1_score: 0.6296
# Epoch 00033: val_f1_score did not improve from 0.78071
# 5/5 [==============================] - 4s 741ms/step - loss: 0.7279 - precision_score: 0.6711 - recall_score: 0.5938 - f1_score: 0.6296 - val_loss: 0.7423 - val_precision_score: 0.7265 - val_recall_score: 0.6687 - val_f1_score: 0.6963
# Epoch 34/100
# 5/5 [==============================] - ETA: 0s - loss: 0.6459 - precision_score: 0.7209 - recall_score: 0.6812 - f1_score: 0.7000
# Epoch 00034: val_f1_score did not improve from 0.78071
# 5/5 [==============================] - 4s 778ms/step - loss: 0.6459 - precision_score: 0.7209 - recall_score: 0.6812 - f1_score: 0.7000 - val_loss: 0.8080 - val_precision_score: 0.7870 - val_recall_score: 0.7188 - val_f1_score: 0.7509
# Epoch 35/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5599 - precision_score: 0.7808 - recall_score: 0.7563 - f1_score: 0.7682
# Epoch 00035: val_f1_score did not improve from 0.78071
# 5/5 [==============================] - 4s 760ms/step - loss: 0.5599 - precision_score: 0.7808 - recall_score: 0.7563 - f1_score: 0.7682 - val_loss: 0.6829 - val_precision_score: 0.7549 - val_recall_score: 0.6750 - val_f1_score: 0.7125
# Epoch 36/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5094 - precision_score: 0.8023 - recall_score: 0.7563 - f1_score: 0.7782
# Epoch 00036: val_f1_score did not improve from 0.78071
# 5/5 [==============================] - 4s 775ms/step - loss: 0.5094 - precision_score: 0.8023 - recall_score: 0.7563 - f1_score: 0.7782 - val_loss: 0.8852 - val_precision_score: 0.7658 - val_recall_score: 0.6500 - val_f1_score: 0.7022
# Epoch 37/100
# 5/5 [==============================] - ETA: 0s - loss: 0.6332 - precision_score: 0.7232 - recall_score: 0.6875 - f1_score: 0.7047
# Epoch 00037: val_f1_score did not improve from 0.78071
# 5/5 [==============================] - 4s 766ms/step - loss: 0.6332 - precision_score: 0.7232 - recall_score: 0.6875 - f1_score: 0.7047 - val_loss: 0.6263 - val_precision_score: 0.7967 - val_recall_score: 0.6875 - val_f1_score: 0.7372
# Epoch 38/100
# 5/5 [==============================] - ETA: 0s - loss: 0.7148 - precision_score: 0.7461 - recall_score: 0.6938 - f1_score: 0.7188
# Epoch 00038: val_f1_score did not improve from 0.78071
# 5/5 [==============================] - 4s 792ms/step - loss: 0.7148 - precision_score: 0.7461 - recall_score: 0.6938 - f1_score: 0.7188 - val_loss: 0.7274 - val_precision_score: 0.7530 - val_recall_score: 0.6812 - val_f1_score: 0.7153
# Epoch 39/100
# 5/5 [==============================] - ETA: 0s - loss: 0.8210 - precision_score: 0.6869 - recall_score: 0.6562 - f1_score: 0.6711
# Epoch 00039: val_f1_score did not improve from 0.78071
# 5/5 [==============================] - 4s 759ms/step - loss: 0.8210 - precision_score: 0.6869 - recall_score: 0.6562 - f1_score: 0.6711 - val_loss: 0.8561 - val_precision_score: 0.7544 - val_recall_score: 0.6687 - val_f1_score: 0.7088
# Epoch 40/100
# 5/5 [==============================] - ETA: 0s - loss: 0.7258 - precision_score: 0.6804 - recall_score: 0.6250 - f1_score: 0.6512
# Epoch 00040: val_f1_score did not improve from 0.78071
# 5/5 [==============================] - 4s 762ms/step - loss: 0.7258 - precision_score: 0.6804 - recall_score: 0.6250 - f1_score: 0.6512 - val_loss: 0.8065 - val_precision_score: 0.6997 - val_recall_score: 0.6250 - val_f1_score: 0.6600
# Epoch 41/100
# 5/5 [==============================] - ETA: 0s - loss: 0.8365 - precision_score: 0.6383 - recall_score: 0.6000 - f1_score: 0.6185
# Epoch 00041: val_f1_score did not improve from 0.78071
# 5/5 [==============================] - 4s 760ms/step - loss: 0.8365 - precision_score: 0.6383 - recall_score: 0.6000 - f1_score: 0.6185 - val_loss: 0.9794 - val_precision_score: 0.6509 - val_recall_score: 0.5938 - val_f1_score: 0.6209
# Epoch 42/100
# 5/5 [==============================] - ETA: 0s - loss: 0.8615 - precision_score: 0.6715 - recall_score: 0.6375 - f1_score: 0.6539
# Epoch 00042: val_f1_score did not improve from 0.78071
# 5/5 [==============================] - 4s 792ms/step - loss: 0.8615 - precision_score: 0.6715 - recall_score: 0.6375 - f1_score: 0.6539 - val_loss: 0.9371 - val_precision_score: 0.7492 - val_recall_score: 0.6875 - val_f1_score: 0.7166
# Epoch 43/100
# 5/5 [==============================] - ETA: 0s - loss: 0.8484 - precision_score: 0.6226 - recall_score: 0.5813 - f1_score: 0.6011
# Epoch 00043: val_f1_score did not improve from 0.78071
# 5/5 [==============================] - 4s 764ms/step - loss: 0.8484 - precision_score: 0.6226 - recall_score: 0.5813 - f1_score: 0.6011 - val_loss: 0.8039 - val_precision_score: 0.7842 - val_recall_score: 0.7063 - val_f1_score: 0.7428
# Epoch 44/100
# 5/5 [==============================] - ETA: 0s - loss: 0.6897 - precision_score: 0.7565 - recall_score: 0.7250 - f1_score: 0.7401
# Epoch 00044: val_f1_score did not improve from 0.78071
# 5/5 [==============================] - 4s 800ms/step - loss: 0.6897 - precision_score: 0.7565 - recall_score: 0.7250 - f1_score: 0.7401 - val_loss: 0.7350 - val_precision_score: 0.8241 - val_recall_score: 0.7312 - val_f1_score: 0.7746
# Epoch 45/100
# 5/5 [==============================] - ETA: 0s - loss: 0.6991 - precision_score: 0.7138 - recall_score: 0.6562 - f1_score: 0.6836
# Epoch 00045: val_f1_score did not improve from 0.78071
# 5/5 [==============================] - 4s 789ms/step - loss: 0.6991 - precision_score: 0.7138 - recall_score: 0.6562 - f1_score: 0.6836 - val_loss: 0.7395 - val_precision_score: 0.8139 - val_recall_score: 0.7375 - val_f1_score: 0.7737
# Epoch 46/100
# 5/5 [==============================] - ETA: 0s - loss: 0.6832 - precision_score: 0.7219 - recall_score: 0.7063 - f1_score: 0.7139
# Epoch 00046: val_f1_score did not improve from 0.78071
# 5/5 [==============================] - 4s 797ms/step - loss: 0.6832 - precision_score: 0.7219 - recall_score: 0.7063 - f1_score: 0.7139 - val_loss: 0.6282 - val_precision_score: 0.7518 - val_recall_score: 0.6562 - val_f1_score: 0.7005
# Epoch 47/100
# 5/5 [==============================] - ETA: 0s - loss: 0.8246 - precision_score: 0.6381 - recall_score: 0.5875 - f1_score: 0.6117
# Epoch 00047: val_f1_score did not improve from 0.78071
# 5/5 [==============================] - 4s 768ms/step - loss: 0.8246 - precision_score: 0.6381 - recall_score: 0.5875 - f1_score: 0.6117 - val_loss: 0.7563 - val_precision_score: 0.7271 - val_recall_score: 0.7000 - val_f1_score: 0.7131
# Epoch 48/100
# 5/5 [==============================] - ETA: 0s - loss: 0.7373 - precision_score: 0.7500 - recall_score: 0.7063 - f1_score: 0.7272
# Epoch 00048: val_f1_score did not improve from 0.78071
# 5/5 [==============================] - 4s 749ms/step - loss: 0.7373 - precision_score: 0.7500 - recall_score: 0.7063 - f1_score: 0.7272 - val_loss: 0.6490 - val_precision_score: 0.7637 - val_recall_score: 0.6500 - val_f1_score: 0.7015
# Epoch 49/100
# 5/5 [==============================] - ETA: 0s - loss: 0.6438 - precision_score: 0.7596 - recall_score: 0.7125 - f1_score: 0.7351
# Epoch 00049: val_f1_score did not improve from 0.78071
# 5/5 [==============================] - 4s 787ms/step - loss: 0.6438 - precision_score: 0.7596 - recall_score: 0.7125 - f1_score: 0.7351 - val_loss: 0.7691 - val_precision_score: 0.7400 - val_recall_score: 0.6750 - val_f1_score: 0.7055
# Epoch 50/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5502 - precision_score: 0.7634 - recall_score: 0.7250 - f1_score: 0.7437
# Epoch 00050: val_f1_score did not improve from 0.78071
# 5/5 [==============================] - 4s 765ms/step - loss: 0.5502 - precision_score: 0.7634 - recall_score: 0.7250 - f1_score: 0.7437 - val_loss: 0.7219 - val_precision_score: 0.8098 - val_recall_score: 0.7250 - val_f1_score: 0.7645
# Epoch 51/100
# 5/5 [==============================] - ETA: 0s - loss: 0.7397 - precision_score: 0.6991 - recall_score: 0.6562 - f1_score: 0.6766
# Epoch 00051: val_f1_score did not improve from 0.78071
# 5/5 [==============================] - 4s 763ms/step - loss: 0.7397 - precision_score: 0.6991 - recall_score: 0.6562 - f1_score: 0.6766 - val_loss: 0.8757 - val_precision_score: 0.7085 - val_recall_score: 0.6687 - val_f1_score: 0.6878
# Epoch 52/100
# 5/5 [==============================] - ETA: 0s - loss: 0.6305 - precision_score: 0.6863 - recall_score: 0.6562 - f1_score: 0.6705
# Epoch 00052: val_f1_score did not improve from 0.78071
# 5/5 [==============================] - 4s 768ms/step - loss: 0.6305 - precision_score: 0.6863 - recall_score: 0.6562 - f1_score: 0.6705 - val_loss: 0.7600 - val_precision_score: 0.7253 - val_recall_score: 0.6750 - val_f1_score: 0.6986
# Epoch 53/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5873 - precision_score: 0.7723 - recall_score: 0.7188 - f1_score: 0.7433
# Epoch 00053: val_f1_score improved from 0.78071 to 0.82105, saving model to .\modelo_xception.hdf5
# 5/5 [==============================] - 5s 963ms/step - loss: 0.5873 - precision_score: 0.7723 - recall_score: 0.7188 - f1_score: 0.7433 - val_loss: 0.6246 - val_precision_score: 0.8577 - val_recall_score: 0.7875 - val_f1_score: 0.8210
# Epoch 54/100
# 5/5 [==============================] - ETA: 0s - loss: 0.6691 - precision_score: 0.7337 - recall_score: 0.6750 - f1_score: 0.7028
# Epoch 00054: val_f1_score did not improve from 0.82105
# 5/5 [==============================] - 4s 746ms/step - loss: 0.6691 - precision_score: 0.7337 - recall_score: 0.6750 - f1_score: 0.7028 - val_loss: 0.6991 - val_precision_score: 0.7899 - val_recall_score: 0.7563 - val_f1_score: 0.7725
# Epoch 55/100
# 5/5 [==============================] - ETA: 0s - loss: 0.7166 - precision_score: 0.6802 - recall_score: 0.6250 - f1_score: 0.6512
# Epoch 00055: val_f1_score did not improve from 0.82105
# 5/5 [==============================] - 4s 787ms/step - loss: 0.7166 - precision_score: 0.6802 - recall_score: 0.6250 - f1_score: 0.6512 - val_loss: 0.8109 - val_precision_score: 0.7526 - val_recall_score: 0.7188 - val_f1_score: 0.7348
# Epoch 56/100
# 5/5 [==============================] - ETA: 0s - loss: 0.8414 - precision_score: 0.6703 - recall_score: 0.6187 - f1_score: 0.6432
# Epoch 00056: val_f1_score did not improve from 0.82105
# 5/5 [==============================] - 4s 768ms/step - loss: 0.8414 - precision_score: 0.6703 - recall_score: 0.6187 - f1_score: 0.6432 - val_loss: 1.1930 - val_precision_score: 0.6649 - val_recall_score: 0.5938 - val_f1_score: 0.6271
# Epoch 57/100
# 5/5 [==============================] - ETA: 0s - loss: 0.7679 - precision_score: 0.6937 - recall_score: 0.6500 - f1_score: 0.6710
# Epoch 00057: val_f1_score did not improve from 0.82105
# 5/5 [==============================] - 4s 770ms/step - loss: 0.7679 - precision_score: 0.6937 - recall_score: 0.6500 - f1_score: 0.6710 - val_loss: 0.7158 - val_precision_score: 0.6933 - val_recall_score: 0.6313 - val_f1_score: 0.6599
# Epoch 58/100
# 5/5 [==============================] - ETA: 0s - loss: 0.8081 - precision_score: 0.6623 - recall_score: 0.6187 - f1_score: 0.6396
# Epoch 00058: val_f1_score did not improve from 0.82105
# 5/5 [==============================] - 4s 811ms/step - loss: 0.8081 - precision_score: 0.6623 - recall_score: 0.6187 - f1_score: 0.6396 - val_loss: 0.7193 - val_precision_score: 0.7445 - val_recall_score: 0.6812 - val_f1_score: 0.7111
# Epoch 59/100
# 5/5 [==============================] - ETA: 0s - loss: 0.6743 - precision_score: 0.7154 - recall_score: 0.6750 - f1_score: 0.6945
# Epoch 00059: val_f1_score did not improve from 0.82105
# 5/5 [==============================] - 4s 736ms/step - loss: 0.6743 - precision_score: 0.7154 - recall_score: 0.6750 - f1_score: 0.6945 - val_loss: 0.6605 - val_precision_score: 0.8070 - val_recall_score: 0.7312 - val_f1_score: 0.7669
# Epoch 60/100
# 5/5 [==============================] - ETA: 0s - loss: 0.6217 - precision_score: 0.7620 - recall_score: 0.7250 - f1_score: 0.7426
# Epoch 00060: val_f1_score did not improve from 0.82105
# 5/5 [==============================] - 4s 755ms/step - loss: 0.6217 - precision_score: 0.7620 - recall_score: 0.7250 - f1_score: 0.7426 - val_loss: 0.8591 - val_precision_score: 0.6339 - val_recall_score: 0.5875 - val_f1_score: 0.6097
# Epoch 61/100
# 5/5 [==============================] - ETA: 0s - loss: 0.6973 - precision_score: 0.7377 - recall_score: 0.6938 - f1_score: 0.7144
# Epoch 00061: val_f1_score did not improve from 0.82105
# 5/5 [==============================] - 4s 803ms/step - loss: 0.6973 - precision_score: 0.7377 - recall_score: 0.6938 - f1_score: 0.7144 - val_loss: 0.7533 - val_precision_score: 0.7646 - val_recall_score: 0.6750 - val_f1_score: 0.7162
# Epoch 62/100
# 5/5 [==============================] - ETA: 0s - loss: 0.7007 - precision_score: 0.7393 - recall_score: 0.6375 - f1_score: 0.6842
# Epoch 00062: val_f1_score did not improve from 0.82105
# 5/5 [==============================] - 4s 774ms/step - loss: 0.7007 - precision_score: 0.7393 - recall_score: 0.6375 - f1_score: 0.6842 - val_loss: 0.6229 - val_precision_score: 0.8037 - val_recall_score: 0.6875 - val_f1_score: 0.7404
# Epoch 63/100
# 5/5 [==============================] - ETA: 0s - loss: 0.6688 - precision_score: 0.7309 - recall_score: 0.6625 - f1_score: 0.6946
# Epoch 00063: val_f1_score did not improve from 0.82105
# 5/5 [==============================] - 4s 799ms/step - loss: 0.6688 - precision_score: 0.7309 - recall_score: 0.6625 - f1_score: 0.6946 - val_loss: 0.6589 - val_precision_score: 0.8096 - val_recall_score: 0.7125 - val_f1_score: 0.7572
# Epoch 64/100
# 5/5 [==============================] - ETA: 0s - loss: 0.6982 - precision_score: 0.7408 - recall_score: 0.7188 - f1_score: 0.7295
# Epoch 00064: val_f1_score did not improve from 0.82105
# 5/5 [==============================] - 4s 788ms/step - loss: 0.6982 - precision_score: 0.7408 - recall_score: 0.7188 - f1_score: 0.7295 - val_loss: 0.8792 - val_precision_score: 0.6909 - val_recall_score: 0.6625 - val_f1_score: 0.6762
# Epoch 65/100
# 5/5 [==============================] - ETA: 0s - loss: 0.7721 - precision_score: 0.6840 - recall_score: 0.6375 - f1_score: 0.6598
# Epoch 00065: val_f1_score did not improve from 0.82105
# 5/5 [==============================] - 4s 779ms/step - loss: 0.7721 - precision_score: 0.6840 - recall_score: 0.6375 - f1_score: 0.6598 - val_loss: 0.4869 - val_precision_score: 0.8429 - val_recall_score: 0.7688 - val_f1_score: 0.8040
# Epoch 66/100
# 5/5 [==============================] - ETA: 0s - loss: 0.6789 - precision_score: 0.6979 - recall_score: 0.6750 - f1_score: 0.6860
# Epoch 00066: val_f1_score did not improve from 0.82105
# 5/5 [==============================] - 4s 779ms/step - loss: 0.6789 - precision_score: 0.6979 - recall_score: 0.6750 - f1_score: 0.6860 - val_loss: 0.6860 - val_precision_score: 0.7623 - val_recall_score: 0.6750 - val_f1_score: 0.7154
# Epoch 67/100
# 5/5 [==============================] - ETA: 0s - loss: 0.7027 - precision_score: 0.7166 - recall_score: 0.6687 - f1_score: 0.6916
# Epoch 00067: val_f1_score did not improve from 0.82105
# 5/5 [==============================] - 4s 764ms/step - loss: 0.7027 - precision_score: 0.7166 - recall_score: 0.6687 - f1_score: 0.6916 - val_loss: 0.6167 - val_precision_score: 0.8572 - val_recall_score: 0.7563 - val_f1_score: 0.8026
# Epoch 68/100
# 5/5 [==============================] - ETA: 0s - loss: 0.6673 - precision_score: 0.7119 - recall_score: 0.6500 - f1_score: 0.6791
# Epoch 00068: val_f1_score did not improve from 0.82105
# 5/5 [==============================] - 4s 765ms/step - loss: 0.6673 - precision_score: 0.7119 - recall_score: 0.6500 - f1_score: 0.6791 - val_loss: 0.8245 - val_precision_score: 0.6728 - val_recall_score: 0.6375 - val_f1_score: 0.6543
# Epoch 69/100
# 5/5 [==============================] - ETA: 0s - loss: 0.7196 - precision_score: 0.6878 - recall_score: 0.6500 - f1_score: 0.6683
# Epoch 00069: val_f1_score did not improve from 0.82105
# 5/5 [==============================] - 4s 774ms/step - loss: 0.7196 - precision_score: 0.6878 - recall_score: 0.6500 - f1_score: 0.6683 - val_loss: 0.6939 - val_precision_score: 0.7897 - val_recall_score: 0.7312 - val_f1_score: 0.7589
# Epoch 70/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5608 - precision_score: 0.7649 - recall_score: 0.7188 - f1_score: 0.7408
# Epoch 00070: val_f1_score did not improve from 0.82105
# 5/5 [==============================] - 4s 835ms/step - loss: 0.5608 - precision_score: 0.7649 - recall_score: 0.7188 - f1_score: 0.7408 - val_loss: 0.7288 - val_precision_score: 0.7358 - val_recall_score: 0.6812 - val_f1_score: 0.7071
# Epoch 71/100
# 5/5 [==============================] - ETA: 0s - loss: 0.6131 - precision_score: 0.7581 - recall_score: 0.7000 - f1_score: 0.7277
# Epoch 00071: val_f1_score did not improve from 0.82105
# 5/5 [==============================] - 4s 793ms/step - loss: 0.6131 - precision_score: 0.7581 - recall_score: 0.7000 - f1_score: 0.7277 - val_loss: 0.5899 - val_precision_score: 0.8115 - val_recall_score: 0.7500 - val_f1_score: 0.7791
# Epoch 72/100
# 5/5 [==============================] - ETA: 0s - loss: 0.7671 - precision_score: 0.6758 - recall_score: 0.6375 - f1_score: 0.6560
# Epoch 00072: val_f1_score did not improve from 0.82105
# 5/5 [==============================] - 4s 799ms/step - loss: 0.7671 - precision_score: 0.6758 - recall_score: 0.6375 - f1_score: 0.6560 - val_loss: 0.6887 - val_precision_score: 0.7641 - val_recall_score: 0.7063 - val_f1_score: 0.7338
# Epoch 73/100
# 5/5 [==============================] - ETA: 0s - loss: 0.7158 - precision_score: 0.7292 - recall_score: 0.7063 - f1_score: 0.7174
# Epoch 00073: val_f1_score did not improve from 0.82105
# 5/5 [==============================] - 4s 786ms/step - loss: 0.7158 - precision_score: 0.7292 - recall_score: 0.7063 - f1_score: 0.7174 - val_loss: 0.7472 - val_precision_score: 0.8376 - val_recall_score: 0.7688 - val_f1_score: 0.8014
# Epoch 74/100
# 5/5 [==============================] - ETA: 0s - loss: 0.7390 - precision_score: 0.7189 - recall_score: 0.6875 - f1_score: 0.7028
# Epoch 00074: val_f1_score did not improve from 0.82105
# 5/5 [==============================] - 4s 810ms/step - loss: 0.7390 - precision_score: 0.7189 - recall_score: 0.6875 - f1_score: 0.7028 - val_loss: 0.6530 - val_precision_score: 0.8098 - val_recall_score: 0.7563 - val_f1_score: 0.7816
# Epoch 75/100
# 5/5 [==============================] - ETA: 0s - loss: 0.7493 - precision_score: 0.7041 - recall_score: 0.6562 - f1_score: 0.6792
# Epoch 00075: val_f1_score did not improve from 0.82105
# 5/5 [==============================] - 4s 793ms/step - loss: 0.7493 - precision_score: 0.7041 - recall_score: 0.6562 - f1_score: 0.6792 - val_loss: 0.7161 - val_precision_score: 0.7735 - val_recall_score: 0.6625 - val_f1_score: 0.7135
# Epoch 76/100
# 5/5 [==============================] - ETA: 0s - loss: 0.6750 - precision_score: 0.6712 - recall_score: 0.6062 - f1_score: 0.6366
# Epoch 00076: val_f1_score did not improve from 0.82105
# 5/5 [==============================] - 4s 766ms/step - loss: 0.6750 - precision_score: 0.6712 - recall_score: 0.6062 - f1_score: 0.6366 - val_loss: 0.6030 - val_precision_score: 0.7943 - val_recall_score: 0.6938 - val_f1_score: 0.7397
# Epoch 77/100
# 5/5 [==============================] - ETA: 0s - loss: 0.6467 - precision_score: 0.7220 - recall_score: 0.6438 - f1_score: 0.6798
# Epoch 00077: val_f1_score did not improve from 0.82105
# 5/5 [==============================] - 4s 774ms/step - loss: 0.6467 - precision_score: 0.7220 - recall_score: 0.6438 - f1_score: 0.6798 - val_loss: 0.7377 - val_precision_score: 0.8506 - val_recall_score: 0.7312 - val_f1_score: 0.7856
# Epoch 78/100
# 5/5 [==============================] - ETA: 0s - loss: 0.7007 - precision_score: 0.6899 - recall_score: 0.6313 - f1_score: 0.6589
# Epoch 00078: val_f1_score did not improve from 0.82105
# 5/5 [==============================] - 4s 807ms/step - loss: 0.7007 - precision_score: 0.6899 - recall_score: 0.6313 - f1_score: 0.6589 - val_loss: 0.6678 - val_precision_score: 0.8030 - val_recall_score: 0.7375 - val_f1_score: 0.7688
# Epoch 79/100
# 5/5 [==============================] - ETA: 0s - loss: 0.6809 - precision_score: 0.7136 - recall_score: 0.6812 - f1_score: 0.6969
# Epoch 00079: val_f1_score did not improve from 0.82105
# 5/5 [==============================] - 4s 773ms/step - loss: 0.6809 - precision_score: 0.7136 - recall_score: 0.6812 - f1_score: 0.6969 - val_loss: 0.6031 - val_precision_score: 0.8185 - val_recall_score: 0.7250 - val_f1_score: 0.7687
# Epoch 80/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5936 - precision_score: 0.7472 - recall_score: 0.7188 - f1_score: 0.7326
# Epoch 00080: val_f1_score did not improve from 0.82105
# 5/5 [==============================] - 4s 804ms/step - loss: 0.5936 - precision_score: 0.7472 - recall_score: 0.7188 - f1_score: 0.7326 - val_loss: 0.7364 - val_precision_score: 0.7493 - val_recall_score: 0.6438 - val_f1_score: 0.6910
# Epoch 81/100
# 5/5 [==============================] - ETA: 0s - loss: 0.6732 - precision_score: 0.7116 - recall_score: 0.6750 - f1_score: 0.6926
# Epoch 00081: val_f1_score did not improve from 0.82105
# 5/5 [==============================] - 4s 781ms/step - loss: 0.6732 - precision_score: 0.7116 - recall_score: 0.6750 - f1_score: 0.6926 - val_loss: 0.8115 - val_precision_score: 0.7747 - val_recall_score: 0.6500 - val_f1_score: 0.7059
# Epoch 82/100
# 5/5 [==============================] - ETA: 0s - loss: 0.7191 - precision_score: 0.6955 - recall_score: 0.6438 - f1_score: 0.6685
# Epoch 00082: val_f1_score did not improve from 0.82105
# 5/5 [==============================] - 4s 798ms/step - loss: 0.7191 - precision_score: 0.6955 - recall_score: 0.6438 - f1_score: 0.6685 - val_loss: 1.1246 - val_precision_score: 0.6810 - val_recall_score: 0.6125 - val_f1_score: 0.6439
# Epoch 83/100
# 5/5 [==============================] - ETA: 0s - loss: 0.6329 - precision_score: 0.7304 - recall_score: 0.7000 - f1_score: 0.7145
# Epoch 00083: val_f1_score did not improve from 0.82105
# 5/5 [==============================] - 4s 792ms/step - loss: 0.6329 - precision_score: 0.7304 - recall_score: 0.7000 - f1_score: 0.7145 - val_loss: 0.5754 - val_precision_score: 0.8011 - val_recall_score: 0.7312 - val_f1_score: 0.7646
# Epoch 84/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5994 - precision_score: 0.7831 - recall_score: 0.7188 - f1_score: 0.7493
# Epoch 00084: val_f1_score did not improve from 0.82105
# 5/5 [==============================] - 4s 803ms/step - loss: 0.5994 - precision_score: 0.7831 - recall_score: 0.7188 - f1_score: 0.7493 - val_loss: 0.8474 - val_precision_score: 0.7058 - val_recall_score: 0.6375 - val_f1_score: 0.6695
# Epoch 85/100
# 5/5 [==============================] - ETA: 0s - loss: 0.7349 - precision_score: 0.7387 - recall_score: 0.7188 - f1_score: 0.7284
# Epoch 00085: val_f1_score did not improve from 0.82105
# 5/5 [==============================] - 4s 727ms/step - loss: 0.7349 - precision_score: 0.7387 - recall_score: 0.7188 - f1_score: 0.7284 - val_loss: 0.5490 - val_precision_score: 0.8586 - val_recall_score: 0.7688 - val_f1_score: 0.8107
# Epoch 86/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5430 - precision_score: 0.7939 - recall_score: 0.7688 - f1_score: 0.7810
# Epoch 00086: val_f1_score did not improve from 0.82105
# 5/5 [==============================] - 4s 807ms/step - loss: 0.5430 - precision_score: 0.7939 - recall_score: 0.7688 - f1_score: 0.7810 - val_loss: 0.6904 - val_precision_score: 0.8353 - val_recall_score: 0.7688 - val_f1_score: 0.8001
# Epoch 87/100
# 5/5 [==============================] - ETA: 0s - loss: 0.6144 - precision_score: 0.7510 - recall_score: 0.6938 - f1_score: 0.7210
# Epoch 00087: val_f1_score did not improve from 0.82105
# 5/5 [==============================] - 4s 771ms/step - loss: 0.6144 - precision_score: 0.7510 - recall_score: 0.6938 - f1_score: 0.7210 - val_loss: 0.5451 - val_precision_score: 0.8303 - val_recall_score: 0.7625 - val_f1_score: 0.7949
# Epoch 88/100
# 5/5 [==============================] - ETA: 0s - loss: 0.7369 - precision_score: 0.6788 - recall_score: 0.6438 - f1_score: 0.6607
# Epoch 00088: val_f1_score did not improve from 0.82105
# 5/5 [==============================] - 4s 758ms/step - loss: 0.7369 - precision_score: 0.6788 - recall_score: 0.6438 - f1_score: 0.6607 - val_loss: 0.6339 - val_precision_score: 0.8472 - val_recall_score: 0.7625 - val_f1_score: 0.8025
# Epoch 89/100
# 5/5 [==============================] - ETA: 0s - loss: 0.6730 - precision_score: 0.6986 - recall_score: 0.6375 - f1_score: 0.6661
# Epoch 00089: val_f1_score did not improve from 0.82105
# 5/5 [==============================] - 4s 818ms/step - loss: 0.6730 - precision_score: 0.6986 - recall_score: 0.6375 - f1_score: 0.6661 - val_loss: 0.6435 - val_precision_score: 0.8163 - val_recall_score: 0.7063 - val_f1_score: 0.7568
# Epoch 90/100
# 5/5 [==============================] - ETA: 0s - loss: 0.6381 - precision_score: 0.7389 - recall_score: 0.6562 - f1_score: 0.6945
# Epoch 00090: val_f1_score did not improve from 0.82105
# 5/5 [==============================] - 4s 804ms/step - loss: 0.6381 - precision_score: 0.7389 - recall_score: 0.6562 - f1_score: 0.6945 - val_loss: 0.5882 - val_precision_score: 0.8040 - val_recall_score: 0.7437 - val_f1_score: 0.7726
# Epoch 91/100
# 5/5 [==============================] - ETA: 0s - loss: 0.7623 - precision_score: 0.6507 - recall_score: 0.6062 - f1_score: 0.6275
# Epoch 00091: val_f1_score did not improve from 0.82105
# 5/5 [==============================] - 4s 776ms/step - loss: 0.7623 - precision_score: 0.6507 - recall_score: 0.6062 - f1_score: 0.6275 - val_loss: 0.9037 - val_precision_score: 0.6831 - val_recall_score: 0.6375 - val_f1_score: 0.6592
# Epoch 92/100
# 5/5 [==============================] - ETA: 0s - loss: 0.7702 - precision_score: 0.6630 - recall_score: 0.6125 - f1_score: 0.6360
# Epoch 00092: val_f1_score did not improve from 0.82105
# 5/5 [==============================] - 4s 809ms/step - loss: 0.7702 - precision_score: 0.6630 - recall_score: 0.6125 - f1_score: 0.6360 - val_loss: 0.7369 - val_precision_score: 0.7918 - val_recall_score: 0.7188 - val_f1_score: 0.7525
# Epoch 93/100
# 5/5 [==============================] - ETA: 0s - loss: 0.5201 - precision_score: 0.8325 - recall_score: 0.7750 - f1_score: 0.8022
# Epoch 00093: val_f1_score did not improve from 0.82105
# 5/5 [==============================] - 4s 752ms/step - loss: 0.5201 - precision_score: 0.8325 - recall_score: 0.7750 - f1_score: 0.8022 - val_loss: 0.7441 - val_precision_score: 0.7277 - val_recall_score: 0.6875 - val_f1_score: 0.7065
# Epoch 94/100
# 5/5 [==============================] - ETA: 0s - loss: 0.6981 - precision_score: 0.7285 - recall_score: 0.6875 - f1_score: 0.7073
# Epoch 00094: val_f1_score did not improve from 0.82105
# 5/5 [==============================] - 4s 794ms/step - loss: 0.6981 - precision_score: 0.7285 - recall_score: 0.6875 - f1_score: 0.7073 - val_loss: 0.7874 - val_precision_score: 0.8281 - val_recall_score: 0.7437 - val_f1_score: 0.7834
# Epoch 95/100
# 5/5 [==============================] - ETA: 0s - loss: 0.6790 - precision_score: 0.7336 - recall_score: 0.6687 - f1_score: 0.6991
# Epoch 00095: val_f1_score did not improve from 0.82105
# 5/5 [==============================] - 4s 790ms/step - loss: 0.6790 - precision_score: 0.7336 - recall_score: 0.6687 - f1_score: 0.6991 - val_loss: 0.6981 - val_precision_score: 0.8118 - val_recall_score: 0.7563 - val_f1_score: 0.7825
# Epoch 96/100
# 5/5 [==============================] - ETA: 0s - loss: 0.6222 - precision_score: 0.7305 - recall_score: 0.6938 - f1_score: 0.7116
# Epoch 00096: val_f1_score did not improve from 0.82105
# 5/5 [==============================] - 4s 791ms/step - loss: 0.6222 - precision_score: 0.7305 - recall_score: 0.6938 - f1_score: 0.7116 - val_loss: 0.5737 - val_precision_score: 0.7542 - val_recall_score: 0.6875 - val_f1_score: 0.7192
# Epoch 97/100
# 5/5 [==============================] - ETA: 0s - loss: 0.7176 - precision_score: 0.6943 - recall_score: 0.6625 - f1_score: 0.6775
# Epoch 00097: val_f1_score did not improve from 0.82105
# 5/5 [==============================] - 4s 771ms/step - loss: 0.7176 - precision_score: 0.6943 - recall_score: 0.6625 - f1_score: 0.6775 - val_loss: 0.9677 - val_precision_score: 0.8090 - val_recall_score: 0.6938 - val_f1_score: 0.7465
# Epoch 98/100
# 5/5 [==============================] - ETA: 0s - loss: 0.7062 - precision_score: 0.6613 - recall_score: 0.6062 - f1_score: 0.6322
# Epoch 00098: val_f1_score did not improve from 0.82105
# 5/5 [==============================] - 4s 792ms/step - loss: 0.7062 - precision_score: 0.6613 - recall_score: 0.6062 - f1_score: 0.6322 - val_loss: 0.8591 - val_precision_score: 0.8068 - val_recall_score: 0.7375 - val_f1_score: 0.7700
# Epoch 99/100
# 5/5 [==============================] - ETA: 0s - loss: 0.6267 - precision_score: 0.7071 - recall_score: 0.6812 - f1_score: 0.6939
# Epoch 00099: val_f1_score did not improve from 0.82105
# 5/5 [==============================] - 4s 755ms/step - loss: 0.6267 - precision_score: 0.7071 - recall_score: 0.6812 - f1_score: 0.6939 - val_loss: 0.9226 - val_precision_score: 0.6416 - val_recall_score: 0.6125 - val_f1_score: 0.6266
# Epoch 100/100
# 5/5 [==============================] - ETA: 0s - loss: 0.6722 - precision_score: 0.7423 - recall_score: 0.7125 - f1_score: 0.7270
# Epoch 00100: val_f1_score did not improve from 0.82105
# 5/5 [==============================] - 4s 806ms/step - loss: 0.6722 - precision_score: 0.7423 - recall_score: 0.7125 - f1_score: 0.7270 - val_loss: 0.6511 - val_precision_score: 0.7757 - val_recall_score: 0.6875 - val_f1_score: 0.7287

# %%
# Exibindo dados de Precisão
plt.plot(history.history['precision_score'])
plt.plot(history.history['val_precision_score'])
plt.title('model precision')
plt.ylabel('precision')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de Sensibilidade
plt.plot(history.history['recall_score'])
plt.plot(history.history['val_recall_score'])
plt.title('model recall')
plt.ylabel('recall')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de F1 Score
plt.plot(history.history['f1_score'])
plt.plot(history.history['val_f1_score'])
plt.title('model f1_score')
plt.ylabel('f1_score')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de Perda
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
model = load_model("./modelo_xception.hdf5", custom_objects={'f1_score': f1_score, 'precision_score': precision_score, 'recall_score': recall_score})

scores = model.evaluate(val_generator)
print()
print(f"Precision Score: {round(scores[1]*100,2)}%")
print(f"Recall Score: {round(scores[2]*100,2)}%")
print(f"F1 Score: {round(scores[3]*100,2)}%")
# Out:
# 20/20 [==============================] - 5s 265ms/step - loss: 0.6731 - precision_score: 0.8411 - recall_score: 0.7703 - f1_score: 0.8037
#
# Precision Score: 84.11%
# Recall Score: 77.03%
# F1 Score: 80.37%

# %% [markdown]
# ### 4.8.1 Conclusões sobre a abordagem extra
#
# Como seu modelo performou em comparação com os demais modelos anteriores? Justifique sua resposta levando em consideração a arquitetura respectiva.

# %% [markdown]
# **Resposta**:
